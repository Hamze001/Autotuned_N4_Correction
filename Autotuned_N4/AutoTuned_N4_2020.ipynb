# %%
import os, sys, time, csv, glob, random, math, itertools
import numpy as np
import SimpleITK as sitk


DATA_ROOT = r"C:\content\BRAIN2020\BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData"
PRE_ROOT  = r"C:\content\BRAIN2020\Preprocessed_N4"
MODS = ["flair","t1","t1ce","t2"]


LHS_SAMPLES = 12
REFINE_TOPK = 4
REFINE_TRIALS_PER_TOP = 4

FAST_ITERS  = [30, 20, 10]
FULL_ITERS_LIST = [[60,40,20],[50,30,20]]

SHRINK_SET = [3, 4]
CONV_THRESH_SET = [0.0, 1e-6, 5e-7]

LAMBDA_SMOOTH = 0.02
LAMBDA_RUNTIME = 0.0
RUNTIME_REF_SECONDS = 15.0

MASK_OTSU_BINS = 200
MIN_MASK_VOXELS = 5000 
MIN_CP_PER_DIM = 4 

_GRID_WARN_PRINTED = False 



def ensure_dir(p):
    if os.path.isfile(p):
        raise ValueError(f"Path exists and is a file: {p}")
    os.makedirs(p, exist_ok=True)

def nii_read(fp, t=sitk.sitkFloat32): return sitk.ReadImage(fp, t)
def nii_write(img, fp): ensure_dir(os.path.dirname(fp)); sitk.WriteImage(img, fp, True)

def modality_glob(subj_dir, mod):
    for p in [f"*_{mod}.nii", f"*_{mod}.nii.gz", f"*_{mod.upper()}.nii", f"*_{mod.upper()}.nii.gz"]:
        g = glob.glob(os.path.join(subj_dir, p))
        if g: return g[0]
    return None

def subject_modalities(subj_dir):
    d={}
    for m in MODS:
        fp = modality_glob(subj_dir, m)
        if fp: d[m]=fp
    return d

def pre_out_path(subj_dir, src_fp):
    base = os.path.basename(src_fp)
    if base.endswith(".nii.gz"):
        stem, ext = base[:-7], ".nii.gz"
    else:
        stem, ext = os.path.splitext(base)[0], ".nii"
    return os.path.join(PRE_ROOT, os.path.relpath(subj_dir, DATA_ROOT), f"{stem}_pre{ext}")


def build_mask_from_flair(flair_img):

    mask = sitk.OtsuThreshold(flair_img, 0, 1, MASK_OTSU_BINS)
    mask = sitk.Cast(mask, sitk.sitkUInt8)

    mask = sitk.BinaryMorphologicalClosing(mask, [1]*flair_img.GetDimension())
    mask = sitk.BinaryFillhole(mask)
    vox = int(sitk.GetArrayFromImage(mask).sum())
    if vox >= MIN_MASK_VOXELS:
        return mask, "otsu"


    nz = sitk.Cast(sitk.BinaryThreshold(flair_img, lowerThreshold=1e-6, upperThreshold=1e30, insideValue=1, outsideValue=0), sitk.sitkUInt8)
    nz = sitk.BinaryMorphologicalClosing(nz, [2]*flair_img.GetDimension())
    nz = sitk.BinaryFillhole(nz)
    if int(sitk.GetArrayFromImage(nz).sum()) >= MIN_MASK_VOXELS:
        return nz, "nonzero"


    cc = sitk.ConnectedComponent(nz)
    stats = sitk.LabelShapeStatisticsImageFilter()
    stats.Execute(cc)
    if stats.GetNumberOfLabels() > 0:
        sizes = [(stats.GetPhysicalSize(l), l) for l in stats.GetLabels()]
        _, lab = max(sizes)
        largest = sitk.Cast(sitk.BinaryThreshold(cc, lab, lab, 1, 0), sitk.sitkUInt8)
        if int(sitk.GetArrayFromImage(largest).sum()) >= MIN_MASK_VOXELS:
            return largest, "largest"


    whole = sitk.Cast(sitk.Image(flair_img.GetSize(), sitk.sitkUInt8)+1, sitk.sitkUInt8)
    whole.CopyInformation(flair_img)
    return whole, "whole"


def feasible_bspline_mm_range(mask_u8):

    spacing = mask_u8.GetSpacing()
    size    = mask_u8.GetSize()
    phys    = [size[i]*spacing[i] for i in range(3)]
    diam    = max(phys)


    center = max(100.0, min(180.0, 0.6*diam))

    lo = max(80.0, 0.6*center) 
    hi = min(200.0, 1.2*center) 

    min_extent = max(1.0, min(phys))
    hi_cap = min_extent / 3.0
    hi = min(hi, max(90.0, hi_cap)) 

    if hi < lo:

        mid = max(90.0, min(160.0, center))
        lo, hi = mid*0.9, mid*1.1

    return float(lo), float(hi)

def clamp_bspline_mm_to_feasible(b_mm, mask_u8):
    lo, hi = feasible_bspline_mm_range(mask_u8)
    b = float(max(lo, min(hi, b_mm)))
    return b, lo, hi


def set_bspline_grid(corrector, img_like, b_mm):

    global _GRID_WARN_PRINTED

    dim      = img_like.GetDimension()
    spacing  = img_like.GetSpacing()
    size     = img_like.GetSize()
    phys     = [size[i]*spacing[i] for i in range(dim)]
    order    = 3

]
    if hasattr(corrector, "SetSplineGridSpacingInPhysicalSpace"):
        try:
            corrector.SetSplineGridSpacingInPhysicalSpace([float(b_mm)]*dim)
            return "spacing_mm"
        except Exception:
            pass


    grid_n = [max(4, int(round(phys[i]/max(1.0, b_mm))) + order) for i in range(dim)]
    if hasattr(corrector, "SetSplineGridSize"):
        try:
            corrector.SetSplineGridSize(grid_n)
            return "grid_size"
        except Exception:
            pass


    if hasattr(corrector, "SetSplineDistance"):
        try:
            corrector.SetSplineDistance(float(b_mm))
            return "spline_distance"
        except Exception:
            pass


    if hasattr(corrector, "SetNumberOfControlPoints"):
        try:
            corrector.SetNumberOfControlPoints(grid_n)
            return "num_ctrl_pts"
        except Exception:
            pass


    if not _GRID_WARN_PRINTED:
        print("[WARN] Could not set N4 B-spline grid via any known API; using SimpleITK defaults.", flush=True)
        _GRID_WARN_PRINTED = True
    return "default"



def cv_mean_std(img, mask):
    arr = sitk.GetArrayFromImage(img)
    msk = sitk.GetArrayFromImage(mask).astype(bool)
    vox = arr[msk]
    if vox.size < 10: return (float("inf"), float("nan"), float("nan"))
    mean = float(np.mean(vox)); std = float(np.std(vox))
    return float(std/(mean+1e-8)), mean, std

def robust_score(corrected, mask, log_field, elapsed_sec=0.0):
    arr = sitk.GetArrayFromImage(corrected)
    msk = sitk.GetArrayFromImage(mask).astype(bool)
    vox = arr[msk]
    if vox.size < 10: return float("inf"), float("nan"), float("nan"), float("nan")
    med = float(np.median(vox))
    mad = float(np.median(np.abs(vox-med))) * 1.4826
    rcv = mad/(med+1e-8)
    lf = sitk.GetArrayFromImage(log_field)
    gx,gy,gz = np.gradient(lf)
    smooth = float(np.sqrt((gx**2+gy**2+gz**2).mean()))
    rt = float(elapsed_sec/max(1e-6,RUNTIME_REF_SECONDS))
    score = rcv + LAMBDA_SMOOTH*smooth + LAMBDA_RUNTIME*rt
    return score, rcv, smooth, rt


def n4_correct(img_f32, mask_u8, bspline_mm, shrink, iters, conv_thresh):

    eps = 1e-6
    img_pos = sitk.Clamp(img_f32, lowerBound=eps, upperBound=float("inf"))


    shrink = int(shrink)
    img_exec  = img_pos  if shrink <= 1 else sitk.Shrink(img_pos,  [shrink]*img_pos.GetDimension())
    mask_exec = mask_u8  if shrink <= 1 else sitk.Shrink(mask_u8,  [shrink]*mask_u8.GetDimension())


    b_clamped, lo, hi = clamp_bspline_mm_to_feasible(bspline_mm, mask_u8)

    corrector = sitk.N4BiasFieldCorrectionImageFilter()
    corrector.SetSplineOrder(3) 
    corrector.SetMaximumNumberOfIterations([int(x) for x in iters])
    corrector.SetConvergenceThreshold(float(conv_thresh))


    _ = set_bspline_grid(corrector, img_exec, b_clamped)


    t0 = time.time()
    _ = corrector.Execute(img_exec, mask_exec)
    elapsed = time.time() - t0


    log_field_full = corrector.GetLogBiasFieldAsImage(img_pos)
    corrected_full = img_pos / sitk.Exp(log_field_full)

    return corrected_full, log_field_full, elapsed, b_clamped



def lhs_uniform(n, d):
    rng=np.random.default_rng()
    res=np.zeros((n,d),float); cut=np.linspace(0,1,n+1)
    for j in range(d):
        u=rng.random(n); pts = cut[:n] + (cut[1:]-cut[:n])*u; rng.shuffle(pts); res[:,j]=pts
    return res

def coarse_candidates_LHS(n, b_lo, b_hi):
    X = lhs_uniform(n, 1)
    cands=[]
    for i in range(n):
        b = b_lo + (b_hi-b_lo)*float(X[i,0])
        s = random.choice(SHRINK_SET)
        eps = random.choice(CONV_THRESH_SET)
        cands.append((b,s,FAST_ITERS,eps))
    return cands

def neighborhood_candidates(best_list, b_lo, b_hi, trials_per_top):
    cands=[]; deltas=[-30,-20,-10,10,20,30]
    for (b0,s0,_i0,eps0) in best_list:
        b_pert = sorted(set([round(max(b_lo,min(b_hi,b0+d)),2) for d in deltas]+[round(b0,2)]))
        for _ in range(trials_per_top):
            b = random.choice(b_pert); s = random.choice(SHRINK_SET)
            eps = random.choice(CONV_THRESH_SET); iters = random.choice(FULL_ITERS_LIST)
            cands.append((b,s,iters,eps))
        for iters in FULL_ITERS_LIST:
            cands.append((b0,s0,iters,eps0))

    uniq=[]; seen=set()
    for c in cands:
        key=(round(c[0],2),int(c[1]),tuple(c[2]),float(c[3]))
        if key not in seen: uniq.append(c); seen.add(key)
    return uniq


def evaluate_candidate(img, mask, cand, subj_name, mod, idx=None):
    b,s,iters,eps = cand
    try:
        corrected, logf, elapsed, b_used = n4_correct(img, mask, b, s, iters, eps)
        score, rcv, smooth, rt = robust_score(corrected, mask, logf, elapsed)
        return {
            "ok": True,
            "params": (float(b_used),int(s),list(map(int,iters)),float(eps)),
            "score": float(score), "rcv": float(rcv), "smooth": float(smooth), "rt": float(rt),
            "corrected": corrected, "logf": logf, "elapsed": float(elapsed)
        }
    except Exception as e:
        print(f"[CAND-ERROR] {subj_name} {mod.upper()} cand#{idx or '?'} "
              f"b={b:.1f} s={s} iters={iters} eps={eps} :: {e}", flush=True)
        return {"ok": False, "err": str(e)}

def tune_modality(img, mask, subj_name, mod, prior_best=None):

    mask_built, mask_mode = build_mask_from_flair(img) if mod=="flair" else (mask, "reused")
    mvox = int(sitk.GetArrayFromImage(mask_built).sum())
    print(f"[{subj_name}] {mod.upper()} mask mode = {mask_mode} | voxels = {mvox}", flush=True)


    b_lo, b_hi = feasible_bspline_mm_range(mask_built)
    print(f"[{subj_name}] {mod.upper()} feasible spacing ~ [{b_lo:.1f}, {b_hi:.1f}] mm", flush=True)


    coarse = coarse_candidates_LHS(LHS_SAMPLES, b_lo, b_hi)
    if prior_best is not None:
        b0,s0,_i0,eps0 = prior_best

        b0c, _, _ = clamp_bspline_mm_to_feasible(b0, mask_built)
        coarse += [(b0c,s0,FAST_ITERS,eps0),
                   (max(b_lo,b0c-20),s0,FAST_ITERS,eps0),
                   (min(b_hi,b0c+20),s0,FAST_ITERS,eps0)]
    coarse_res=[]
    for i,c in enumerate(coarse,1):
        r = evaluate_candidate(img, mask_built, c, subj_name, mod, idx=i)
        if r["ok"]: coarse_res.append(r)
    if not coarse_res:
        raise RuntimeError("Coarse search failed: all candidates invalid (see CAND-ERROR lines).")

    coarse_res.sort(key=lambda x:x["score"])
    topK = coarse_res[:max(1,REFINE_TOPK)]
    top_params = [tuple(x["params"]) for x in topK]


    neigh = neighborhood_candidates(top_params, b_lo, b_hi, REFINE_TRIALS_PER_TOP)
    best = None
    for i,c in enumerate(neigh,1):
        r = evaluate_candidate(img, mask_built, c, subj_name, mod, idx=f"R{i}")
        if r["ok"] and (best is None or r["score"] < best["score"]):
            best = r
    if best is None:

        best = topK[0]
    return best, mask_built


def cv_block(img, mask): 
    cv, mean, std = cv_mean_std(img, mask); return cv, mean, std

def find_subject_dirs():

    dirs = []


    subdirs = [os.path.join(DATA_ROOT, d) for d in os.listdir(DATA_ROOT)
               if os.path.isdir(os.path.join(DATA_ROOT, d))]
    flat_hits = []
    for p in subdirs:
        if glob.glob(os.path.join(p, "*_flair.nii*")):
            flat_hits.append(p)

    if flat_hits:
        return sorted(flat_hits)


    nested_hits = []
    for grade in ["HGG", "LGG"]:
        root = os.path.join(DATA_ROOT, grade)
        if not os.path.isdir(root):
            continue
        for d in os.listdir(root):
            p = os.path.join(root, d)
            if os.path.isdir(p) and glob.glob(os.path.join(p, "*_flair.nii*")):
                nested_hits.append(p)

    return sorted(nested_hits)


def run():
    print("[INFO] DATA_ROOT:", DATA_ROOT)
    print("[INFO] PRE_ROOT :", PRE_ROOT)
    ensure_dir(PRE_ROOT)
    subjects = find_subject_dirs()
    print(f"[INFO] Subjects found: {len(subjects)}")
    if not subjects:
        print(" No subjects found."); return

    csv_fp = os.path.join(PRE_ROOT, "n4_autotune_report.csv")
    rows=[]; t0=time.time()

    for si, subj_dir in enumerate(subjects,1):
        subj = os.path.basename(subj_dir)
        print(f"\n[SUBJECT-START] {subj}", flush=True)
        mod_fps = subject_modalities(subj_dir)
        if "flair" not in mod_fps:
            print(f"[WARN] {subj}: missing FLAIR → skip"); continue


        flair_img = nii_read(mod_fps["flair"], sitk.sitkFloat32)
        best_flair, mask = tune_modality(flair_img, None, subj, "flair", prior_best=None)
        b_mm,s,iters,eps = best_flair["params"]
        out_fp = pre_out_path(subj_dir, mod_fps["flair"])
        nii_write(best_flair["corrected"], out_fp)
        raw_cv, raw_mean, raw_std = cv_block(flair_img, mask)
        cor_cv, cor_mean, cor_std = cv_block(best_flair["corrected"], mask)
        row = dict(subject=subj, modality="flair",
                   raw_mean=raw_mean, raw_std=raw_std, raw_cv=raw_cv,
                   cor_mean=cor_mean, cor_std=cor_std, cor_cv=cor_cv,
                   improved=bool(cor_cv<raw_cv), bspline_mm=b_mm, shrink=s,
                   iters=str(iters), conv_thresh=eps,
                   score=float(best_flair["score"]), rcv=float(best_flair["rcv"]),
                   smooth=float(best_flair["smooth"]), rt=float(best_flair["rt"]),
                   seconds=float(best_flair["elapsed"]), output_path=out_fp)
        print("[RESULT]", row, flush=True)
        rows.append(row)
        prior = (b_mm,s,iters,eps)


        for mod in [m for m in MODS if m in mod_fps and m!="flair"]:
            img = nii_read(mod_fps[mod], sitk.sitkFloat32)
            best, _ = tune_modality(img, mask, subj, mod, prior_best=prior)
            out_fp = pre_out_path(subj_dir, mod_fps[mod])
            nii_write(best["corrected"], out_fp)
            raw_cv, raw_mean, raw_std = cv_block(img, mask)
            cor_cv, cor_mean, cor_std = cv_block(best["corrected"], mask)
            row = dict(subject=subj, modality=mod,
                       raw_mean=raw_mean, raw_std=raw_std, raw_cv=raw_cv,
                       cor_mean=cor_mean, cor_std=cor_std, cor_cv=cor_cv,
                       improved=bool(cor_cv<raw_cv),
                       bspline_mm=float(best["params"][0]), shrink=int(best["params"][1]),
                       iters=str(best["params"][2]), conv_thresh=float(best["params"][3]),
                       score=float(best["score"]), rcv=float(best["rcv"]),
                       smooth=float(best["smooth"]), rt=float(best["rt"]),
                       seconds=float(best["elapsed"]), output_path=out_fp)
            print("[RESULT]", row, flush=True)
            rows.append(row)
            prior = best["params"]

        print(f"[SUBJECT-DONE] {subj} | scans={len([r for r in rows if r['subject']==subj])}", flush=True)


    with open(csv_fp, "w", newline="") as f:
        w = csv.DictWriter(f, fieldnames=[
            "subject","modality",
            "raw_mean","raw_std","raw_cv",
            "cor_mean","cor_std","cor_cv",
            "improved","bspline_mm","shrink","iters","conv_thresh",
            "score","rcv","smooth","rt","seconds","output_path"
        ])
        w.writeheader()
        for r in rows: w.writerow(r)

    improved = sum(1 for r in rows if r["improved"])
    print("\n================ RUN SUMMARY ================")
    print(f"[DONE] Corrected {len(rows)} volumes | CV improved in {improved}/{len(rows)}.")
    print(f"[REPORT] {csv_fp}")
    print(f"[WALL-TIME] {(time.time()-t0)/60.2:.2f} minutes")
    print("=============================================")

run()
# Out:
# [INFO] DATA_ROOT: C:\content\BRAIN2020\BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData
# [INFO] PRE_ROOT : C:\content\BRAIN2020\Preprocessed_N4
# [INFO] Subjects found: 369
#
# [SUBJECT-START] BraTS20_Training_001
# [BraTS20_Training_001] FLAIR mask mode = otsu | voxels = 1323324
# [BraTS20_Training_001] FLAIR feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_001', 'modality': 'flair', 'raw_mean': 174.56007385253906, 'raw_std': 64.06365966796875, 'raw_cv': 0.3670006448233804, 'cor_mean': 175.39908295965506, 'cor_std': 41.11882759349615, 'cor_cv': 0.23443011729206084, 'improved': True, 'bspline_mm': 90.0, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 0.0, 'score': 0.16451723367989496, 'rcv': 0.16440643994220033, 'smooth': 0.005539686884731054, 'rt': 0.8955059210459392, 'seconds': 13.432588815689087, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_001\\BraTS20_Training_001_flair_pre.nii'}
# [BraTS20_Training_001] T1 mask mode = reused | voxels = 1323324
# [BraTS20_Training_001] T1 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_001', 'modality': 't1', 'raw_mean': 355.88543701171875, 'raw_std': 83.2447509765625, 'raw_cv': 0.23390884345594137, 'cor_mean': 426.12600261453014, 'cor_std': 75.97001989605012, 'cor_cv': 0.17828064804341248, 'improved': True, 'bspline_mm': 86.4, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 0.0, 'score': 0.1493895413208938, 'rcv': 0.14926955051200452, 'smooth': 0.0059995404444634914, 'rt': 0.8458649794260661, 'seconds': 12.687974691390991, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_001\\BraTS20_Training_001_t1_pre.nii'}
# [BraTS20_Training_001] T1CE mask mode = reused | voxels = 1323324
# [BraTS20_Training_001] T1CE feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_001', 'modality': 't1ce', 'raw_mean': 417.10186767578125, 'raw_std': 104.88605499267578, 'raw_cv': 0.25146388237151324, 'cor_mean': 424.41378195464716, 'cor_std': 100.99056143578582, 'cor_cv': 0.23795306780164396, 'improved': True, 'bspline_mm': 90.0, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 1e-06, 'score': 0.13774749102021974, 'rcv': 0.13763144958715362, 'smooth': 0.005802071653306484, 'rt': 0.8719202677408854, 'seconds': 13.078804016113281, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_001\\BraTS20_Training_001_t1ce_pre.nii'}
# [BraTS20_Training_001] T2 mask mode = reused | voxels = 1323324
# [BraTS20_Training_001] T2 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_001', 'modality': 't2', 'raw_mean': 114.72894287109375, 'raw_std': 47.550846099853516, 'raw_cv': 0.41446251404177675, 'cor_mean': 113.08215226226213, 'cor_std': 33.11844170515852, 'cor_cv': 0.29287063466408864, 'improved': True, 'bspline_mm': 86.4, 'shrink': 4, 'iters': '[60, 40, 20]', 'conv_thresh': 0.0, 'score': 0.221023005005981, 'rcv': 0.22090370959703173, 'smooth': 0.005964770447462797, 'rt': 0.5559496084849039, 'seconds': 8.33924412727356, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_001\\BraTS20_Training_001_t2_pre.nii'}
# [SUBJECT-DONE] BraTS20_Training_001 | scans=4
#
# [SUBJECT-START] BraTS20_Training_002
# [BraTS20_Training_002] FLAIR mask mode = otsu | voxels = 1493491
# [BraTS20_Training_002] FLAIR feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_002', 'modality': 'flair', 'raw_mean': 292.3006896972656, 'raw_std': 88.48760223388672, 'raw_cv': 0.30272799671634576, 'cor_mean': 299.0041359223292, 'cor_std': 57.36143912896208, 'cor_cv': 0.19184162436450095, 'improved': True, 'bspline_mm': 86.4, 'shrink': 3, 'iters': '[50, 30, 20]', 'conv_thresh': 5e-07, 'score': 0.13650454088537164, 'rcv': 0.1363867779584057, 'smooth': 0.005888146348297596, 'rt': 0.7353816668192545, 'seconds': 11.030725002288818, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_002\\BraTS20_Training_002_flair_pre.nii'}
# [BraTS20_Training_002] T1 mask mode = reused | voxels = 1493491
# [BraTS20_Training_002] T1 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_002', 'modality': 't1', 'raw_mean': 415.971435546875, 'raw_std': 96.265869140625, 'raw_cv': 0.23142422991557252, 'cor_mean': 506.27014775388216, 'cor_std': 89.67188937776871, 'cor_cv': 0.1771226088953412, 'improved': True, 'bspline_mm': 90.0, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 1e-06, 'score': 0.14109192349522923, 'rcv': 0.14097475836559747, 'smooth': 0.005858256481587887, 'rt': 0.9148487408955892, 'seconds': 13.722731113433838, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_002\\BraTS20_Training_002_t1_pre.nii'}
# [BraTS20_Training_002] T1CE mask mode = reused | voxels = 1493491
# [BraTS20_Training_002] T1CE feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_002', 'modality': 't1ce', 'raw_mean': 443.09222412109375, 'raw_std': 100.8548583984375, 'raw_cv': 0.22761595195269885, 'cor_mean': 459.76417409792, 'cor_std': 96.01372390039052, 'cor_cv': 0.20883254787453995, 'improved': True, 'bspline_mm': 86.4, 'shrink': 4, 'iters': '[60, 40, 20]', 'conv_thresh': 5e-07, 'score': 0.11855070764673033, 'rcv': 0.11845847149853685, 'smooth': 0.004611807409673929, 'rt': 0.5404035409291585, 'seconds': 8.106053113937378, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_002\\BraTS20_Training_002_t1ce_pre.nii'}
# [BraTS20_Training_002] T2 mask mode = reused | voxels = 1493491
# [BraTS20_Training_002] T2 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_002', 'modality': 't2', 'raw_mean': 190.48646545410156, 'raw_std': 68.69929504394531, 'raw_cv': 0.3606518440906876, 'cor_mean': 188.34907906164244, 'cor_std': 52.37224470951436, 'cor_cv': 0.2780594679180433, 'improved': True, 'bspline_mm': 86.4, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 0.0, 'score': 0.1916107228649158, 'rcv': 0.1915080082946766, 'smooth': 0.005135728511959314, 'rt': 0.8743111292521158, 'seconds': 13.114666938781738, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_002\\BraTS20_Training_002_t2_pre.nii'}
# [SUBJECT-DONE] BraTS20_Training_002 | scans=4
#
# [SUBJECT-START] BraTS20_Training_003
# [BraTS20_Training_003] FLAIR mask mode = otsu | voxels = 1210540
# [BraTS20_Training_003] FLAIR feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_003', 'modality': 'flair', 'raw_mean': 317.54608154296875, 'raw_std': 64.91925811767578, 'raw_cv': 0.20444043207897947, 'cor_mean': 334.14720740098886, 'cor_std': 53.08083997298468, 'cor_cv': 0.1588546568569618, 'improved': True, 'bspline_mm': 86.4, 'shrink': 4, 'iters': '[50, 30, 20]', 'conv_thresh': 5e-07, 'score': 0.09489819011440585, 'rcv': 0.09480457239573906, 'smooth': 0.004680885933339596, 'rt': 0.39981988271077473, 'seconds': 5.997298240661621, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_003\\BraTS20_Training_003_flair_pre.nii'}
# [BraTS20_Training_003] T1 mask mode = reused | voxels = 1210540
# [BraTS20_Training_003] T1 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_003', 'modality': 't1', 'raw_mean': 391.2811279296875, 'raw_std': 86.89706420898438, 'raw_cv': 0.22208345356839898, 'cor_mean': 480.5896131381471, 'cor_std': 86.8075209509213, 'cor_cv': 0.1806271267127072, 'improved': True, 'bspline_mm': 89.7, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 0.0, 'score': 0.13684125536994157, 'rcv': 0.13672930317872284, 'smooth': 0.005597609560936689, 'rt': 0.7653776168823242, 'seconds': 11.480664253234863, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_003\\BraTS20_Training_003_t1_pre.nii'}
# [BraTS20_Training_003] T1CE mask mode = reused | voxels = 1210540
# [BraTS20_Training_003] T1CE feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_003', 'modality': 't1ce', 'raw_mean': 427.5195007324219, 'raw_std': 100.85325622558594, 'raw_cv': 0.23590328873991986, 'cor_mean': 452.3386233326569, 'cor_std': 93.11147986394712, 'cor_cv': 0.2058446373114883, 'improved': True, 'bspline_mm': 88.69482947542308, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 0.0, 'score': 0
 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_004\\BraTS20_Training_004_t2_pre.nii'}
# [SUBJECT-DONE] BraTS20_Training_004 | scans=4
#
# [SUBJECT-START] BraTS20_Training_005
# [BraTS20_Training_005] FLAIR mask mode = otsu | voxels = 1388836
# [BraTS20_Training_005] FLAIR feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_005', 'modality': 'flair', 'raw_mean': 159.86285400390625, 'raw_std': 49.66851043701172, 'raw_cv': 0.31069450588371905, 'cor_mean': 157.18040498843143, 'cor_std': 44.2222551245167, 'cor_cv': 0.2813471254572605, 'improved': True, 'bspline_mm': 89.22723748734232, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 5e-07, 'score': 0.21730358273052114, 'rcv': 0.2172311460020064, 'smooth': 0.0036218364257365465, 'rt': 0.8193960984547933, 'seconds': 12.2909414768219, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_005\\BraTS20_Training_005_flair_pre.nii'}
# [BraTS20_Training_005] T1 mask mode = reused | voxels = 1388836
# [BraTS20_Training_005] T1 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_005', 'modality': 't1', 'raw_mean': 353.6647644042969, 'raw_std': 87.83403778076172, 'raw_cv': 0.24835394028077237, 'cor_mean': 447.5796303351229, 'cor_std': 97.42104576582716, 'cor_cv': 0.21766192909786142, 'improved': True, 'bspline_mm': 86.4, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 1e-06, 'score': 0.16357639553527656, 'rcv': 0.16347226577381913, 'smooth': 0.005206488072872162, 'rt': 0.8158759911855061, 'seconds': 12.238139867782593, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_005\\BraTS20_Training_005_t1_pre.nii'}
# [BraTS20_Training_005] T1CE mask mode = reused | voxels = 1388836
# [BraTS20_Training_005] T1CE feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_005', 'modality': 't1ce', 'raw_mean': 382.5018310546875, 'raw_std': 107.85245513916016, 'raw_cv': 0.281965853180244, 'cor_mean': 405.01225886222863, 'cor_std': 110.86128843096934, 'cor_cv': 0.273723291091649, 'improved': True, 'bspline_mm': 88.94154482318632, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 1e-06, 'score': 0.13018050699753106, 'rcv': 0.13009746247229517, 'smooth': 0.004152226261794567, 'rt': 0.8271941184997559, 'seconds': 12.407911777496338, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_005\\BraTS20_Training_005_t1ce_pre.nii'}
# [BraTS20_Training_005] T2 mask mode = reused | voxels = 1388836
# [BraTS20_Training_005] T2 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_005', 'modality': 't2', 'raw_mean': 142.3782196044922, 'raw_std': 60.532962799072266, 'raw_cv': 0.4251560594237886, 'cor_mean': 139.46251973427113, 'cor_std': 56.594781000370766, 'cor_cv': 0.4058063851430992, 'improved': True, 'bspline_mm': 86.4, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 1e-06, 'score': 0.2789616727262878, 'rcv': 0.27888922749014133, 'smooth': 0.003622261807322502, 'rt': 0.8253933270772298, 'seconds': 12.380899906158447, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_005\\BraTS20_Training_005_t2_pre.nii'}
# [SUBJECT-DONE] BraTS20_Training_005 | scans=4
#
# [SUBJECT-START] BraTS20_Training_006
# [BraTS20_Training_006] FLAIR mask mode = otsu | voxels = 1446415
# [BraTS20_Training_006] FLAIR feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_006', 'modality': 'flair', 'raw_mean': 186.19100952148438, 'raw_std': 76.10550689697266, 'raw_cv': 0.4087496334462026, 'cor_mean': 183.7048450092258, 'cor_std': 53.03370428722979, 'cor_cv': 0.2886897418610788, 'improved': True, 'bspline_mm': 88.65599674047715, 'shrink': 3, 'iters': '[50, 30, 20]', 'conv_thresh': 5e-07, 'score': 0.19064358964174594, 'rcv': 0.1905554490497669, 'smooth': 0.00440702959895134, 'rt': 0.7123505274454752, 'seconds': 10.685257911682129, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training
 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_011\\BraTS20_Training_011_t1ce_pre.nii'}
# [BraTS20_Training_011] T2 mask mode = reused | voxels = 1575537
# [BraTS20_Training_011] T2 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_011', 'modality': 't2', 'raw_mean': 552.4900512695312, 'raw_std': 245.36708068847656, 'raw_cv': 0.44411131045748653, 'cor_mean': 540.9324231571194, 'cor_std': 232.17397631267596, 'cor_cv': 0.42921068578828103, 'improved': True, 'bspline_mm': 86.4, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 1e-06, 'score': 0.26503150506946893, 'rcv': 0.26495612428128423, 'smooth': 0.00376903940923512, 'rt': 0.8703042348225911, 'seconds': 13.054563522338867, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_011\\BraTS20_Training_011_t2_pre.nii'}
# [SUBJECT-DONE] BraTS20_Training_011 | scans=4
#
# [SUBJECT-START] BraTS20_Training_012
# [BraTS20_Training_012] FLAIR mask mode = otsu | voxels = 1506779
# [BraTS20_Training_012] FLAIR feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_012', 'modality': 'flair', 'raw_mean': 203.16510009765625, 'raw_std': 69.30829620361328, 'raw_cv': 0.3411427266143995, 'cor_mean': 199.97601290666918, 'cor_std': 58.95717948481472, 'cor_cv': 0.2948212569343625, 'improved': True, 'bspline_mm': 88.92504271796724, 'shrink': 4, 'iters': '[60, 40, 20]', 'conv_thresh': 1e-06, 'score': 0.21149012347528867, 'rcv': 0.21141362963555538, 'smooth': 0.0038246919866651297, 'rt': 0.5303494294484457, 'seconds': 7.955241441726685, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_012\\BraTS20_Training_012_flair_pre.nii'}
# [BraTS20_Training_012] T1 mask mode = reused | voxels = 1506779
# [BraTS20_Training_012] T1 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_012', 'modality': 't1', 'raw_mean': 401.2713317871094, 'raw_std': 106.18240356445312, 'raw_cv': 0.26461497533080935, 'cor_mean': 450.24657864448903, 'cor_std': 96.95009996875996, 'cor_cv': 0.21532667779172107, 'improved': True, 'bspline_mm': 88.48117117854306, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 5e-07, 'score': 0.16501254959050843, 'rcv': 0.16490217966977783, 'smooth': 0.005518496036529541, 'rt': 0.850847085316976, 'seconds': 12.762706279754639, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_012\\BraTS20_Training_012_t1_pre.nii'}
# [BraTS20_Training_012] T1CE mask mode = reused | voxels = 1506779
# [BraTS20_Training_012] T1CE feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_012', 'modality': 't1ce', 'raw_mean': 440.72943115234375, 'raw_std': 122.92973327636719, 'raw_cv': 0.27892335883302, 'cor_mean': 442.46944078672226, 'cor_std': 117.16414134316963, 'cor_cv': 0.26479600745353343, 'improved': True, 'bspline_mm': 90.0, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 0.0, 'score': 0.13337070869764567, 'rcv': 0.1332751033317137, 'smooth': 0.004780268296599388, 'rt': 0.8011264642079671, 'seconds': 12.016896963119507, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_012\\BraTS20_Training_012_t1ce_pre.nii'}
# [BraTS20_Training_012] T2 mask mode = reused | voxels = 1506779
# [BraTS20_Training_012] T2 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_012', 'modality': 't2', 'raw_mean': 658.1508178710938, 'raw_std': 295.98065185546875, 'raw_cv': 0.4497155421129367, 'cor_mean': 638.0727386421175, 'cor_std': 270.7224019363838, 'cor_cv': 0.4242814110947057, 'improved': True, 'bspline_mm': 86.58944041206937, 'shrink': 4, 'iters': '[60, 40, 20]', 'conv_thresh': 5e-07, 'score': 0.276106993670269, 'rcv': 0.2760277846666715, 'smooth': 0.003960450179874897, 'rt': 0.5373302777608235, 'seconds': 8.059954166412354, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_012\\BraTS20_Training_012_t2_pre.nii'}
# [SUBJECT-DONE] BraTS20_Training_012 | scans=4
#
# [SUBJECT-START] BraTS20_Training_013
# [BraTS20_Training_013] FLAIR mask mode = otsu | voxels = 1439985
# [BraTS20_Training_013] FLAIR feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training
 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_014\\BraTS20_Training_014_t1_pre.nii'}
# [BraTS20_Training_014] T1CE mask mode = reused | voxels = 1707282
# [BraTS20_Training_014] T1CE feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_014', 'modality': 't1ce', 'raw_mean': 422.9416809082031, 'raw_std': 103.62787628173828, 'raw_cv': 0.24501693958553095, 'cor_mean': 438.75639039675843, 'cor_std': 106.01674928864757, 'cor_cv': 0.24163009726277146, 'improved': True, 'bspline_mm': 86.73, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 0.0, 'score': 0.10976655771584101, 'rcv': 0.10967268069834299, 'smooth': 0.004693850874900818, 'rt': 0.8451305866241455, 'seconds': 12.676958799362183, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_014\\BraTS20_Training_014_t1ce_pre.nii'}
# [BraTS20_Training_014] T2 mask mode = reused | voxels = 1707282
# [BraTS20_Training_014] T2 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_014', 'modality': 't2', 'raw_mean': 151.3618621826172, 'raw_std': 63.22772979736328, 'raw_cv': 0.41772563366657145, 'cor_mean': 151.54988027976708, 'cor_std': 53.92697356748122, 'cor_cv': 0.35583646430054267, 'improved': True, 'bspline_mm': 86.4, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 0.0, 'score': 0.20369686122656824, 'rcv': 0.2035956809916443, 'smooth': 0.005059011746197939, 'rt': 0.9109795252482097, 'seconds': 13.664692878723145, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_014\\BraTS20_Training_014_t2_pre.nii'}
# [SUBJECT-DONE] BraTS20_Training_014 | scans=4
#
# [SUBJECT-START] BraTS20_Training_015
# [BraTS20_Training_015] FLAIR mask mode = otsu | voxels = 1552870
# [BraTS20_Training_015] FLAIR feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_015', 'modality': 'flair', 'raw_mean': 229.12393188476562, 'raw_std': 88.39892578125, 'raw_cv': 0.3858127130161626, 'cor_mean': 226.24893143323723, 'cor_std': 65.47595484467129, 'cor_cv': 0.289397852299242, 'improved': True, 'bspline_mm': 89.12941046334257, 'shrink': 3, 'iters': '[50, 30, 20]', 'conv_thresh': 5e-07, 'score': 0.20687591986935155, 'rcv': 0.2067949490642132, 'smooth': 0.004048540256917477, 'rt': 0.7130487442016602, 'seconds': 10.695731163024902, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_015\\BraTS20_Training_015_flair_pre.nii'}
# [BraTS20_Training_015] T1 mask mode = reused | voxels = 1552870
# [BraTS20_Training_015] T1 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_015', 'modality': 't1', 'raw_mean': 377.3711242675781, 'raw_std': 91.44915771484375, 'raw_cv': 0.24233215482480225, 'cor_mean': 444.2891042616907, 'cor_std': 89.7895075719958, 'cor_cv': 0.20209702805830665, 'improved': True, 'bspline_mm': 86.4, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 5e-07, 'score': 0.16104181412983917, 'rcv': 0.16093817828599596, 'smooth': 0.005181792192161083, 'rt': 0.8043344497680665, 'seconds': 12.065016746520996, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_015\\BraTS20_Training_015_t1_pre.nii'}
# [BraTS20_Training_015] T1CE mask mode = reused | voxels = 1552870
# [BraTS20_Training_015] T1CE feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_015', 'modality': 't1ce', 'raw_mean': 418.7398986816406, 'raw_std': 106.99969482421875, 'raw_cv': 0.25552782325864093, 'cor_mean': 421.3514976273302, 'cor_std': 98.84288307086798, 'cor_cv': 0.23458533700512677, 'improved': True, 'bspline_mm': 87.3, 'shrink': 3, 'iters': '[50, 30, 20]', 'conv_thresh': 5e-07, 'score': 0.12861760326241978, 'rcv': 0.12852473218506105, 'smooth': 0.004643553867936134, 'rt': 0.6893541177113851, 'seconds': 10.340311765670776, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training
 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_365\\BraTS20_Training_365_flair_pre.nii'}
# [BraTS20_Training_365] T1 mask mode = reused | voxels = 1273131
# [BraTS20_Training_365] T1 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_365', 'modality': 't1', 'raw_mean': 2773.041259765625, 'raw_std': 630.8226928710938, 'raw_cv': 0.22748406308319247, 'cor_mean': 3322.732222153232, 'cor_std': 588.6302146502871, 'cor_cv': 0.17715246829823236, 'improved': True, 'bspline_mm': 89.62, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 5e-07, 'score': 0.1619139215305309, 'rcv': 0.16178868425561593, 'smooth': 0.006261863745748997, 'rt': 0.9434315045674642, 'seconds': 14.151472568511963, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_365\\BraTS20_Training_365_t1_pre.nii'}
# [BraTS20_Training_365] T1CE mask mode = reused | voxels = 1273131
# [BraTS20_Training_365] T1CE feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_365', 'modality': 't1ce', 'raw_mean': 3302.66015625, 'raw_std': 784.4853515625, 'raw_cv': 0.23753135788905005, 'cor_mean': 3619.622686281795, 'cor_std': 750.4649315922029, 'cor_cv': 0.20733236489934642, 'improved': True, 'bspline_mm': 87.47, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 1e-06, 'score': 0.1284319687041662, 'rcv': 0.12830157921307006, 'smooth': 0.006519474554806948, 'rt': 0.9552137692769368, 'seconds': 14.328206539154053, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_365\\BraTS20_Training_365_t1ce_pre.nii'}
# [BraTS20_Training_365] T2 mask mode = reused | voxels = 1273131
# [BraTS20_Training_365] T2 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_365', 'modality': 't2', 'raw_mean': 1260.0870361328125, 'raw_std': 249.8189697265625, 'raw_cv': 0.19825532884718067, 'cor_mean': 1387.4073468292397, 'cor_std': 198.03741818809885, 'cor_cv': 0.14273920246945734, 'improved': True, 'bspline_mm': 86.4, 'shrink': 3, 'iters': '[50, 30, 20]', 'conv_thresh': 1e-06, 'score': 0.06769953562752351, 'rcv': 0.06754625283987269, 'smooth': 0.00766413938254118, 'rt': 0.803415314356486, 'seconds': 12.05122971534729, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_365\\BraTS20_Training_365_t2_pre.nii'}
# [SUBJECT-DONE] BraTS20_Training_365 | scans=4
#
# [SUBJECT-START] BraTS20_Training_366
# [BraTS20_Training_366] FLAIR mask mode = otsu | voxels = 992474
# [BraTS20_Training_366] FLAIR feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_366', 'modality': 'flair', 'raw_mean': 194.35693359375, 'raw_std': 45.67679977416992, 'raw_cv': 0.23501502584566714, 'cor_mean': 205.3500700417224, 'cor_std': 39.30181617786544, 'cor_cv': 0.19138934877385883, 'improved': True, 'bspline_mm': 90.0, 'shrink': 3, 'iters': '[50, 30, 20]', 'conv_thresh': 5e-07, 'score': 0.11742728819587878, 'rcv': 0.11734537271300009, 'smooth': 0.00409577414393425, 'rt': 0.7136731465657552, 'seconds': 10.705097198486328, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_366\\BraTS20_Training_366_flair_pre.nii'}
# [BraTS20_Training_366] T1 mask mode = reused | voxels = 992474
# [BraTS20_Training_366] T1 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_366', 'modality': 't1', 'raw_mean': 351.3889465332031, 'raw_std': 51.733585357666016, 'raw_cv': 0.14722598950990448, 'cor_mean': 627.3370389387505, 'cor_std': 75.06712069315203, 'cor_cv': 0.11965995315523613, 'improved': True, 'bspline_mm': 90.0, 'shrink': 4, 'iters': '[50, 30, 20]', 'conv_thresh': 5e-07, 'score': 0.07007918017365942, 'rcv': 0.06992751202926943, 'smooth': 0.00758340721949935, 'rt': 0.46762801806132, 'seconds': 7.0144202709198, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_366\\BraTS20_Training_366_t1_pre.nii'}
# [BraTS20_Training_366] T1CE mask mode = reused | voxels = 992474
# [BraTS20_Training_366] T1CE feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_366', 'modality': 't1ce', 'raw_mean': 372.5018310546875, 'raw_std': 53.68672180175781, 'raw_cv': 0.14412471919482925, 'cor_mean': 766.7377513102301, 'cor_std': 90.86108197472542, 'cor_cv': 0.1185034672132337, 'improved': True, 'bspline_mm': 90.0, 'shrink': 4, 'iters': '[60, 40, 20]', 'conv_thresh': 5e-07, 'score': 0.0629730454405954, 'rcv': 0.06280459090528989, 'smooth': 0.008422726765275002, 'rt': 0.5579733848571777, 'seconds': 8.369600772857666, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_366\\BraTS20_Training_366_t1ce_pre.nii'}
# [BraTS20_Training_366] T2 mask mode = reused | voxels = 992474
# [BraTS20_Training_366] T2 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_366', 'modality': 't2', 'raw_mean': 303.22125244140625, 'raw_std': 116.59056854248047, 'raw_cv': 0.38450658586724584, 'cor_mean': 296.7167020899827, 'cor_std': 104.7950977753421, 'cor_cv': 0.3531823353173762, 'improved': True, 'bspline_mm': 86.4, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 1e-06, 'score': 0.19961783140939807, 'rcv': 0.19954739535269475, 'smooth': 0.0035218028351664543, 'rt': 0.8533359209696452, 'seconds': 12.800038814544678, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_366\\BraTS20_Training_366_t2_pre.nii'}
# [SUBJECT-DONE] BraTS20_Training_366 | scans=4
#
# [SUBJECT-START] BraTS20_Training_367
# [BraTS20_Training_367] FLAIR mask mode = otsu | voxels = 1671957
# [BraTS20_Training_367] FLAIR feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_367', 'modality': 'flair', 'raw_mean': 908.5568237304688, 'raw_std': 172.87640380859375, 'raw_cv': 0.19027583007617835, 'cor_mean': 875.8285115776839, 'cor_std': 137.8361764703744, 'cor_cv': 0.1573780422157162, 'improved': True, 'bspline_mm': 86.4, 'shrink': 4, 'iters': '[60, 40, 20]', 'conv_thresh': 0.0, 'score': 0.09665679800221216, 'rcv': 0.09654650646158945, 'smooth': 0.005514577031135559, 'rt': 0.6615228017171224, 'seconds': 9.922842025756836, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_367\\BraTS20_Training_367_flair_pre.nii'}
# [BraTS20_Training_367] T1 mask mode = reused | voxels = 1671957
# [BraTS20_Training_367] T1 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_367', 'modality': 't1', 'raw_mean': 2140.450439453125, 'raw_std': 508.2485046386719, 'raw_cv': 0.23744932153913945, 'cor_mean': 2625.0463016349177, 'cor_std': 548.7985713399802, 'cor_cv': 0.20906243482108858, 'improved': True, 'bspline_mm': 90.0, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 5e-07, 'score': 0.17448444261233206, 'rcv': 0.17437555181811448, 'smooth': 0.005444539710879326, 'rt': 1.0919580141703287, 'seconds': 16.37937021255493, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_367\\BraTS20_Training_367_t1_pre.nii'}
# [BraTS20_Training_367] T1CE mask mode = reused | voxels = 1671957
# [BraTS20_Training_367] T1CE feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_367', 'modality': 't1ce', 'raw_mean': 2618.220458984375, 'raw_std': 594.7459106445312, 'raw_cv': 0.22715654390423853, 'cor_mean': 2892.6777308382825, 'cor_std': 569.5507809298961, 'cor_cv': 0.1968939625925334, 'improved': True, 'bspline_mm': 89.77, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 5e-07, 'score': 0.13664850597164402, 'rcv': 0.13652600278972457, 'smooth': 0.006125159095972776, 'rt': 1.052503760655721, 'seconds': 15.787556409835815, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_367\\BraTS20_Training_367_t1ce_pre.nii'}
# [BraTS20_Training_367] T2 mask mode = reused | voxels = 1671957
# [BraTS20_Training_367] T2 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_367', 'modality': 't2', 'raw_mean': 3506.88916015625, 'raw_std': 1103.02685546875, 'raw_cv': 0.31453142802393536, 'cor_mean': 3332.392256277742, 'cor_std': 1012.7660672388852, 'cor_cv': 0.30391562257652655, 'improved': True, 'bspline_mm': 90.0, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 0.0, 'score': 0.16964924797813946, 'rcv': 0.16954674468773956, 'smooth': 0.005125164519995451, 'rt': 1.08163636525472, 'seconds': 16.2245454788208, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_367\\BraTS20_Training_367_t2_pre.nii'}
# [SUBJECT-DONE] BraTS20_Training_367 | scans=4
#
# [SUBJECT-START] BraTS20_Training_368
# [BraTS20_Training_368] FLAIR mask mode = otsu | voxels = 1306406
# [BraTS20_Training_368] FLAIR feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_368', 'modality': 'flair', 'raw_mean': 1000.97314453125, 'raw_std': 210.64120483398438, 'raw_cv': 0.2104364197807945, 'cor_mean': 980.2957831531526, 'cor_std': 160.3514549223059, 'cor_cv': 0.1635745635923217, 'improved': True, 'bspline_mm': 89.07719408025214, 'shrink': 3, 'iters': '[50, 30, 20]', 'conv_thresh': 5e-07, 'score': 0.10361195918858197, 'rcv': 0.1035001432498559, 'smooth': 0.005590796936303377, 'rt': 0.8098708788553873, 'seconds': 12.14806318283081, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_368\\BraTS20_Training_368_flair_pre.nii'}
# [BraTS20_Training_368] T1 mask mode = reused | voxels = 1306406
# [BraTS20_Training_368] T1 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_368', 'modality': 't1', 'raw_mean': 994.8733520507812, 'raw_std': 227.68373107910156, 'raw_cv': 0.22885700034831302, 'cor_mean': 1132.0642584142017, 'cor_std': 225.05538206704293, 'cor_cv': 0.19880088996035705, 'improved': True, 'bspline_mm': 88.60527078767983, 'shrink': 4, 'iters': '[60, 40, 20]', 'conv_thresh': 1e-06, 'score': 0.1411440106261313, 'rcv': 0.14103907435795068, 'smooth': 0.0052468134090304375, 'rt': 0.6069430987040202, 'seconds': 9.104146480560303, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_368\\BraTS20_Training_368_t1_pre.nii'}
# [BraTS20_Training_368] T1CE mask mode = reused | voxels = 1306406
# [BraTS20_Training_368] T1CE feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_368', 'modality': 't1ce', 'raw_mean': 4884.33349609375, 'raw_std': 937.51611328125, 'raw_cv': 0.19194350959636763, 'cor_mean': 5409.786392666833, 'cor_std': 858.6206133132343, 'cor_cv': 0.15871617675617272, 'improved': True, 'bspline_mm': 89.65, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 0.0, 'score': 0.10004191814662021, 'rcv': 0.09992255454623204, 'smooth': 0.005968180019408464, 'rt': 0.985074504216512, 'seconds': 14.77611756324768, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_368\\BraTS20_Training_368_t1ce_pre.nii'}
# [BraTS20_Training_368] T2 mask mode = reused | voxels = 1306406
# [BraTS20_Training_368] T2 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_368', 'modality': 't2', 'raw_mean': 1771.1800537109375, 'raw_std': 512.5092163085938, 'raw_cv': 0.2893603138946276, 'cor_mean': 1686.5870033441931, 'cor_std': 419.98881547679696, 'cor_cv': 0.24901698794165134, 'improved': True, 'bspline_mm': 90.0, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 1e-06, 'score': 0.14485013484308565, 'rcv': 0.14472728612186456, 'smooth': 0.006142436061054468, 'rt': 0.970866330464681, 'seconds': 14.562994956970215, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_368\\BraTS20_Training_368_t2_pre.nii'}
# [SUBJECT-DONE] BraTS20_Training_368 | scans=4
#
# [SUBJECT-START] BraTS20_Training_369
# [BraTS20_Training_369] FLAIR mask mode = otsu | voxels = 1790809
# [BraTS20_Training_369] FLAIR feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_369', 'modality': 'flair', 'raw_mean': 1044.29638671875, 'raw_std': 202.86727905273438, 'raw_cv': 0.1942621669775326, 'cor_mean': 1046.9728303369573, 'cor_std': 149.54486361981478, 'cor_cv': 0.14283547699156338, 'improved': True, 'bspline_mm': 88.14886048551834, 'shrink': 3, 'iters': '[50, 30, 20]', 'conv_thresh': 5e-07, 'score': 0.10726549219852516, 'rcv': 0.10715013003489204, 'smooth': 0.005768108181655407, 'rt': 0.9301307996114095, 'seconds': 13.951961994171143, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_369\\BraTS20_Training_369_flair_pre.nii'}
# [BraTS20_Training_369] T1 mask mode = reused | voxels = 1790809
# [BraTS20_Training_369] T1 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_369', 'modality': 't1', 'raw_mean': 1096.4305419921875, 'raw_std': 208.61996459960938, 'raw_cv': 0.19027193844732682, 'cor_mean': 1286.084586815952, 'cor_std': 181.64116279630127, 'cor_cv': 0.14123578235595718, 'improved': True, 'bspline_mm': 86.4, 'shrink': 4, 'iters': '[60, 40, 20]', 'conv_thresh': 1e-06, 'score': 0.09475827954846501, 'rcv': 0.0946224911710906, 'smooth': 0.0067894188687205315, 'rt': 0.6779595216115316, 'seconds': 10.169392824172974, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_369\\BraTS20_Training_369_t1_pre.nii'}
# [BraTS20_Training_369] T1CE mask mode = reused | voxels = 1790809
# [BraTS20_Training_369] T1CE feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_369', 'modality': 't1ce', 'raw_mean': 5116.34619140625, 'raw_std': 1031.565185546875, 'raw_cv': 0.20162145932922662, 'cor_mean': 5808.4216198649365, 'cor_std': 952.4718145119612, 'cor_cv': 0.16398117713301763, 'improved': True, 'bspline_mm': 90.0, 'shrink': 4, 'iters': '[60, 40, 20]', 'conv_thresh': 0.0, 'score': 0.09244918422480852, 'rcv': 0.09228345727255376, 'smooth': 0.00828634761273861, 'rt': 0.6838973522186279, 'seconds': 10.258460283279419, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_369\\BraTS20_Training_369_t1ce_pre.nii'}
# [BraTS20_Training_369] T2 mask mode = reused | voxels = 1790809
# [BraTS20_Training_369] T2 feasible spacing ~ [86.4, 90.0] mm
# [RESULT] {'subject': 'BraTS20_Training_369', 'modality': 't2', 'raw_mean': 1613.178466796875, 'raw_std': 405.00347900390625, 'raw_cv': 0.25105931385606084, 'cor_mean': 1555.163547222708, 'cor_std': 333.0848938703127, 'cor_cv': 0.21417997770267397, 'improved': True, 'bspline_mm': 86.4, 'shrink': 3, 'iters': '[60, 40, 20]', 'conv_thresh': 0.0, 'score': 0.13899860092226798, 'rcv': 0.13888321924742694, 'smooth': 0.005769083742052317, 'rt': 1.1016975879669189, 'seconds': 16.525463819503784, 'output_path': 'C:\\content\\BRAIN2020\\Preprocessed_N4\\BraTS20_Training_369\\BraTS20_Training_369_t2_pre.nii'}
# [SUBJECT-DONE] BraTS20_Training_369 | scans=4
#
# ================ RUN SUMMARY ================
# [DONE] Corrected 1476 volumes | CV improved in 1458/1476.
# [REPORT] C:\content\BRAIN2020\Preprocessed_N4\n4_autotune_report.csv
# [WALL-TIME] 7096.49 minutes
# =============================================

# %%
import os, glob, shutil


RAW_ROOT = r"C:\content\BRAIN2020\BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData"

PRE_ROOT = r"C:\content\BRAIN2020\Preprocessed_N4"

count = 0
missing = []


for subj in sorted(os.listdir(RAW_ROOT)):
    raw_subj_dir = os.path.join(RAW_ROOT, subj)
    pre_subj_dir = os.path.join(PRE_ROOT, subj)

    if not os.path.isdir(raw_subj_dir):
        continue
    if not os.path.isdir(pre_subj_dir):
        continue


    seg_src = None
    for pattern in ["*_seg.nii", "*_seg.nii.gz"]:
        matches = glob.glob(os.path.join(raw_subj_dir, pattern))
        if matches:
            seg_src = matches[0]
            break

    if not seg_src:
        missing.append(subj)
        continue


    base = os.path.basename(seg_src)
    if base.endswith(".nii.gz"):
        seg_dst = os.path.join(pre_subj_dir, base[:-7] + "_pre.nii.gz")
    else:
        seg_dst = os.path.join(pre_subj_dir, base[:-4] + "_pre.nii")


    shutil.copy(seg_src, seg_dst)
    count += 1
    print(f"[COPY] {subj} → {os.path.basename(seg_dst)}")

print("\n✅ Done.")
print(f"Copied {count} segmentation files to preprocessed folders.")
if missing:
    print(f" Missing segmentation files for: {missing}")
# Out:
# [COPY] BraTS20_Training_001 → BraTS20_Training_001_seg_pre.nii
# [COPY] BraTS20_Training_002 → BraTS20_Training_002_seg_pre.nii
# [COPY] BraTS20_Training_003 → BraTS20_Training_003_seg_pre.nii
# [COPY] BraTS20_Training_004 → BraTS20_Training_004_seg_pre.nii
# [COPY] BraTS20_Training_005 → BraTS20_Training_005_seg_pre.nii
# [COPY] BraTS20_Training_006 → BraTS20_Training_006_seg_pre.nii
# [COPY] BraTS20_Training_007 → BraTS20_Training_007_seg_pre.nii
# [COPY] BraTS20_Training_008 → BraTS20_Training_008_seg_pre.nii
# [COPY] BraTS20_Training_009 → BraTS20_Training_009_seg_pre.nii
# [COPY] BraTS20_Training_010 → BraTS20_Training_010_seg_pre.nii
# [COPY] BraTS20_Training_011 → BraTS20_Training_011_seg_pre.nii
# [COPY] BraTS20_Training_012 → BraTS20_Training_012_seg_pre.nii
# [COPY] BraTS20_Training_013 → BraTS20_Training_013_seg_pre.nii
# [COPY] BraTS20_Training_014 → BraTS20_Training_014_seg_pre.nii
# [COPY] BraTS20_Training_015 → BraTS20_Training_015_seg_pre.nii
# [COPY] BraTS20_Training_016 → BraTS20_Training_016_seg_pre.nii
# [COPY] BraTS20_Training_017 → BraTS20_Training_017_seg_pre.nii
# [COPY] BraTS20_Training_018 → BraTS20_Training_018_seg_pre.nii
# [COPY] BraTS20_Training_019 → BraTS20_Training_019_seg_pre.nii
# [COPY] BraTS20_Training_020 → BraTS20_Training_020_seg_pre.nii
# [COPY] BraTS20_Training_021 → BraTS20_Training_021_seg_pre.nii
# [COPY] BraTS20_Training_022 → BraTS20_Training_022_seg_pre.nii
# [COPY] BraTS20_Training_023 → BraTS20_Training_023_seg_pre.nii
# [COPY] BraTS20_Training_024 → BraTS20_Training_024_seg_pre.nii
# [COPY] BraTS20_Training_025 → BraTS20_Training_025_seg_pre.nii
# [COPY] BraTS20_Training_026 → BraTS20_Training_026_seg_pre.nii
# [COPY] BraTS20_Training_027 → BraTS20_Training_027_seg_pre.nii
# [COPY] BraTS20_Training_028 → BraTS20_Training_028_seg_pre.nii
# [COPY] BraTS20_Training_029 → BraTS20_Training_029_seg_pre.nii
# [COPY] BraTS20_Training_030 → BraTS20_Training_030_seg_pre.nii
# [COPY] BraTS20_Training_031 → BraTS20_Training_031_seg_pre.nii
# [COPY] BraTS20_Training_032 → BraTS20_Training_032_seg_pre.nii
# [COPY] BraTS20_Training_033 → BraTS20_Training_033_seg_pre.nii
# [COPY] BraTS20_Training_034 → BraTS20_Training_034_seg_pre.nii
# [COPY] BraTS20_Training_035 → BraTS20_Training_035_seg_pre.nii
# [COPY] BraTS20_Training_036 → BraTS20_Training_036_seg_pre.nii
# [COPY] BraTS20_Training_037 → BraTS20_Training_037_seg_pre.nii
# [COPY] BraTS20_Training_038 → BraTS20_Training_038_seg_pre.nii
# [COPY] BraTS20_Training_039 → BraTS20_Training_039_seg_pre.nii
# [COPY] BraTS20_Training_040 → BraTS20_Training_040_seg_pre.nii
# [COPY] BraTS20_Training_041 → BraTS20_Training_041_seg_pre.nii
# [COPY] BraTS20_Training_042 → BraTS20_Training_042_seg_pre.nii
# [COPY] BraTS20_Training_043 → BraTS20_Training_043_seg_pre.nii
# [COPY] BraTS20_Training_044 → BraTS20_Training_044_seg_pre.nii
# [COPY] BraTS20_Training_045 → BraTS20_Training_045_seg_pre.nii
# [COPY] BraTS20_Training_046 → BraTS20_Training_046_seg_pre.nii
# [COPY] BraTS20_Training_047 → BraTS20_Training_047_seg_pre.nii
# [COPY] BraTS20_Training_048 → BraTS20_Training_048_seg_pre.nii
# [COPY] BraTS20_Training_049 → BraTS20_Training_049_seg_pre.nii
# [COPY] BraTS20_Training_050 → BraTS20_Training_050_seg_pre.nii
# [COPY] BraTS20_Training_051 → BraTS20_Training_051_seg_pre.nii
# [COPY] BraTS20_Training_052 → BraTS20_Training_052_seg_pre.nii
# [COPY] BraTS20_Training_053 → BraTS20_Training_053_seg_pre.nii
# [COPY] BraTS20_Training_054 → BraTS20_Training_054_seg_pre.nii
# [COPY] BraTS20_Training_055 → BraTS20_Training_055_seg_pre.nii
# [COPY] BraTS20_Training_056 → BraTS20_Training_056_seg_pre.nii
# [COPY] BraTS20_Training_057 → BraTS20_Training_057_seg_pre.nii
# [COPY] BraTS20_Training_058 → BraTS20_Training_058_seg_pre.nii
# [COPY] BraTS20_Training_059 → BraTS20_Training_059_seg_pre.nii
# [COPY] BraTS20_Training_060 → BraTS20_Training_060_seg_pre.nii
# [COPY] BraTS20_Training_061 → BraTS20_Training_061_seg_pre.nii
# [COPY] BraTS20_Training_062 → BraTS20_Training_062_seg_pre.nii
# [COPY] BraTS20_Training_063 → BraTS20_Training_063_seg_pre.nii
# [COPY] BraTS20_Training_064 → BraTS20_Training_064_seg_pre.nii
# [COPY] BraTS20_Training_065 → BraTS20_Training_065_seg_pre.nii
# [COPY] BraTS20_Training_066 → BraTS20_Training_066_seg_pre.nii
# [COPY] BraTS20_Training_067 → BraTS20_Training_067_seg_pre.nii
# [COPY] BraTS20_Training_068 → BraTS20_Training_068_seg_pre.nii
# [COPY] BraTS20_Training_069 → BraTS20_Training_069_seg_pre.nii
# [COPY] BraTS20_Training_070 → BraTS20_Training_070_seg_pre.nii
# [COPY] BraTS20_Training_071 → BraTS20_Training_071_seg_pre.nii
# [COPY] BraTS20_Training_072 → BraTS20_Training_072_seg_pre.nii
# [COPY] BraTS20_Training_073 → BraTS20_Training_073_seg_pre.nii
# [COPY] BraTS20_Training_074 → BraTS20_Training_074_seg_pre.nii
# [COPY] BraTS20_Training_075 → BraTS20_Training_075_seg_pre.nii
# [COPY] BraTS20_Training_076 → BraTS20_Training_076_seg_pre.nii
# [COPY] BraTS20_Training_077 → BraTS20_Training_077_seg_pre.nii
# [COPY] BraTS20_Training_078 → BraTS20_Training_078_seg_pre.nii
# [COPY] BraTS20_Training_079 → BraTS20_Training_079_seg_pre.nii
# [COPY] BraTS20_Training_080 → BraTS20_Training_080_seg_pre.nii
# [COPY] BraTS20_Training_081 → BraTS20_Training_081_seg_pre.nii
# [COPY] BraTS20_Training_082 → BraTS20_Training_082_seg_pre.nii
# [COPY] BraTS20_Training_083 → BraTS20_Training_083_seg_pre.nii
# [COPY] BraTS20_Training_084 → BraTS20_Training_084_seg_pre.nii
# [COPY] BraTS20_Training_085 → BraTS20_Training_085_seg_pre.nii
# [COPY] BraTS20_Training_086 → BraTS20_Training_086_seg_pre.nii
# [COPY] BraTS20_Training_087 → BraTS20_Training_087_seg_pre.nii
# [COPY] BraTS20_Training_088 → BraTS20_Training_088_seg_pre.nii
# [COPY] BraTS20_Training_089 → BraTS20_Training_089_seg_pre.nii
# [COPY] BraTS20_Training_090 → BraTS20_Training_090_seg_pre.nii
# [COPY] BraTS20_Training_091 → BraTS20_Training_091_seg_pre.nii
# [COPY] BraTS20_Training_092 → BraTS20_Training_092_seg_pre.nii
# [COPY] BraTS20_Training_093 → BraTS20_Training_093_seg_pre.nii
# [COPY] BraTS20_Training_094 → BraTS20_Training_094_seg_pre.nii
# [COPY] BraTS20_Training_095 → BraTS20_Training_095_seg_pre.nii
# [COPY] BraTS20_Training_096 → BraTS20_Training_096_seg_pre.nii
# [COPY] BraTS20_Training_097 → BraTS20_Training_097_seg_pre.nii
# [COPY] BraTS20_Training_098 → BraTS20_Training_098_seg_pre.nii
# [COPY] BraTS20_Training_099 → BraTS20_Training_099_seg_pre.nii
# [COPY] BraTS20_Training_100 → BraTS20_Training_100_seg_pre.nii
# [COPY] BraTS20_Training_101 → BraTS20_Training_101_seg_pre.nii
# [COPY] BraTS20_Training_102 → BraTS20_Training_102_seg_pre.nii
# [COPY] BraTS20_Training_103 → BraTS20_Training_103_seg_pre.nii
# [COPY] BraTS20_Training_104 → BraTS20_Training_104_seg_pre.nii
# [COPY] BraTS20_Training_105 → BraTS20_Training_105_seg_pre.nii
# [COPY] BraTS20_Training_106 → BraTS20_Training_106_seg_pre.nii
# [COPY] BraTS20_Training_107 → BraTS20_Training_107_seg_pre.nii
# [COPY] BraTS20_Training_108 → BraTS20_Training_108_seg_pre.nii
# [COPY] BraTS20_Training_109 → BraTS20_Training_109_seg_pre.nii
# [COPY] BraTS20_Training_110 → BraTS20_Training_110_seg_pre.nii
# [COPY] BraTS20_Training_111 → BraTS20_Training_111_seg_pre.nii
# [COPY] BraTS20_Training_112 → BraTS20_Training_112_seg_pre.nii
# [COPY] BraTS20_Training_113 → BraTS20_Training_113_seg_pre.nii
# [COPY] BraTS20_Training_114 → BraTS20_Training_114_seg_pre.nii
# [COPY] BraTS20_Training_115 → BraTS20_Training_115_seg_pre.nii
# [COPY] BraTS20_Training_116 → BraTS20_Training_116_seg_pre.nii
# [COPY] BraTS20_Training_117 → BraTS20_Training_117_seg_pre.nii
# [COPY] BraTS20_Training_118 → BraTS20_Training_118_seg_pre.nii
# [COPY] BraTS20_Training_119 → BraTS20_Training_119_seg_pre.nii
# [COPY] BraTS20_Training_120 → BraTS20_Training_120_seg_pre.nii
# [COPY] BraTS20_Training_121 → BraTS20_Training_121_seg_pre.nii
# [COPY] BraTS20_Training_122 → BraTS20_Training_122_seg_pre.nii
# [COPY] BraTS20_Training_123 → BraTS20_Training_123_seg_pre.nii
# [COPY] BraTS20_Training_124 → BraTS20_Training_124_seg_pre.nii
# [COPY] BraTS20_Training_125 → BraTS20_Training_125_seg_pre.nii
# [COPY] BraTS20_Training_126 → BraTS20_Training_126_seg_pre.nii
# [COPY] BraTS20_Training_127 → BraTS20_Training_127_seg_pre.nii
# [COPY] BraTS20_Training_128 → BraTS20_Training_128_seg_pre.nii
# [COPY] BraTS20_Training_129 → BraTS20_Training_129_seg_pre.nii
# [COPY] BraTS20_Training_130 → BraTS20_Training_130_seg_pre.nii
# [COPY] BraTS20_Training_131 → BraTS20_Training_131_seg_pre.nii
# [COPY] BraTS20_Training_132 → BraTS20_Training_132_seg_pre.nii
# [COPY] BraTS20_Training_133 → BraTS20_Training_133_seg_pre.nii
# [COPY] BraTS20_Training_134 → BraTS20_Training_134_seg_pre.nii
# [COPY] BraTS20_Training_135 → BraTS20_Training_135_seg_pre.nii
# [COPY] BraTS20_Training_136 → BraTS20_Training_136_seg_pre.nii
# [COPY] BraTS20_Training_137 → BraTS20_Training_137_seg_pre.nii
# [COPY] BraTS20_Training_138 → BraTS20_Training_138_seg_pre.nii
# [COPY] BraTS20_Training_139 → BraTS20_Training_139_seg_pre.nii
# [COPY] BraTS20_Training_140 → BraTS20_Training_140_seg_pre.nii
# [COPY] BraTS20_Training_141 → BraTS20_Training_141_seg_pre.nii
# [COPY] BraTS20_Training_142 → BraTS20_Training_142_seg_pre.nii
# [COPY] BraTS20_Training_143 → BraTS20_Training_143_seg_pre.nii
# [COPY] BraTS20_Training_144 → BraTS20_Training_144_seg_pre.nii
# [COPY] BraTS20_Training_145 → BraTS20_Training_145_seg_pre.nii
# [COPY] BraTS20_Training_146 → BraTS20_Training_146_seg_pre.nii
# [COPY] BraTS20_Training_147 → BraTS20_Training_147_seg_pre.nii
# [COPY] BraTS20_Training_148 → BraTS20_Training_148_seg_pre.nii
# [COPY] BraTS20_Training_149 → BraTS20_Training_149_seg_pre.nii
# [COPY] BraTS20_Training_150 → BraTS20_Training_150_seg_pre.nii
# [COPY] BraTS20_Training_151 → BraTS20_Training_151_seg_pre.nii
# [COPY] BraTS20_Training_152 → BraTS20_Training_152_seg_pre.nii
# [COPY] BraTS20_Training_153 → BraTS20_Training_153_seg_pre.nii
# [COPY] BraTS20_Training_154 → BraTS20_Training_154_seg_pre.nii
# [COPY] BraTS20_Training_155 → BraTS20_Training_155_seg_pre.nii
# [COPY] BraTS20_Training_156 → BraTS20_Training_156_seg_pre.nii
# [COPY] BraTS20_Training_157 → BraTS20_Training_157_seg_pre.nii
# [COPY] BraTS20_Training_158 → BraTS20_Training_158_seg_pre.nii
# [COPY] BraTS20_Training_159 → BraTS20_Training_159_seg_pre.nii
# [COPY] BraTS20_Training_160 → BraTS20_Training_160_seg_pre.nii
# [COPY] BraTS20_Training_161 → BraTS20_Training_161_seg_pre.nii
# [COPY] BraTS20_Training_162 → BraTS20_Training_162_seg_pre.nii
# [COPY] BraTS20_Training_163 → BraTS20_Training_163_seg_pre.nii
# [COPY] BraTS20_Training_164 → BraTS20_Training_164_seg_pre.nii
# [COPY] BraTS20_Training_165 → BraTS20_Training_165_seg_pre.nii
# [COPY] BraTS20_Training_166 → BraTS20_Training_166_seg_pre.nii
# [COPY] BraTS20_Training_167 → BraTS20_Training_167_seg_pre.nii
# [COPY] BraTS20_Training_168 → BraTS20_Training_168_seg_pre.nii
# [COPY] BraTS20_Training_169 → BraTS20_Training_169_seg_pre.nii
# [COPY] BraTS20_Training_170 → BraTS20_Training_170_seg_pre.nii
# [COPY] BraTS20_Training_171 → BraTS20_Training_171_seg_pre.nii
# [COPY] BraTS20_Training_172 → BraTS20_Training_172_seg_pre.nii
# [COPY] BraTS20_Training_173 → BraTS20_Training_173_seg_pre.nii
# [COPY] BraTS20_Training_174 → BraTS20_Training_174_seg_pre.nii
# [COPY] BraTS20_Training_175 → BraTS20_Training_175_seg_pre.nii
# [COPY] BraTS20_Training_176 → BraTS20_Training_176_seg_pre.nii
# [COPY] BraTS20_Training_177 → BraTS20_Training_177_seg_pre.nii
# [COPY] BraTS20_Training_178 → BraTS20_Training_178_seg_pre.nii
# [COPY] BraTS20_Training_179 → BraTS20_Training_179_seg_pre.nii
# [COPY] BraTS20_Training_180 → BraTS20_Training_180_seg_pre.nii
# [COPY] BraTS20_Training_181 → BraTS20_Training_181_seg_pre.nii
# [COPY] BraTS20_Training_182 → BraTS20_Training_182_seg_pre.nii
# [COPY] BraTS20_Training_183 → BraTS20_Training_183_seg_pre.nii
# [COPY] BraTS20_Training_184 → BraTS20_Training_184_seg_pre.nii
# [COPY] BraTS20_Training_185 → BraTS20_Training_185_seg_pre.nii
# [COPY] BraTS20_Training_186 → BraTS20_Training_186_seg_pre.nii
# [COPY] BraTS20_Training_187 → BraTS20_Training_187_seg_pre.nii
# [COPY] BraTS20_Training_188 → BraTS20_Training_188_seg_pre.nii
# [COPY] BraTS20_Training_189 → BraTS20_Training_189_seg_pre.nii
# [COPY] BraTS20_Training_190 → BraTS20_Training_190_seg_pre.nii
# [COPY] BraTS20_Training_191 → BraTS20_Training_191_seg_pre.nii
# [COPY] BraTS20_Training_192 → BraTS20_Training_192_seg_pre.nii
# [COPY] BraTS20_Training_193 → BraTS20_Training_193_seg_pre.nii
# [COPY] BraTS20_Training_194 → BraTS20_Training_194_seg_pre.nii
# [COPY] BraTS20_Training_195 → BraTS20_Training_195_seg_pre.nii
# [COPY] BraTS20_Training_196 → BraTS20_Training_196_seg_pre.nii
# [COPY] BraTS20_Training_197 → BraTS20_Training_197_seg_pre.nii
# [COPY] BraTS20_Training_198 → BraTS20_Training_198_seg_pre.nii
# [COPY] BraTS20_Training_199 → BraTS20_Training_199_seg_pre.nii
# [COPY] BraTS20_Training_200 → BraTS20_Training_200_seg_pre.nii
# [COPY] BraTS20_Training_201 → BraTS20_Training_201_seg_pre.nii
# [COPY] BraTS20_Training_202 → BraTS20_Training_202_seg_pre.nii
# [COPY] BraTS20_Training_203 → BraTS20_Training_203_seg_pre.nii
# [COPY] BraTS20_Training_204 → BraTS20_Training_204_seg_pre.nii
# [COPY] BraTS20_Training_205 → BraTS20_Training_205_seg_pre.nii
# [COPY] BraTS20_Training_206 → BraTS20_Training_206_seg_pre.nii
# [COPY] BraTS20_Training_207 → BraTS20_Training_207_seg_pre.nii
# [COPY] BraTS20_Training_208 → BraTS20_Training_208_seg_pre.nii
# [COPY] BraTS20_Training_209 → BraTS20_Training_209_seg_pre.nii
# [COPY] BraTS20_Training_210 → BraTS20_Training_210_seg_pre.nii
# [COPY] BraTS20_Training_211 → BraTS20_Training_211_seg_pre.nii
# [COPY] BraTS20_Training_212 → BraTS20_Training_212_seg_pre.nii
# [COPY] BraTS20_Training_213 → BraTS20_Training_213_seg_pre.nii
# [COPY] BraTS20_Training_214 → BraTS20_Training_214_seg_pre.nii
# [COPY] BraTS20_Training_215 → BraTS20_Training_215_seg_pre.nii
# [COPY] BraTS20_Training_216 → BraTS20_Training_216_seg_pre.nii
# [COPY] BraTS20_Training_217 → BraTS20_Training_217_seg_pre.nii
# [COPY] BraTS20_Training_218 → BraTS20_Training_218_seg_pre.nii
# [COPY] BraTS20_Training_219 → BraTS20_Training_219_seg_pre.nii
# [COPY] BraTS20_Training_220 → BraTS20_Training_220_seg_pre.nii
# [COPY] BraTS20_Training_221 → BraTS20_Training_221_seg_pre.nii
# [COPY] BraTS20_Training_222 → BraTS20_Training_222_seg_pre.nii
# [COPY] BraTS20_Training_223 → BraTS20_Training_223_seg_pre.nii
# [COPY] BraTS20_Training_224 → BraTS20_Training_224_seg_pre.nii
# [COPY] BraTS20_Training_225 → BraTS20_Training_225_seg_pre.nii
# [COPY] BraTS20_Training_226 → BraTS20_Training_226_seg_pre.nii
# [COPY] BraTS20_Training_227 → BraTS20_Training_227_seg_pre.nii
# [COPY] BraTS20_Training_228 → BraTS20_Training_228_seg_pre.nii
# [COPY] BraTS20_Training_229 → BraTS20_Training_229_seg_pre.nii
# [COPY] BraTS20_Training_230 → BraTS20_Training_230_seg_pre.nii
# [COPY] BraTS20_Training_231 → BraTS20_Training_231_seg_pre.nii
# [COPY] BraTS20_Training_232 → BraTS20_Training_232_seg_pre.nii
# [COPY] BraTS20_Training_233 → BraTS20_Training_233_seg_pre.nii
# [COPY] BraTS20_Training_234 → BraTS20_Training_234_seg_pre.nii
# [COPY] BraTS20_Training_235 → BraTS20_Training_235_seg_pre.nii
# [COPY] BraTS20_Training_236 → BraTS20_Training_236_seg_pre.nii
# [COPY] BraTS20_Training_237 → BraTS20_Training_237_seg_pre.nii
# [COPY] BraTS20_Training_238 → BraTS20_Training_238_seg_pre.nii
# [COPY] BraTS20_Training_239 → BraTS20_Training_239_seg_pre.nii
# [COPY] BraTS20_Training_240 → BraTS20_Training_240_seg_pre.nii
# [COPY] BraTS20_Training_241 → BraTS20_Training_241_seg_pre.nii
# [COPY] BraTS20_Training_242 → BraTS20_Training_242_seg_pre.nii
# [COPY] BraTS20_Training_243 → BraTS20_Training_243_seg_pre.nii
# [COPY] BraTS20_Training_244 → BraTS20_Training_244_seg_pre.nii
# [COPY] BraTS20_Training_245 → BraTS20_Training_245_seg_pre.nii
# [COPY] BraTS20_Training_246 → BraTS20_Training_246_seg_pre.nii
# [COPY] BraTS20_Training_247 → BraTS20_Training_247_seg_pre.nii
# [COPY] BraTS20_Training_248 → BraTS20_Training_248_seg_pre.nii
# [COPY] BraTS20_Training_249 → BraTS20_Training_249_seg_pre.nii
# [COPY] BraTS20_Training_250 → BraTS20_Training_250_seg_pre.nii
# [COPY] BraTS20_Training_251 → BraTS20_Training_251_seg_pre.nii
# [COPY] BraTS20_Training_252 → BraTS20_Training_252_seg_pre.nii
# [COPY] BraTS20_Training_253 → BraTS20_Training_253_seg_pre.nii
# [COPY] BraTS20_Training_254 → BraTS20_Training_254_seg_pre.nii
# [COPY] BraTS20_Training_255 → BraTS20_Training_255_seg_pre.nii
# [COPY] BraTS20_Training_256 → BraTS20_Training_256_seg_pre.nii
# [COPY] BraTS20_Training_257 → BraTS20_Training_257_seg_pre.nii
# [COPY] BraTS20_Training_258 → BraTS20_Training_258_seg_pre.nii
# [COPY] BraTS20_Training_259 → BraTS20_Training_259_seg_pre.nii
# [COPY] BraTS20_Training_260 → BraTS20_Training_260_seg_pre.nii
# [COPY] BraTS20_Training_261 → BraTS20_Training_261_seg_pre.nii
# [COPY] BraTS20_Training_262 → BraTS20_Training_262_seg_pre.nii
# [COPY] BraTS20_Training_263 → BraTS20_Training_263_seg_pre.nii
# [COPY] BraTS20_Training_264 → BraTS20_Training_264_seg_pre.nii
# [COPY] BraTS20_Training_265 → BraTS20_Training_265_seg_pre.nii
# [COPY] BraTS20_Training_266 → BraTS20_Training_266_seg_pre.nii
# [COPY] BraTS20_Training_267 → BraTS20_Training_267_seg_pre.nii
# [COPY] BraTS20_Training_268 → BraTS20_Training_268_seg_pre.nii
# [COPY] BraTS20_Training_269 → BraTS20_Training_269_seg_pre.nii
# [COPY] BraTS20_Training_270 → BraTS20_Training_270_seg_pre.nii
# [COPY] BraTS20_Training_271 → BraTS20_Training_271_seg_pre.nii
# [COPY] BraTS20_Training_272 → BraTS20_Training_272_seg_pre.nii
# [COPY] BraTS20_Training_273 → BraTS20_Training_273_seg_pre.nii
# [COPY] BraTS20_Training_274 → BraTS20_Training_274_seg_pre.nii
# [COPY] BraTS20_Training_275 → BraTS20_Training_275_seg_pre.nii
# [COPY] BraTS20_Training_276 → BraTS20_Training_276_seg_pre.nii
# [COPY] BraTS20_Training_277 → BraTS20_Training_277_seg_pre.nii
# [COPY] BraTS20_Training_278 → BraTS20_Training_278_seg_pre.nii
# [COPY] BraTS20_Training_279 → BraTS20_Training_279_seg_pre.nii
# [COPY] BraTS20_Training_280 → BraTS20_Training_280_seg_pre.nii
# [COPY] BraTS20_Training_281 → BraTS20_Training_281_seg_pre.nii
# [COPY] BraTS20_Training_282 → BraTS20_Training_282_seg_pre.nii
# [COPY] BraTS20_Training_283 → BraTS20_Training_283_seg_pre.nii
# [COPY] BraTS20_Training_284 → BraTS20_Training_284_seg_pre.nii
# [COPY] BraTS20_Training_285 → BraTS20_Training_285_seg_pre.nii
# [COPY] BraTS20_Training_286 → BraTS20_Training_286_seg_pre.nii
# [COPY] BraTS20_Training_287 → BraTS20_Training_287_seg_pre.nii
# [COPY] BraTS20_Training_288 → BraTS20_Training_288_seg_pre.nii
# [COPY] BraTS20_Training_289 → BraTS20_Training_289_seg_pre.nii
# [COPY] BraTS20_Training_290 → BraTS20_Training_290_seg_pre.nii
# [COPY] BraTS20_Training_291 → BraTS20_Training_291_seg_pre.nii
# [COPY] BraTS20_Training_292 → BraTS20_Training_292_seg_pre.nii
# [COPY] BraTS20_Training_293 → BraTS20_Training_293_seg_pre.nii
# [COPY] BraTS20_Training_294 → BraTS20_Training_294_seg_pre.nii
# [COPY] BraTS20_Training_295 → BraTS20_Training_295_seg_pre.nii
# [COPY] BraTS20_Training_296 → BraTS20_Training_296_seg_pre.nii
# [COPY] BraTS20_Training_297 → BraTS20_Training_297_seg_pre.nii
# [COPY] BraTS20_Training_298 → BraTS20_Training_298_seg_pre.nii
# [COPY] BraTS20_Training_299 → BraTS20_Training_299_seg_pre.nii
# [COPY] BraTS20_Training_300 → BraTS20_Training_300_seg_pre.nii
# [COPY] BraTS20_Training_301 → BraTS20_Training_301_seg_pre.nii
# [COPY] BraTS20_Training_302 → BraTS20_Training_302_seg_pre.nii
# [COPY] BraTS20_Training_303 → BraTS20_Training_303_seg_pre.nii
# [COPY] BraTS20_Training_304 → BraTS20_Training_304_seg_pre.nii
# [COPY] BraTS20_Training_305 → BraTS20_Training_305_seg_pre.nii
# [COPY] BraTS20_Training_306 → BraTS20_Training_306_seg_pre.nii
# [COPY] BraTS20_Training_307 → BraTS20_Training_307_seg_pre.nii
# [COPY] BraTS20_Training_308 → BraTS20_Training_308_seg_pre.nii
# [COPY] BraTS20_Training_309 → BraTS20_Training_309_seg_pre.nii
# [COPY] BraTS20_Training_310 → BraTS20_Training_310_seg_pre.nii
# [COPY] BraTS20_Training_311 → BraTS20_Training_311_seg_pre.nii
# [COPY] BraTS20_Training_312 → BraTS20_Training_312_seg_pre.nii
# [COPY] BraTS20_Training_313 → BraTS20_Training_313_seg_pre.nii
# [COPY] BraTS20_Training_314 → BraTS20_Training_314_seg_pre.nii
# [COPY] BraTS20_Training_315 → BraTS20_Training_315_seg_pre.nii
# [COPY] BraTS20_Training_316 → BraTS20_Training_316_seg_pre.nii
# [COPY] BraTS20_Training_317 → BraTS20_Training_317_seg_pre.nii
# [COPY] BraTS20_Training_318 → BraTS20_Training_318_seg_pre.nii
# [COPY] BraTS20_Training_319 → BraTS20_Training_319_seg_pre.nii
# [COPY] BraTS20_Training_320 → BraTS20_Training_320_seg_pre.nii
# [COPY] BraTS20_Training_321 → BraTS20_Training_321_seg_pre.nii
# [COPY] BraTS20_Training_322 → BraTS20_Training_322_seg_pre.nii
# [COPY] BraTS20_Training_323 → BraTS20_Training_323_seg_pre.nii
# [COPY] BraTS20_Training_324 → BraTS20_Training_324_seg_pre.nii
# [COPY] BraTS20_Training_325 → BraTS20_Training_325_seg_pre.nii
# [COPY] BraTS20_Training_326 → BraTS20_Training_326_seg_pre.nii
# [COPY] BraTS20_Training_327 → BraTS20_Training_327_seg_pre.nii
# [COPY] BraTS20_Training_328 → BraTS20_Training_328_seg_pre.nii
# [COPY] BraTS20_Training_329 → BraTS20_Training_329_seg_pre.nii
# [COPY] BraTS20_Training_330 → BraTS20_Training_330_seg_pre.nii
# [COPY] BraTS20_Training_331 → BraTS20_Training_331_seg_pre.nii
# [COPY] BraTS20_Training_332 → BraTS20_Training_332_seg_pre.nii
# [COPY] BraTS20_Training_333 → BraTS20_Training_333_seg_pre.nii
# [COPY] BraTS20_Training_334 → BraTS20_Training_334_seg_pre.nii
# [COPY] BraTS20_Training_335 → BraTS20_Training_335_seg_pre.nii
# [COPY] BraTS20_Training_336 → BraTS20_Training_336_seg_pre.nii
# [COPY] BraTS20_Training_337 → BraTS20_Training_337_seg_pre.nii
# [COPY] BraTS20_Training_338 → BraTS20_Training_338_seg_pre.nii
# [COPY] BraTS20_Training_339 → BraTS20_Training_339_seg_pre.nii
# [COPY] BraTS20_Training_340 → BraTS20_Training_340_seg_pre.nii
# [COPY] BraTS20_Training_341 → BraTS20_Training_341_seg_pre.nii
# [COPY] BraTS20_Training_342 → BraTS20_Training_342_seg_pre.nii
# [COPY] BraTS20_Training_343 → BraTS20_Training_343_seg_pre.nii
# [COPY] BraTS20_Training_344 → BraTS20_Training_344_seg_pre.nii
# [COPY] BraTS20_Training_345 → BraTS20_Training_345_seg_pre.nii
# [COPY] BraTS20_Training_346 → BraTS20_Training_346_seg_pre.nii
# [COPY] BraTS20_Training_347 → BraTS20_Training_347_seg_pre.nii
# [COPY] BraTS20_Training_348 → BraTS20_Training_348_seg_pre.nii
# [COPY] BraTS20_Training_349 → BraTS20_Training_349_seg_pre.nii
# [COPY] BraTS20_Training_350 → BraTS20_Training_350_seg_pre.nii
# [COPY] BraTS20_Training_351 → BraTS20_Training_351_seg_pre.nii
# [COPY] BraTS20_Training_352 → BraTS20_Training_352_seg_pre.nii
# [COPY] BraTS20_Training_353 → BraTS20_Training_353_seg_pre.nii
# [COPY] BraTS20_Training_354 → BraTS20_Training_354_seg_pre.nii
# [COPY] BraTS20_Training_355 → BraTS20_Training_355_seg_pre.nii
# [COPY] BraTS20_Training_356 → BraTS20_Training_356_seg_pre.nii
# [COPY] BraTS20_Training_357 → BraTS20_Training_357_seg_pre.nii
# [COPY] BraTS20_Training_358 → BraTS20_Training_358_seg_pre.nii
# [COPY] BraTS20_Training_359 → BraTS20_Training_359_seg_pre.nii
# [COPY] BraTS20_Training_360 → BraTS20_Training_360_seg_pre.nii
# [COPY] BraTS20_Training_361 → BraTS20_Training_361_seg_pre.nii
# [COPY] BraTS20_Training_362 → BraTS20_Training_362_seg_pre.nii
# [COPY] BraTS20_Training_363 → BraTS20_Training_363_seg_pre.nii
# [COPY] BraTS20_Training_364 → BraTS20_Training_364_seg_pre.nii
# [COPY] BraTS20_Training_365 → BraTS20_Training_365_seg_pre.nii
# [COPY] BraTS20_Training_366 → BraTS20_Training_366_seg_pre.nii
# [COPY] BraTS20_Training_367 → BraTS20_Training_367_seg_pre.nii
# [COPY] BraTS20_Training_368 → BraTS20_Training_368_seg_pre.nii
# [COPY] BraTS20_Training_369 → BraTS20_Training_369_seg_pre.nii
#
# ✅ Done.
# Copied 369 segmentation files to preprocessed folders.

# %%
import os, glob
import numpy as np
import SimpleITK as sitk
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats


DATA_ROOT = r"C:\content\BRAIN2020\BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData"
PRE_ROOT  = r"C:\content\BRAIN2020\AutoTuned_N4_Brast2020"
CSV_PATH  = os.path.join(PRE_ROOT, "evaluation_report.csv")
VIZ_DIR   = os.path.join(PRE_ROOT, "visualizations")
os.makedirs(VIZ_DIR, exist_ok=True)

MODS = ["flair", "t1", "t1ce", "t2"]

print("✅ Configuration loaded.")
print(f"   DATA_ROOT : {DATA_ROOT}")
print(f"   PRE_ROOT  : {PRE_ROOT}")
print(f"   VIZ_DIR   : {VIZ_DIR}")



def find_subject_pairs():
    """
    For BraTS 2020 (flat structure):
    Each subject folder contains all modalities.
    """
    pairs = []


    raw_root = DATA_ROOT
    pre_root = PRE_ROOT

    if not os.path.isdir(raw_root):
        raise ValueError(f"[ERROR] DATA_ROOT not found: {raw_root}")

    for subj in sorted(os.listdir(raw_root)):
        raw_subj = os.path.join(raw_root, subj)
        pre_subj = os.path.join(pre_root, subj)

        if not os.path.isdir(raw_subj):
            continue

        if not os.path.isdir(pre_subj):
            print(f"[WARN] No preprocessed folder for {subj} → skip")
            continue

        for mod in MODS:

            raw_fp = None
            for pattern in [f"*_{mod}.nii.gz", f"*_{mod}.nii"]:
                hits = glob.glob(os.path.join(raw_subj, pattern))
                if hits:
                    raw_fp = hits[0]
                    break


            pre_fp = None
            for pattern in [f"*_{mod}_pre.nii.gz", f"*_{mod}_pre.nii"]:
                hits = glob.glob(os.path.join(pre_subj, pattern))
                if hits:
                    pre_fp = hits[0]
                    break

            if raw_fp and pre_fp:
                pairs.append({
                    "subject"  : subj,
                    "grade"    : "N/A", 
                    "modality" : mod,
                    "raw_fp"   : raw_fp,
                    "pre_fp"   : pre_fp,
                })
            else:
                if not raw_fp:
                    print(f"[WARN] {subj} {mod}: missing raw file")
                if not pre_fp:
                    print(f"[WARN] {subj} {mod}: missing preprocessed file")

    print(f"\n✅ Found {len(pairs)} subject-modality pairs.")
    return pairs


pairs = find_subject_pairs()
# Out:
# ✅ Configuration loaded.
#    DATA_ROOT : C:\content\BRAIN2020\BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData
#    PRE_ROOT  : C:\content\BRAIN2020\AutoTuned_N4_Brast2020
#    VIZ_DIR   : C:\content\BRAIN2020\AutoTuned_N4_Brast2020\visualizations
#
# ✅ Found 1476 subject-modality pairs.

# %%
def build_brain_mask(img_sitk, otsu_bins=200, min_voxels=5000):
    """
    Build brain mask with robust fallbacks.
    Returns (mask_sitk, method_str).
    """

    mask = sitk.OtsuThreshold(img_sitk, 0, 1, otsu_bins)
    mask = sitk.Cast(mask, sitk.sitkUInt8)
    mask = sitk.BinaryMorphologicalClosing(mask, [1] * img_sitk.GetDimension())
    mask = sitk.BinaryFillhole(mask)
    if int(sitk.GetArrayFromImage(mask).sum()) >= min_voxels:
        return mask, "otsu"


    nz = sitk.Cast(
        sitk.BinaryThreshold(img_sitk, 1e-6, 1e30, 1, 0),
        sitk.sitkUInt8
    )
    nz = sitk.BinaryMorphologicalClosing(nz, [2] * img_sitk.GetDimension())
    nz = sitk.BinaryFillhole(nz)
    if int(sitk.GetArrayFromImage(nz).sum()) >= min_voxels:
        return nz, "nonzero"


    whole = sitk.Cast(
        sitk.Image(img_sitk.GetSize(), sitk.sitkUInt8) + 1,
        sitk.sitkUInt8
    )
    whole.CopyInformation(img_sitk)
    return whole, "whole"

print("Mask builder defined.")



def get_brain_voxels(img_sitk, mask_sitk):
    arr = sitk.GetArrayFromImage(img_sitk)
    msk = sitk.GetArrayFromImage(mask_sitk).astype(bool)
    return arr[msk]


def compute_cv(vox):

    if vox.size < 10:
        return float("nan")
    return float(np.std(vox) / (np.mean(vox) + 1e-8))


def compute_rcv(vox):

    if vox.size < 10:
        return float("nan")
    med = np.median(vox)
    mad = np.median(np.abs(vox - med)) * 1.4826
    return float(mad / (med + 1e-8))


def compute_snr(vox):

    if vox.size < 10:
        return float("nan")
    return float(np.mean(vox) / (np.std(vox) + 1e-8))


def compute_cnr(vox):

    if vox.size < 20:
        return float("nan")
    threshold = np.percentile(vox, 65)
    wm = vox[vox >= threshold]
    gm = vox[vox <  threshold]
    if len(wm) < 10 or len(gm) < 10:
        return float("nan")
    cnr = abs(np.mean(wm) - np.mean(gm)) / (
        np.sqrt((np.std(wm)**2 + np.std(gm)**2) / 2) + 1e-8
    )
    return float(cnr)


def compute_iu(vox):

    if vox.size < 10:
        return float("nan")
    return float(1.0 - np.std(vox) / (np.mean(vox) + 1e-8))


def compute_all_metrics(img_sitk, mask_sitk):

    vox = get_brain_voxels(img_sitk, mask_sitk)
    return {
        "mean" : float(np.mean(vox))   if vox.size >= 10 else float("nan"),
        "std"  : float(np.std(vox))    if vox.size >= 10 else float("nan"),
        "cv"   : compute_cv(vox),
        "rcv"  : compute_rcv(vox),
        "snr"  : compute_snr(vox),
        "cnr"  : compute_cnr(vox),
        "iu"   : compute_iu(vox),
    }

print("Metric functions defined.")
# Out:
# Mask builder defined.
# Metric functions defined.

# %%
rows = []
total = len(pairs)

for i, p in enumerate(pairs, 1):
    try:

        raw_img = sitk.ReadImage(p["raw_fp"], sitk.sitkFloat32)
        pre_img = sitk.ReadImage(p["pre_fp"], sitk.sitkFloat32)


        mask, mask_mode = build_brain_mask(raw_img)


        raw_m = compute_all_metrics(raw_img, mask)
        pre_m = compute_all_metrics(pre_img, mask)

        row = {
            "subject"      : p["subject"],
            "grade"        : p["grade"],
            "modality"     : p["modality"],
            "mask_mode"    : mask_mode,


            "raw_mean"     : raw_m["mean"],
            "raw_std"      : raw_m["std"],
            "raw_cv"       : raw_m["cv"],
            "raw_rcv"      : raw_m["rcv"],
            "raw_snr"      : raw_m["snr"],
            "raw_cnr"      : raw_m["cnr"],
            "raw_iu"       : raw_m["iu"],


            "pre_mean"     : pre_m["mean"],
            "pre_std"      : pre_m["std"],
            "pre_cv"       : pre_m["cv"],
            "pre_rcv"      : pre_m["rcv"],
            "pre_snr"      : pre_m["snr"],
            "pre_cnr"      : pre_m["cnr"],
            "pre_iu"       : pre_m["iu"],


            "cv_improved"  : bool(pre_m["cv"]  < raw_m["cv"]),
            "snr_improved" : bool(pre_m["snr"] > raw_m["snr"]),
            "cnr_improved" : bool(pre_m["cnr"] > raw_m["cnr"]),
            "iu_improved"  : bool(pre_m["iu"]  > raw_m["iu"]),
        }
        rows.append(row)

        if i % 50 == 0 or i == total:
            print(f"Progress: {i}/{total} | "
                  f"{p['subject']} {p['modality'].upper()} | "
                  f"CV: {raw_m['cv']:.4f}→{pre_m['cv']:.4f} | "
                  f"SNR: {raw_m['snr']:.3f}→{pre_m['snr']:.3f}",
                  flush=True)

    except Exception as e:
        print(f"[ERROR] {p['subject']} {p['modality']}: {e}")
        continue

df = pd.DataFrame(rows)


df["cv_reduction_pct"]  = (df["raw_cv"]  - df["pre_cv"])  / (df["raw_cv"]  + 1e-8) * 100
df["snr_gain_pct"]      = (df["pre_snr"] - df["raw_snr"]) / (df["raw_snr"] + 1e-8) * 100
df["cnr_gain_pct"]      = (df["pre_cnr"] - df["raw_cnr"]) / (df["raw_cnr"] + 1e-8) * 100
df["iu_gain_pct"]       = (df["pre_iu"]  - df["raw_iu"])  / (df["raw_iu"]  + 1e-8) * 100

df.to_csv(CSV_PATH, index=False)
print(f"\n Evaluation complete. {len(df)} rows saved to:\n   {CSV_PATH}")
# Out:
# Progress: 50/1476 | BraTS20_Training_013 T1 | CV: 0.2508→0.1975 | SNR: 3.987→5.062
# Progress: 1450/1476 | BraTS20_Training_363 T1 | CV: 0.1902→0.1564 | SNR: 5.257→6.395
# Progress: 1476/1476 | BraTS20_Training_369 T2 | CV: 0.2494→0.2129 | SNR: 4.009→4.697
#
#  Evaluation complete. 1476 rows saved to:
#    C:\content\BRAIN2020\AutoTuned_N4_Brast2020\evaluation_report.csv

# %%
print("=" * 65)
print("MEAN METRICS BEFORE vs AFTER — ALL MODALITIES")
print("=" * 65)

summary = df.groupby("modality").agg(
    raw_cv  =("raw_cv",  "mean"),
    pre_cv  =("pre_cv",  "mean"),
    raw_snr =("raw_snr", "mean"),
    pre_snr =("pre_snr", "mean"),
    raw_cnr =("raw_cnr", "mean"),
    pre_cnr =("pre_cnr", "mean"),
    raw_iu  =("raw_iu",  "mean"),
    pre_iu  =("pre_iu",  "mean"),
    cv_red_pct  =("cv_reduction_pct", "mean"),
    snr_gain_pct=("snr_gain_pct",     "mean"),
    pct_cv_improved =("cv_improved",  "mean"),
    pct_snr_improved=("snr_improved", "mean"),
).round(4)

summary["pct_cv_improved"]  = (summary["pct_cv_improved"]  * 100).round(1)
summary["pct_snr_improved"] = (summary["pct_snr_improved"] * 100).round(1)

print(summary.to_string())
summary.to_csv(os.path.join(VIZ_DIR, "summary_table.csv"))
print(f"\n✅ Summary saved.")
# Out:
# =================================================================
# MEAN METRICS BEFORE vs AFTER — ALL MODALITIES
# =================================================================
#           raw_cv  pre_cv  raw_snr  pre_snr  raw_cnr  pre_cnr  raw_iu  pre_iu  cv_red_pct  snr_gain_pct  pct_cv_improved  pct_snr_improved
# modality
# flair     0.2946  0.2283   3.6563   4.6965   1.9090   1.8171  0.7054  0.7717     21.6113       30.1291            100.0             100.0
# t1        0.2209  0.1810   4.6870   5.7671   2.4446   1.9452  0.7791  0.8190     18.0351       23.0538             99.5              99.5
# t1ce      0.2629  0.2355   4.0462   4.6722   1.8329   1.4379  0.7371  0.7645     11.2806       14.2286             93.5              93.5
# t2        0.3784  0.3401   2.8018   3.2299   2.2196   2.0477  0.6216  0.6599     11.0698       13.7535             96.2              96.2
#
# ✅ Summary saved.

# %%
print("=" * 65)
print("WILCOXON SIGNED-RANK TESTS")
print("=" * 65)

metric_pairs = [
    ("raw_cv",  "pre_cv",  "CV",  "↓ lower is better"),
    ("raw_rcv", "pre_rcv", "rCV", "↓ lower is better"),
    ("raw_snr", "pre_snr", "SNR", "↑ higher is better"),
    ("raw_cnr", "pre_cnr", "CNR", "↑ higher is better"),
    ("raw_iu",  "pre_iu",  "IU",  "↑ higher is better"),
]

for mod in MODS:
    sub = df[df["modality"] == mod].dropna()
    print(f"\n--- {mod.upper()} (n={len(sub)}) ---")
    for raw_col, pre_col, label, direction in metric_pairs:
        raw_v = sub[raw_col].values
        pre_v = sub[pre_col].values
        if len(raw_v) < 5:
            continue
        stat, p = stats.wilcoxon(raw_v, pre_v)
        delta   = np.mean(pre_v) - np.mean(raw_v)
        sig     = ("***" if p < 0.001 else
                   "**"  if p < 0.01  else
                   "*"   if p < 0.05  else "ns")
        print(f"  {label:4s} {direction:20s} | "
              f"{np.mean(raw_v):.4f} → {np.mean(pre_v):.4f} "
              f"| Δ={delta:+.4f} | p={p:.2e} {sig}")
# Out:
# =================================================================
# WILCOXON SIGNED-RANK TESTS
# =================================================================
#
# --- FLAIR (n=369) ---
#   CV   ↓ lower is better    | 0.2946 → 0.2283 | Δ=-0.0663 | p=3.18e-62 ***
#   rCV  ↓ lower is better    | 0.1908 → 0.1452 | Δ=-0.0457 | p=3.18e-62 ***
#   SNR  ↑ higher is better   | 3.6563 → 4.6965 | Δ=+1.0402 | p=3.18e-62 ***
#   CNR  ↑ higher is better   | 1.9090 → 1.8171 | Δ=-0.0920 | p=1.63e-09 ***
#   IU   ↑ higher is better   | 0.7054 → 0.7717 | Δ=+0.0663 | p=3.18e-62 ***
#
# --- T1 (n=369) ---
#   CV   ↓ lower is better    | 0.2209 → 0.1810 | Δ=-0.0398 | p=8.12e-61 ***
#   rCV  ↓ lower is better    | 0.2099 → 0.1345 | Δ=-0.0753 | p=6.12e-61 ***
#   SNR  ↑ higher is better   | 4.6870 → 5.7671 | Δ=+1.0802 | p=8.32e-61 ***
#   CNR  ↑ higher is better   | 2.4446 → 1.9452 | Δ=-0.4994 | p=4.44e-62 ***
#   IU   ↑ higher is better   | 0.7791 → 0.8190 | Δ=+0.0398 | p=8.12e-61 ***
#
# --- T1CE (n=369) ---
#   CV   ↓ lower is better    | 0.2629 → 0.2355 | Δ=-0.0274 | p=8.87e-57 ***
#   rCV  ↓ lower is better    | 0.1925 → 0.1224 | Δ=-0.0701 | p=4.06e-61 ***
#   SNR  ↑ higher is better   | 4.0462 → 4.6722 | Δ=+0.6261 | p=1.10e-57 ***
#   CNR  ↑ higher is better   | 1.8329 → 1.4379 | Δ=-0.3950 | p=2.30e-61 ***
#   IU   ↑ higher is better   | 0.7371 → 0.7645 | Δ=+0.0274 | p=8.87e-57 ***
#
# --- T2 (n=369) ---
#   CV   ↓ lower is better    | 0.3784 → 0.3401 | Δ=-0.0384 | p=2.27e-59 ***
#   rCV  ↓ lower is better    | 0.2843 → 0.2267 | Δ=-0.0576 | p=7.86e-61 ***
#   SNR  ↑ higher is better   | 2.8018 → 3.2299 | Δ=+0.4281 | p=2.13e-60 ***
#   CNR  ↑ higher is better   | 2.2196 → 2.0477 | Δ=-0.1719 | p=2.56e-43 ***
#   IU   ↑ higher is better   | 0.6216 → 0.6599 | Δ=+0.0384 | p=2.27e-59 ***

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes  = axes.flatten()
x     = np.arange(len(MODS))
width = 0.35

metrics_config = [
    ("raw_cv",  "pre_cv",  "CV",  "Coefficient of Variation (↓)"),
    ("raw_snr", "pre_snr", "SNR", "Signal-to-Noise Ratio (↑)"),
    ("raw_cnr", "pre_cnr", "CNR", "Contrast-to-Noise Ratio (↑)"),
    ("raw_iu",  "pre_iu",  "IU",  "Intensity Uniformity (↑)"),
]

for idx, (raw_col, pre_col, ylabel, title) in enumerate(metrics_config):
    ax = axes[idx]

    raw_means = [df[df["modality"]==m][raw_col].mean() for m in MODS]
    pre_means = [df[df["modality"]==m][pre_col].mean() for m in MODS]
    raw_stds  = [df[df["modality"]==m][raw_col].std()  for m in MODS]
    pre_stds  = [df[df["modality"]==m][pre_col].std()  for m in MODS]

    ax.bar(x - width/2, raw_means, width, yerr=raw_stds,
           label="Before N4", color="#E74C3C", alpha=0.8,
           capsize=4, error_kw={"linewidth":1})
    ax.bar(x + width/2, pre_means, width, yerr=pre_stds,
           label="After Autotuned N4", color="#2ECC71", alpha=0.8,
           capsize=4, error_kw={"linewidth":1})

    ax.set_xticks(x)
    ax.set_xticklabels([m.upper() for m in MODS])
    ax.set_title(title, fontsize=12, fontweight="bold")
    ax.set_ylabel(ylabel)
    ax.legend(fontsize=9)
    ax.grid(axis="y", alpha=0.3)

plt.suptitle("Image Quality Metrics: Before vs After Autotuned N4 Correction\n(BraTS 2020)",
             fontsize=14, fontweight="bold")
plt.tight_layout()
plt.savefig(os.path.join(VIZ_DIR, "chart1_grouped_bar.png"), dpi=150, bbox_inches="tight")
plt.show()
print("✅ Saved: chart1_grouped_bar.png")
# Out:
# ✅ Saved: chart1_grouped_bar.png

# %%
print("=" * 65)
print("FINAL EVALUATION SUMMARY — BraTS 2020")
print("=" * 65)
print(f"Total volumes evaluated : {len(df)}")
print(f"Subjects                : {df['subject'].nunique()}")
print(f"HGG subjects            : {df[df['grade']=='HGG']['subject'].nunique()}")
print(f"LGG subjects            : {df[df['grade']=='LGG']['subject'].nunique()}")
print()
print(f"CV  improved in : {df['cv_improved'].sum()}/{len(df)} "
      f"({df['cv_improved'].mean()*100:.1f}%)")
print(f"SNR improved in : {df['snr_improved'].sum()}/{len(df)} "
      f"({df['snr_improved'].mean()*100:.1f}%)")
print(f"CNR improved in : {df['cnr_improved'].sum()}/{len(df)} "
      f"({df['cnr_improved'].mean()*100:.1f}%)")
print(f"IU  improved in : {df['iu_improved'].sum()}/{len(df)} "
      f"({df['iu_improved'].mean()*100:.1f}%)")
print()
print(f"Mean CV  reduction : {df['cv_reduction_pct'].mean():.2f}%")
print(f"Mean SNR gain      : {df['snr_gain_pct'].mean():.2f}%")
print(f"Mean CNR gain      : {df['cnr_gain_pct'].mean():.2f}%")
print(f"Mean IU  gain      : {df['iu_gain_pct'].mean():.2f}%")
print()
print(f"All outputs saved to: {VIZ_DIR}")
print("=" * 65)
# Out:
# =================================================================
# FINAL EVALUATION SUMMARY — BraTS 2020
# =================================================================
# Total volumes evaluated : 1476
# Subjects                : 369
# HGG subjects            : 0
# LGG subjects            : 0
#
# CV  improved in : 1436/1476 (97.3%)
# SNR improved in : 1436/1476 (97.3%)
# CNR improved in : 196/1476 (13.3%)
# IU  improved in : 1436/1476 (97.3%)
#
# Mean CV  reduction : 15.50%
# Mean SNR gain      : 20.29%
# Mean CNR gain      : -13.22%
# Mean IU  gain      : 6.28%
#
# All outputs saved to: C:\content\BRAIN2020\AutoTuned_N4_Brast2020\visualizations
# =================================================================
