# %%
pip install nilearn
# Out:
# Collecting nilearn
#   Downloading nilearn-0.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from nilearn) (3.1.6)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (1.5.3)
# Requirement already satisfied: nibabel>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (5.4.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.12/dist-packages (from nilearn) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from nilearn) (26.0)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (2.2.2)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (2.32.4)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (1.6.1)
# Requirement already satisfied: scipy>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (1.16.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1.2->nilearn) (3.0.3)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.12/dist-packages (from nibabel>=5.2.0->nilearn) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->nilearn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->nilearn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->nilearn) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (2026.2.25)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.0->nilearn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->nilearn) (1.17.0)
# Downloading nilearn-0.13.1-py3-none-any.whl (10.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 144.2 MB/s eta 0:00:00
# Installing collected packages: nilearn
# Successfully installed nilearn-0.13.1

# %%
import os
import cv2
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
from skimage import data
from skimage.util import montage
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps

import nilearn as nl
import nibabel as nib
import nilearn.plotting as nlplt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom, Rescaling
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam

from scipy.spatial.distance import directed_hausdorff
from scipy.ndimage import binary_erosion, generate_binary_structure
from scipy.spatial.distance import cdist

np.set_printoptions(precision=3, suppress=True)
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import (
    EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
)
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split

import matplotlib
matplotlib.use("module://ipykernel.pylab.backend_inline")
import matplotlib.pyplot as plt
plt.rcParams["figure.dpi"] = 110

print("TensorFlow:", tf.__version__)
print("Keras:     ", tf.keras.__version__)
print("GPU:", tf.config.list_physical_devices("GPU"))
tf.keras.backend.set_floatx("float32")

SAVE_DIR = "/content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82"
os.makedirs(SAVE_DIR, exist_ok=True)
# Out:
# TensorFlow: 2.19.0
# Keras:      3.13.2
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Paths & Configuration

BEST_MODEL_PATH   = os.path.join(SAVE_DIR, "best_model.keras")
LAST_WEIGHTS_PATH = os.path.join(SAVE_DIR, "last.weights.h5")
LOG_PATH          = os.path.join(SAVE_DIR, "history.csv")
CURVES_PATH       = os.path.join(SAVE_DIR, "training_curves.png")
PREDS_PATH        = os.path.join(SAVE_DIR, "predictions.png")
EVAL_PATH         = os.path.join(SAVE_DIR, "evaluation_results.txt")


IMG_HEIGHT    = 160
IMG_WIDTH     = 160
IN_CHANNELS   = 4
OUT_CHANNELS  = 3
BASE_FILTERS  = 64
GROUPS        = 8

BATCH_SIZE    = 16
EPOCHS        = 100
LEARNING_RATE = 1e-4
PATIENCE      = 10
VAL_SPLIT     = 0.15
TEST_SPLIT    = 0.15
SEED          = 42

WT_WEIGHT     = 0.5
ET_WEIGHT     = 2.0
TC_WEIGHT     = 1.5

KEEP_TIER_A   = 1.00
KEEP_TIER_B   = 0.60
KEEP_TIER_C   = 0.15
KEEP_TIER_D   = 0.05
MIN_ET_VOXELS = 5
MIN_TC_VOXELS = 10
MIN_WT_VOXELS = 10

CHANNEL_NAMES   = ["WT", "ET", "TC"]
CHANNEL_WEIGHTS = [WT_WEIGHT, ET_WEIGHT, TC_WEIGHT]

# %%
# save figure to Drive AND display inline

def save_and_show(fig, save_path, caption=""):
    fig.savefig(save_path, dpi=150, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print(f"Saved → {save_path}" + (f"  ({caption})" if caption else ""))

# %%
# Data Loading

from zipfile import ZipFile
with ZipFile('/content/drive/MyDrive/BRAIN2020_DeCORRECTION_NORMALIZED_CROPPED.zip', 'r') as z:
    z.extractall('/content/CROPPED2020')

BRAIN2020_CROPPED = "/content/CROPPED2020"


def create_multimodal_image(dataset_root_dir):
    modalities = ["t1", "t1ce", "t2", "flair"]
    data, grade = {}, {}
    for pid in os.listdir(dataset_root_dir):
        pd_ = os.path.join(dataset_root_dir, pid)
        if not os.path.isdir(pd_):
            continue
        imgs, ok = [], True
        for mod in modalities:
            fp = os.path.join(pd_, f"{pid}_{mod}.nii")
            if not os.path.exists(fp):
                ok = False; break
            imgs.append(nib.load(fp).get_fdata().astype(np.float32))
        if ok:
            data[pid]  = np.stack(imgs, axis=-1)
            grade[pid] = "unknown"
    return data, grade


def create_combined_label_masks(seg_path):
    seg = nib.load(seg_path).get_fdata().astype(np.uint8)
    return np.stack([
        np.isin(seg, [1, 2, 4]).astype(np.float32),   # WT
        (seg == 4).astype(np.float32),                  # ET
        np.isin(seg, [1, 4]).astype(np.float32),        # TC
    ], axis=-1)


def load_all_patients(root):
    mdata, mgrade = create_multimodal_image(root)
    pids, grades, xvols, yvols = [], [], [], []
    for pid in mdata:
        sp = os.path.join(root, pid, f"{pid}_seg.nii")
        if os.path.exists(sp):
            xv = mdata[pid]; yv = create_combined_label_masks(sp)
            if xv.shape[:3] == yv.shape[:3]:
                pids.append(pid); grades.append(mgrade[pid])
                xvols.append(xv);  yvols.append(yv)

    print(f"Loaded {len(xvols)} patients")
    return pids, grades, xvols, yvols


patient_ids, grades, X_volumes, Y_volumes = load_all_patients(BRAIN2020_CROPPED)
# Out:
# Loaded 369 patients

# %%
# Volume Cleaning

def clean_volumes(xvols):
    return [
        np.clip(np.nan_to_num(x, nan=0., posinf=0., neginf=0.), -5., 5.)
        for x in xvols
    ]

X_volumes = clean_volumes(X_volumes)

# %%
# Balanced Slice Extraction

def volumes_to_2d_slices_balanced(
    x_volumes, y_volumes,
    min_et_voxels=MIN_ET_VOXELS, min_tc_voxels=MIN_TC_VOXELS,
    min_wt_voxels=MIN_WT_VOXELS,
    keep_tier_a=KEEP_TIER_A, keep_tier_b=KEEP_TIER_B,
    keep_tier_c=KEEP_TIER_C, keep_tier_d=KEEP_TIER_D, seed=SEED,
):
    rng = np.random.default_rng(seed)
    xl, yl, tl = [], [], []
    counts = {t: 0 for t in ["A","B","C","D","A_skip","B_skip","C_skip","D_skip"]}
    for xv, yv in zip(x_volumes, y_volumes):
        for d in range(xv.shape[2]):
            xs = xv[:, :, d, :]; ys = yv[:, :, d, :]
            wt_fg = int(ys[..., 0].sum()) >= min_wt_voxels
            tc_fg = int(ys[..., 2].sum()) >= min_tc_voxels
            et_fg = int(ys[..., 1].sum()) >= min_et_voxels
            if   wt_fg and tc_fg and et_fg: tier, rate = "A", keep_tier_a
            elif wt_fg and tc_fg:           tier, rate = "B", keep_tier_b
            elif wt_fg:                     tier, rate = "C", keep_tier_c
            else:                           tier, rate = "D", keep_tier_d
            if rng.random() < rate:
                xl.append(xs); yl.append(ys); tl.append(tier)
                counts[tier] += 1
            else:
                counts[f"{tier}_skip"] += 1
    X = np.array(xl, np.float32); Y = np.array(yl, np.float32)
    descs = {"A":"WT+TC+ET","B":"WT+TC (no ET)","C":"WT only","D":"no fg"}
    print("\n" + "="*58)
    print("  Balanced Slice Extraction")
    print("="*58)
    for t in ["A","B","C","D"]:
        print(f"  Tier {t} ({descs[t]:<16}): "
              f"kept={counts[t]:5d}  skipped={counts[t+'_skip']:5d}")
    print(f"  Total: {len(X)}")
    print("="*58)
    return X, Y, tl


def print_slice_balance(Y, tier_labels, split_name="Dataset"):
    wt_v = Y[...,0].sum(axis=(1,2)); et_v = Y[...,1].sum(axis=(1,2))
    tc_v = Y[...,2].sum(axis=(1,2)); N = len(Y)
    tc = {t: tier_labels.count(t) for t in ["A","B","C","D"]}
    print(f"\n  [{split_name}]  {N} slices  "
          f"A={tc['A']} B={tc['B']} C={tc['C']} D={tc['D']}")
    for name, v in [("WT", wt_v), ("ET", et_v), ("TC", tc_v)]:
        print(f"    {name}: {(v>0).mean()*100:5.1f}% present  "
              f"mean={v.mean():.1f} vox")
    print(f"    Nesting: ET≤TC={(et_v<=tc_v+1).all()}  "
          f"TC≤WT={(tc_v<=wt_v+1).all()}")


X_sl, Y_sl, tier_labels = volumes_to_2d_slices_balanced(X_volumes, Y_volumes)
del X_volumes, Y_volumes
print_slice_balance(Y_sl, tier_labels, "Full balanced dataset")
# Out:
# ==========================================================
#   Balanced Slice Extraction
# ==========================================================
#   Tier A (WT+TC+ET        ): kept=13874  skipped=    0
#   Tier B (WT+TC (no ET)   ): kept= 1416  skipped=  984
#   Tier C (WT only         ): kept= 1147  skipped= 6385
#   Tier D (no fg           ): kept= 1167  skipped=22259
#   Total: 17604
# ==========================================================
#
#   [Full balanced dataset]  17604 slices  A=13874 B=1416 C=1147 D=1167
#     WT:  93.5% present  mean=1758.4 vox
#     ET:  79.7% present  mean=411.8 vox
#     TC:  87.2% present  mean=821.4 vox
#     Nesting: ET≤TC=True  TC≤WT=True

# %%
# Train / Val / Test Split  (70% / 15% / 15%)

X_trainval, X_test, Y_trainval, Y_test, tl_trainval, tl_test = train_test_split(
    X_sl, Y_sl, tier_labels,
    test_size=TEST_SPLIT, random_state=SEED, shuffle=True
)

val_fraction_of_trainval = VAL_SPLIT / (1.0 - TEST_SPLIT)

X_train, X_val, Y_train, Y_val, tl_train, tl_val = train_test_split(
    X_trainval, Y_trainval, tl_trainval,
    test_size=val_fraction_of_trainval, random_state=SEED, shuffle=True
)

del X_sl, Y_sl, X_trainval, Y_trainval

print("\nAfter split:")
print_slice_balance(Y_train, tl_train, "Train  (~70%)")
print_slice_balance(Y_val,   tl_val,   "Val    (~15%)")
print_slice_balance(Y_test,  tl_test,  "Test   (~15%)")
print(f"\nTrain : {X_train.shape}"
      f"\nVal   : {X_val.shape}"
      f"\nTest  : {X_test.shape}")
# Out:
# After split:
#
#   [Train  (~70%)]  12322 slices  A=9706 B=1002 C=786 D=828
#     WT:  93.5% present  mean=1766.6 vox
#     ET:  79.7% present  mean=411.7 vox
#     TC:  87.3% present  mean=821.3 vox
#     Nesting: ET≤TC=True  TC≤WT=True
#
#   [Val    (~15%)]  2641 slices  A=2111 B=198 C=172 D=160
#     WT:  94.1% present  mean=1774.0 vox
#     ET:  80.7% present  mean=418.3 vox
#     TC:  87.7% present  mean=835.1 vox
#     Nesting: ET≤TC=True  TC≤WT=True
#
#   [Test   (~15%)]  2641 slices  A=2057 B=216 C=189 D=179
#     WT:  93.3% present  mean=1705.0 vox
#     ET:  78.8% present  mean=405.9 vox
#     TC:  86.4% present  mean=808.1 vox
#     Nesting: ET≤TC=True  TC≤WT=True
#
# Train : (12322, 160, 160, 4)
# Val   : (2641, 160, 160, 4)
# Test  : (2641, 160, 160, 4)

# %%
# tf.data Pipeline

AUTOTUNE = tf.data.AUTOTUNE


def augment(img, msk):

    # Zoom (±20%)
    zoom = tf.random.uniform([], 0.8, 1.2)

    h = tf.shape(img)[0]
    w = tf.shape(img)[1]

    new_h = tf.cast(tf.cast(h, tf.float32) * zoom, tf.int32)
    new_w = tf.cast(tf.cast(w, tf.float32) * zoom, tf.int32)

    img = tf.image.resize(img, (new_h, new_w), method='bilinear')
    msk = tf.image.resize(msk, (new_h, new_w), method='nearest')

    img = tf.image.resize_with_crop_or_pad(img, h, w)
    msk = tf.image.resize_with_crop_or_pad(msk, h, w)


    # Width & Height Shift (±20%)
    max_dx = tf.cast(0.2 * tf.cast(w, tf.float32), tf.int32)
    max_dy = tf.cast(0.2 * tf.cast(h, tf.float32), tf.int32)

    dx = tf.random.uniform([], -max_dx, max_dx, dtype=tf.int32)
    dy = tf.random.uniform([], -max_dy, max_dy, dtype=tf.int32)

    img = tf.roll(img, shift=[dy, dx], axis=[0, 1])
    msk = tf.roll(msk, shift=[dy, dx], axis=[0, 1])

    #Flip
    if tf.random.uniform(()) > 0.2:
      img = tf.image.flip_left_right(img)
      msk = tf.image.flip_left_right(msk)
    if tf.random.uniform(()) > 0.2:
      img = tf.image.flip_up_down(img)
      msk = tf.image.flip_up_down(msk)

    return img, msk


def make_dataset(X, Y, training=False):
    ds = tf.data.Dataset.from_tensor_slices((X, Y))
    if training:
        ds = ds.shuffle(len(X), seed=SEED).map(augment, num_parallel_calls=AUTOTUNE)
    return ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)


train_ds = make_dataset(X_train, Y_train, training=True)
val_ds   = make_dataset(X_val,   Y_val,   training=False)
test_ds  = make_dataset(X_test,  Y_test,  training=False)

print(f"\nTrain batches : {len(train_ds)}"
      f"\nVal   batches : {len(val_ds)}"
      f"\nTest  batches : {len(test_ds)}")
# Out:
# Train batches : 771
# Val   batches : 166
# Test  batches : 166

# %%
# U-Net Architecture

def conv_block(x, filters, groups=GROUPS):

    for _ in range(2):
        x = layers.Conv2D(
            filters, 3, padding="same", use_bias=False,
            kernel_initializer="he_normal"
        )(x)
        x = layers.GroupNormalization(groups=groups)(x)
        x = layers.Activation("relu")(x)
    return x


def encoder_block(x, filters):

    skip = conv_block(x, filters)
    pool = layers.MaxPooling2D(2)(skip)
    return skip, pool


def decoder_block(x, skip, filters):

    x = layers.Conv2DTranspose(
        filters, 2, strides=2, padding="same",
        kernel_initializer="he_normal"
    )(x)
    x = layers.Concatenate()([x, skip])
    x = conv_block(x, filters)
    return x


def build_unet(
    img_height=IMG_HEIGHT, img_width=IMG_WIDTH,
    in_channels=IN_CHANNELS, out_channels=OUT_CHANNELS,
    base_filters=BASE_FILTERS, dropout_rate=0.3
):

    inputs = layers.Input(
        shape=(img_height, img_width, in_channels), name="input"
    )

    # ── Encoder ────────────────────────────────────────────────────────────
    s1, p1 = encoder_block(inputs, base_filters)         # filters=64
    s2, p2 = encoder_block(p1,     base_filters * 2)     # filters=128
    s3, p3 = encoder_block(p2,     base_filters * 4)     # filters=256
    s4, p4 = encoder_block(p3,     base_filters * 8)     # filters=512

    # ── Bottleneck ─────────────────────────────────────────────────────────
    b = conv_block(p4, base_filters * 16)                # filters=1024
    b = layers.Dropout(dropout_rate)(b)

    # ── Decoder ────────────────────────────────────────────────────────────
    d4 = decoder_block(b,  s4, base_filters * 8)         # filters=512
    d3 = decoder_block(d4, s3, base_filters * 4)         # filters=256
    d2 = decoder_block(d3, s2, base_filters * 2)         # filters=128
    d1 = decoder_block(d2, s1, base_filters)             # filters=64

    # ── Output ────────────────────────────────────────────────────────
    outputs = layers.Conv2D(
        out_channels, 1, activation="sigmoid", name="output"
    )(d1)

    return Model(inputs, outputs, name="UNet_2D")


model = build_unet()
model.summary()
# Out:
# Model: "UNet_2D"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 160, 160,  │          0 │ -                 │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 160, 160,  │      2,304 │ input[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalization │ (None, 160, 160,  │        128 │ conv2d[0][0]      │
# │ (GroupNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 160, 160,  │          0 │ group_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 160, 160,  │     36,864 │ activation[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 160, 160,  │        128 │ conv2d_1[0][0]    │
# │ (GroupNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 160, 160,  │          0 │ group_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 80, 80,    │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 80, 80,    │     73,728 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 80, 80,    │        256 │ conv2d_2[0][0]    │
# │ (GroupNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 80, 80,    │          0 │ group_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 80, 80,    │    147,456 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 80, 80,    │        256 │ conv2d_3[0][0]    │
# │ (GroupNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 80, 80,    │          0 │ group_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 40, 40,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 40, 40,    │    294,912 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 40, 40,    │        512 │ conv2d_4[0][0]    │
# │ (GroupNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 40, 40,    │          0 │ group_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 40, 40,    │    589,824 │ activation_4[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 40, 40,    │        512 │ conv2d_5[0][0]    │
# │ (GroupNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 40, 40,    │          0 │ group_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 20, 20,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 20, 20,    │  1,179,648 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 20, 20,    │      1,024 │ conv2d_6[0][0]    │
# │ (GroupNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 20, 20,    │          0 │ group_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 20, 20,    │  2,359,296 │ activation_6[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 20, 20,    │      1,024 │ conv2d_7[0][0]    │
# │ (GroupNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 20, 20,    │          0 │ group_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 10, 10,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 10, 10,    │  4,718,592 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 10, 10,    │      2,048 │ conv2d_8[0][0]    │
# │ (GroupNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 10, 10,    │          0 │ group_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 10, 10,    │  9,437,184 │ activation_8[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 10, 10,    │      2,048 │ conv2d_9[0][0]    │
# │ (GroupNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 10, 10,    │          0 │ group_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 10, 10,    │          0 │ activation_9[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 20, 20,    │  2,097,664 │ dropout[0][0]     │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 20, 20,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 20, 20,    │  4,718,592 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 20, 20,    │      1,024 │ conv2d_10[0][0]   │
# │ (GroupNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 20, 20,    │          0 │ group_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 20, 20,    │  2,359,296 │ activation_10[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 20, 20,    │      1,024 │ conv2d_11[0][0]   │
# │ (GroupNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 20, 20,    │          0 │ group_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 40, 40,    │    524,544 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 40, 40,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 40, 40,    │  1,179,648 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 40, 40,    │        512 │ conv2d_12[0][0]   │
# │ (GroupNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 40, 40,    │          0 │ group_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 40, 40,    │    589,824 │ activation_12[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 40, 40,    │        512 │ conv2d_13[0][0]   │
# │ (GroupNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 40, 40,    │          0 │ group_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 80, 80,    │    131,200 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 80, 80,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 80, 80,    │    294,912 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 80, 80,    │        256 │ conv2d_14[0][0]   │
# │ (GroupNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 80, 80,    │          0 │ group_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 80, 80,    │    147,456 │ activation_14[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 80, 80,    │        256 │ conv2d_15[0][0]   │
# │ (GroupNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 80, 80,    │          0 │ group_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 160, 160,  │     32,832 │ activation_15[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 160, 160,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 160, 160,  │     73,728 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 160, 160,  │        128 │ conv2d_16[0][0]   │
# │ (GroupNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 160, 160,  │          0 │ group_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 160, 160,  │     36,864 │ activation_16[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 160, 160,  │        128 │ conv2d_17[0][0]   │
# │ (GroupNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 160, 160,  │          0 │ group_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Conv2D)     │ (None, 160, 160,  │        195 │ activation_17[0]… │
# │                     │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,038,339 (118.40 MB)
#  Trainable params: 31,038,339 (118.40 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Loss Function

def _boundary_weight_map(y_true_ch, pool_size=11, border_weight=3.0):

    averaged = tf.nn.avg_pool2d(
        y_true_ch,
        ksize=pool_size,
        strides=1,
        padding="SAME"
    )                                      # (B, H, W, 1)

    border = tf.cast(averaged > 0.005, tf.float32) * \
             tf.cast(averaged < 0.995, tf.float32)   # (B, H, W, 1)

    weight  = tf.ones_like(averaged)
    w0      = tf.reduce_sum(weight)
    weight  = weight + border * (border_weight - 1.0)
    w1      = tf.reduce_sum(weight)

    weight  = weight * (w0 / (w1 + 1e-8))
    return weight


def _weighted_bce_channel(y_true_ch, y_pred_ch, weight):

    epsilon   = 1e-7
    y_pred_ch = tf.clip_by_value(y_pred_ch, epsilon, 1.0 - epsilon)
    logit     = tf.math.log(y_pred_ch / (1.0 - y_pred_ch))

    bce = ((1.0 - y_true_ch) * logit
           + (1.0 + (weight - 1.0) * y_true_ch)
           * (tf.math.log(1.0 + tf.exp(-tf.abs(logit)))
              + tf.maximum(-logit, 0.0)))

    return tf.reduce_sum(bce) / (tf.reduce_sum(weight) + 1e-8)


def _weighted_dice_channel(y_true_ch, y_pred_ch, weight, smooth=1.0):

    w   = weight * weight
    m1  = y_true_ch
    m2  = y_pred_ch
    intersection = tf.reduce_sum(w * m1 * m2)
    denom        = tf.reduce_sum(w * (m1 ** 2)) + tf.reduce_sum(w * (m2 ** 2))
    score        = (2.0 * intersection + smooth) / (denom + smooth)
    return 1.0 - score


def weighted_boundary_loss_fn(
    wt_weight   = WT_WEIGHT,    # 1.0
    et_weight   = ET_WEIGHT,    # 2.0
    tc_weight   = TC_WEIGHT,    # 1.5
    pool_size   = 5,
    border_mult = 3.0,
    bce_frac    = 0.5,
):

    channel_weights = tf.constant(
        [wt_weight, et_weight, tc_weight], dtype=tf.float32)
    total_w = wt_weight + et_weight + tc_weight

    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.clip_by_value(tf.cast(y_pred, tf.float32), 1e-7, 1 - 1e-7)

        channel_losses = []
        for ch in range(3):
            y_t_ch = tf.expand_dims(y_true[..., ch], axis=-1)  # (B,H,W,1)
            y_p_ch = tf.expand_dims(y_pred[..., ch], axis=-1)

            w_map = _boundary_weight_map(y_t_ch, pool_size, border_mult)

            bce  = _weighted_bce_channel( y_t_ch, y_p_ch, w_map)
            dice = _weighted_dice_channel(y_t_ch, y_p_ch, w_map)

            ch_loss = bce_frac * bce + (1.0 - bce_frac) * dice
            channel_losses.append(ch_loss * channel_weights[ch])

        return tf.reduce_sum(tf.stack(channel_losses)) / total_w

    loss.__name__ = "weighted_boundary_loss"
    return loss


loss_fn = weighted_boundary_loss_fn()

# ── Pre-training loss check ────────────────────────────────────────────────────
print("\nLoss function: Weighted Boundary-Aware BCE + Dice (Rehman et al.)")
print(f"  pool_size={11}  border_mult=3.0  bce_frac=0.5")
print(f"  Channel weights: WT={WT_WEIGHT}  ET={ET_WEIGHT}  TC={TC_WEIGHT}")

for xb, yb in train_ds.take(1):
    out = model(xb, training=False)
    lv  = loss_fn(yb, out).numpy()
    print(f"\nPre-training check:  loss={lv:.4f}  "
          f"NaN={np.isnan(out.numpy()).any()}")
# Out:
# Loss function: Weighted Boundary-Aware BCE + Dice (Rehman et al.)
#   pool_size=11  border_mult=3.0  bce_frac=0.5
#   Channel weights: WT=0.5  ET=2.0  TC=1.5
#
# Pre-training check:  loss=0.8562  NaN=False

# %%
# Metrics

def soft_dice_per_channel(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    axes         = [1, 2]
    intersection = tf.reduce_sum(y_true * y_pred, axis=axes)   # (B, C)
    denom        = tf.reduce_sum(y_true + y_pred, axis=axes)   # (B, C)
    return (2.0 * intersection + smooth) / (denom + smooth)    # (B, C)


def dice_WT(y_true, y_pred, smooth=1e-6):
    return tf.reduce_mean(
        soft_dice_per_channel(y_true[..., 0:1], y_pred[..., 0:1], smooth)
    )

def dice_ET(y_true, y_pred, smooth=1e-6):
    return tf.reduce_mean(
        soft_dice_per_channel(y_true[..., 1:2], y_pred[..., 1:2], smooth)
    )

def dice_TC(y_true, y_pred, smooth=1e-6):
    return tf.reduce_mean(
        soft_dice_per_channel(y_true[..., 2:3], y_pred[..., 2:3], smooth)
    )

def dice_mean(y_true, y_pred, smooth=1e-6):
    return (dice_WT(y_true, y_pred, smooth) +
            dice_ET(y_true, y_pred, smooth) +
            dice_TC(y_true, y_pred, smooth)) / 3.0

def make_metrics():
    return [
        tf.keras.metrics.MeanMetricWrapper(dice_WT,   name="dice_WT"),
        tf.keras.metrics.MeanMetricWrapper(dice_ET,   name="dice_ET"),
        tf.keras.metrics.MeanMetricWrapper(dice_TC,   name="dice_TC"),
        tf.keras.metrics.MeanMetricWrapper(dice_mean, name="mean_dice"),
    ]


# ── Metric sanity check ────────────────────────────────────────────────────
print("\nMetric check ...")
_m = make_metrics()
for xb, yb in train_ds.take(1):
    _out = model(xb, training=False)
    for m in _m:
        m.update_state(yb, _out)
        print(f"  {m.name:<15} = {m.result().numpy():.4f}")
        m.reset_state()
del _m, _out
# Out:
# Metric check ...
#   dice_WT         = 0.0593
#   dice_ET         = 0.0311
#   dice_TC         = 0.0554
#   mean_dice       = 0.0486

# %%
# Compile

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=loss_fn,
    metrics=make_metrics()
)

for xb, yb in train_ds.take(1):
    out = model(xb, training=False)
    lv  = loss_fn(yb, out).numpy()
    print(f"\nPre-training check:  loss={lv:.4f}  NaN={np.isnan(out.numpy()).any()}")
# Out:
# Pre-training check:  loss=0.8497  NaN=False

# %%
callbacks = [
    ModelCheckpoint(
        filepath=BEST_MODEL_PATH,
        monitor="val_mean_dice",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    ModelCheckpoint(
        filepath=LAST_WEIGHTS_PATH,
        save_weights_only=True,
        verbose=0
    ),
    EarlyStopping(
        monitor="val_mean_dice",
        mode="max",
        patience=PATIENCE,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor="val_mean_dice",
        mode="max",
        factor=0.5,
        patience=5,
        min_lr=1e-7,
        verbose=0
    ),
    CSVLogger(LOG_PATH, append=True),
]

# %%
# Training

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - dice_ET: 0.5984 - dice_TC: 0.7037 - dice_WT: 0.7766 - loss: 0.0650 - mean_dice: 0.6929
# Epoch 1: val_mean_dice improved from None to 0.68395, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
# 771/771 ━━━━━━━━━━━━━━━━━━━━
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 50ms/step - dice_ET: 0.6490 - dice_TC: 0.7667 - dice_WT: 0.8274 - loss: 0.0474 - mean_dice: 0.7477 - val_dice_ET: 0.6297 - val_dice_TC: 0.7357 - val_dice_WT: 0.8081 - val_loss: 0.0574 - val_mean_dice: 0.7245
# Epoch 52/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6469 - dice_TC: 0.7680 - dice_WT: 0.8274 - loss: 0.0470 - mean_dice: 0.7474
# Epoch 52: val_mean_dice did not improve from 0.72739
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - dice_ET: 0.6497 - dice_TC: 0.7675 - dice_WT: 0.8284 - loss: 0.0470 - mean_dice: 0.7486 - val_dice_ET: 0.6299 - val_dice_TC: 0.7353 - val_dice_WT: 0.8092 - val_loss: 0.0574 - val_mean_dice: 0.7248
# Epoch 53/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6513 - dice_TC: 0.7687 - dice_WT: 0.8289 - loss: 0.0472 - mean_dice: 0.7496
# Epoch 53: val_mean_dice improved from 0.72739 to 0.72848, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
#
# Epoch 53: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 40s 52ms/step - dice_ET: 0.6515 - dice_TC: 0.7687 - dice_WT: 0.8293 - loss: 0.0469 - mean_dice: 0.7499 - val_dice_ET: 0.6316 - val_dice_TC: 0.7400 - val_dice_WT: 0.8138 - val_loss: 0.0570 - val_mean_dice: 0.7285
# Epoch 54/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6514 - dice_TC: 0.7662 - dice_WT: 0.8280 - loss: 0.0466 - mean_dice: 0.7486
# Epoch 54: val_mean_dice did not improve from 0.72848
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 50ms/step - dice_ET: 0.6511 - dice_TC: 0.7692 - dice_WT: 0.8301 - loss: 0.0467 - mean_dice: 0.7502 - val_dice_ET: 0.6309 - val_dice_TC: 0.7382 - val_dice_WT: 0.8143 - val_loss: 0.0571 - val_mean_dice: 0.7278
# Epoch 55/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6508 - dice_TC: 0.7670 - dice_WT: 0.8285 - loss: 0.0461 - mean_dice: 0.7488
# Epoch 55: val_mean_dice improved from 0.72848 to 0.73284, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
#
# Epoch 55: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 40s 52ms/step - dice_ET: 0.6517 - dice_TC: 0.7694 - dice_WT: 0.8306 - loss: 0.0463 - mean_dice: 0.7506 - val_dice_ET: 0.6383 - val_dice_TC: 0.7418 - val_dice_WT: 0.8184 - val_loss: 0.0578 - val_mean_dice: 0.7328
# Epoch 56/100
# 770/771 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - dice_ET: 0.6527 - dice_TC: 0.7709 - dice_WT: 0.8340 - loss: 0.0461 - mean_dice: 0.7525
# Epoch 56: val_mean_dice did not improve from 0.73284
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 50ms/step - dice_ET: 0.6525 - dice_TC: 0.7704 - dice_WT: 0.8317 - loss: 0.0462 - mean_dice: 0.7515 - val_dice_ET: 0.6347 - val_dice_TC: 0.7411 - val_dice_WT: 0.8112 - val_loss: 0.0571 - val_mean_dice: 0.7290
# Epoch 57/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6520 - dice_TC: 0.7714 - dice_WT: 0.8333 - loss: 0.0464 - mean_dice: 0.7522
# Epoch 57: val_mean_dice did not improve from 0.73284
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - dice_ET: 0.6530 - dice_TC: 0.7715 - dice_WT: 0.8317 - loss: 0.0461 - mean_dice: 0.7521 - val_dice_ET: 0.6362 - val_dice_TC: 0.7406 - val_dice_WT: 0.8160 - val_loss: 0.0563 - val_mean_dice: 0.7310
# Epoch 58/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6517 - dice_TC: 0.7715 - dice_WT: 0.8350 - loss: 0.0460 - mean_dice: 0.7527
# Epoch 58: val_mean_dice did not improve from 0.73284
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - dice_ET: 0.6542 - dice_TC: 0.7717 - dice_WT: 0.8326 - loss: 0.0457 - mean_dice: 0.7528 - val_dice_ET: 0.6336 - val_dice_TC: 0.7407 - val_dice_WT: 0.8144 - val_loss: 0.0560 - val_mean_dice: 0.7296
# Epoch 59/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6483 - dice_TC: 0.7698 - dice_WT: 0.8327 - loss: 0.0457 - mean_dice: 0.7503
# Epoch 59: val_mean_dice improved from 0.73284 to 0.73469, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
#
# Epoch 59: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 40s 52ms/step - dice_ET: 0.6553 - dice_TC: 0.7731 - dice_WT: 0.8332 - loss: 0.0455 - mean_dice: 0.7539 - val_dice_ET: 0.6398 - val_dice_TC: 0.7450 - val_dice_WT: 0.8192 - val_loss: 0.0560 - val_mean_dice: 0.7347
# Epoch 60/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6551 - dice_TC: 0.7725 - dice_WT: 0.8354 - loss: 0.0455 - mean_dice: 0.7543
# Epoch 60: val_mean_dice did not improve from 0.73469
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 50ms/step - dice_ET: 0.6546 - dice_TC: 0.7733 - dice_WT: 0.8340 - loss: 0.0456 - mean_dice: 0.7540 - val_dice_ET: 0.6361 - val_dice_TC: 0.7423 - val_dice_WT: 0.8196 - val_loss: 0.0554 - val_mean_dice: 0.7327
# Epoch 61/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6565 - dice_TC: 0.7762 - dice_WT: 0.8367 - loss: 0.0454 - mean_dice: 0.7565
# Epoch 61: val_mean_dice did not improve from 0.73469
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 50ms/step - dice_ET: 0.6554 - dice_TC: 0.7738 - dice_WT: 0.8344 - loss: 0.0452 - mean_dice: 0.7545 - val_dice_ET: 0.6379 - val_dice_TC: 0.7445 - val_dice_WT: 0.8204 - val_loss: 0.0556 - val_mean_dice: 0.7343
# Epoch 62/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6552 - dice_TC: 0.7735 - dice_WT: 0.8345 - loss: 0.0452 - mean_dice: 0.7544
# Epoch 62: val_mean_dice did not improve from 0.73469
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 44s 57ms/step - dice_ET: 0.6564 - dice_TC: 0.7753 - dice_WT: 0.8358 - loss: 0.0449 - mean_dice: 0.7558 - val_dice_ET: 0.6359 - val_dice_TC: 0.7436 - val_dice_WT: 0.8207 - val_loss: 0.0559 - val_mean_dice: 0.7334
# Epoch 63/100
# 770/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6580 - dice_TC: 0.7781 - dice_WT: 0.8378 - loss: 0.0449 - mean_dice: 0.7580
# Epoch 63: val_mean_dice improved from 0.73469 to 0.73648, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
#
# Epoch 63: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 40s 52ms/step - dice_ET: 0.6573 - dice_TC: 0.7762 - dice_WT: 0.8358 - loss: 0.0447 - mean_dice: 0.7564 - val_dice_ET: 0.6399 - val_dice_TC: 0.7459 - val_dice_WT: 0.8236 - val_loss: 0.0557 - val_mean_dice: 0.7365
# Epoch 64/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6608 - dice_TC: 0.7814 - dice_WT: 0.8386 - loss: 0.0444 - mean_dice: 0.7603
# Epoch 64: val_mean_dice did not improve from 0.73648
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - dice_ET: 0.6575 - dice_TC: 0.7767 - dice_WT: 0.8364 - loss: 0.0445 - mean_dice: 0.7569 - val_dice_ET: 0.6362 - val_dice_TC: 0.7445 - val_dice_WT: 0.8198 - val_loss: 0.0552 - val_mean_dice: 0.7335
# Epoch 65/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6567 - dice_TC: 0.7769 - dice_WT: 0.8368 - loss: 0.0440 - mean_dice: 0.7568
# Epoch 65: val_mean_dice did not improve from 0.73648
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - dice_ET: 0.6575 - dice_TC: 0.7763 - dice_WT: 0.8361 - loss: 0.0443 - mean_dice: 0.7566 - val_dice_ET: 0.6381 - val_dice_TC: 0.7444 - val_dice_WT: 0.8172 - val_loss: 0.0551 - val_mean_dice: 0.7332
# Epoch 66/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6575 - dice_TC: 0.7773 - dice_WT: 0.8376 - loss: 0.0443 - mean_dice: 0.7574
# Epoch 66: val_mean_dice did not improve from 0.73648
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - dice_ET: 0.6584 - dice_TC: 0.7776 - dice_WT: 0.8376 - loss: 0.0442 - mean_dice: 0.7579 - val_dice_ET: 0.6385 - val_dice_TC: 0.7455 - val_dice_WT: 0.8224 - val_loss: 0.0547 - val_mean_dice: 0.7355
# Epoch 67/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6525 - dice_TC: 0.7747 - dice_WT: 0.8354 - loss: 0.0442 - mean_dice: 0.7542
# Epoch 67: val_mean_dice improved from 0.73648 to 0.73796, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
#
# Epoch 67: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 40s 52ms/step - dice_ET: 0.6589 - dice_TC: 0.7785 - dice_WT: 0.8381 - loss: 0.0441 - mean_dice: 0.7585 - val_dice_ET: 0.6404 - val_dice_TC: 0.7490 - val_dice_WT: 0.8245 - val_loss: 0.0550 - val_mean_dice: 0.7380
# Epoch 68/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6601 - dice_TC: 0.7781 - dice_WT: 0.8375 - loss: 0.0437 - mean_dice: 0.7586
# Epoch 68: val_mean_dice did not improve from 0.73796
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 50ms/step - dice_ET: 0.6594 - dice_TC: 0.7790 - dice_WT: 0.8383 - loss: 0.0439 - mean_dice: 0.7589 - val_dice_ET: 0.6400 - val_dice_TC: 0.7482 - val_dice_WT: 0.8211 - val_loss: 0.0545 - val_mean_dice: 0.7364
# Epoch 69/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6611 - dice_TC: 0.7799 - dice_WT: 0.8393 - loss: 0.0438 - mean_dice: 0.7601
# Epoch 69: val_mean_dice did not improve from 0.73796
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - dice_ET: 0.6598 - dice_TC: 0.7798 - dice_WT: 0.8395 - loss: 0.0437 - mean_dice: 0.7597 - val_dice_ET: 0.6402 - val_dice_TC: 0.7487 - val_dice_WT: 0.8222 - val_loss: 0.0545 - val_mean_dice: 0.7370
# Epoch 70/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6600 - dice_TC: 0.7793 - dice_WT: 0.8391 - loss: 0.0438 - mean_dice: 0.7595
# Epoch 70: val_mean_dice did not improve from 0.73796
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - dice_ET: 0.6600 - dice_TC: 0.7801 - dice_WT: 0.8392 - loss: 0.0436 - mean_dice: 0.7598 - val_dice_ET: 0.6411 - val_dice_TC: 0.7474 - val_dice_WT: 0.8209 - val_loss: 0.0543 - val_mean_dice: 0.7365
# Epoch 71/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6597 - dice_TC: 0.7776 - dice_WT: 0.8357 - loss: 0.0436 - mean_dice: 0.7577
# Epoch 71: val_mean_dice did not improve from 0.73796
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 46s 59ms/step - dice_ET: 0.6606 - dice_TC: 0.7802 - dice_WT: 0.8389 - loss: 0.0434 - mean_dice: 0.7599 - val_dice_ET: 0.6401 - val_dice_TC: 0.7483 - val_dice_WT: 0.8225 - val_loss: 0.0546 - val_mean_dice: 0.7370
# Epoch 72/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6573 - dice_TC: 0.7813 - dice_WT: 0.8389 - loss: 0.0429 - mean_dice: 0.7592
# Epoch 72: val_mean_dice improved from 0.73796 to 0.73889, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
#
# Epoch 72: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 40s 52ms/step - dice_ET: 0.6605 - dice_TC: 0.7803 - dice_WT: 0.8402 - loss: 0.0434 - mean_dice: 0.7603 - val_dice_ET: 0.6423 - val_dice_TC: 0.7496 - val_dice_WT: 0.8247 - val_loss: 0.0540 - val_mean_dice: 0.7389
# Epoch 73/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6581 - dice_TC: 0.7819 - dice_WT: 0.8409 - loss: 0.0430 - mean_dice: 0.7603
# Epoch 73: val_mean_dice did not improve from 0.73889
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 44s 57ms/step - dice_ET: 0.6616 - dice_TC: 0.7816 - dice_WT: 0.8410 - loss: 0.0431 - mean_dice: 0.7614 - val_dice_ET: 0.6422 - val_dice_TC: 0.7503 - val_dice_WT: 0.8219 - val_loss: 0.0536 - val_mean_dice: 0.7381
# Epoch 74/100
# 770/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6613 - dice_TC: 0.7792 - dice_WT: 0.8383 - loss: 0.0431 - mean_dice: 0.7596
# Epoch 74: val_mean_dice did not improve from 0.73889
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 50ms/step - dice_ET: 0.6611 - dice_TC: 0.7809 - dice_WT: 0.8405 - loss: 0.0432 - mean_dice: 0.7608 - val_dice_ET: 0.6421 - val_dice_TC: 0.7497 - val_dice_WT: 0.8226 - val_loss: 0.0534 - val_mean_dice: 0.7381
# Epoch 75/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6645 - dice_TC: 0.7831 - dice_WT: 0.8427 - loss: 0.0428 - mean_dice: 0.7634
# Epoch 75: val_mean_dice improved from 0.73889 to 0.73919, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
#
# Epoch 75: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 40s 52ms/step - dice_ET: 0.6617 - dice_TC: 0.7812 - dice_WT: 0.8413 - loss: 0.0428 - mean_dice: 0.7614 - val_dice_ET: 0.6427 - val_dice_TC: 0.7509 - val_dice_WT: 0.8240 - val_loss: 0.0536 - val_mean_dice: 0.7392
# Epoch 76/100
# 770/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6619 - dice_TC: 0.7840 - dice_WT: 0.8440 - loss: 0.0430 - mean_dice: 0.7633
# Epoch 76: val_mean_dice improved from 0.73919 to 0.73947, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
#
# Epoch 76: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 40s 52ms/step - dice_ET: 0.6618 - dice_TC: 0.7812 - dice_WT: 0.8413 - loss: 0.0428 - mean_dice: 0.7614 - val_dice_ET: 0.6434 - val_dice_TC: 0.7505 - val_dice_WT: 0.8246 - val_loss: 0.0535 - val_mean_dice: 0.7395
# Epoch 77/100
# 770/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6682 - dice_TC: 0.7872 - dice_WT: 0.8450 - loss: 0.0425 - mean_dice: 0.7668
# Epoch 77: val_mean_dice improved from 0.73947 to 0.73994, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
#
# Epoch 77: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 40s 52ms/step - dice_ET: 0.6635 - dice_TC: 0.7834 - dice_WT: 0.8421 - loss: 0.0426 - mean_dice: 0.7630 - val_dice_ET: 0.6429 - val_dice_TC: 0.7509 - val_dice_WT: 0.8261 - val_loss: 0.0535 - val_mean_dice: 0.7399
# Epoch 78/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6667 - dice_TC: 0.7851 - dice_WT: 0.8433 - loss: 0.0426 - mean_dice: 0.7650
# Epoch 78: val_mean_dice improved from 0.73994 to 0.74068, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
#
# Epoch 78: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - dice_ET: 0.6627 - dice_TC: 0.7828 - dice_WT: 0.8419 - loss: 0.0427 - mean_dice: 0.7625 - val_dice_ET: 0.6433 - val_dice_TC: 0.7519 - val_dice_WT: 0.8268 - val_loss: 0.0538 - val_mean_dice: 0.7407
# Epoch 79/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6616 - dice_TC: 0.7819 - dice_WT: 0.8399 - loss: 0.0427 - mean_dice: 0.7611
# Epoch 79: val_mean_dice did not improve from 0.74068
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - dice_ET: 0.6630 - dice_TC: 0.7829 - dice_WT: 0.8419 - loss: 0.0425 - mean_dice: 0.7626 - val_dice_ET: 0.6427 - val_dice_TC: 0.7507 - val_dice_WT: 0.8259 - val_loss: 0.0534 - val_mean_dice: 0.7398
# Epoch 80/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6638 - dice_TC: 0.7815 - dice_WT: 0.8404 - loss: 0.0422 - mean_dice: 0.7619
# Epoch 80: val_mean_dice improved from 0.74068 to 0.74151, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
#
# Epoch 80: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 40s 52ms/step - dice_ET: 0.6641 - dice_TC: 0.7842 - dice_WT: 0.8436 - loss: 0.0422 - mean_dice: 0.7639 - val_dice_ET: 0.6442 - val_dice_TC: 0.7530 - val_dice_WT: 0.8274 - val_loss: 0.0530 - val_mean_dice: 0.7415
# Epoch 81/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6659 - dice_TC: 0.7862 - dice_WT: 0.8462 - loss: 0.0422 - mean_dice: 0.7661
# Epoch 81: val_mean_dice did not improve from 0.74151
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 50s 65ms/step - dice_ET: 0.6635 - dice_TC: 0.7839 - dice_WT: 0.8430 - loss: 0.0424 - mean_dice: 0.7635 - val_dice_ET: 0.6434 - val_dice_TC: 0.7517 - val_dice_WT: 0.8256 - val_loss: 0.0530 - val_mean_dice: 0.7402
# Epoch 82/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6579 - dice_TC: 0.7783 - dice_WT: 0.8391 - loss: 0.0420 - mean_dice: 0.7584
# Epoch 82: val_mean_dice did not improve from 0.74151
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 42s 54ms/step - dice_ET: 0.6640 - dice_TC: 0.7847 - dice_WT: 0.8440 - loss: 0.0421 - mean_dice: 0.7642 - val_dice_ET: 0.6447 - val_dice_TC: 0.7527 - val_dice_WT: 0.8263 - val_loss: 0.0528 - val_mean_dice: 0.7412
# Epoch 83/100
# 770/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6573 - dice_TC: 0.7785 - dice_WT: 0.8387 - loss: 0.0422 - mean_dice: 0.7582
# Epoch 83: val_mean_dice did not improve from 0.74151
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 50ms/step - dice_ET: 0.6643 - dice_TC: 0.7847 - dice_WT: 0.8436 - loss: 0.0421 - mean_dice: 0.7642 - val_dice_ET: 0.6420 - val_dice_TC: 0.7511 - val_dice_WT: 0.8251 - val_loss: 0.0531 - val_mean_dice: 0.7394
# Epoch 84/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6669 - dice_TC: 0.7878 - dice_WT: 0.8437 - loss: 0.0420 - mean_dice: 0.7661
# Epoch 84: val_mean_dice did not improve from 0.74151
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 44s 57ms/step - dice_ET: 0.6638 - dice_TC: 0.7848 - dice_WT: 0.8440 - loss: 0.0419 - mean_dice: 0.7642 - val_dice_ET: 0.6437 - val_dice_TC: 0.7527 - val_dice_WT: 0.8266 - val_loss: 0.0529 - val_mean_dice: 0.7410
# Epoch 85/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6555 - dice_TC: 0.7794 - dice_WT: 0.8402 - loss: 0.0419 - mean_dice: 0.7584
# Epoch 85: val_mean_dice improved from 0.74151 to 0.74190, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
#
# Epoch 85: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 47s 61ms/step - dice_ET: 0.6647 - dice_TC: 0.7856 - dice_WT: 0.8441 - loss: 0.0419 - mean_dice: 0.7648 - val_dice_ET: 0.6451 - val_dice_TC: 0.7537 - val_dice_WT: 0.8269 - val_loss: 0.0530 - val_mean_dice: 0.7419
# Epoch 86/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6651 - dice_TC: 0.7831 - dice_WT: 0.8434 - loss: 0.0415 - mean_dice: 0.7639
# Epoch 86: val_mean_dice improved from 0.74190 to 0.74253, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
#
# Epoch
100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6684 - dice_TC: 0.7892 - dice_WT: 0.8473 - loss: 0.0417 - mean_dice: 0.7683
# Epoch 94: val_mean_dice did not improve from 0.74253
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 46s 59ms/step - dice_ET: 0.6658 - dice_TC: 0.7862 - dice_WT: 0.8451 - loss: 0.0416 - mean_dice: 0.7657 - val_dice_ET: 0.6455 - val_dice_TC: 0.7541 - val_dice_WT: 0.8274 - val_loss: 0.0524 - val_mean_dice: 0.7423
# Epoch 95/100
# 770/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6677 - dice_TC: 0.7887 - dice_WT: 0.8447 - loss: 0.0413 - mean_dice: 0.7670
# Epoch 95: val_mean_dice improved from 0.74253 to 0.74253, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
#
# Epoch 95: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 47s 60ms/step - dice_ET: 0.6665 - dice_TC: 0.7870 - dice_WT: 0.8456 - loss: 0.0415 - mean_dice: 0.7664 - val_dice_ET: 0.6459 - val_dice_TC: 0.7544 - val_dice_WT: 0.8273 - val_loss: 0.0525 - val_mean_dice: 0.7425
# Epoch 96/100
# 770/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6672 - dice_TC: 0.7868 - dice_WT: 0.8460 - loss: 0.0417 - mean_dice: 0.7667
# Epoch 96: val_mean_dice improved from 0.74253 to 0.74290, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
#
# Epoch 96: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/best_model.keras
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 45s 58ms/step - dice_ET: 0.6655 - dice_TC: 0.7861 - dice_WT: 0.8448 - loss: 0.0416 - mean_dice: 0.7654 - val_dice_ET: 0.6463 - val_dice_TC: 0.7545 - val_dice_WT: 0.8279 - val_loss: 0.0525 - val_mean_dice: 0.7429
# Epoch 97/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6706 - dice_TC: 0.7910 - dice_WT: 0.8485 - loss: 0.0415 - mean_dice: 0.7700
# Epoch 97: val_mean_dice did not improve from 0.74290
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 45s 58ms/step - dice_ET: 0.6670 - dice_TC: 0.7872 - dice_WT: 0.8458 - loss: 0.0415 - mean_dice: 0.7667 - val_dice_ET: 0.6460 - val_dice_TC: 0.7546 - val_dice_WT: 0.8280 - val_loss: 0.0524 - val_mean_dice: 0.7429
# Epoch 98/100
# 770/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6637 - dice_TC: 0.7834 - dice_WT: 0.8439 - loss: 0.0415 - mean_dice: 0.7637
# Epoch 98: val_mean_dice did not improve from 0.74290
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - dice_ET: 0.6650 - dice_TC: 0.7858 - dice_WT: 0.8451 - loss: 0.0415 - mean_dice: 0.7653 - val_dice_ET: 0.6459 - val_dice_TC: 0.7545 - val_dice_WT: 0.8276 - val_loss: 0.0524 - val_mean_dice: 0.7427
# Epoch 99/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6653 - dice_TC: 0.7856 - dice_WT: 0.8421 - loss: 0.0412 - mean_dice: 0.7643
# Epoch 99: val_mean_dice did not improve from 0.74290
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - dice_ET: 0.6664 - dice_TC: 0.7877 - dice_WT: 0.8457 - loss: 0.0414 - mean_dice: 0.7666 - val_dice_ET: 0.6456 - val_dice_TC: 0.7546 - val_dice_WT: 0.8279 - val_loss: 0.0526 - val_mean_dice: 0.7427
# Epoch 100/100
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6647 - dice_TC: 0.7846 - dice_WT: 0.8429 - loss: 0.0411 - mean_dice: 0.7641
# Epoch 100: val_mean_dice did not improve from 0.74290
# 771/771 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - dice_ET: 0.6666 - dice_TC: 0.7877 - dice_WT: 0.8460 - loss: 0.0413 - mean_dice: 0.7667 - val_dice_ET: 0.6459 - val_dice_TC: 0.7545 - val_dice_WT: 0.8279 - val_loss: 0.0525 - val_mean_dice: 0.7428
# Restoring model weights from the end of the best epoch: 96.

# %%
# Training Curves

def plot_training_curves(history, save_path):
    hist   = history.history
    epochs = range(1, len(hist["loss"]) + 1)

    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    fig.suptitle("Training & Validation Curves", fontsize=14)

    # Loss
    ax = axes[0, 0]
    ax.plot(epochs, hist["loss"],     label="Train", color="steelblue")
    ax.plot(epochs, hist["val_loss"], label="Val",   color="tomato", linestyle="--")
    ax.set_title("Loss")
    ax.set_xlabel("Epoch"); ax.legend(); ax.grid(True, alpha=0.3)

    # Mean Dice
    ax = axes[0, 1]
    ax.plot(epochs, hist["mean_dice"],     label="Train", color="steelblue")
    ax.plot(epochs, hist["val_mean_dice"], label="Val",   color="tomato", linestyle="--")
    ax.set_title("Mean Dice")
    ax.set_xlabel("Epoch"); ax.legend(); ax.grid(True, alpha=0.3)

    # Learning rate
    ax = axes[0, 2]
    if "lr" in hist:
        ax.semilogy(epochs, hist["lr"], color="purple")
    ax.set_title("Learning Rate (log scale)")
    ax.set_xlabel("Epoch"); ax.grid(True, alpha=0.3)

    # Per-region Dice
    region_cfg = [
        ("dice_WT", "val_dice_WT", "WT Dice", "royalblue"),
        ("dice_ET", "val_dice_ET", "ET Dice", "tomato"),
        ("dice_TC", "val_dice_TC", "TC Dice", "darkorange"),
    ]
    for idx, (tr_key, val_key, title, color) in enumerate(region_cfg):
        ax = axes[1, idx]
        if tr_key  in hist: ax.plot(epochs, hist[tr_key],  label="Train",
                                    color=color)
        if val_key in hist: ax.plot(epochs, hist[val_key], label="Val",
                                    color=color, linestyle="--", alpha=0.7)
        ax.set_title(title)
        ax.set_xlabel("Epoch"); ax.legend(); ax.grid(True, alpha=0.3)

    fig.tight_layout()
    save_and_show(fig, save_path, "training curves")

plot_training_curves(history, CURVES_PATH)
# Out:
# Saved → /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/training_curves.png  (training curves)

# %%
# Evaluation on Test Set

print("\n" + "="*58)
print("  Evaluating on Test  (best model weights)")
print("="*58)

test_results = model.evaluate(test_ds, verbose=1)
metric_names = model.metrics_names

print("\n ")
print("   Test Evaluation:         ")

for name, val in zip(metric_names, test_results):
    print(f"  {name:<24s}: {val:.4f}  ")


with open(EVAL_PATH, "w") as f:
    f.write("=" * 52 + "\n")
    f.write("  Test Evaluation Results\n")
    f.write("=" * 52 + "\n")
    for name, val in zip(metric_names, test_results):
        f.write(f"  {name:<28s}: {val:.6f}\n")
    f.write("=" * 52 + "\n")

print(f"\nEvaluation results saved → {EVAL_PATH}")
# Out:
# ==========================================================
#   Evaluating on Test  (best model weights)
# ==========================================================
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - dice_ET: 0.6312 - dice_TC: 0.7386 - dice_WT: 0.8117 - loss: 0.0526 - mean_dice: 0.7272
#
#
#    Test Evaluation:
#   loss                    : 0.0526
#   compile_metrics         : 0.8117
#
# Evaluation results saved → /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run82/evaluation_results.txt
