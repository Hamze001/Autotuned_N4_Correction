# %%
pip install nilearn
# Out:
# Collecting nilearn
#   Downloading nilearn-0.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from nilearn) (3.1.6)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (1.5.3)
# Requirement already satisfied: nibabel>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (5.4.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.12/dist-packages (from nilearn) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from nilearn) (26.0)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (2.2.2)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (2.32.4)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (1.6.1)
# Requirement already satisfied: scipy>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (1.16.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1.2->nilearn) (3.0.3)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.12/dist-packages (from nibabel>=5.2.0->nilearn) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->nilearn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->nilearn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->nilearn) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (2026.2.25)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.0->nilearn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->nilearn) (1.17.0)
# Downloading nilearn-0.13.1-py3-none-any.whl (10.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 132.1 MB/s eta 0:00:00
# Installing collected packages: nilearn
# Successfully installed nilearn-0.13.1

# %%
import os
import cv2
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
from skimage import data
from skimage.util import montage
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps

import nilearn as nl
import nibabel as nib
import nilearn.plotting as nlplt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom, Rescaling
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam

from scipy.spatial.distance import directed_hausdorff
from scipy.ndimage import binary_erosion, generate_binary_structure
from scipy.spatial.distance import cdist

np.set_printoptions(precision=3, suppress=True)
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import (
    EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
)
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split

import matplotlib
matplotlib.use("module://ipykernel.pylab.backend_inline")
import matplotlib.pyplot as plt
plt.rcParams["figure.dpi"] = 110

print("TensorFlow:", tf.__version__)
print("Keras:     ", tf.keras.__version__)
print("GPU:", tf.config.list_physical_devices("GPU"))
tf.keras.backend.set_floatx("float32")

SAVE_DIR = "/content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79"
os.makedirs(SAVE_DIR, exist_ok=True)
# Out:
# TensorFlow: 2.19.0
# Keras:      3.13.2
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Paths & Configuration

BEST_MODEL_PATH   = os.path.join(SAVE_DIR, "best_model.keras")
LAST_WEIGHTS_PATH = os.path.join(SAVE_DIR, "last.weights.h5")
LOG_PATH          = os.path.join(SAVE_DIR, "history.csv")
CURVES_PATH       = os.path.join(SAVE_DIR, "training_curves.png")
PREDS_PATH        = os.path.join(SAVE_DIR, "predictions.png")
EVAL_PATH         = os.path.join(SAVE_DIR, "evaluation_results.txt")


IMG_HEIGHT    = 160
IMG_WIDTH     = 160
IN_CHANNELS   = 4
OUT_CHANNELS  = 3
BASE_FILTERS  = 64
GROUPS        = 8

BATCH_SIZE    = 16
EPOCHS        = 100
LEARNING_RATE = 1e-4
PATIENCE      = 10
VAL_SPLIT     = 0.15
TEST_SPLIT    = 0.15
SEED          = 42

WT_WEIGHT     = 0.5
ET_WEIGHT     = 2.0
TC_WEIGHT     = 1.5

KEEP_TIER_A   = 1.00
KEEP_TIER_B   = 0.60
KEEP_TIER_C   = 0.15
KEEP_TIER_D   = 0.05
MIN_ET_VOXELS = 5
MIN_TC_VOXELS = 10
MIN_WT_VOXELS = 10

CHANNEL_NAMES   = ["WT", "ET", "TC"]
CHANNEL_WEIGHTS = [WT_WEIGHT, ET_WEIGHT, TC_WEIGHT]

# %%
# save figure to Drive AND display inline

def save_and_show(fig, save_path, caption=""):
    fig.savefig(save_path, dpi=150, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print(f"Saved → {save_path}" + (f"  ({caption})" if caption else ""))

# %%
# Data Loading

from zipfile import ZipFile
with ZipFile('/content/drive/MyDrive/BRAIN2018_DeCORRECTED_NORMALIZED_CROPPED160.zip', 'r') as z:
    z.extractall('/content/CROPPED2018')

BRAIN2018_CROPPED = "/content/CROPPED2018"


def create_multimodal_image(dataset_root_dir):
    modalities = ["t1", "t1ce", "t2", "flair"]
    data, grade = {}, {}
    for gf in ["HGG", "LGG"]:
        gp = os.path.join(dataset_root_dir, gf)
        if not os.path.exists(gp):
            continue
        for pid in os.listdir(gp):
            pd_ = os.path.join(gp, pid)
            if not os.path.isdir(pd_):
                continue
            imgs, ok = [], True
            for mod in modalities:
                fp = os.path.join(pd_, f"{pid}_{mod}_n4.nii")
                if not os.path.exists(fp):
                    ok = False; break
                imgs.append(nib.load(fp).get_fdata().astype(np.float32))
            if ok:
                data[pid]  = np.stack(imgs, axis=-1)
                grade[pid] = gf
    return data, grade


def create_combined_label_masks(seg_path):
    seg = nib.load(seg_path).get_fdata().astype(np.uint8)
    return np.stack([
        np.isin(seg, [1, 2, 4]).astype(np.float32),   # WT
        (seg == 4).astype(np.float32),                  # ET
        np.isin(seg, [1, 4]).astype(np.float32),        # TC
    ], axis=-1)


def load_all_patients(root):
    mdata, mgrade = create_multimodal_image(root)
    pids, grades, xvols, yvols = [], [], [], []
    for pid in mdata:
        for gf in ["HGG", "LGG"]:
            sp = os.path.join(root, gf, pid, f"{pid}_seg_n4.nii")
            if os.path.exists(sp):
                xv = mdata[pid]; yv = create_combined_label_masks(sp)
                if xv.shape[:3] == yv.shape[:3]:
                    pids.append(pid); grades.append(mgrade[pid])
                    xvols.append(xv);  yvols.append(yv)
                break
    print(f"Loaded {len(xvols)} patients")
    return pids, grades, xvols, yvols


patient_ids, grades, X_volumes, Y_volumes = load_all_patients(BRAIN2018_CROPPED)
# Out:
# Loaded 285 patients

# %%
# Volume Cleaning

def clean_volumes(xvols):
    return [
        np.clip(np.nan_to_num(x, nan=0., posinf=0., neginf=0.), -5., 5.)
        for x in xvols
    ]

X_volumes = clean_volumes(X_volumes)

# %%
# Balanced Slice Extraction

def volumes_to_2d_slices_balanced(
    x_volumes, y_volumes,
    min_et_voxels=MIN_ET_VOXELS, min_tc_voxels=MIN_TC_VOXELS,
    min_wt_voxels=MIN_WT_VOXELS,
    keep_tier_a=KEEP_TIER_A, keep_tier_b=KEEP_TIER_B,
    keep_tier_c=KEEP_TIER_C, keep_tier_d=KEEP_TIER_D, seed=SEED,
):
    rng = np.random.default_rng(seed)
    xl, yl, tl = [], [], []
    counts = {t: 0 for t in ["A","B","C","D","A_skip","B_skip","C_skip","D_skip"]}
    for xv, yv in zip(x_volumes, y_volumes):
        for d in range(xv.shape[2]):
            xs = xv[:, :, d, :]; ys = yv[:, :, d, :]
            wt_fg = int(ys[..., 0].sum()) >= min_wt_voxels
            tc_fg = int(ys[..., 2].sum()) >= min_tc_voxels
            et_fg = int(ys[..., 1].sum()) >= min_et_voxels
            if   wt_fg and tc_fg and et_fg: tier, rate = "A", keep_tier_a
            elif wt_fg and tc_fg:           tier, rate = "B", keep_tier_b
            elif wt_fg:                     tier, rate = "C", keep_tier_c
            else:                           tier, rate = "D", keep_tier_d
            if rng.random() < rate:
                xl.append(xs); yl.append(ys); tl.append(tier)
                counts[tier] += 1
            else:
                counts[f"{tier}_skip"] += 1
    X = np.array(xl, np.float32); Y = np.array(yl, np.float32)
    descs = {"A":"WT+TC+ET","B":"WT+TC (no ET)","C":"WT only","D":"no fg"}
    print("\n" + "="*58)
    print("  Balanced Slice Extraction")
    print("="*58)
    for t in ["A","B","C","D"]:
        print(f"  Tier {t} ({descs[t]:<16}): "
              f"kept={counts[t]:5d}  skipped={counts[t+'_skip']:5d}")
    print(f"  Total: {len(X)}")
    print("="*58)
    return X, Y, tl


def print_slice_balance(Y, tier_labels, split_name="Dataset"):
    wt_v = Y[...,0].sum(axis=(1,2)); et_v = Y[...,1].sum(axis=(1,2))
    tc_v = Y[...,2].sum(axis=(1,2)); N = len(Y)
    tc = {t: tier_labels.count(t) for t in ["A","B","C","D"]}
    print(f"\n  [{split_name}]  {N} slices  "
          f"A={tc['A']} B={tc['B']} C={tc['C']} D={tc['D']}")
    for name, v in [("WT", wt_v), ("ET", et_v), ("TC", tc_v)]:
        print(f"    {name}: {(v>0).mean()*100:5.1f}% present  "
              f"mean={v.mean():.1f} vox")
    print(f"    Nesting: ET≤TC={(et_v<=tc_v+1).all()}  "
          f"TC≤WT={(tc_v<=wt_v+1).all()}")


X_sl, Y_sl, tier_labels = volumes_to_2d_slices_balanced(X_volumes, Y_volumes)
del X_volumes, Y_volumes
print_slice_balance(Y_sl, tier_labels, "Full balanced dataset")
# Out:
# ==========================================================
#   Balanced Slice Extraction
# ==========================================================
#   Tier A (WT+TC+ET        ): kept=10288  skipped=    0
#   Tier B (WT+TC (no ET)   ): kept= 1412  skipped=  973
#   Tier C (WT only         ): kept=  855  skipped= 4874
#   Tier D (no fg           ): kept=  926  skipped=17152
#   Total: 13481
# ==========================================================
#
#   [Full balanced dataset]  13481 slices  A=10288 B=1412 C=855 D=926
#     WT:  93.3% present  mean=1765.1 vox
#     ET:  77.2% present  mean=384.1 vox
#     TC:  87.2% present  mean=834.7 vox
#     Nesting: ET≤TC=True  TC≤WT=True

# %%
# Train / Val / Test Split  (70% / 15% / 15%)

X_trainval, X_test, Y_trainval, Y_test, tl_trainval, tl_test = train_test_split(
    X_sl, Y_sl, tier_labels,
    test_size=TEST_SPLIT, random_state=SEED, shuffle=True
)

val_fraction_of_trainval = VAL_SPLIT / (1.0 - TEST_SPLIT)

X_train, X_val, Y_train, Y_val, tl_train, tl_val = train_test_split(
    X_trainval, Y_trainval, tl_trainval,
    test_size=val_fraction_of_trainval, random_state=SEED, shuffle=True
)

del X_sl, Y_sl, X_trainval, Y_trainval

print("\nAfter split:")
print_slice_balance(Y_train, tl_train, "Train  (~70%)")
print_slice_balance(Y_val,   tl_val,   "Val    (~15%)")
print_slice_balance(Y_test,  tl_test,  "Test   (~15%)")
print(f"\nTrain : {X_train.shape}"
      f"\nVal   : {X_val.shape}"
      f"\nTest  : {X_test.shape}")
# Out:
# After split:
#
#   [Train  (~70%)]  9435 slices  A=7197 B=989 C=590 D=659
#     WT:  93.2% present  mean=1764.9 vox
#     ET:  77.1% present  mean=386.1 vox
#     TC:  87.1% present  mean=835.2 vox
#     Nesting: ET≤TC=True  TC≤WT=True
#
#   [Val    (~15%)]  2023 slices  A=1558 B=213 C=128 D=124
#     WT:  93.9% present  mean=1776.1 vox
#     ET:  78.1% present  mean=381.4 vox
#     TC:  87.8% present  mean=836.0 vox
#     Nesting: ET≤TC=True  TC≤WT=True
#
#   [Test   (~15%)]  2023 slices  A=1533 B=210 C=137 D=143
#     WT:  93.1% present  mean=1754.5 vox
#     ET:  76.8% present  mean=377.4 vox
#     TC:  86.8% present  mean=830.8 vox
#     Nesting: ET≤TC=True  TC≤WT=True
#
# Train : (9435, 160, 160, 4)
# Val   : (2023, 160, 160, 4)
# Test  : (2023, 160, 160, 4)

# %%
# tf.data Pipeline

AUTOTUNE = tf.data.AUTOTUNE


def augment(img, msk):

    # Zoom (±20%)
    zoom = tf.random.uniform([], 0.8, 1.2)

    h = tf.shape(img)[0]
    w = tf.shape(img)[1]

    new_h = tf.cast(tf.cast(h, tf.float32) * zoom, tf.int32)
    new_w = tf.cast(tf.cast(w, tf.float32) * zoom, tf.int32)

    img = tf.image.resize(img, (new_h, new_w), method='bilinear')
    msk = tf.image.resize(msk, (new_h, new_w), method='nearest')

    img = tf.image.resize_with_crop_or_pad(img, h, w)
    msk = tf.image.resize_with_crop_or_pad(msk, h, w)


    # Width & Height Shift (±20%)
    max_dx = tf.cast(0.2 * tf.cast(w, tf.float32), tf.int32)
    max_dy = tf.cast(0.2 * tf.cast(h, tf.float32), tf.int32)

    dx = tf.random.uniform([], -max_dx, max_dx, dtype=tf.int32)
    dy = tf.random.uniform([], -max_dy, max_dy, dtype=tf.int32)

    img = tf.roll(img, shift=[dy, dx], axis=[0, 1])
    msk = tf.roll(msk, shift=[dy, dx], axis=[0, 1])

    #Flip
    if tf.random.uniform(()) > 0.2:
      img = tf.image.flip_left_right(img)
      msk = tf.image.flip_left_right(msk)
    if tf.random.uniform(()) > 0.2:
      img = tf.image.flip_up_down(img)
      msk = tf.image.flip_up_down(msk)

    return img, msk


def make_dataset(X, Y, training=False):
    ds = tf.data.Dataset.from_tensor_slices((X, Y))
    if training:
        ds = ds.shuffle(len(X), seed=SEED).map(augment, num_parallel_calls=AUTOTUNE)
    return ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)


train_ds = make_dataset(X_train, Y_train, training=True)
val_ds   = make_dataset(X_val,   Y_val,   training=False)
test_ds  = make_dataset(X_test,  Y_test,  training=False)

print(f"\nTrain batches : {len(train_ds)}"
      f"\nVal   batches : {len(val_ds)}"
      f"\nTest  batches : {len(test_ds)}")
# Out:
# Train batches : 590
# Val   batches : 127
# Test  batches : 127

# %%
# U-Net Architecture

def conv_block(x, filters, groups=GROUPS):

    for _ in range(2):
        x = layers.Conv2D(
            filters, 3, padding="same", use_bias=False,
            kernel_initializer="he_normal"
        )(x)
        x = layers.GroupNormalization(groups=groups)(x)
        x = layers.Activation("relu")(x)
    return x


def encoder_block(x, filters):

    skip = conv_block(x, filters)
    pool = layers.MaxPooling2D(2)(skip)
    return skip, pool


def decoder_block(x, skip, filters):

    x = layers.Conv2DTranspose(
        filters, 2, strides=2, padding="same",
        kernel_initializer="he_normal"
    )(x)
    x = layers.Concatenate()([x, skip])
    x = conv_block(x, filters)
    return x


def build_unet(
    img_height=IMG_HEIGHT, img_width=IMG_WIDTH,
    in_channels=IN_CHANNELS, out_channels=OUT_CHANNELS,
    base_filters=BASE_FILTERS, dropout_rate=0.3
):

    inputs = layers.Input(
        shape=(img_height, img_width, in_channels), name="input"
    )

    # ── Encoder ────────────────────────────────────────────────────────────
    s1, p1 = encoder_block(inputs, base_filters)         # filters=64
    s2, p2 = encoder_block(p1,     base_filters * 2)     # filters=128
    s3, p3 = encoder_block(p2,     base_filters * 4)     # filters=256
    s4, p4 = encoder_block(p3,     base_filters * 8)     # filters=512

    # ── Bottleneck ─────────────────────────────────────────────────────────
    b = conv_block(p4, base_filters * 16)                # filters=1024
    b = layers.Dropout(dropout_rate)(b)

    # ── Decoder ────────────────────────────────────────────────────────────
    d4 = decoder_block(b,  s4, base_filters * 8)         # filters=512
    d3 = decoder_block(d4, s3, base_filters * 4)         # filters=256
    d2 = decoder_block(d3, s2, base_filters * 2)         # filters=128
    d1 = decoder_block(d2, s1, base_filters)             # filters=64

    # ── Output ────────────────────────────────────────────────────────
    outputs = layers.Conv2D(
        out_channels, 1, activation="sigmoid", name="output"
    )(d1)

    return Model(inputs, outputs, name="UNet_2D")


model = build_unet()
model.summary()
# Out:
# Model: "UNet_2D"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 160, 160,  │          0 │ -                 │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 160, 160,  │      2,304 │ input[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalization │ (None, 160, 160,  │        128 │ conv2d[0][0]      │
# │ (GroupNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 160, 160,  │          0 │ group_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 160, 160,  │     36,864 │ activation[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 160, 160,  │        128 │ conv2d_1[0][0]    │
# │ (GroupNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 160, 160,  │          0 │ group_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 80, 80,    │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 80, 80,    │     73,728 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 80, 80,    │        256 │ conv2d_2[0][0]    │
# │ (GroupNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 80, 80,    │          0 │ group_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 80, 80,    │    147,456 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 80, 80,    │        256 │ conv2d_3[0][0]    │
# │ (GroupNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 80, 80,    │          0 │ group_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 40, 40,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 40, 40,    │    294,912 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 40, 40,    │        512 │ conv2d_4[0][0]    │
# │ (GroupNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 40, 40,    │          0 │ group_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 40, 40,    │    589,824 │ activation_4[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 40, 40,    │        512 │ conv2d_5[0][0]    │
# │ (GroupNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 40, 40,    │          0 │ group_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 20, 20,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 20, 20,    │  1,179,648 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 20, 20,    │      1,024 │ conv2d_6[0][0]    │
# │ (GroupNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 20, 20,    │          0 │ group_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 20, 20,    │  2,359,296 │ activation_6[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 20, 20,    │      1,024 │ conv2d_7[0][0]    │
# │ (GroupNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 20, 20,    │          0 │ group_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 10, 10,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 10, 10,    │  4,718,592 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 10, 10,    │      2,048 │ conv2d_8[0][0]    │
# │ (GroupNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 10, 10,    │          0 │ group_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 10, 10,    │  9,437,184 │ activation_8[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 10, 10,    │      2,048 │ conv2d_9[0][0]    │
# │ (GroupNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 10, 10,    │          0 │ group_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 10, 10,    │          0 │ activation_9[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 20, 20,    │  2,097,664 │ dropout[0][0]     │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 20, 20,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 20, 20,    │  4,718,592 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 20, 20,    │      1,024 │ conv2d_10[0][0]   │
# │ (GroupNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 20, 20,    │          0 │ group_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 20, 20,    │  2,359,296 │ activation_10[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 20, 20,    │      1,024 │ conv2d_11[0][0]   │
# │ (GroupNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 20, 20,    │          0 │ group_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 40, 40,    │    524,544 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 40, 40,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 40, 40,    │  1,179,648 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 40, 40,    │        512 │ conv2d_12[0][0]   │
# │ (GroupNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 40, 40,    │          0 │ group_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 40, 40,    │    589,824 │ activation_12[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 40, 40,    │        512 │ conv2d_13[0][0]   │
# │ (GroupNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 40, 40,    │          0 │ group_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 80, 80,    │    131,200 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 80, 80,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 80, 80,    │    294,912 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 80, 80,    │        256 │ conv2d_14[0][0]   │
# │ (GroupNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 80, 80,    │          0 │ group_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 80, 80,    │    147,456 │ activation_14[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 80, 80,    │        256 │ conv2d_15[0][0]   │
# │ (GroupNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 80, 80,    │          0 │ group_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 160, 160,  │     32,832 │ activation_15[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 160, 160,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 160, 160,  │     73,728 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 160, 160,  │        128 │ conv2d_16[0][0]   │
# │ (GroupNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 160, 160,  │          0 │ group_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 160, 160,  │     36,864 │ activation_16[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 160, 160,  │        128 │ conv2d_17[0][0]   │
# │ (GroupNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 160, 160,  │          0 │ group_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Conv2D)     │ (None, 160, 160,  │        195 │ activation_17[0]… │
# │                     │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,038,339 (118.40 MB)
#  Trainable params: 31,038,339 (118.40 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Loss Function

def _boundary_weight_map(y_true_ch, pool_size=11, border_weight=3.0):

    averaged = tf.nn.avg_pool2d(
        y_true_ch,
        ksize=pool_size,
        strides=1,
        padding="SAME"
    )                                      # (B, H, W, 1)

    border = tf.cast(averaged > 0.005, tf.float32) * \
             tf.cast(averaged < 0.995, tf.float32)   # (B, H, W, 1)

    weight  = tf.ones_like(averaged)
    w0      = tf.reduce_sum(weight)
    weight  = weight + border * (border_weight - 1.0)
    w1      = tf.reduce_sum(weight)

    weight  = weight * (w0 / (w1 + 1e-8))
    return weight


def _weighted_bce_channel(y_true_ch, y_pred_ch, weight):

    epsilon   = 1e-7
    y_pred_ch = tf.clip_by_value(y_pred_ch, epsilon, 1.0 - epsilon)
    logit     = tf.math.log(y_pred_ch / (1.0 - y_pred_ch))

    bce = ((1.0 - y_true_ch) * logit
           + (1.0 + (weight - 1.0) * y_true_ch)
           * (tf.math.log(1.0 + tf.exp(-tf.abs(logit)))
              + tf.maximum(-logit, 0.0)))

    return tf.reduce_sum(bce) / (tf.reduce_sum(weight) + 1e-8)


def _weighted_dice_channel(y_true_ch, y_pred_ch, weight, smooth=1.0):

    w   = weight * weight
    m1  = y_true_ch
    m2  = y_pred_ch
    intersection = tf.reduce_sum(w * m1 * m2)
    denom        = tf.reduce_sum(w * (m1 ** 2)) + tf.reduce_sum(w * (m2 ** 2))
    score        = (2.0 * intersection + smooth) / (denom + smooth)
    return 1.0 - score


def weighted_boundary_loss_fn(
    wt_weight   = WT_WEIGHT,    # 1.0
    et_weight   = ET_WEIGHT,    # 2.0
    tc_weight   = TC_WEIGHT,    # 1.5
    pool_size   = 5,
    border_mult = 3.0,
    bce_frac    = 0.5,
):

    channel_weights = tf.constant(
        [wt_weight, et_weight, tc_weight], dtype=tf.float32)
    total_w = wt_weight + et_weight + tc_weight

    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.clip_by_value(tf.cast(y_pred, tf.float32), 1e-7, 1 - 1e-7)

        channel_losses = []
        for ch in range(3):
            y_t_ch = tf.expand_dims(y_true[..., ch], axis=-1)  # (B,H,W,1)
            y_p_ch = tf.expand_dims(y_pred[..., ch], axis=-1)

            w_map = _boundary_weight_map(y_t_ch, pool_size, border_mult)

            bce  = _weighted_bce_channel( y_t_ch, y_p_ch, w_map)
            dice = _weighted_dice_channel(y_t_ch, y_p_ch, w_map)

            ch_loss = bce_frac * bce + (1.0 - bce_frac) * dice
            channel_losses.append(ch_loss * channel_weights[ch])

        return tf.reduce_sum(tf.stack(channel_losses)) / total_w

    loss.__name__ = "weighted_boundary_loss"
    return loss


loss_fn = weighted_boundary_loss_fn()

# ── Pre-training loss check ────────────────────────────────────────────────────
print("\nLoss function: Weighted Boundary-Aware BCE + Dice (Rehman et al.)")
print(f"  pool_size={11}  border_mult=3.0  bce_frac=0.5")
print(f"  Channel weights: WT={WT_WEIGHT}  ET={ET_WEIGHT}  TC={TC_WEIGHT}")

for xb, yb in train_ds.take(1):
    out = model(xb, training=False)
    lv  = loss_fn(yb, out).numpy()
    print(f"\nPre-training check:  loss={lv:.4f}  "
          f"NaN={np.isnan(out.numpy()).any()}")
# Out:
# Loss function: Weighted Boundary-Aware BCE + Dice (Rehman et al.)
#   pool_size=11  border_mult=3.0  bce_frac=0.5
#   Channel weights: WT=0.5  ET=2.0  TC=1.5
#
# Pre-training check:  loss=1.1234  NaN=False

# %%
# Metrics

def soft_dice_per_channel(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    axes         = [1, 2]
    intersection = tf.reduce_sum(y_true * y_pred, axis=axes)   # (B, C)
    denom        = tf.reduce_sum(y_true + y_pred, axis=axes)   # (B, C)
    return (2.0 * intersection + smooth) / (denom + smooth)    # (B, C)


def dice_WT(y_true, y_pred, smooth=1e-6):
    return tf.reduce_mean(
        soft_dice_per_channel(y_true[..., 0:1], y_pred[..., 0:1], smooth)
    )

def dice_ET(y_true, y_pred, smooth=1e-6):
    return tf.reduce_mean(
        soft_dice_per_channel(y_true[..., 1:2], y_pred[..., 1:2], smooth)
    )

def dice_TC(y_true, y_pred, smooth=1e-6):
    return tf.reduce_mean(
        soft_dice_per_channel(y_true[..., 2:3], y_pred[..., 2:3], smooth)
    )

def dice_mean(y_true, y_pred, smooth=1e-6):
    return (dice_WT(y_true, y_pred, smooth) +
            dice_ET(y_true, y_pred, smooth) +
            dice_TC(y_true, y_pred, smooth)) / 3.0

def make_metrics():
    return [
        tf.keras.metrics.MeanMetricWrapper(dice_WT,   name="dice_WT"),
        tf.keras.metrics.MeanMetricWrapper(dice_ET,   name="dice_ET"),
        tf.keras.metrics.MeanMetricWrapper(dice_TC,   name="dice_TC"),
        tf.keras.metrics.MeanMetricWrapper(dice_mean, name="mean_dice"),
    ]


# ── Metric sanity check ────────────────────────────────────────────────────
print("\nMetric check ...")
_m = make_metrics()
for xb, yb in train_ds.take(1):
    _out = model(xb, training=False)
    for m in _m:
        m.update_state(yb, _out)
        print(f"  {m.name:<15} = {m.result().numpy():.4f}")
        m.reset_state()
del _m, _out
# Out:
# Metric check ...
#   dice_WT         = 0.1308
#   dice_ET         = 0.0394
#   dice_TC         = 0.0505
#   mean_dice       = 0.0735

# %%
# Compile

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=loss_fn,
    metrics=make_metrics()
)

for xb, yb in train_ds.take(1):
    out = model(xb, training=False)
    lv  = loss_fn(yb, out).numpy()
    print(f"\nPre-training check:  loss={lv:.4f}  NaN={np.isnan(out.numpy()).any()}")
# Out:
# Pre-training check:  loss=1.1573  NaN=False

# %%
callbacks = [
    ModelCheckpoint(
        filepath=BEST_MODEL_PATH,
        monitor="val_mean_dice",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    ModelCheckpoint(
        filepath=LAST_WEIGHTS_PATH,
        save_weights_only=True,
        verbose=0
    ),
    EarlyStopping(
        monitor="val_mean_dice",
        mode="max",
        patience=PATIENCE,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor="val_mean_dice",
        mode="max",
        factor=0.5,
        patience=5,
        min_lr=1e-7,
        verbose=0
    ),
    CSVLogger(LOG_PATH, append=True),
]

# %%
# Training

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - dice_ET: 0.5033 - dice_TC: 0.6546 - dice_WT: 0.7410 - loss: 0.0223 - mean_dice: 0.6330
# Epoch 1: val_mean_dice improved from None to 0.64863, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 128s 141ms/step - dice_ET: 0.5040 - dice_TC: 0.6555 - dice_WT: 0.7424 - loss: 0.0226 - mean_dice: 0.6339 - val_dice_ET: 0.5209 - val_dice_TC: 0.6710 - val_dice_WT: 0.7540 - val_loss: 0.0222 - val_mean_dice: 0.6486
# Epoch 2/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.5111 - dice_TC: 0.6557 - dice_WT: 0.7418 - loss: 0.0226 - mean_dice: 0.6362
# Epoch 2: val_mean_dice did not improve from 0.64863
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.5111 - dice_TC: 0.6572 - dice_WT: 0.7463 - loss: 0.0228 - mean_dice: 0.6382 - val_dice_ET: 0.5288 - val_dice_TC: 0.6614 - val_dice_WT: 0.7507 - val_loss: 0.0229 - val_mean_dice: 0.6470
# Epoch 3/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5162 - dice_TC: 0.6589 - dice_WT: 0.7504 - loss: 0.0231 - mean_dice: 0.6418
# Epoch 3: val_mean_dice improved from 0.64863 to 0.65676, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.5196 - dice_TC: 0.6586 - dice_WT: 0.7491 - loss: 0.0230 - mean_dice: 0.6424 - val_dice_ET: 0.5406 - val_dice_TC: 0.6749 - val_dice_WT: 0.7548 - val_loss: 0.0221 - val_mean_dice: 0.6568
# Epoch 4/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5250 - dice_TC: 0.6662 - dice_WT: 0.7547 - loss: 0.0224 - mean_dice: 0.6486
# Epoch 4: val_mean_dice improved from 0.65676 to 0.66616, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.5247 - dice_TC: 0.6628 - dice_WT: 0.7529 - loss: 0.0228 - mean_dice: 0.6468 - val_dice_ET: 0.5468 - val_dice_TC: 0.6880 - val_dice_WT: 0.7638 - val_loss: 0.0210 - val_mean_dice: 0.6662
# Epoch 5/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.5408 - dice_TC: 0.6776 - dice_WT: 0.7622 - loss: 0.0221 - mean_dice: 0.6602
# Epoch 5: val_mean_dice did not improve from 0.66616
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.5327 - dice_TC: 0.6674 - dice_WT: 0.7583 - loss: 0.0222 - mean_dice: 0.6528 - val_dice_ET: 0.5509 - val_dice_TC: 0.6775 - val_dice_WT: 0.7531 - val_loss: 0.0223 - val_mean_dice: 0.6605
# Epoch 6/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.5355 - dice_TC: 0.6684 - dice_WT: 0.7525 - loss: 0.0222 - mean_dice: 0.6521
# Epoch 6: val_mean_dice improved from 0.66616 to 0.66915, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.5389 - dice_TC: 0.6734 - dice_WT: 0.7601 - loss: 0.0218 - mean_dice: 0.6575 - val_dice_ET: 0.5599 - val_dice_TC: 0.6819 - val_dice_WT: 0.7657 - val_loss: 0.0201 - val_mean_dice: 0.6692
# Epoch 7/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5386 - dice_TC: 0.6788 - dice_WT: 0.7705 - loss: 0.0203 - mean_dice: 0.6626
# Epoch 7: val_mean_dice improved from 0.66915 to 0.67984, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.5457 - dice_TC: 0.6832 - dice_WT: 0.7680 - loss: 0.0205 - mean_dice: 0.6657 - val_dice_ET: 0.5618 - val_dice_TC: 0.7073 - val_dice_WT: 0.7704 - val_loss: 0.0188 - val_mean_dice: 0.6798
# Epoch 8/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5608 - dice_TC: 0.6979 - dice_WT: 0.7753 - loss: 0.0195 - mean_dice: 0.6780
# Epoch 8: val_mean_dice did not improve from 0.67984
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.5518 - dice_TC: 0.6907 - dice_WT: 0.7746 - loss: 0.0198 - mean_dice: 0.6724 - val_dice_ET: 0.5539 - val_dice_TC: 0.7056 - val_dice_WT: 0.7724 - val_loss: 0.0190 - val_mean_dice: 0.6773
# Epoch 9/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5516 - dice_TC: 0.6929 - dice_WT: 0.7765 - loss: 0.0193 - mean_dice: 0.6737
# Epoch 9: val_mean_dice did not improve from 0.67984
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.5548 - dice_TC: 0.6946 - dice_WT: 0.7769 - loss: 0.0194 - mean_dice: 0.6754 - val_dice_ET: 0.5437 - val_dice_TC: 0.6948 - val_dice_WT: 0.7851 - val_loss: 0.0198 - val_mean_dice: 0.6745
# Epoch 10/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5645 - dice_TC: 0.6982 - dice_WT: 0.7797 - loss: 0.0184 - mean_dice: 0.6808
# Epoch 10: val_mean_dice improved from 0.67984 to 0.69835, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.5605 - dice_TC: 0.7024 - dice_WT: 0.7832 - loss: 0.0183 - mean_dice: 0.6821 - val_dice_ET: 0.5794 - val_dice_TC: 0.7189 - val_dice_WT: 0.7968 - val_loss: 0.0178 - val_mean_dice: 0.6984
# Epoch 11/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.5701 - dice_TC: 0.7110 - dice_WT: 0.7896 - loss: 0.0174 - mean_dice: 0.6902
# Epoch 11: val_mean_dice improved from 0.69835 to 0.69851, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.5676 - dice_TC: 0.7113 - dice_WT: 0.7884 - loss: 0.0176 - mean_dice: 0.6891 - val_dice_ET: 0.5756 - val_dice_TC: 0.7232 - val_dice_WT: 0.7968 - val_loss: 0.0172 - val_mean_dice: 0.6985
# Epoch 12/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5734 - dice_TC: 0.7172 - dice_WT: 0.7926 - loss: 0.0167 - mean_dice: 0.6944
# Epoch 12: val_mean_dice improved from 0.69851 to 0.70563, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.5707 - dice_TC: 0.7145 - dice_WT: 0.7921 - loss: 0.0171 - mean_dice: 0.6924 - val_dice_ET: 0.5878 - val_dice_TC: 0.7305 - val_dice_WT: 0.7985 - val_loss: 0.0166 - val_mean_dice: 0.7056
# Epoch 13/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5800 - dice_TC: 0.7222 - dice_WT: 0.7957 - loss: 0.0165 - mean_dice: 0.6993
# Epoch 13: val_mean_dice improved from 0.70563 to 0.70601, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 13: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.5762 - dice_TC: 0.7204 - dice_WT: 0.7973 - loss: 0.0165 - mean_dice: 0.6979 - val_dice_ET: 0.5902 - val_dice_TC: 0.7288 - val_dice_WT: 0.7991 - val_loss: 0.0163 - val_mean_dice: 0.7060
# Epoch 14/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5824 - dice_TC: 0.7248 - dice_WT: 0.7995 - loss: 0.0161 - mean_dice: 0.7022
# Epoch 14: val_mean_dice improved from 0.70601 to 0.71442, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 14: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.5801 - dice_TC: 0.7248 - dice_WT: 0.7994 - loss: 0.0161 - mean_dice: 0.7014 - val_dice_ET: 0.5986 - val_dice_TC: 0.7386 - val_dice_WT: 0.8060 - val_loss: 0.0154 - val_mean_dice: 0.7144
# Epoch 15/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5836 - dice_TC: 0.7270 - dice_WT: 0.8016 - loss: 0.0161 - mean_dice: 0.7041
# Epoch 15: val_mean_dice improved from 0.71442 to 0.71869, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 15: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.5798 - dice_TC: 0.7241 - dice_WT: 0.8006 - loss: 0.0162 - mean_dice: 0.7015 - val_dice_ET: 0.6009 - val_dice_TC: 0.7417 - val_dice_WT: 0.8135 - val_loss: 0.0158 - val_mean_dice: 0.7187
# Epoch 16/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5850 - dice_TC: 0.7280 - dice_WT: 0.8043 - loss: 0.0154 - mean_dice: 0.7058
# Epoch 16: val_mean_dice did not improve from 0.71869
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.5836 - dice_TC: 0.7305 - dice_WT: 0.8052 - loss: 0.0156 - mean_dice: 0.7064 - val_dice_ET: 0.5951 - val_dice_TC: 0.7387 - val_dice_WT: 0.8111 - val_loss: 0.0153 - val_mean_dice: 0.7150
# Epoch 17/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5915 - dice_TC: 0.7403 - dice_WT: 0.8133 - loss: 0.0152 - mean_dice: 0.7150
# Epoch 17: val_mean_dice did not improve from 0.71869
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.5874 - dice_TC: 0.7327 - dice_WT: 0.8075 - loss: 0.0153 - mean_dice: 0.7092 - val_dice_ET: 0.5887 - val_dice_TC: 0.7309 - val_dice_WT: 0.7860 - val_loss: 0.0176 - val_mean_dice: 0.7018
# Epoch 18/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.5911 - dice_TC: 0.7365 - dice_WT: 0.8074 - loss: 0.0154 - mean_dice: 0.7117
# Epoch 18: val_mean_dice did not improve from 0.71869
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.5879 - dice_TC: 0.7340 - dice_WT: 0.8096 - loss: 0.0151 - mean_dice: 0.7105 - val_dice_ET: 0.5996 - val_dice_TC: 0.7394 - val_dice_WT: 0.8146 - val_loss: 0.0148 - val_mean_dice: 0.7179
# Epoch 19/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.5944 - dice_TC: 0.7364 - dice_WT: 0.8119 - loss: 0.0144 - mean_dice: 0.7142
# Epoch 19: val_mean_dice improved from 0.71869 to 0.72580, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 19: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.5918 - dice_TC: 0.7392 - dice_WT: 0.8139 - loss: 0.0146 - mean_dice: 0.7150 - val_dice_ET: 0.6091 - val_dice_TC: 0.7484 - val_dice_WT: 0.8199 - val_loss: 0.0147 - val_mean_dice: 0.7258
# Epoch 20/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5939 - dice_TC: 0.7443 - dice_WT: 0.8199 - loss: 0.0143 - mean_dice: 0.7194
# Epoch 20: val_mean_dice did not improve from 0.72580
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.5931 - dice_TC: 0.7378 - dice_WT: 0.8132 - loss: 0.0147 - mean_dice: 0.7147 - val_dice_ET: 0.6025 - val_dice_TC: 0.7322 - val_dice_WT: 0.8079 - val_loss: 0.0154 - val_mean_dice: 0.7142
# Epoch 21/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.5918 - dice_TC: 0.7391 - dice_WT: 0.8103 - loss: 0.0142 - mean_dice: 0.7137
# Epoch 21: val_mean_dice did not improve from 0.72580
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.5948 - dice_TC: 0.7423 - dice_WT: 0.8165 - loss: 0.0142 - mean_dice: 0.7179 - val_dice_ET: 0.6064 - val_dice_TC: 0.7465 - val_dice_WT: 0.8174 - val_loss: 0.0141 - val_mean_dice: 0.7234
# Epoch 22/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5978 - dice_TC: 0.7426 - dice_WT: 0.8169 - loss: 0.0139 - mean_dice: 0.7191
# Epoch 22: val_mean_dice improved from 0.72580 to 0.72677, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 22: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.5972 - dice_TC: 0.7444 - dice_WT: 0.8192 - loss: 0.0140 - mean_dice: 0.7203 - val_dice_ET: 0.6076 - val_dice_TC: 0.7477 - val_dice_WT: 0.8250 - val_loss: 0.0143 - val_mean_dice: 0.7268
# Epoch 23/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6086 - dice_TC: 0.7515 - dice_WT: 0.8214 - loss: 0.0136 - mean_dice: 0.7272
# Epoch 23: val_mean_dice improved from 0.72677 to 0.73173, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 23: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6005 - dice_TC: 0.7482 - dice_WT: 0.8221 - loss: 0.0136 - mean_dice: 0.7236 - val_dice_ET: 0.6109 - val_dice_TC: 0.7537 - val_dice_WT: 0.8306 - val_loss: 0.0138 - val_mean_dice: 0.7317
# Epoch 24/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6017 - dice_TC: 0.7497 - dice_WT: 0.8275 - loss: 0.0132 - mean_dice: 0.7263
# Epoch 24: val_mean_dice did not improve from 0.73173
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6019 - dice_TC: 0.7493 - dice_WT: 0.8240 - loss: 0.0134 - mean_dice: 0.7251 - val_dice_ET: 0.6079 - val_dice_TC: 0.7528 - val_dice_WT: 0.8294 - val_loss: 0.0139 - val_mean_dice: 0.7300
# Epoch 25/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6095 - dice_TC: 0.7551 - dice_WT: 0.8326 - loss: 0.0131 - mean_dice: 0.7324
# Epoch 25: val_mean_dice improved from 0.73173 to 0.73313, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 25: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6038 - dice_TC: 0.7525 - dice_WT: 0.8273 - loss: 0.0133 - mean_dice: 0.7278 - val_dice_ET: 0.6149 - val_dice_TC: 0.7546 - val_dice_WT: 0.8298 - val_loss: 0.0138 - val_mean_dice: 0.7331
# Epoch 26/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6074 - dice_TC: 0.7508 - dice_WT: 0.8264 - loss: 0.0133 - mean_dice: 0.7282
# Epoch 26: val_mean_dice did not improve from 0.73313
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6040 - dice_TC: 0.7517 - dice_WT: 0.8255 - loss: 0.0133 - mean_dice: 0.7271 - val_dice_ET: 0.6111 - val_dice_TC: 0.7572 - val_dice_WT: 0.8276 - val_loss: 0.0137 - val_mean_dice: 0.7320
# Epoch 27/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6090 - dice_TC: 0.7595 - dice_WT: 0.8317 - loss: 0.0130 - mean_dice: 0.7334
# Epoch 27: val_mean_dice did not improve from 0.73313
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6062 - dice_TC: 0.7550 - dice_WT: 0.8285 - loss: 0.0130 - mean_dice: 0.7299 - val_dice_ET: 0.6005 - val_dice_TC: 0.7493 - val_dice_WT: 0.8260 - val_loss: 0.0136 - val_mean_dice: 0.7253
# Epoch 28/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6059 - dice_TC: 0.7578 - dice_WT: 0.8275 - loss: 0.0127 - mean_dice: 0.7304
# Epoch 28: val_mean_dice did not improve from 0.73313
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6078 - dice_TC: 0.7567 - dice_WT: 0.8303 - loss: 0.0128 - mean_dice: 0.7316 - val_dice_ET: 0.6101 - val_dice_TC: 0.7545 - val_dice_WT: 0.8286 - val_loss: 0.0144 - val_mean_dice: 0.7310
# Epoch 29/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6113 - dice_TC: 0.7561 - dice_WT: 0.8284 - loss: 0.0131 - mean_dice: 0.7320
# Epoch 29: val_mean_dice improved from 0.73313 to 0.73913, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 29: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6046 - dice_TC: 0.7512 - dice_WT: 0.8248 - loss: 0.0133 - mean_dice: 0.7269 - val_dice_ET: 0.6183 - val_dice_TC: 0.7641 - val_dice_WT: 0.8350 - val_loss: 0.0131 - val_mean_dice: 0.7391
# Epoch 30/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6097 - dice_TC: 0.7635 - dice_WT: 0.8366 - loss: 0.0124 - mean_dice: 0.7366
# Epoch 30: val_mean_dice did not improve from 0.73913
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6114 - dice_TC: 0.7606 - dice_WT: 0.8331 - loss: 0.0125 - mean_dice: 0.7350 - val_dice_ET: 0.6175 - val_dice_TC: 0.7608 - val_dice_WT: 0.8352 - val_loss: 0.0132 - val_mean_dice: 0.7378
# Epoch 31/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6177 - dice_TC: 0.7664 - dice_WT: 0.8377 - loss: 0.0122 - mean_dice: 0.7406
# Epoch 31: val_mean_dice did not improve from 0.73913
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6123 - dice_TC: 0.7607 - dice_WT: 0.8349 - loss: 0.0123 - mean_dice: 0.7360 - val_dice_ET: 0.6146 - val_dice_TC: 0.7579 - val_dice_WT: 0.8287 - val_loss: 0.0137 - val_mean_dice: 0.7337
# Epoch 32/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6110 - dice_TC: 0.7544 - dice_WT: 0.8278 - loss: 0.0125 - mean_dice: 0.7311
# Epoch 32: val_mean_dice did not improve from 0.73913
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6116 - dice_TC: 0.7593 - dice_WT: 0.8326 - loss: 0.0125 - mean_dice: 0.7345 - val_dice_ET: 0.6168 - val_dice_TC: 0.7583 - val_dice_WT: 0.8321 - val_loss: 0.0132 - val_mean_dice: 0.7357
# Epoch 33/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6184 - dice_TC: 0.7647 - dice_WT: 0.8364 - loss: 0.0121 - mean_dice: 0.7398
# Epoch 33: val_mean_dice improved from 0.73913 to 0.74077, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 33: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6145 - dice_TC: 0.7635 - dice_WT: 0.8373 - loss: 0.0121 - mean_dice: 0.7384 - val_dice_ET: 0.6206 - val_dice_TC: 0.7640 - val_dice_WT: 0.8377 - val_loss: 0.0127 - val_mean_dice: 0.7408
# Epoch 34/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6127 - dice_TC: 0.7689 - dice_WT: 0.8406 - loss: 0.0121 - mean_dice: 0.7407
# Epoch 34: val_mean_dice did not improve from 0.74077
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6154 - dice_TC: 0.7646 - dice_WT: 0.8383 - loss: 0.0120 - mean_dice: 0.7394 - val_dice_ET: 0.6201 - val_dice_TC: 0.7658 - val_dice_WT: 0.8342 - val_loss: 0.0127 - val_mean_dice: 0.7400
# Epoch 35/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6189 - dice_TC: 0.7639 - dice_WT: 0.8399 - loss: 0.0118 - mean_dice: 0.7409
# Epoch 35: val_mean_dice improved from 0.74077 to 0.74115, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 35: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6163 - dice_TC: 0.7662 - dice_WT: 0.8394 - loss: 0.0119 - mean_dice: 0.7406 - val_dice_ET: 0.6229 - val_dice_TC: 0.7675 - val_dice_WT: 0.8331 - val_loss: 0.0126 - val_mean_dice: 0.7412
# Epoch 36/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6175 - dice_TC: 0.7704 - dice_WT: 0.8419 - loss: 0.0116 - mean_dice: 0.7433
# Epoch 36: val_mean_dice improved from 0.74115 to 0.74286, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 36: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6176 - dice_TC: 0.7674 - dice_WT: 0.8398 - loss: 0.0117 - mean_dice: 0.7416 - val_dice_ET: 0.6235 - val_dice_TC: 0.7678 - val_dice_WT: 0.8373 - val_loss: 0.0133 - val_mean_dice: 0.7429
# Epoch 37/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6167 - dice_TC: 0.7684 - dice_WT: 0.8428 - loss: 0.0116 - mean_dice: 0.7426
# Epoch 37: val_mean_dice improved from 0.74286 to 0.74328, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 37: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 32s 54ms/step - dice_ET: 0.6188 - dice_TC: 0.7681 - dice_WT: 0.8414 - loss: 0.0116 - mean_dice: 0.7427 - val_dice_ET: 0.6239 - val_dice_TC: 0.7664 - val_dice_WT: 0.8395 - val_loss: 0.0125 - val_mean_dice: 0.7433
# Epoch 38/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6160 - dice_TC: 0.7679 - dice_WT: 0.8395 - loss: 0.0115 - mean_dice: 0.7411
# Epoch 38: val_mean_dice did not improve from 0.74328
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6178 - dice_TC: 0.7679 - dice_WT: 0.8410 - loss: 0.0116 - mean_dice: 0.7422 - val_dice_ET: 0.6241 - val_dice_TC: 0.7659 - val_dice_WT: 0.8363 - val_loss: 0.0129 - val_mean_dice: 0.7421
# Epoch 39/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6183 - dice_TC: 0.7628 - dice_WT: 0.8357 - loss: 0.0113 - mean_dice: 0.7389
# Epoch 39: val_mean_dice improved from 0.74328 to 0.74638, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 39: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6205 - dice_TC: 0.7697 - dice_WT: 0.8424 - loss: 0.0115 - mean_dice: 0.7442 - val_dice_ET: 0.6255 - val_dice_TC: 0.7715 - val_dice_WT: 0.8422 - val_loss: 0.0128 - val_mean_dice: 0.7464
# Epoch 40/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6153 - dice_TC: 0.7673 - dice_WT: 0.8418 - loss: 0.0112 - mean_dice: 0.7415
# Epoch 40: val_mean_dice did not improve from 0.74638
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6204 - dice_TC: 0.7706 - dice_WT: 0.8432 - loss: 0.0114 - mean_dice: 0.7447 - val_dice_ET: 0.6271 - val_dice_TC: 0.7718 - val_dice_WT: 0.8396 - val_loss: 0.0124 - val_mean_dice: 0.7462
# Epoch 41/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6229 - dice_TC: 0.7755 - dice_WT: 0.8475 - loss: 0.0111 - mean_dice: 0.7487
# Epoch 41: val_mean_dice improved from 0.74638 to 0.74669, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 41: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6225 - dice_TC: 0.7722 - dice_WT: 0.8453 - loss: 0.0112 - mean_dice: 0.7467 - val_dice_ET: 0.6294 - val_dice_TC: 0.7696 - val_dice_WT: 0.8410 - val_loss: 0.0128 - val_mean_dice: 0.7467
# Epoch 42/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6239 - dice_TC: 0.7764 - dice_WT: 0.8490 - loss: 0.0112 - mean_dice: 0.7498
# Epoch 42: val_mean_dice did not improve from 0.74669
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6232 - dice_TC: 0.7732 - dice_WT: 0.8458 - loss: 0.0112 - mean_dice: 0.7474 - val_dice_ET: 0.6273 - val_dice_TC: 0.7691 - val_dice_WT: 0.8424 - val_loss: 0.0122 - val_mean_dice: 0.7463
# Epoch 43/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6256 - dice_TC: 0.7765 - dice_WT: 0.8459 - loss: 0.0111 - mean_dice: 0.7493
# Epoch 43: val_mean_dice improved from 0.74669 to 0.74835, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 43: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6247 - dice_TC: 0.7742 - dice_WT: 0.8461 - loss: 0.0110 - mean_dice: 0.7483 - val_dice_ET: 0.6284 - val_dice_TC: 0.7734 - val_dice_WT: 0.8432 - val_loss: 0.0124 - val_mean_dice: 0.7484
# Epoch 44/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6248 - dice_TC: 0.7762 - dice_WT: 0.8486 - loss: 0.0110 - mean_dice: 0.7498
# Epoch 44: val_mean_dice did not improve from 0.74835
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6246 - dice_TC: 0.7748 - dice_WT: 0.8474 - loss: 0.0110 - mean_dice: 0.7489 - val_dice_ET: 0.6293 - val_dice_TC: 0.7720 - val_dice_WT: 0.8425 - val_loss: 0.0125 - val_mean_dice: 0.7479
# Epoch 45/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6186 - dice_TC: 0.7746 - dice_WT: 0.8464 - loss: 0.0109 - mean_dice: 0.7465
# Epoch 45: val_mean_dice did not improve from 0.74835
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6261 - dice_TC: 0.7752 - dice_WT: 0.8471 - loss: 0.0109 - mean_dice: 0.7495 - val_dice_ET: 0.6282 - val_dice_TC: 0.7715 - val_dice_WT: 0.8453 - val_loss: 0.0126 - val_mean_dice: 0.7483
# Epoch 46/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6284 - dice_TC: 0.7766 - dice_WT: 0.8471 - loss: 0.0108 - mean_dice: 0.7507
# Epoch 46: val_mean_dice improved from 0.74835 to 0.74977, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 46: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6265 - dice_TC: 0.7762 - dice_WT: 0.8490 - loss: 0.0108 - mean_dice: 0.7506 - val_dice_ET: 0.6324 - val_dice_TC: 0.7758 - val_dice_WT: 0.8411 - val_loss: 0.0122 - val_mean_dice: 0.7498
# Epoch 47/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6300 - dice_TC: 0.7768 - dice_WT: 0.8475 - loss: 0.0107 - mean_dice: 0.7514
# Epoch 47: val_mean_dice improved from 0.74977 to 0.75057, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 47: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6277 - dice_TC: 0.7777 - dice_WT: 0.8494 - loss: 0.0107 - mean_dice: 0.7516 - val_dice_ET: 0.6307 - val_dice_TC: 0.7753 - val_dice_WT: 0.8457 - val_loss: 0.0121 - val_mean_dice: 0.7506
# Epoch 48/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6293 - dice_TC: 0.7787 - dice_WT: 0.8521 - loss: 0.0106 - mean_dice: 0.7534
# Epoch 48: val_mean_dice improved from 0.75057 to 0.75298, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 48: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6297 - dice_TC: 0.7793 - dice_WT: 0.8504 - loss: 0.0106 - mean_dice: 0.7531 - val_dice_ET: 0.6360 - val_dice_TC: 0.7754 - val_dice_WT: 0.8476 - val_loss: 0.0121 - val_mean_dice: 0.7530
# Epoch 49/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6266 - dice_TC: 0.7770 - dice_WT: 0.8514 - loss: 0.0105 - mean_dice: 0.7517
# Epoch 49: val_mean_dice did not improve from 0.75298
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6288 - dice_TC: 0.7788 - dice_WT: 0.8506 - loss: 0.0106 - mean_dice: 0.7527 - val_dice_ET: 0.6320 - val_dice_TC: 0.7759 - val_dice_WT: 0.8455 - val_loss: 0.0121 - val_mean_dice: 0.7511
# Epoch 50/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6293 - dice_TC: 0.7775 - dice_WT: 0.8504 - loss: 0.0103 - mean_dice: 0.7524
# Epoch 50: val_mean_dice did not improve from 0.75298
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6302 - dice_TC: 0.7800 - dice_WT: 0.8514 - loss: 0.0105 - mean_dice: 0.7538 - val_dice_ET: 0.6314 - val_dice_TC: 0.7765 - val_dice_WT: 0.8476 - val_loss: 0.0120 - val_mean_dice: 0.7518
# Epoch 51/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6323 - dice_TC: 0.7811 - dice_WT: 0.8552 - loss: 0.0105 - mean_dice: 0.7562
# Epoch 51: val_mean_dice did not improve from 0.75298
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6304 - dice_TC: 0.7802 - dice_WT: 0.8519 - loss: 0.0105 - mean_dice: 0.7542 - val_dice_ET: 0.6327 - val_dice_TC: 0.7761 - val_dice_WT: 0.8460 - val_loss: 0.0123 - val_mean_dice: 0.7516
# Epoch 52/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6328 - dice_TC: 0.7790 - dice_WT: 0.8517 - loss: 0.0102 - mean_dice: 0.7545
# Epoch 52: val_mean_dice improved from 0.75298 to 0.75343, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 52: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6301 - dice_TC: 0.7804 - dice_WT: 0.8523 - loss: 0.0104 - mean_dice: 0.7543 - val_dice_ET: 0.6337 - val_dice_TC: 0.7778 - val_dice_WT: 0.8488 - val_loss: 0.0122 - val_mean_dice: 0.7534
# Epoch 53/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6306 - dice_TC: 0.7769 - dice_WT: 0.8496 - loss: 0.0102 - mean_dice: 0.7524
# Epoch 53: val_mean_dice improved from 0.75343 to 0.75400, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 53: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 32s 54ms/step - dice_ET: 0.6323 - dice_TC: 0.7822 - dice_WT: 0.8531 - loss: 0.0103 - mean_dice: 0.7559 - val_dice_ET: 0.6369 - val_dice_TC: 0.7774 - val_dice_WT: 0.8477 - val_loss: 0.0117 - val_mean_dice: 0.7540
# Epoch 54/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6353 - dice_TC: 0.7850 - dice_WT: 0.8555 - loss: 0.0103 - mean_dice: 0.7586
# Epoch 54: val_mean_dice improved from 0.75400 to 0.75515, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 54: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6329 - dice_TC: 0.7829 - dice_WT: 0.8539 - loss: 0.0102 - mean_dice: 0.7566 - val_dice_ET: 0.6372 - val_dice_TC: 0.7784 - val_dice_WT: 0.8498 - val_loss: 0.0121 - val_mean_dice: 0.7551
# Epoch 55/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6361 - dice_TC: 0.7870 - dice_WT: 0.8578 - loss: 0.0102 - mean_dice: 0.7603
# Epoch 55: val_mean_dice did not improve from 0.75515
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6331 - dice_TC: 0.7830 - dice_WT: 0.8544 - loss: 0.0102 - mean_dice: 0.7569 - val_dice_ET: 0.6354 - val_dice_TC: 0.7790 - val_dice_WT: 0.8487 - val_loss: 0.0120 - val_mean_dice: 0.7544
# Epoch 56/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6345 - dice_TC: 0.7816 - dice_WT: 0.8528 - loss: 0.0100 - mean_dice: 0.7563
# Epoch 56: val_mean_dice did not improve from 0.75515
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6345 - dice_TC: 0.7841 - dice_WT: 0.8553 - loss: 0.0101 - mean_dice: 0.7580 - val_dice_ET: 0.6356 - val_dice_TC: 0.7782 - val_dice_WT: 0.8502 - val_loss: 0.0119 - val_mean_dice: 0.7547
# Epoch 57/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6370 - dice_TC: 0.7858 - dice_WT: 0.8570 - loss: 0.0101 - mean_dice: 0.7599
# Epoch 57: val_mean_dice did not improve from 0.75515
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6342 - dice_TC: 0.7844 - dice_WT: 0.8553 - loss: 0.0100 - mean_dice: 0.7580 - val_dice_ET: 0.6327 - val_dice_TC: 0.7780 - val_dice_WT: 0.8499 - val_loss: 0.0120 - val_mean_dice: 0.7535
# Epoch 58/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6279 - dice_TC: 0.7788 - dice_WT: 0.8513 - loss: 0.0098 - mean_dice: 0.7527
# Epoch 58: val_mean_dice improved from 0.75515 to 0.75637, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 58: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6357 - dice_TC: 0.7859 - dice_WT: 0.8563 - loss: 0.0099 - mean_dice: 0.7593 - val_dice_ET: 0.6384 - val_dice_TC: 0.7801 - val_dice_WT: 0.8506 - val_loss: 0.0121 - val_mean_dice: 0.7564
# Epoch 59/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6344 - dice_TC: 0.7831 - dice_WT: 0.8569 - loss: 0.0100 - mean_dice: 0.7581
# Epoch 59: val_mean_dice did not improve from 0.75637
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6350 - dice_TC: 0.7847 - dice_WT: 0.8561 - loss: 0.0099 - mean_dice: 0.7586 - val_dice_ET: 0.6378 - val_dice_TC: 0.7804 - val_dice_WT: 0.8508 - val_loss: 0.0120 - val_mean_dice: 0.7563
# Epoch 60/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6364 - dice_TC: 0.7845 - dice_WT: 0.8563 - loss: 0.0099 - mean_dice: 0.7591
# Epoch 60: val_mean_dice improved from 0.75637 to 0.75741, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 60: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6362 - dice_TC: 0.7859 - dice_WT: 0.8569 - loss: 0.0098 - mean_dice: 0.7597 - val_dice_ET: 0.6391 - val_dice_TC: 0.7816 - val_dice_WT: 0.8515 - val_loss: 0.0121 - val_mean_dice: 0.7574
# Epoch 61/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6396 - dice_TC: 0.7901 - dice_WT: 0.8583 - loss: 0.0098 - mean_dice: 0.7627
# Epoch 61: val_mean_dice did not improve from 0.75741
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6362 - dice_TC: 0.7863 - dice_WT: 0.8569 - loss: 0.0098 - mean_dice: 0.7598 - val_dice_ET: 0.6381 - val_dice_TC: 0.7811 - val_dice_WT: 0.8494 - val_loss: 0.0118 - val_mean_dice: 0.7562
# Epoch 62/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6332 - dice_TC: 0.7835 - dice_WT: 0.8563 - loss: 0.0097 - mean_dice: 0.7577
# Epoch 62: val_mean_dice did not improve from 0.75741
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6375 - dice_TC: 0.7872 - dice_WT: 0.8576 - loss: 0.0098 - mean_dice: 0.7608 - val_dice_ET: 0.6384 - val_dice_TC: 0.7815 - val_dice_WT: 0.8513 - val_loss: 0.0120 - val_mean_dice: 0.7571
# Epoch 63/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6380 - dice_TC: 0.7867 - dice_WT: 0.8570 - loss: 0.0096 - mean_dice: 0.7605
# Epoch 63: val_mean_dice improved from 0.75741 to 0.75792, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 63: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6378 - dice_TC: 0.7877 - dice_WT: 0.8583 - loss: 0.0097 - mean_dice: 0.7613 - val_dice_ET: 0.6400 - val_dice_TC: 0.7815 - val_dice_WT: 0.8522 - val_loss: 0.0119 - val_mean_dice: 0.7579
# Epoch 64/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6367 - dice_TC: 0.7876 - dice_WT: 0.8585 - loss: 0.0095 - mean_dice: 0.7609
# Epoch 64: val_mean_dice did not improve from 0.75792
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6387 - dice_TC: 0.7887 - dice_WT: 0.8588 - loss: 0.0096 - mean_dice: 0.7621 - val_dice_ET: 0.6393 - val_dice_TC: 0.7813 - val_dice_WT: 0.8513 - val_loss: 0.0119 - val_mean_dice: 0.7573
# Epoch 65/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6419 - dice_TC: 0.7909 - dice_WT: 0.8611 - loss: 0.0096 - mean_dice: 0.7646
# Epoch 65: val_mean_dice improved from 0.75792 to 0.75843, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 65: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6386 - dice_TC: 0.7882 - dice_WT: 0.8584 - loss: 0.0096 - mean_dice: 0.7617 - val_dice_ET: 0.6390 - val_dice_TC: 0.7822 - val_dice_WT: 0.8541 - val_loss: 0.0120 - val_mean_dice: 0.7584
# Epoch 66/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6409 - dice_TC: 0.7940 - dice_WT: 0.8603 - loss: 0.0095 - mean_dice: 0.7650
# Epoch 66: val_mean_dice did not improve from 0.75843
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6394 - dice_TC: 0.7895 - dice_WT: 0.8593 - loss: 0.0095 - mean_dice: 0.7627 - val_dice_ET: 0.6396 - val_dice_TC: 0.7816 - val_dice_WT: 0.8521 - val_loss: 0.0121 - val_mean_dice: 0.7577
# Epoch 67/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6388 - dice_TC: 0.7934 - dice_WT: 0.8613 - loss: 0.0095 - mean_dice: 0.7645
# Epoch 67: val_mean_dice improved from 0.75843 to 0.76012, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 67: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6396 - dice_TC: 0.7901 - dice_WT: 0.8597 - loss: 0.0095 - mean_dice: 0.7631 - val_dice_ET: 0.6426 - val_dice_TC: 0.7836 - val_dice_WT: 0.8541 - val_loss: 0.0123 - val_mean_dice: 0.7601
# Epoch 68/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6416 - dice_TC: 0.7890 - dice_WT: 0.8583 - loss: 0.0095 - mean_dice: 0.7630
# Epoch 68: val_mean_dice did not improve from 0.76012
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6400 - dice_TC: 0.7900 - dice_WT: 0.8600 - loss: 0.0095 - mean_dice: 0.7633 - val_dice_ET: 0.6407 - val_dice_TC: 0.7833 - val_dice_WT: 0.8536 - val_loss: 0.0119 - val_mean_dice: 0.7592
# Epoch 69/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6405 - dice_TC: 0.7944 - dice_WT: 0.8606 - loss: 0.0093 - mean_dice: 0.7652
# Epoch 69: val_mean_dice did not improve from 0.76012
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6411 - dice_TC: 0.7910 - dice_WT: 0.8603 - loss: 0.0094 - mean_dice: 0.7641 - val_dice_ET: 0.6404 - val_dice_TC: 0.7826 - val_dice_WT: 0.8537 - val_loss: 0.0120 - val_mean_dice: 0.7589
# Epoch 70/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6385 - dice_TC: 0.7903 - dice_WT: 0.8602 - loss: 0.0094 - mean_dice: 0.7630
# Epoch 70: val_mean_dice did not improve from 0.76012
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6413 - dice_TC: 0.7912 - dice_WT: 0.8608 - loss: 0.0093 - mean_dice: 0.7644 - val_dice_ET: 0.6407 - val_dice_TC: 0.7832 - val_dice_WT: 0.8540 - val_loss: 0.0125 - val_mean_dice: 0.7593
# Epoch 71/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6470 - dice_TC: 0.7998 - dice_WT: 0.8656 - loss: 0.0094 - mean_dice: 0.7708
# Epoch 71: val_mean_dice did not improve from 0.76012
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6412 - dice_TC: 0.7913 - dice_WT: 0.8612 - loss: 0.0093 - mean_dice: 0.7646 - val_dice_ET: 0.6424 - val_dice_TC: 0.7840 - val_dice_WT: 0.8533 - val_loss: 0.0119 - val_mean_dice: 0.7599
# Epoch 72/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6466 - dice_TC: 0.7947 - dice_WT: 0.8628 - loss: 0.0092 - mean_dice: 0.7681
# Epoch 72: val_mean_dice improved from 0.76012 to 0.76056, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 72: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6421 - dice_TC: 0.7922 - dice_WT: 0.8611 - loss: 0.0092 - mean_dice: 0.7651 - val_dice_ET: 0.6433 - val_dice_TC: 0.7844 - val_dice_WT: 0.8540 - val_loss: 0.0120 - val_mean_dice: 0.7606
# Epoch 73/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6478 - dice_TC: 0.7949 - dice_WT: 0.8658 - loss: 0.0092 - mean_dice: 0.7695
# Epoch 73: val_mean_dice did not improve from 0.76056
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6423 - dice_TC: 0.7923 - dice_WT: 0.8618 - loss: 0.0092 - mean_dice: 0.7655 - val_dice_ET: 0.6419 - val_dice_TC: 0.7841 - val_dice_WT: 0.8547 - val_loss: 0.0119 - val_mean_dice: 0.7602
# Epoch 74/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6447 - dice_TC: 0.7950 - dice_WT: 0.8635 - loss: 0.0092 - mean_dice: 0.7677
# Epoch 74: val_mean_dice did not improve from 0.76056
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6420 - dice_TC: 0.7920 - dice_WT: 0.8617 - loss: 0.0092 - mean_dice: 0.7653 - val_dice_ET: 0.6411 - val_dice_TC: 0.7841 - val_dice_WT: 0.8538 - val_loss: 0.0119 - val_mean_dice: 0.7597
# Epoch 75/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6465 - dice_TC: 0.7952 - dice_WT: 0.8637 - loss: 0.0093 - mean_dice: 0.7685
# Epoch 75: val_mean_dice improved from 0.76056 to 0.76082, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 75: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6427 - dice_TC: 0.7929 - dice_WT: 0.8621 - loss: 0.0092 - mean_dice: 0.7659 - val_dice_ET: 0.6426 - val_dice_TC: 0.7850 - val_dice_WT: 0.8549 - val_loss: 0.0120 - val_mean_dice: 0.7608
# Epoch 76/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6449 - dice_TC: 0.7920 - dice_WT: 0.8611 - loss: 0.0091 - mean_dice: 0.7660
# Epoch 76: val_mean_dice improved from 0.76082 to 0.76136, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 76: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6436 - dice_TC: 0.7937 - dice_WT: 0.8626 - loss: 0.0091 - mean_dice: 0.7666 - val_dice_ET: 0.6436 - val_dice_TC: 0.7857 - val_dice_WT: 0.8547 - val_loss: 0.0119 - val_mean_dice: 0.7614
# Epoch 77/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6471 - dice_TC: 0.7930 - dice_WT: 0.8618 - loss: 0.0092 - mean_dice: 0.7673
# Epoch 77: val_mean_dice improved from 0.76136 to 0.76153, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 77: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6434 - dice_TC: 0.7931 - dice_WT: 0.8625 - loss: 0.0091 - mean_dice: 0.7664 - val_dice_ET: 0.6435 - val_dice_TC: 0.7857 - val_dice_WT: 0.8554 - val_loss: 0.0119 - val_mean_dice: 0.7615
# Epoch 78/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6406 - dice_TC: 0.7894 - dice_WT: 0.8611 - loss: 0.0092 - mean_dice: 0.7637
# Epoch 78: val_mean_dice did not improve from 0.76153
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6441 - dice_TC: 0.7939 - dice_WT: 0.8623 - loss: 0.0091 - mean_dice: 0.7668 - val_dice_ET: 0.6419 - val_dice_TC: 0.7848 - val_dice_WT: 0.8552 - val_loss: 0.0120 - val_mean_dice: 0.7606
# Epoch 79/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6468 - dice_TC: 0.7983 - dice_WT: 0.8682 - loss: 0.0092 - mean_dice: 0.7711
# Epoch 79: val_mean_dice did not improve from 0.76153
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6444 - dice_TC: 0.7944 - dice_WT: 0.8629 - loss: 0.0091 - mean_dice: 0.7672 - val_dice_ET: 0.6430 - val_dice_TC: 0.7859 - val_dice_WT: 0.8552 - val_loss: 0.0120 - val_mean_dice: 0.7614
# Epoch 80/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6465 - dice_TC: 0.7948 - dice_WT: 0.8594 - loss: 0.0090 - mean_dice: 0.7669
# Epoch 80: val_mean_dice did not improve from 0.76153
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 50ms/step - dice_ET: 0.6447 - dice_TC: 0.7947 - dice_WT: 0.8633 - loss: 0.0091 - mean_dice: 0.7675 - val_dice_ET: 0.6429 - val_dice_TC: 0.7857 - val_dice_WT: 0.8545 - val_loss: 0.0120 - val_mean_dice: 0.7610
# Epoch 81/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6482 - dice_TC: 0.7961 - dice_WT: 0.8638 - loss: 0.0089 - mean_dice: 0.7693
# Epoch 81: val_mean_dice improved from 0.76153 to 0.76197, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 81: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 41s 69ms/step - dice_ET: 0.6449 - dice_TC: 0.7950 - dice_WT: 0.8634 - loss: 0.0090 - mean_dice: 0.7678 - val_dice_ET: 0.6440 - val_dice_TC: 0.7859 - val_dice_WT: 0.8560 - val_loss: 0.0120 - val_mean_dice: 0.7620
# Epoch 82/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6504 - dice_TC: 0.8002 - dice_WT: 0.8664 - loss: 0.0090 - mean_dice: 0.7723
# Epoch 82: val_mean_dice did not improve from 0.76197
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6449 - dice_TC: 0.7948 - dice_WT: 0.8636 - loss: 0.0090 - mean_dice: 0.7678 - val_dice_ET: 0.6436 - val_dice_TC: 0.7854 - val_dice_WT: 0.8549 - val_loss: 0.0121 - val_mean_dice: 0.7613
# Epoch 83/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6516 - dice_TC: 0.8035 - dice_WT: 0.8684 - loss: 0.0090 - mean_dice: 0.7745
# Epoch 83: val_mean_dice did not improve from 0.76197
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6456 - dice_TC: 0.7954 - dice_WT: 0.8637 - loss: 0.0090 - mean_dice: 0.7682 - val_dice_ET: 0.6437 - val_dice_TC: 0.7860 - val_dice_WT: 0.8556 - val_loss: 0.0121 - val_mean_dice: 0.7618
# Epoch 84/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6383 - dice_TC: 0.7888 - dice_WT: 0.8599 - loss: 0.0088 - mean_dice: 0.7623
# Epoch 84: val_mean_dice improved from 0.76197 to 0.76260, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 84: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6457 - dice_TC: 0.7956 - dice_WT: 0.8639 - loss: 0.0090 - mean_dice: 0.7684 - val_dice_ET: 0.6453 - val_dice_TC: 0.7866 - val_dice_WT: 0.8559 - val_loss: 0.0121 - val_mean_dice: 0.7626
# Epoch 85/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6445 - dice_TC: 0.7902 - dice_WT: 0.8598 - loss: 0.0089 - mean_dice: 0.7649
# Epoch 85: val_mean_dice did not improve from 0.76260
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6458 - dice_TC: 0.7955 - dice_WT: 0.8643 - loss: 0.0089 - mean_dice: 0.7686 - val_dice_ET: 0.6450 - val_dice_TC: 0.7866 - val_dice_WT: 0.8560 - val_loss: 0.0121 - val_mean_dice: 0.7626
# Epoch 86/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6542 - dice_TC: 0.8022 - dice_WT: 0.8663 - loss: 0.0090 - mean_dice: 0.7742
# Epoch 86: val_mean_dice did not improve from 0.76260
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6459 - dice_TC: 0.7961 - dice_WT: 0.8643 - loss: 0.0089 - mean_dice: 0.7688 - val_dice_ET: 0.6450 - val_dice_TC: 0.7863 - val_dice_WT: 0.8562 - val_loss: 0.0121 - val_mean_dice: 0.7625
# Epoch 87/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6449 - dice_TC: 0.7929 - dice_WT: 0.8644 - loss: 0.0088 - mean_dice: 0.7674
# Epoch 87: val_mean_dice did not improve from 0.76260
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6460 - dice_TC: 0.7958 - dice_WT: 0.8638 - loss: 0.0089 - mean_dice: 0.7685 - val_dice_ET: 0.6447 - val_dice_TC: 0.7861 - val_dice_WT: 0.8554 - val_loss: 0.0121 - val_mean_dice: 0.7621
# Epoch 88/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6477 - dice_TC: 0.8005 - dice_WT: 0.8668 - loss: 0.0089 - mean_dice: 0.7717
# Epoch 88: val_mean_dice did not improve from 0.76260
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6461 - dice_TC: 0.7960 - dice_WT: 0.8644 - loss: 0.0089 - mean_dice: 0.7688 - val_dice_ET: 0.6450 - val_dice_TC: 0.7868 - val_dice_WT: 0.8559 - val_loss: 0.0120 - val_mean_dice: 0.7626
# Epoch 89/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6373 - dice_TC: 0.7930 - dice_WT: 0.8597 - loss: 0.0088 - mean_dice: 0.7633
# Epoch 89: val_mean_dice improved from 0.76260 to 0.76290, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 89: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6465 - dice_TC: 0.7962 - dice_WT: 0.8645 - loss: 0.0089 - mean_dice: 0.7690 - val_dice_ET: 0.6456 - val_dice_TC: 0.7869 - val_dice_WT: 0.8562 - val_loss: 0.0121 - val_mean_dice: 0.7629
# Epoch 90/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6517 - dice_TC: 0.8026 - dice_WT: 0.8698 - loss: 0.0088 - mean_dice: 0.7747
# Epoch 90: val_mean_dice did not improve from 0.76290
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6464 - dice_TC: 0.7963 - dice_WT: 0.8646 - loss: 0.0088 - mean_dice: 0.7691 - val_dice_ET: 0.6444 - val_dice_TC: 0.7865 - val_dice_WT: 0.8561 - val_loss: 0.0122 - val_mean_dice: 0.7623
# Epoch 91/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6518 - dice_TC: 0.7997 - dice_WT: 0.8676 - loss: 0.0088 - mean_dice: 0.7730
# Epoch 91: val_mean_dice did not improve from 0.76290
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6465 - dice_TC: 0.7965 - dice_WT: 0.8649 - loss: 0.0089 - mean_dice: 0.7693 - val_dice_ET: 0.6451 - val_dice_TC: 0.7866 - val_dice_WT: 0.8560 - val_loss: 0.0122 - val_mean_dice: 0.7626
# Epoch 92/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6533 - dice_TC: 0.8015 - dice_WT: 0.8681 - loss: 0.0089 - mean_dice: 0.7743
# Epoch 92: val_mean_dice did not improve from 0.76290
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6470 - dice_TC: 0.7968 - dice_WT: 0.8648 - loss: 0.0088 - mean_dice: 0.7695 - val_dice_ET: 0.6452 - val_dice_TC: 0.7866 - val_dice_WT: 0.8559 - val_loss: 0.0122 - val_mean_dice: 0.7626
# Epoch 93/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6503 - dice_TC: 0.8007 - dice_WT: 0.8676 - loss: 0.0089 - mean_dice: 0.7729
# Epoch 93: val_mean_dice improved from 0.76290 to 0.76291, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
#
# Epoch 93: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6471 - dice_TC: 0.7968 - dice_WT: 0.8647 - loss: 0.0089 - mean_dice: 0.7695 - val_dice_ET: 0.6453 - val_dice_TC: 0.7868 - val_dice_WT: 0.8565 - val_loss: 0.0122 - val_mean_dice: 0.7629
# Epoch 94/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6542 - dice_TC: 0.7997 - dice_WT: 0.8655 - loss: 0.0090 - mean_dice: 0.7731
# Epoch 94: val_mean_dice did not improve from 0.76291
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6468 - dice_TC: 0.7969 - dice_WT: 0.8649 - loss: 0.0089 - mean_dice: 0.7695 - val_dice_ET: 0.6445 - val_dice_TC: 0.7868 - val_dice_WT: 0.8563 - val_loss: 0.0121 - val_mean_dice: 0.7625
# Epoch 95/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6435 - dice_TC: 0.7956 - dice_WT: 0.8661 - loss: 0.0087 - mean_dice: 0.7684
# Epoch 95: val_mean_dice did not improve from 0.76291
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6472 - dice_TC: 0.7970 - dice_WT: 0.8648 - loss: 0.0088 - mean_dice: 0.7697 - val_dice_ET: 0.6450 - val_dice_TC: 0.7868 - val_dice_WT: 0.8564 - val_loss: 0.0121 - val_mean_dice: 0.7627
# Epoch 96/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6475 - dice_TC: 0.7977 - dice_WT: 0.8640 - loss: 0.0089 - mean_dice: 0.7698
# Epoch 96: val_mean_dice did not improve from 0.76291
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6465 - dice_TC: 0.7966 - dice_WT: 0.8648 - loss: 0.0088 - mean_dice: 0.7693 - val_dice_ET: 0.6450 - val_dice_TC: 0.7867 - val_dice_WT: 0.8562 - val_loss: 0.0122 - val_mean_dice: 0.7626
# Epoch 97/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6427 - dice_TC: 0.7921 - dice_WT: 0.8644 - loss: 0.0088 - mean_dice: 0.7664
# Epoch 97: val_mean_dice did not improve from 0.76291
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6472 - dice_TC: 0.7972 - dice_WT: 0.8650 - loss: 0.0088 - mean_dice: 0.7698 - val_dice_ET: 0.6453 - val_dice_TC: 0.7869 - val_dice_WT: 0.8564 - val_loss: 0.0121 - val_mean_dice: 0.7629
# Epoch 98/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6438 - dice_TC: 0.7949 - dice_WT: 0.8644 - loss: 0.0088 - mean_dice: 0.7677
# Epoch 98: val_mean_dice did not improve from 0.76291
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6469 - dice_TC: 0.7969 - dice_WT: 0.8651 - loss: 0.0088 - mean_dice: 0.7697 - val_dice_ET: 0.6451 - val_dice_TC: 0.7869 - val_dice_WT: 0.8565 - val_loss: 0.0122 - val_mean_dice: 0.7628
# Epoch 99/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6473 - dice_TC: 0.7968 - dice_WT: 0.8672 - loss: 0.0087 - mean_dice: 0.7704
# Epoch 99: val_mean_dice did not improve from 0.76291
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6470 - dice_TC: 0.7969 - dice_WT: 0.8650 - loss: 0.0088 - mean_dice: 0.7696 - val_dice_ET: 0.6452 - val_dice_TC: 0.7869 - val_dice_WT: 0.8565 - val_loss: 0.0121 - val_mean_dice: 0.7629
# Epoch 100/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6441 - dice_TC: 0.7926 - dice_WT: 0.8645 - loss: 0.0088 - mean_dice: 0.7671
# Epoch 100: val_mean_dice did not improve from 0.76291
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6470 - dice_TC: 0.7965 - dice_WT: 0.8650 - loss: 0.0088 - mean_dice: 0.7695 - val_dice_ET: 0.6450 - val_dice_TC: 0.7869 - val_dice_WT: 0.8564 - val_loss: 0.0121 - val_mean_dice: 0.7628
# Restoring model weights from the end of the best epoch: 93.

# %%
# Training Curves

def plot_training_curves(history, save_path):
    hist   = history.history
    epochs = range(1, len(hist["loss"]) + 1)

    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    fig.suptitle("Training & Validation Curves", fontsize=14)

    # Loss
    ax = axes[0, 0]
    ax.plot(epochs, hist["loss"],     label="Train", color="steelblue")
    ax.plot(epochs, hist["val_loss"], label="Val",   color="tomato", linestyle="--")
    ax.set_title("Loss")
    ax.set_xlabel("Epoch"); ax.legend(); ax.grid(True, alpha=0.3)

    # Mean Dice
    ax = axes[0, 1]
    ax.plot(epochs, hist["mean_dice"],     label="Train", color="steelblue")
    ax.plot(epochs, hist["val_mean_dice"], label="Val",   color="tomato", linestyle="--")
    ax.set_title("Mean Dice")
    ax.set_xlabel("Epoch"); ax.legend(); ax.grid(True, alpha=0.3)

    # Learning rate
    ax = axes[0, 2]
    if "lr" in hist:
        ax.semilogy(epochs, hist["lr"], color="purple")
    ax.set_title("Learning Rate (log scale)")
    ax.set_xlabel("Epoch"); ax.grid(True, alpha=0.3)

    # Per-region Dice
    region_cfg = [
        ("dice_WT", "val_dice_WT", "WT Dice", "royalblue"),
        ("dice_ET", "val_dice_ET", "ET Dice", "tomato"),
        ("dice_TC", "val_dice_TC", "TC Dice", "darkorange"),
    ]
    for idx, (tr_key, val_key, title, color) in enumerate(region_cfg):
        ax = axes[1, idx]
        if tr_key  in hist: ax.plot(epochs, hist[tr_key],  label="Train",
                                    color=color)
        if val_key in hist: ax.plot(epochs, hist[val_key], label="Val",
                                    color=color, linestyle="--", alpha=0.7)
        ax.set_title(title)
        ax.set_xlabel("Epoch"); ax.legend(); ax.grid(True, alpha=0.3)

    fig.tight_layout()
    save_and_show(fig, save_path, "training curves")

plot_training_curves(history, CURVES_PATH)
# Out:
# Saved → /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/training_curves.png  (training curves)

# %%
# Evaluation on Test Set

print("\n" + "="*58)
print("  Evaluating on Test  (best model weights)")
print("="*58)

test_results = model.evaluate(test_ds, verbose=1)
metric_names = model.metrics_names

print("\n ")
print("   Test Evaluation:         ")

for name, val in zip(metric_names, test_results):
    print(f"  {name:<24s}: {val:.4f}  ")


with open(EVAL_PATH, "w") as f:
    f.write("=" * 52 + "\n")
    f.write("  Test Evaluation Results\n")
    f.write("=" * 52 + "\n")
    for name, val in zip(metric_names, test_results):
        f.write(f"  {name:<28s}: {val:.6f}\n")
    f.write("=" * 52 + "\n")

print(f"\nEvaluation results saved → {EVAL_PATH}")
# Out:
# ==========================================================
#   Evaluating on Test  (best model weights)
# ==========================================================
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - dice_ET: 0.6381 - dice_TC: 0.7734 - dice_WT: 0.8467 - loss: 0.0123 - mean_dice: 0.7527
#
#
#    Test Evaluation:
#   loss                    : 0.0123
#   compile_metrics         : 0.8467
#
# Evaluation results saved → /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run79/evaluation_results.txt
