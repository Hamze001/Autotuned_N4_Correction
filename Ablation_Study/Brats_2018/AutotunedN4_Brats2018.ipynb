# %%
pip install nilearn
# Out:
# Collecting nilearn
#   Downloading nilearn-0.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from nilearn) (3.1.6)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (1.5.3)
# Requirement already satisfied: nibabel>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (5.4.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.12/dist-packages (from nilearn) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from nilearn) (26.0)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (2.2.2)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (2.32.4)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (1.6.1)
# Requirement already satisfied: scipy>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (1.16.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1.2->nilearn) (3.0.3)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.12/dist-packages (from nibabel>=5.2.0->nilearn) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->nilearn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->nilearn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->nilearn) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (2026.2.25)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.0->nilearn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->nilearn) (1.17.0)
# Downloading nilearn-0.13.1-py3-none-any.whl (10.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 131.7 MB/s eta 0:00:00
# Installing collected packages: nilearn
# Successfully installed nilearn-0.13.1

# %%
import os
import cv2
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
from skimage import data
from skimage.util import montage
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps

import nilearn as nl
import nibabel as nib
import nilearn.plotting as nlplt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom, Rescaling
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam

from scipy.spatial.distance import directed_hausdorff
from scipy.ndimage import binary_erosion, generate_binary_structure
from scipy.spatial.distance import cdist

np.set_printoptions(precision=3, suppress=True)
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import (
    EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
)
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split

import matplotlib
matplotlib.use("module://ipykernel.pylab.backend_inline")
import matplotlib.pyplot as plt
plt.rcParams["figure.dpi"] = 110

print("TensorFlow:", tf.__version__)
print("Keras:     ", tf.keras.__version__)
print("GPU:", tf.config.list_physical_devices("GPU"))
tf.keras.backend.set_floatx("float32")

SAVE_DIR = "/content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80"
os.makedirs(SAVE_DIR, exist_ok=True)
# Out:
# TensorFlow: 2.19.0
# Keras:      3.13.2
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Paths & Configuration

BEST_MODEL_PATH   = os.path.join(SAVE_DIR, "best_model.keras")
LAST_WEIGHTS_PATH = os.path.join(SAVE_DIR, "last.weights.h5")
LOG_PATH          = os.path.join(SAVE_DIR, "history.csv")
CURVES_PATH       = os.path.join(SAVE_DIR, "training_curves.png")
PREDS_PATH        = os.path.join(SAVE_DIR, "predictions.png")
EVAL_PATH         = os.path.join(SAVE_DIR, "evaluation_results.txt")


IMG_HEIGHT    = 160
IMG_WIDTH     = 160
IN_CHANNELS   = 4
OUT_CHANNELS  = 3
BASE_FILTERS  = 64
GROUPS        = 8

BATCH_SIZE    = 16
EPOCHS        = 100
LEARNING_RATE = 1e-4
PATIENCE      = 10
VAL_SPLIT     = 0.15
TEST_SPLIT    = 0.15
SEED          = 42

WT_WEIGHT     = 0.5
ET_WEIGHT     = 2.0
TC_WEIGHT     = 1.5

KEEP_TIER_A   = 1.00
KEEP_TIER_B   = 0.60
KEEP_TIER_C   = 0.15
KEEP_TIER_D   = 0.05
MIN_ET_VOXELS = 5
MIN_TC_VOXELS = 10
MIN_WT_VOXELS = 10

CHANNEL_NAMES   = ["WT", "ET", "TC"]
CHANNEL_WEIGHTS = [WT_WEIGHT, ET_WEIGHT, TC_WEIGHT]

# %%
# save figure to Drive AND display inline

def save_and_show(fig, save_path, caption=""):
    fig.savefig(save_path, dpi=150, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print(f"Saved → {save_path}" + (f"  ({caption})" if caption else ""))

# %%
# Data Loading

from zipfile import ZipFile
with ZipFile('/content/drive/MyDrive/BRAIN2018_CORRECTED_NORMALIZED_CROPPED160.zip', 'r') as z:
    z.extractall('/content/CROPPED2018')

BRAIN2018_CROPPED = "/content/CROPPED2018"


def create_multimodal_image(dataset_root_dir):
    modalities = ["t1", "t1ce", "t2", "flair"]
    data, grade = {}, {}
    for gf in ["HGG", "LGG"]:
        gp = os.path.join(dataset_root_dir, gf)
        if not os.path.exists(gp):
            continue
        for pid in os.listdir(gp):
            pd_ = os.path.join(gp, pid)
            if not os.path.isdir(pd_):
                continue
            imgs, ok = [], True
            for mod in modalities:
                fp = os.path.join(pd_, f"{pid}_{mod}_pre.nii")
                if not os.path.exists(fp):
                    ok = False; break
                imgs.append(nib.load(fp).get_fdata().astype(np.float32))
            if ok:
                data[pid]  = np.stack(imgs, axis=-1)
                grade[pid] = gf
    return data, grade


def create_combined_label_masks(seg_path):
    seg = nib.load(seg_path).get_fdata().astype(np.uint8)
    return np.stack([
        np.isin(seg, [1, 2, 4]).astype(np.float32),   # WT
        (seg == 4).astype(np.float32),                  # ET
        np.isin(seg, [1, 4]).astype(np.float32),        # TC
    ], axis=-1)


def load_all_patients(root):
    mdata, mgrade = create_multimodal_image(root)
    pids, grades, xvols, yvols = [], [], [], []
    for pid in mdata:
        for gf in ["HGG", "LGG"]:
            sp = os.path.join(root, gf, pid, f"{pid}_seg_pre.nii")
            if os.path.exists(sp):
                xv = mdata[pid]; yv = create_combined_label_masks(sp)
                if xv.shape[:3] == yv.shape[:3]:
                    pids.append(pid); grades.append(mgrade[pid])
                    xvols.append(xv);  yvols.append(yv)
                break
    print(f"Loaded {len(xvols)} patients")
    return pids, grades, xvols, yvols


patient_ids, grades, X_volumes, Y_volumes = load_all_patients(BRAIN2018_CROPPED)
# Out:
# Loaded 285 patients

# %%
# Volume Cleaning

def clean_volumes(xvols):
    return [
        np.clip(np.nan_to_num(x, nan=0., posinf=0., neginf=0.), -5., 5.)
        for x in xvols
    ]

X_volumes = clean_volumes(X_volumes)

# %%
# Balanced Slice Extraction

def volumes_to_2d_slices_balanced(
    x_volumes, y_volumes,
    min_et_voxels=MIN_ET_VOXELS, min_tc_voxels=MIN_TC_VOXELS,
    min_wt_voxels=MIN_WT_VOXELS,
    keep_tier_a=KEEP_TIER_A, keep_tier_b=KEEP_TIER_B,
    keep_tier_c=KEEP_TIER_C, keep_tier_d=KEEP_TIER_D, seed=SEED,
):
    rng = np.random.default_rng(seed)
    xl, yl, tl = [], [], []
    counts = {t: 0 for t in ["A","B","C","D","A_skip","B_skip","C_skip","D_skip"]}
    for xv, yv in zip(x_volumes, y_volumes):
        for d in range(xv.shape[2]):
            xs = xv[:, :, d, :]; ys = yv[:, :, d, :]
            wt_fg = int(ys[..., 0].sum()) >= min_wt_voxels
            tc_fg = int(ys[..., 2].sum()) >= min_tc_voxels
            et_fg = int(ys[..., 1].sum()) >= min_et_voxels
            if   wt_fg and tc_fg and et_fg: tier, rate = "A", keep_tier_a
            elif wt_fg and tc_fg:           tier, rate = "B", keep_tier_b
            elif wt_fg:                     tier, rate = "C", keep_tier_c
            else:                           tier, rate = "D", keep_tier_d
            if rng.random() < rate:
                xl.append(xs); yl.append(ys); tl.append(tier)
                counts[tier] += 1
            else:
                counts[f"{tier}_skip"] += 1
    X = np.array(xl, np.float32); Y = np.array(yl, np.float32)
    descs = {"A":"WT+TC+ET","B":"WT+TC (no ET)","C":"WT only","D":"no fg"}
    print("\n" + "="*58)
    print("  Balanced Slice Extraction")
    print("="*58)
    for t in ["A","B","C","D"]:
        print(f"  Tier {t} ({descs[t]:<16}): "
              f"kept={counts[t]:5d}  skipped={counts[t+'_skip']:5d}")
    print(f"  Total: {len(X)}")
    print("="*58)
    return X, Y, tl


def print_slice_balance(Y, tier_labels, split_name="Dataset"):
    wt_v = Y[...,0].sum(axis=(1,2)); et_v = Y[...,1].sum(axis=(1,2))
    tc_v = Y[...,2].sum(axis=(1,2)); N = len(Y)
    tc = {t: tier_labels.count(t) for t in ["A","B","C","D"]}
    print(f"\n  [{split_name}]  {N} slices  "
          f"A={tc['A']} B={tc['B']} C={tc['C']} D={tc['D']}")
    for name, v in [("WT", wt_v), ("ET", et_v), ("TC", tc_v)]:
        print(f"    {name}: {(v>0).mean()*100:5.1f}% present  "
              f"mean={v.mean():.1f} vox")
    print(f"    Nesting: ET≤TC={(et_v<=tc_v+1).all()}  "
          f"TC≤WT={(tc_v<=wt_v+1).all()}")


X_sl, Y_sl, tier_labels = volumes_to_2d_slices_balanced(X_volumes, Y_volumes)
del X_volumes, Y_volumes
print_slice_balance(Y_sl, tier_labels, "Full balanced dataset")
# Out:
# ==========================================================
#   Balanced Slice Extraction
# ==========================================================
#   Tier A (WT+TC+ET        ): kept=10288  skipped=    0
#   Tier B (WT+TC (no ET)   ): kept= 1412  skipped=  973
#   Tier C (WT only         ): kept=  855  skipped= 4874
#   Tier D (no fg           ): kept=  926  skipped=17152
#   Total: 13481
# ==========================================================
#
#   [Full balanced dataset]  13481 slices  A=10288 B=1412 C=855 D=926
#     WT:  93.3% present  mean=1765.1 vox
#     ET:  77.2% present  mean=384.1 vox
#     TC:  87.2% present  mean=834.7 vox
#     Nesting: ET≤TC=True  TC≤WT=True

# %%
# Train / Val / Test Split  (70% / 15% / 15%)

X_trainval, X_test, Y_trainval, Y_test, tl_trainval, tl_test = train_test_split(
    X_sl, Y_sl, tier_labels,
    test_size=TEST_SPLIT, random_state=SEED, shuffle=True
)


val_fraction_of_trainval = VAL_SPLIT / (1.0 - TEST_SPLIT)

X_train, X_val, Y_train, Y_val, tl_train, tl_val = train_test_split(
    X_trainval, Y_trainval, tl_trainval,
    test_size=val_fraction_of_trainval, random_state=SEED, shuffle=True
)

del X_sl, Y_sl, X_trainval, Y_trainval

print("\nAfter split:")
print_slice_balance(Y_train, tl_train, "Train  (~70%)")
print_slice_balance(Y_val,   tl_val,   "Val    (~15%)")
print_slice_balance(Y_test,  tl_test,  "Test   (~15%)")
print(f"\nTrain : {X_train.shape}"
      f"\nVal   : {X_val.shape}"
      f"\nTest  : {X_test.shape}")
# Out:
# After split:
#
#   [Train  (~70%)]  9435 slices  A=7197 B=989 C=590 D=659
#     WT:  93.2% present  mean=1764.9 vox
#     ET:  77.1% present  mean=386.1 vox
#     TC:  87.1% present  mean=835.2 vox
#     Nesting: ET≤TC=True  TC≤WT=True
#
#   [Val    (~15%)]  2023 slices  A=1558 B=213 C=128 D=124
#     WT:  93.9% present  mean=1776.1 vox
#     ET:  78.1% present  mean=381.4 vox
#     TC:  87.8% present  mean=836.0 vox
#     Nesting: ET≤TC=True  TC≤WT=True
#
#   [Test   (~15%)]  2023 slices  A=1533 B=210 C=137 D=143
#     WT:  93.1% present  mean=1754.5 vox
#     ET:  76.8% present  mean=377.4 vox
#     TC:  86.8% present  mean=830.8 vox
#     Nesting: ET≤TC=True  TC≤WT=True
#
# Train : (9435, 160, 160, 4)
# Val   : (2023, 160, 160, 4)
# Test  : (2023, 160, 160, 4)

# %%
# tf.data Pipeline

AUTOTUNE = tf.data.AUTOTUNE


def augment(img, msk):

    # Zoom (±20%)
    zoom = tf.random.uniform([], 0.8, 1.2)

    h = tf.shape(img)[0]
    w = tf.shape(img)[1]

    new_h = tf.cast(tf.cast(h, tf.float32) * zoom, tf.int32)
    new_w = tf.cast(tf.cast(w, tf.float32) * zoom, tf.int32)

    img = tf.image.resize(img, (new_h, new_w), method='bilinear')
    msk = tf.image.resize(msk, (new_h, new_w), method='nearest')

    img = tf.image.resize_with_crop_or_pad(img, h, w)
    msk = tf.image.resize_with_crop_or_pad(msk, h, w)


    # Width & Height Shift (±20%)
    max_dx = tf.cast(0.2 * tf.cast(w, tf.float32), tf.int32)
    max_dy = tf.cast(0.2 * tf.cast(h, tf.float32), tf.int32)

    dx = tf.random.uniform([], -max_dx, max_dx, dtype=tf.int32)
    dy = tf.random.uniform([], -max_dy, max_dy, dtype=tf.int32)

    img = tf.roll(img, shift=[dy, dx], axis=[0, 1])
    msk = tf.roll(msk, shift=[dy, dx], axis=[0, 1])

    #Flip
    if tf.random.uniform(()) > 0.2:
      img = tf.image.flip_left_right(img)
      msk = tf.image.flip_left_right(msk)
    if tf.random.uniform(()) > 0.2:
      img = tf.image.flip_up_down(img)
      msk = tf.image.flip_up_down(msk)

    return img, msk


def make_dataset(X, Y, training=False):
    ds = tf.data.Dataset.from_tensor_slices((X, Y))
    if training:
        ds = ds.shuffle(len(X), seed=SEED).map(augment, num_parallel_calls=AUTOTUNE)
    return ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)


train_ds = make_dataset(X_train, Y_train, training=True)
val_ds   = make_dataset(X_val,   Y_val,   training=False)
test_ds  = make_dataset(X_test,  Y_test,  training=False)

print(f"\nTrain batches : {len(train_ds)}"
      f"\nVal   batches : {len(val_ds)}"
      f"\nTest  batches : {len(test_ds)}")
# Out:
# Train batches : 590
# Val   batches : 127
# Test  batches : 127

# %%
# U-Net Architecture

def conv_block(x, filters, groups=GROUPS):

    for _ in range(2):
        x = layers.Conv2D(
            filters, 3, padding="same", use_bias=False,
            kernel_initializer="he_normal"
        )(x)
        x = layers.GroupNormalization(groups=groups)(x)
        x = layers.Activation("relu")(x)
    return x


def encoder_block(x, filters):

    skip = conv_block(x, filters)
    pool = layers.MaxPooling2D(2)(skip)
    return skip, pool


def decoder_block(x, skip, filters):

    x = layers.Conv2DTranspose(
        filters, 2, strides=2, padding="same",
        kernel_initializer="he_normal"
    )(x)
    x = layers.Concatenate()([x, skip])
    x = conv_block(x, filters)
    return x


def build_unet(
    img_height=IMG_HEIGHT, img_width=IMG_WIDTH,
    in_channels=IN_CHANNELS, out_channels=OUT_CHANNELS,
    base_filters=BASE_FILTERS, dropout_rate=0.3
):

    inputs = layers.Input(
        shape=(img_height, img_width, in_channels), name="input"
    )

    # ── Encoder ────────────────────────────────────────────────────────────
    s1, p1 = encoder_block(inputs, base_filters)         # filters=64
    s2, p2 = encoder_block(p1,     base_filters * 2)     # filters=128
    s3, p3 = encoder_block(p2,     base_filters * 4)     # filters=256
    s4, p4 = encoder_block(p3,     base_filters * 8)     # filters=512

    # ── Bottleneck ─────────────────────────────────────────────────────────
    b = conv_block(p4, base_filters * 16)                # filters=1024
    b = layers.Dropout(dropout_rate)(b)

    # ── Decoder ────────────────────────────────────────────────────────────
    d4 = decoder_block(b,  s4, base_filters * 8)         # filters=512
    d3 = decoder_block(d4, s3, base_filters * 4)         # filters=256
    d2 = decoder_block(d3, s2, base_filters * 2)         # filters=128
    d1 = decoder_block(d2, s1, base_filters)             # filters=64

    # ── Output ────────────────────────────────────────────────────────
    outputs = layers.Conv2D(
        out_channels, 1, activation="sigmoid", name="output"
    )(d1)

    return Model(inputs, outputs, name="UNet_2D")


model = build_unet()
model.summary()
# Out:
# Model: "UNet_2D"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 160, 160,  │          0 │ -                 │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 160, 160,  │      2,304 │ input[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalization │ (None, 160, 160,  │        128 │ conv2d[0][0]      │
# │ (GroupNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 160, 160,  │          0 │ group_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 160, 160,  │     36,864 │ activation[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 160, 160,  │        128 │ conv2d_1[0][0]    │
# │ (GroupNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 160, 160,  │          0 │ group_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 80, 80,    │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 80, 80,    │     73,728 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 80, 80,    │        256 │ conv2d_2[0][0]    │
# │ (GroupNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 80, 80,    │          0 │ group_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 80, 80,    │    147,456 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 80, 80,    │        256 │ conv2d_3[0][0]    │
# │ (GroupNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 80, 80,    │          0 │ group_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 40, 40,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 40, 40,    │    294,912 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 40, 40,    │        512 │ conv2d_4[0][0]    │
# │ (GroupNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 40, 40,    │          0 │ group_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 40, 40,    │    589,824 │ activation_4[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 40, 40,    │        512 │ conv2d_5[0][0]    │
# │ (GroupNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 40, 40,    │          0 │ group_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 20, 20,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 20, 20,    │  1,179,648 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 20, 20,    │      1,024 │ conv2d_6[0][0]    │
# │ (GroupNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 20, 20,    │          0 │ group_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 20, 20,    │  2,359,296 │ activation_6[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 20, 20,    │      1,024 │ conv2d_7[0][0]    │
# │ (GroupNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 20, 20,    │          0 │ group_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 10, 10,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 10, 10,    │  4,718,592 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 10, 10,    │      2,048 │ conv2d_8[0][0]    │
# │ (GroupNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 10, 10,    │          0 │ group_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 10, 10,    │  9,437,184 │ activation_8[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 10, 10,    │      2,048 │ conv2d_9[0][0]    │
# │ (GroupNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 10, 10,    │          0 │ group_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 10, 10,    │          0 │ activation_9[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 20, 20,    │  2,097,664 │ dropout[0][0]     │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 20, 20,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 20, 20,    │  4,718,592 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 20, 20,    │      1,024 │ conv2d_10[0][0]   │
# │ (GroupNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 20, 20,    │          0 │ group_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 20, 20,    │  2,359,296 │ activation_10[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 20, 20,    │      1,024 │ conv2d_11[0][0]   │
# │ (GroupNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 20, 20,    │          0 │ group_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 40, 40,    │    524,544 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 40, 40,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 40, 40,    │  1,179,648 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 40, 40,    │        512 │ conv2d_12[0][0]   │
# │ (GroupNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 40, 40,    │          0 │ group_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 40, 40,    │    589,824 │ activation_12[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 40, 40,    │        512 │ conv2d_13[0][0]   │
# │ (GroupNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 40, 40,    │          0 │ group_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 80, 80,    │    131,200 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 80, 80,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 80, 80,    │    294,912 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 80, 80,    │        256 │ conv2d_14[0][0]   │
# │ (GroupNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 80, 80,    │          0 │ group_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 80, 80,    │    147,456 │ activation_14[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 80, 80,    │        256 │ conv2d_15[0][0]   │
# │ (GroupNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 80, 80,    │          0 │ group_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 160, 160,  │     32,832 │ activation_15[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 160, 160,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 160, 160,  │     73,728 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 160, 160,  │        128 │ conv2d_16[0][0]   │
# │ (GroupNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 160, 160,  │          0 │ group_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 160, 160,  │     36,864 │ activation_16[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 160, 160,  │        128 │ conv2d_17[0][0]   │
# │ (GroupNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 160, 160,  │          0 │ group_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Conv2D)     │ (None, 160, 160,  │        195 │ activation_17[0]… │
# │                     │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,038,339 (118.40 MB)
#  Trainable params: 31,038,339 (118.40 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Loss Function

def _boundary_weight_map(y_true_ch, pool_size=11, border_weight=3.0):

    averaged = tf.nn.avg_pool2d(
        y_true_ch,
        ksize=pool_size,
        strides=1,
        padding="SAME"
    )                                      # (B, H, W, 1)

    border = tf.cast(averaged > 0.005, tf.float32) * \
             tf.cast(averaged < 0.995, tf.float32)   # (B, H, W, 1)

    weight  = tf.ones_like(averaged)
    w0      = tf.reduce_sum(weight)
    weight  = weight + border * (border_weight - 1.0)
    w1      = tf.reduce_sum(weight)

    weight  = weight * (w0 / (w1 + 1e-8))
    return weight


def _weighted_bce_channel(y_true_ch, y_pred_ch, weight):

    epsilon   = 1e-7
    y_pred_ch = tf.clip_by_value(y_pred_ch, epsilon, 1.0 - epsilon)
    logit     = tf.math.log(y_pred_ch / (1.0 - y_pred_ch))

    bce = ((1.0 - y_true_ch) * logit
           + (1.0 + (weight - 1.0) * y_true_ch)
           * (tf.math.log(1.0 + tf.exp(-tf.abs(logit)))
              + tf.maximum(-logit, 0.0)))

    return tf.reduce_sum(bce) / (tf.reduce_sum(weight) + 1e-8)


def _weighted_dice_channel(y_true_ch, y_pred_ch, weight, smooth=1.0):

    w   = weight * weight
    m1  = y_true_ch
    m2  = y_pred_ch
    intersection = tf.reduce_sum(w * m1 * m2)
    denom        = tf.reduce_sum(w * (m1 ** 2)) + tf.reduce_sum(w * (m2 ** 2))
    score        = (2.0 * intersection + smooth) / (denom + smooth)
    return 1.0 - score


def weighted_boundary_loss_fn(
    wt_weight   = WT_WEIGHT,    # 1.0
    et_weight   = ET_WEIGHT,    # 2.0
    tc_weight   = TC_WEIGHT,    # 1.5
    pool_size   = 11,
    border_mult = 3.0,
    bce_frac    = 0.5,
):

    channel_weights = tf.constant(
        [wt_weight, et_weight, tc_weight], dtype=tf.float32)
    total_w = wt_weight + et_weight + tc_weight

    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.clip_by_value(tf.cast(y_pred, tf.float32), 1e-7, 1 - 1e-7)

        channel_losses = []
        for ch in range(3):
            y_t_ch = tf.expand_dims(y_true[..., ch], axis=-1)  # (B,H,W,1)
            y_p_ch = tf.expand_dims(y_pred[..., ch], axis=-1)

            w_map = _boundary_weight_map(y_t_ch, pool_size, border_mult)

            bce  = _weighted_bce_channel( y_t_ch, y_p_ch, w_map)
            dice = _weighted_dice_channel(y_t_ch, y_p_ch, w_map)

            ch_loss = bce_frac * bce + (1.0 - bce_frac) * dice
            channel_losses.append(ch_loss * channel_weights[ch])

        return tf.reduce_sum(tf.stack(channel_losses)) / total_w

    loss.__name__ = "weighted_boundary_loss"
    return loss


loss_fn = weighted_boundary_loss_fn()

# ── Pre-training loss check ────────────────────────────────────────────────────
print("\nLoss function: Weighted Boundary-Aware BCE + Dice")
print(f"  pool_size={11}  border_mult=3.0  bce_frac=0.5")
print(f"  Channel weights: WT={WT_WEIGHT}  ET={ET_WEIGHT}  TC={TC_WEIGHT}")

for xb, yb in train_ds.take(1):
    out = model(xb, training=False)
    lv  = loss_fn(yb, out).numpy()
    print(f"\nPre-training check:  loss={lv:.4f}  "
          f"NaN={np.isnan(out.numpy()).any()}")
# Out:
# Loss function: Weighted Boundary-Aware BCE + Dice
#   pool_size=11  border_mult=3.0  bce_frac=0.5
#   Channel weights: WT=0.5  ET=0.5  TC=0.5
#
# Pre-training check:  loss=0.7768  NaN=False

# %%
# Metrics

def soft_dice_per_channel(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    axes         = [1, 2]
    intersection = tf.reduce_sum(y_true * y_pred, axis=axes)   # (B, C)
    denom        = tf.reduce_sum(y_true + y_pred, axis=axes)   # (B, C)
    return (2.0 * intersection + smooth) / (denom + smooth)    # (B, C)


def dice_WT(y_true, y_pred, smooth=1e-6):
    return tf.reduce_mean(
        soft_dice_per_channel(y_true[..., 0:1], y_pred[..., 0:1], smooth)
    )

def dice_ET(y_true, y_pred, smooth=1e-6):
    return tf.reduce_mean(
        soft_dice_per_channel(y_true[..., 1:2], y_pred[..., 1:2], smooth)
    )

def dice_TC(y_true, y_pred, smooth=1e-6):
    return tf.reduce_mean(
        soft_dice_per_channel(y_true[..., 2:3], y_pred[..., 2:3], smooth)
    )

def dice_mean(y_true, y_pred, smooth=1e-6):
    return (dice_WT(y_true, y_pred, smooth) +
            dice_ET(y_true, y_pred, smooth) +
            dice_TC(y_true, y_pred, smooth)) / 3.0

def make_metrics():
    return [
        tf.keras.metrics.MeanMetricWrapper(dice_WT,   name="dice_WT"),
        tf.keras.metrics.MeanMetricWrapper(dice_ET,   name="dice_ET"),
        tf.keras.metrics.MeanMetricWrapper(dice_TC,   name="dice_TC"),
        tf.keras.metrics.MeanMetricWrapper(dice_mean, name="mean_dice"),
    ]


# ── Metric sanity check ────────────────────────────────────────────────────
print("\nMetric check ...")
_m = make_metrics()
for xb, yb in train_ds.take(1):
    _out = model(xb, training=False)
    for m in _m:
        m.update_state(yb, _out)
        print(f"  {m.name:<15} = {m.result().numpy():.4f}")
        m.reset_state()
del _m, _out
# Out:
# Metric check ...
#   dice_WT         = 0.0183
#   dice_ET         = 0.0432
#   dice_TC         = 0.0239
#   mean_dice       = 0.0285

# %%
# Compile

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=loss_fn,
    metrics=make_metrics()
)

for xb, yb in train_ds.take(1):
    out = model(xb, training=False)
    lv  = loss_fn(yb, out).numpy()
    print(f"\nPre-training check:  loss={lv:.4f}  NaN={np.isnan(out.numpy()).any()}")
# Out:
# Pre-training check:  loss=0.7652  NaN=False

# %%
callbacks = [
    ModelCheckpoint(
        filepath=BEST_MODEL_PATH,
        monitor="val_mean_dice",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    ModelCheckpoint(
        filepath=LAST_WEIGHTS_PATH,
        save_weights_only=True,
        verbose=0
    ),
    EarlyStopping(
        monitor="val_mean_dice",
        mode="max",
        patience=PATIENCE,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor="val_mean_dice",
        mode="max",
        factor=0.5,
        patience=5,
        min_lr=1e-7,
        verbose=0
    ),
    CSVLogger(LOG_PATH, append=True),
]

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - dice_ET: 0.4323 - dice_TC: 0.4342 - dice_WT: 0.5869 - loss: 0.2373 - mean_dice: 0.4844
# Epoch 1: val_mean_dice improved from None to 0.67879, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 116s 126ms/step - dice_ET: 0.5171 - dice_TC: 0.5358 - dice_WT: 0.6934 - loss: 0.1685 - mean_dice: 0.5821 - val_dice_ET: 0.6093 - val_dice_TC: 0.6607 - val_dice_WT: 0.7664 - val_loss: 0.1199 - val_mean_dice: 0.6788
# Epoch 2/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.5928 - dice_TC: 0.6507 - dice_WT: 0.7631 - loss: 0.1187 - mean_dice: 0.6689
# Epoch 2: val_mean_dice improved from 0.67879 to 0.71416, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 36s 61ms/step - dice_ET: 0.5988 - dice_TC: 0.6594 - dice_WT: 0.7697 - loss: 0.1144 - mean_dice: 0.6760 - val_dice_ET: 0.6432 - val_dice_TC: 0.7056 - val_dice_WT: 0.7936 - val_loss: 0.1030 - val_mean_dice: 0.7142
# Epoch 3/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6219 - dice_TC: 0.6848 - dice_WT: 0.7878 - loss: 0.1040 - mean_dice: 0.6982
# Epoch 3: val_mean_dice improved from 0.71416 to 0.73710, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.6364 - dice_TC: 0.7008 - dice_WT: 0.7946 - loss: 0.1000 - mean_dice: 0.7106 - val_dice_ET: 0.6684 - val_dice_TC: 0.7390 - val_dice_WT: 0.8039 - val_loss: 0.0943 - val_mean_dice: 0.7371
# Epoch 4/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6505 - dice_TC: 0.7168 - dice_WT: 0.8019 - loss: 0.0943 - mean_dice: 0.7230
# Epoch 4: val_mean_dice improved from 0.73710 to 0.74427, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 33s 55ms/step - dice_ET: 0.6585 - dice_TC: 0.7176 - dice_WT: 0.8041 - loss: 0.0927 - mean_dice: 0.7267 - val_dice_ET: 0.6967 - val_dice_TC: 0.7233 - val_dice_WT: 0.8128 - val_loss: 0.0904 - val_mean_dice: 0.7443
# Epoch 5/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6735 - dice_TC: 0.7415 - dice_WT: 0.8168 - loss: 0.0874 - mean_dice: 0.7439
# Epoch 5: val_mean_dice improved from 0.74427 to 0.74988, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.6733 - dice_TC: 0.7363 - dice_WT: 0.8135 - loss: 0.0871 - mean_dice: 0.7410 - val_dice_ET: 0.6808 - val_dice_TC: 0.7587 - val_dice_WT: 0.8101 - val_loss: 0.0894 - val_mean_dice: 0.7499
# Epoch 6/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6791 - dice_TC: 0.7453 - dice_WT: 0.8117 - loss: 0.0842 - mean_dice: 0.7454
# Epoch 6: val_mean_dice improved from 0.74988 to 0.77290, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 32s 54ms/step - dice_ET: 0.6815 - dice_TC: 0.7438 - dice_WT: 0.8202 - loss: 0.0838 - mean_dice: 0.7485 - val_dice_ET: 0.7258 - val_dice_TC: 0.7644 - val_dice_WT: 0.8285 - val_loss: 0.0832 - val_mean_dice: 0.7729
# Epoch 7/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.6933 - dice_TC: 0.7446 - dice_WT: 0.8230 - loss: 0.0807 - mean_dice: 0.7536
# Epoch 7: val_mean_dice did not improve from 0.77290
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.6986 - dice_TC: 0.7549 - dice_WT: 0.8240 - loss: 0.0799 - mean_dice: 0.7592 - val_dice_ET: 0.7208 - val_dice_TC: 0.7673 - val_dice_WT: 0.8136 - val_loss: 0.0816 - val_mean_dice: 0.7673
# Epoch 8/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7071 - dice_TC: 0.7619 - dice_WT: 0.8279 - loss: 0.0774 - mean_dice: 0.7657
# Epoch 8: val_mean_dice did not improve from 0.77290
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7038 - dice_TC: 0.7643 - dice_WT: 0.8309 - loss: 0.0769 - mean_dice: 0.7663 - val_dice_ET: 0.6898 - val_dice_TC: 0.7677 - val_dice_WT: 0.8269 - val_loss: 0.0811 - val_mean_dice: 0.7615
# Epoch 9/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7068 - dice_TC: 0.7666 - dice_WT: 0.8339 - loss: 0.0759 - mean_dice: 0.7691
# Epoch 9: val_mean_dice did not improve from 0.77290
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7113 - dice_TC: 0.7723 - dice_WT: 0.8351 - loss: 0.0744 - mean_dice: 0.7729 - val_dice_ET: 0.6768 - val_dice_TC: 0.7557 - val_dice_WT: 0.8310 - val_loss: 0.0790 - val_mean_dice: 0.7545
# Epoch 10/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7155 - dice_TC: 0.7715 - dice_WT: 0.8370 - loss: 0.0730 - mean_dice: 0.7746
# Epoch 10: val_mean_dice did not improve from 0.77290
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7142 - dice_TC: 0.7756 - dice_WT: 0.8390 - loss: 0.0725 - mean_dice: 0.7763 - val_dice_ET: 0.7140 - val_dice_TC: 0.7765 - val_dice_WT: 0.8254 - val_loss: 0.0831 - val_mean_dice: 0.7720
# Epoch 11/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7175 - dice_TC: 0.7781 - dice_WT: 0.8417 - loss: 0.0716 - mean_dice: 0.7791
# Epoch 11: val_mean_dice improved from 0.77290 to 0.77814, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 51ms/step - dice_ET: 0.7193 - dice_TC: 0.7799 - dice_WT: 0.8420 - loss: 0.0714 - mean_dice: 0.7804 - val_dice_ET: 0.7238 - val_dice_TC: 0.7732 - val_dice_WT: 0.8374 - val_loss: 0.0792 - val_mean_dice: 0.7781
# Epoch 12/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7271 - dice_TC: 0.7882 - dice_WT: 0.8402 - loss: 0.0700 - mean_dice: 0.7851
# Epoch 12: val_mean_dice improved from 0.77814 to 0.78816, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.7257 - dice_TC: 0.7843 - dice_WT: 0.8416 - loss: 0.0697 - mean_dice: 0.7838 - val_dice_ET: 0.7348 - val_dice_TC: 0.7849 - val_dice_WT: 0.8448 - val_loss: 0.0762 - val_mean_dice: 0.7882
# Epoch 13/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7269 - dice_TC: 0.7876 - dice_WT: 0.8428 - loss: 0.0676 - mean_dice: 0.7858
# Epoch 13: val_mean_dice did not improve from 0.78816
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.7278 - dice_TC: 0.7879 - dice_WT: 0.8451 - loss: 0.0681 - mean_dice: 0.7869 - val_dice_ET: 0.7317 - val_dice_TC: 0.7895 - val_dice_WT: 0.8390 - val_loss: 0.0727 - val_mean_dice: 0.7868
# Epoch 14/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7418 - dice_TC: 0.7955 - dice_WT: 0.8477 - loss: 0.0661 - mean_dice: 0.7950
# Epoch 14: val_mean_dice did not improve from 0.78816
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7298 - dice_TC: 0.7937 - dice_WT: 0.8487 - loss: 0.0663 - mean_dice: 0.7907 - val_dice_ET: 0.7288 - val_dice_TC: 0.7894 - val_dice_WT: 0.8432 - val_loss: 0.0744 - val_mean_dice: 0.7872
# Epoch 15/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7375 - dice_TC: 0.8040 - dice_WT: 0.8536 - loss: 0.0649 - mean_dice: 0.7984
# Epoch 15: val_mean_dice did not improve from 0.78816
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7363 - dice_TC: 0.8009 - dice_WT: 0.8517 - loss: 0.0649 - mean_dice: 0.7963 - val_dice_ET: 0.7331 - val_dice_TC: 0.7859 - val_dice_WT: 0.8434 - val_loss: 0.0705 - val_mean_dice: 0.7874
# Epoch 16/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7376 - dice_TC: 0.7997 - dice_WT: 0.8566 - loss: 0.0642 - mean_dice: 0.7979
# Epoch 16: val_mean_dice did not improve from 0.78816
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7320 - dice_TC: 0.7991 - dice_WT: 0.8534 - loss: 0.0648 - mean_dice: 0.7948 - val_dice_ET: 0.7346 - val_dice_TC: 0.7835 - val_dice_WT: 0.8395 - val_loss: 0.0809 - val_mean_dice: 0.7859
# Epoch 17/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7420 - dice_TC: 0.8092 - dice_WT: 0.8611 - loss: 0.0628 - mean_dice: 0.8041
# Epoch 17: val_mean_dice did not improve from 0.78816
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7414 - dice_TC: 0.8067 - dice_WT: 0.8560 - loss: 0.0622 - mean_dice: 0.8014 - val_dice_ET: 0.7233 - val_dice_TC: 0.7742 - val_dice_WT: 0.8358 - val_loss: 0.0754 - val_mean_dice: 0.7778
# Epoch 18/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7548 - dice_TC: 0.8224 - dice_WT: 0.8658 - loss: 0.0588 - mean_dice: 0.8143
# Epoch 18: val_mean_dice improved from 0.78816 to 0.80153, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 18: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.7537 - dice_TC: 0.8224 - dice_WT: 0.8669 - loss: 0.0584 - mean_dice: 0.8143 - val_dice_ET: 0.7502 - val_dice_TC: 0.8023 - val_dice_WT: 0.8520 - val_loss: 0.0724 - val_mean_dice: 0.8015
# Epoch 19/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7592 - dice_TC: 0.8273 - dice_WT: 0.8675 - loss: 0.0564 - mean_dice: 0.8180
# Epoch 19: val_mean_dice did not improve from 0.80153
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7550 - dice_TC: 0.8286 - dice_WT: 0.8700 - loss: 0.0570 - mean_dice: 0.8179 - val_dice_ET: 0.7438 - val_dice_TC: 0.8043 - val_dice_WT: 0.8521 - val_loss: 0.0670 - val_mean_dice: 0.8001
# Epoch 20/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7548 - dice_TC: 0.8297 - dice_WT: 0.8735 - loss: 0.0565 - mean_dice: 0.8194
# Epoch 20: val_mean_dice improved from 0.80153 to 0.80209, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 20: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.7560 - dice_TC: 0.8273 - dice_WT: 0.8689 - loss: 0.0567 - mean_dice: 0.8174 - val_dice_ET: 0.7561 - val_dice_TC: 0.7995 - val_dice_WT: 0.8506 - val_loss: 0.0684 - val_mean_dice: 0.8021
# Epoch 21/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7629 - dice_TC: 0.8347 - dice_WT: 0.8691 - loss: 0.0555 - mean_dice: 0.8222
# Epoch 21: val_mean_dice improved from 0.80209 to 0.80490, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 21: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.7588 - dice_TC: 0.8306 - dice_WT: 0.8708 - loss: 0.0557 - mean_dice: 0.8200 - val_dice_ET: 0.7534 - val_dice_TC: 0.8068 - val_dice_WT: 0.8545 - val_loss: 0.0681 - val_mean_dice: 0.8049
# Epoch 22/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7614 - dice_TC: 0.8273 - dice_WT: 0.8725 - loss: 0.0555 - mean_dice: 0.8204
# Epoch 22: val_mean_dice improved from 0.80490 to 0.80510, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 22: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 51ms/step - dice_ET: 0.7628 - dice_TC: 0.8306 - dice_WT: 0.8726 - loss: 0.0554 - mean_dice: 0.8220 - val_dice_ET: 0.7530 - val_dice_TC: 0.8065 - val_dice_WT: 0.8558 - val_loss: 0.0667 - val_mean_dice: 0.8051
# Epoch 23/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7716 - dice_TC: 0.8429 - dice_WT: 0.8772 - loss: 0.0542 - mean_dice: 0.8306
# Epoch 23: val_mean_dice did not improve from 0.80510
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7643 - dice_TC: 0.8357 - dice_WT: 0.8743 - loss: 0.0546 - mean_dice: 0.8248 - val_dice_ET: 0.7507 - val_dice_TC: 0.8085 - val_dice_WT: 0.8557 - val_loss: 0.0670 - val_mean_dice: 0.8050
# Epoch 24/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7712 - dice_TC: 0.8403 - dice_WT: 0.8755 - loss: 0.0534 - mean_dice: 0.8290
# Epoch 24: val_mean_dice did not improve from 0.80510
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 32s 55ms/step - dice_ET: 0.7689 - dice_TC: 0.8399 - dice_WT: 0.8755 - loss: 0.0535 - mean_dice: 0.8281 - val_dice_ET: 0.7516 - val_dice_TC: 0.8077 - val_dice_WT: 0.8545 - val_loss: 0.0691 - val_mean_dice: 0.8046
# Epoch 25/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7671 - dice_TC: 0.8358 - dice_WT: 0.8792 - loss: 0.0526 - mean_dice: 0.8273
# Epoch 25: val_mean_dice did not improve from 0.80510
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 35s 60ms/step - dice_ET: 0.7676 - dice_TC: 0.8389 - dice_WT: 0.8769 - loss: 0.0528 - mean_dice: 0.8278 - val_dice_ET: 0.7453 - val_dice_TC: 0.8047 - val_dice_WT: 0.8506 - val_loss: 0.0655 - val_mean_dice: 0.8002
# Epoch 26/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7750 - dice_TC: 0.8457 - dice_WT: 0.8813 - loss: 0.0525 - mean_dice: 0.8340
# Epoch 26: val_mean_dice did not improve from 0.80510
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7708 - dice_TC: 0.8429 - dice_WT: 0.8801 - loss: 0.0524 - mean_dice: 0.8313 - val_dice_ET: 0.7507 - val_dice_TC: 0.8057 - val_dice_WT: 0.8552 - val_loss: 0.0647 - val_mean_dice: 0.8039
# Epoch 27/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7728 - dice_TC: 0.8484 - dice_WT: 0.8796 - loss: 0.0517 - mean_dice: 0.8336
# Epoch 27: val_mean_dice improved from 0.80510 to 0.81068, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 27: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.7726 - dice_TC: 0.8474 - dice_WT: 0.8798 - loss: 0.0516 - mean_dice: 0.8333 - val_dice_ET: 0.7558 - val_dice_TC: 0.8171 - val_dice_WT: 0.8592 - val_loss: 0.0652 - val_mean_dice: 0.8107
# Epoch 28/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7809 - dice_TC: 0.8558 - dice_WT: 0.8782 - loss: 0.0510 - mean_dice: 0.8383
# Epoch 28: val_mean_dice improved from 0.81068 to 0.81121, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 28: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.7783 - dice_TC: 0.8484 - dice_WT: 0.8804 - loss: 0.0515 - mean_dice: 0.8357 - val_dice_ET: 0.7620 - val_dice_TC: 0.8117 - val_dice_WT: 0.8599 - val_loss: 0.0654 - val_mean_dice: 0.8112
# Epoch 29/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7841 - dice_TC: 0.8526 - dice_WT: 0.8822 - loss: 0.0506 - mean_dice: 0.8397
# Epoch 29: val_mean_dice did not improve from 0.81121
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7795 - dice_TC: 0.8489 - dice_WT: 0.8818 - loss: 0.0506 - mean_dice: 0.8367 - val_dice_ET: 0.7475 - val_dice_TC: 0.8181 - val_dice_WT: 0.8581 - val_loss: 0.0630 - val_mean_dice: 0.8079
# Epoch 30/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7729 - dice_TC: 0.8484 - dice_WT: 0.8829 - loss: 0.0506 - mean_dice: 0.8347
# Epoch 30: val_mean_dice improved from 0.81121 to 0.81375, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 30: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.7768 - dice_TC: 0.8485 - dice_WT: 0.8834 - loss: 0.0506 - mean_dice: 0.8362 - val_dice_ET: 0.7621 - val_dice_TC: 0.8196 - val_dice_WT: 0.8596 - val_loss: 0.0654 - val_mean_dice: 0.8138
# Epoch 31/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7811 - dice_TC: 0.8488 - dice_WT: 0.8864 - loss: 0.0502 - mean_dice: 0.8388
# Epoch 31: val_mean_dice did not improve from 0.81375
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7795 - dice_TC: 0.8489 - dice_WT: 0.8850 - loss: 0.0502 - mean_dice: 0.8378 - val_dice_ET: 0.7556 - val_dice_TC: 0.8154 - val_dice_WT: 0.8649 - val_loss: 0.0619 - val_mean_dice: 0.8120
# Epoch 32/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7816 - dice_TC: 0.8500 - dice_WT: 0.8830 - loss: 0.0502 - mean_dice: 0.8382
# Epoch 32: val_mean_dice did not improve from 0.81375
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7841 - dice_TC: 0.8523 - dice_WT: 0.8860 - loss: 0.0497 - mean_dice: 0.8408 - val_dice_ET: 0.7541 - val_dice_TC: 0.8110 - val_dice_WT: 0.8619 - val_loss: 0.0640 - val_mean_dice: 0.8090
# Epoch 33/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7887 - dice_TC: 0.8562 - dice_WT: 0.8909 - loss: 0.0490 - mean_dice: 0.8453
# Epoch 33: val_mean_dice did not improve from 0.81375
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7819 - dice_TC: 0.8547 - dice_WT: 0.8880 - loss: 0.0491 - mean_dice: 0.8416 - val_dice_ET: 0.7633 - val_dice_TC: 0.8172 - val_dice_WT: 0.8603 - val_loss: 0.0621 - val_mean_dice: 0.8136
# Epoch 34/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7818 - dice_TC: 0.8608 - dice_WT: 0.8882 - loss: 0.0486 - mean_dice: 0.8436
# Epoch 34: val_mean_dice did not improve from 0.81375
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7877 - dice_TC: 0.8590 - dice_WT: 0.8876 - loss: 0.0486 - mean_dice: 0.8448 - val_dice_ET: 0.7519 - val_dice_TC: 0.8164 - val_dice_WT: 0.8597 - val_loss: 0.0622 - val_mean_dice: 0.8093
# Epoch 35/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7870 - dice_TC: 0.8575 - dice_WT: 0.8854 - loss: 0.0485 - mean_dice: 0.8433
# Epoch 35: val_mean_dice improved from 0.81375 to 0.81828, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 35: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.7877 - dice_TC: 0.8558 - dice_WT: 0.8867 - loss: 0.0488 - mean_dice: 0.8434 - val_dice_ET: 0.7633 - val_dice_TC: 0.8236 - val_dice_WT: 0.8679 - val_loss: 0.0609 - val_mean_dice: 0.8183
# Epoch 36/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7853 - dice_TC: 0.8587 - dice_WT: 0.8917 - loss: 0.0481 - mean_dice: 0.8452
# Epoch 36: val_mean_dice improved from 0.81828 to 0.81907, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 36: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.7884 - dice_TC: 0.8582 - dice_WT: 0.8908 - loss: 0.0480 - mean_dice: 0.8458 - val_dice_ET: 0.7717 - val_dice_TC: 0.8231 - val_dice_WT: 0.8624 - val_loss: 0.0620 - val_mean_dice: 0.8191
# Epoch 37/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7913 - dice_TC: 0.8585 - dice_WT: 0.8918 - loss: 0.0476 - mean_dice: 0.8472
# Epoch 37: val_mean_dice did not improve from 0.81907
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7901 - dice_TC: 0.8581 - dice_WT: 0.8898 - loss: 0.0476 - mean_dice: 0.8460 - val_dice_ET: 0.7651 - val_dice_TC: 0.8215 - val_dice_WT: 0.8652 - val_loss: 0.0608 - val_mean_dice: 0.8172
# Epoch 38/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7899 - dice_TC: 0.8623 - dice_WT: 0.8918 - loss: 0.0473 - mean_dice: 0.8480
# Epoch 38: val_mean_dice did not improve from 0.81907
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7872 - dice_TC: 0.8581 - dice_WT: 0.8909 - loss: 0.0475 - mean_dice: 0.8454 - val_dice_ET: 0.7587 - val_dice_TC: 0.8223 - val_dice_WT: 0.8634 - val_loss: 0.0607 - val_mean_dice: 0.8148
# Epoch 39/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7933 - dice_TC: 0.8595 - dice_WT: 0.8915 - loss: 0.0469 - mean_dice: 0.8481
# Epoch 39: val_mean_dice improved from 0.81907 to 0.82115, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 39: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.7917 - dice_TC: 0.8606 - dice_WT: 0.8916 - loss: 0.0471 - mean_dice: 0.8480 - val_dice_ET: 0.7704 - val_dice_TC: 0.8265 - val_dice_WT: 0.8665 - val_loss: 0.0600 - val_mean_dice: 0.8211
# Epoch 40/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7914 - dice_TC: 0.8626 - dice_WT: 0.8927 - loss: 0.0466 - mean_dice: 0.8489
# Epoch 40: val_mean_dice did not improve from 0.82115
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7920 - dice_TC: 0.8650 - dice_WT: 0.8926 - loss: 0.0467 - mean_dice: 0.8499 - val_dice_ET: 0.7698 - val_dice_TC: 0.8245 - val_dice_WT: 0.8610 - val_loss: 0.0626 - val_mean_dice: 0.8185
# Epoch 41/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7926 - dice_TC: 0.8647 - dice_WT: 0.8955 - loss: 0.0464 - mean_dice: 0.8509
# Epoch 41: val_mean_dice improved from 0.82115 to 0.82179, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 41: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 51ms/step - dice_ET: 0.7927 - dice_TC: 0.8620 - dice_WT: 0.8937 - loss: 0.0466 - mean_dice: 0.8495 - val_dice_ET: 0.7732 - val_dice_TC: 0.8290 - val_dice_WT: 0.8632 - val_loss: 0.0615 - val_mean_dice: 0.8218
# Epoch 42/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7948 - dice_TC: 0.8636 - dice_WT: 0.8926 - loss: 0.0460 - mean_dice: 0.8503
# Epoch 42: val_mean_dice did not improve from 0.82179
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7966 - dice_TC: 0.8644 - dice_WT: 0.8937 - loss: 0.0460 - mean_dice: 0.8516 - val_dice_ET: 0.7626 - val_dice_TC: 0.8266 - val_dice_WT: 0.8696 - val_loss: 0.0593 - val_mean_dice: 0.8196
# Epoch 43/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7997 - dice_TC: 0.8684 - dice_WT: 0.8974 - loss: 0.0462 - mean_dice: 0.8552
# Epoch 43: val_mean_dice improved from 0.82179 to 0.82211, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 43: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.7980 - dice_TC: 0.8654 - dice_WT: 0.8946 - loss: 0.0461 - mean_dice: 0.8526 - val_dice_ET: 0.7632 - val_dice_TC: 0.8330 - val_dice_WT: 0.8701 - val_loss: 0.0593 - val_mean_dice: 0.8221
# Epoch 44/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7932 - dice_TC: 0.8678 - dice_WT: 0.8972 - loss: 0.0457 - mean_dice: 0.8527
# Epoch 44: val_mean_dice improved from 0.82211 to 0.82769, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 44: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 40s 67ms/step - dice_ET: 0.7955 - dice_TC: 0.8677 - dice_WT: 0.8964 - loss: 0.0454 - mean_dice: 0.8532 - val_dice_ET: 0.7804 - val_dice_TC: 0.8308 - val_dice_WT: 0.8720 - val_loss: 0.0601 - val_mean_dice: 0.8277
# Epoch 45/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7943 - dice_TC: 0.8690 - dice_WT: 0.8964 - loss: 0.0453 - mean_dice: 0.8532
# Epoch 45: val_mean_dice did not improve from 0.82769
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7975 - dice_TC: 0.8684 - dice_WT: 0.8962 - loss: 0.0454 - mean_dice: 0.8540 - val_dice_ET: 0.7751 - val_dice_TC: 0.8290 - val_dice_WT: 0.8650 - val_loss: 0.0601 - val_mean_dice: 0.8230
# Epoch 46/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7965 - dice_TC: 0.8704 - dice_WT: 0.9010 - loss: 0.0449 - mean_dice: 0.8560
# Epoch 46: val_mean_dice did not improve from 0.82769
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 34s 57ms/step - dice_ET: 0.7984 - dice_TC: 0.8684 - dice_WT: 0.8978 - loss: 0.0450 - mean_dice: 0.8549 - val_dice_ET: 0.7653 - val_dice_TC: 0.8275 - val_dice_WT: 0.8678 - val_loss: 0.0592 - val_mean_dice: 0.8202
# Epoch 47/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8045 - dice_TC: 0.8737 - dice_WT: 0.8966 - loss: 0.0445 - mean_dice: 0.8582
# Epoch 47: val_mean_dice did not improve from 0.82769
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8016 - dice_TC: 0.8715 - dice_WT: 0.8963 - loss: 0.0448 - mean_dice: 0.8564 - val_dice_ET: 0.7657 - val_dice_TC: 0.8293 - val_dice_WT: 0.8689 - val_loss: 0.0579 - val_mean_dice: 0.8213
# Epoch 48/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8030 - dice_TC: 0.8720 - dice_WT: 0.9004 - loss: 0.0446 - mean_dice: 0.8585
# Epoch 48: val_mean_dice did not improve from 0.82769
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.7999 - dice_TC: 0.8693 - dice_WT: 0.9004 - loss: 0.0448 - mean_dice: 0.8565 - val_dice_ET: 0.7706 - val_dice_TC: 0.8242 - val_dice_WT: 0.8704 - val_loss: 0.0579 - val_mean_dice: 0.8217
# Epoch 49/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.7993 - dice_TC: 0.8682 - dice_WT: 0.8978 - loss: 0.0441 - mean_dice: 0.8551
# Epoch 49: val_mean_dice did not improve from 0.82769
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8018 - dice_TC: 0.8714 - dice_WT: 0.8983 - loss: 0.0443 - mean_dice: 0.8572 - val_dice_ET: 0.7761 - val_dice_TC: 0.8291 - val_dice_WT: 0.8678 - val_loss: 0.0573 - val_mean_dice: 0.8243
# Epoch 50/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8147 - dice_TC: 0.8760 - dice_WT: 0.9042 - loss: 0.0430 - mean_dice: 0.8650
# Epoch 50: val_mean_dice improved from 0.82769 to 0.83067, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 50: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.8119 - dice_TC: 0.8781 - dice_WT: 0.9040 - loss: 0.0424 - mean_dice: 0.8647 - val_dice_ET: 0.7784 - val_dice_TC: 0.8413 - val_dice_WT: 0.8723 - val_loss: 0.0578 - val_mean_dice: 0.8307
# Epoch 51/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8098 - dice_TC: 0.8814 - dice_WT: 0.9051 - loss: 0.0426 - mean_dice: 0.8655
# Epoch 51: val_mean_dice did not improve from 0.83067
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8104 - dice_TC: 0.8819 - dice_WT: 0.9044 - loss: 0.0422 - mean_dice: 0.8656 - val_dice_ET: 0.7773 - val_dice_TC: 0.8376 - val_dice_WT: 0.8688 - val_loss: 0.0556 - val_mean_dice: 0.8279
# Epoch 52/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8223 - dice_TC: 0.8840 - dice_WT: 0.9067 - loss: 0.0419 - mean_dice: 0.8710
# Epoch 52: val_mean_dice did not improve from 0.83067
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8159 - dice_TC: 0.8831 - dice_WT: 0.9053 - loss: 0.0419 - mean_dice: 0.8681 - val_dice_ET: 0.7776 - val_dice_TC: 0.8372 - val_dice_WT: 0.8729 - val_loss: 0.0558 - val_mean_dice: 0.8293
# Epoch 53/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8148 - dice_TC: 0.8821 - dice_WT: 0.9065 - loss: 0.0417 - mean_dice: 0.8678
# Epoch 53: val_mean_dice did not improve from 0.83067
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8127 - dice_TC: 0.8822 - dice_WT: 0.9073 - loss: 0.0417 - mean_dice: 0.8674 - val_dice_ET: 0.7760 - val_dice_TC: 0.8354 - val_dice_WT: 0.8698 - val_loss: 0.0544 - val_mean_dice: 0.8271
# Epoch 54/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8117 - dice_TC: 0.8830 - dice_WT: 0.9088 - loss: 0.0416 - mean_dice: 0.8678
# Epoch 54: val_mean_dice improved from 0.83067 to 0.83352, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 54: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 33s 56ms/step - dice_ET: 0.8146 - dice_TC: 0.8841 - dice_WT: 0.9082 - loss: 0.0414 - mean_dice: 0.8689 - val_dice_ET: 0.7838 - val_dice_TC: 0.8410 - val_dice_WT: 0.8757 - val_loss: 0.0552 - val_mean_dice: 0.8335
# Epoch 55/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8180 - dice_TC: 0.8871 - dice_WT: 0.9096 - loss: 0.0409 - mean_dice: 0.8716
# Epoch 55: val_mean_dice did not improve from 0.83352
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.8133 - dice_TC: 0.8840 - dice_WT: 0.9079 - loss: 0.0413 - mean_dice: 0.8684 - val_dice_ET: 0.7752 - val_dice_TC: 0.8406 - val_dice_WT: 0.8732 - val_loss: 0.0551 - val_mean_dice: 0.8296
# Epoch 56/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8188 - dice_TC: 0.8841 - dice_WT: 0.9090 - loss: 0.0407 - mean_dice: 0.8706
# Epoch 56: val_mean_dice did not improve from 0.83352
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8199 - dice_TC: 0.8854 - dice_WT: 0.9096 - loss: 0.0410 - mean_dice: 0.8716 - val_dice_ET: 0.7801 - val_dice_TC: 0.8438 - val_dice_WT: 0.8729 - val_loss: 0.0553 - val_mean_dice: 0.8323
# Epoch 57/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8213 - dice_TC: 0.8891 - dice_WT: 0.9105 - loss: 0.0408 - mean_dice: 0.8736
# Epoch 57: val_mean_dice did not improve from 0.83352
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8162 - dice_TC: 0.8859 - dice_WT: 0.9079 - loss: 0.0408 - mean_dice: 0.8700 - val_dice_ET: 0.7824 - val_dice_TC: 0.8413 - val_dice_WT: 0.8750 - val_loss: 0.0552 - val_mean_dice: 0.8329
# Epoch 58/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8144 - dice_TC: 0.8875 - dice_WT: 0.9066 - loss: 0.0405 - mean_dice: 0.8695
# Epoch 58: val_mean_dice did not improve from 0.83352
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8169 - dice_TC: 0.8884 - dice_WT: 0.9095 - loss: 0.0408 - mean_dice: 0.8716 - val_dice_ET: 0.7724 - val_dice_TC: 0.8334 - val_dice_WT: 0.8721 - val_loss: 0.0545 - val_mean_dice: 0.8259
# Epoch 59/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8142 - dice_TC: 0.8824 - dice_WT: 0.9079 - loss: 0.0406 - mean_dice: 0.8682
# Epoch 59: val_mean_dice did not improve from 0.83352
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8163 - dice_TC: 0.8847 - dice_WT: 0.9102 - loss: 0.0408 - mean_dice: 0.8704 - val_dice_ET: 0.7837 - val_dice_TC: 0.8417 - val_dice_WT: 0.8750 - val_loss: 0.0543 - val_mean_dice: 0.8335
# Epoch 60/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8226 - dice_TC: 0.8896 - dice_WT: 0.9115 - loss: 0.0400 - mean_dice: 0.8746
# Epoch 60: val_mean_dice improved from 0.83352 to 0.83694, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 60: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 51ms/step - dice_ET: 0.8229 - dice_TC: 0.8910 - dice_WT: 0.9125 - loss: 0.0397 - mean_dice: 0.8755 - val_dice_ET: 0.7862 - val_dice_TC: 0.8466 - val_dice_WT: 0.8780 - val_loss: 0.0533 - val_mean_dice: 0.8369
# Epoch 61/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8265 - dice_TC: 0.8942 - dice_WT: 0.9125 - loss: 0.0395 - mean_dice: 0.8778
# Epoch 61: val_mean_dice did not improve from 0.83694
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.8261 - dice_TC: 0.8919 - dice_WT: 0.9126 - loss: 0.0396 - mean_dice: 0.8768 - val_dice_ET: 0.7853 - val_dice_TC: 0.8414 - val_dice_WT: 0.8759 - val_loss: 0.0535 - val_mean_dice: 0.8342
# Epoch 62/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8238 - dice_TC: 0.8924 - dice_WT: 0.9144 - loss: 0.0395 - mean_dice: 0.8769
# Epoch 62: val_mean_dice did not improve from 0.83694
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 50ms/step - dice_ET: 0.8224 - dice_TC: 0.8919 - dice_WT: 0.9133 - loss: 0.0394 - mean_dice: 0.8758 - val_dice_ET: 0.7815 - val_dice_TC: 0.8454 - val_dice_WT: 0.8764 - val_loss: 0.0540 - val_mean_dice: 0.8344
# Epoch 63/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8220 - dice_TC: 0.8906 - dice_WT: 0.9105 - loss: 0.0393 - mean_dice: 0.8744
# Epoch 63: val_mean_dice improved from 0.83694 to 0.83907, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 63: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.8239 - dice_TC: 0.8914 - dice_WT: 0.9140 - loss: 0.0392 - mean_dice: 0.8764 - val_dice_ET: 0.7926 - val_dice_TC: 0.8482 - val_dice_WT: 0.8764 - val_loss: 0.0534 - val_mean_dice: 0.8391
# Epoch 64/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8250 - dice_TC: 0.8933 - dice_WT: 0.9148 - loss: 0.0391 - mean_dice: 0.8777
# Epoch 64: val_mean_dice did not improve from 0.83907
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.8221 - dice_TC: 0.8923 - dice_WT: 0.9151 - loss: 0.0393 - mean_dice: 0.8765 - val_dice_ET: 0.7815 - val_dice_TC: 0.8455 - val_dice_WT: 0.8780 - val_loss: 0.0531 - val_mean_dice: 0.8350
# Epoch 65/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8278 - dice_TC: 0.8956 - dice_WT: 0.9149 - loss: 0.0391 - mean_dice: 0.8794
# Epoch 65: val_mean_dice did not improve from 0.83907
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.8268 - dice_TC: 0.8961 - dice_WT: 0.9150 - loss: 0.0391 - mean_dice: 0.8793 - val_dice_ET: 0.7858 - val_dice_TC: 0.8419 - val_dice_WT: 0.8769 - val_loss: 0.0537 - val_mean_dice: 0.8349
# Epoch 66/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8254 - dice_TC: 0.8948 - dice_WT: 0.9160 - loss: 0.0391 - mean_dice: 0.8787
# Epoch 66: val_mean_dice did not improve from 0.83907
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8264 - dice_TC: 0.8926 - dice_WT: 0.9130 - loss: 0.0390 - mean_dice: 0.8773 - val_dice_ET: 0.7844 - val_dice_TC: 0.8440 - val_dice_WT: 0.8766 - val_loss: 0.0529 - val_mean_dice: 0.8350
# Epoch 67/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8238 - dice_TC: 0.8932 - dice_WT: 0.9145 - loss: 0.0389 - mean_dice: 0.8771
# Epoch 67: val_mean_dice did not improve from 0.83907
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8246 - dice_TC: 0.8937 - dice_WT: 0.9139 - loss: 0.0387 - mean_dice: 0.8774 - val_dice_ET: 0.7815 - val_dice_TC: 0.8453 - val_dice_WT: 0.8777 - val_loss: 0.0524 - val_mean_dice: 0.8349
# Epoch 68/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8238 - dice_TC: 0.8912 - dice_WT: 0.9146 - loss: 0.0387 - mean_dice: 0.8765
# Epoch 68: val_mean_dice did not improve from 0.83907
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8241 - dice_TC: 0.8933 - dice_WT: 0.9145 - loss: 0.0388 - mean_dice: 0.8773 - val_dice_ET: 0.7873 - val_dice_TC: 0.8479 - val_dice_WT: 0.8782 - val_loss: 0.0531 - val_mean_dice: 0.8378
# Epoch 69/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8232 - dice_TC: 0.8984 - dice_WT: 0.9144 - loss: 0.0384 - mean_dice: 0.8787
# Epoch 69: val_mean_dice did not improve from 0.83907
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8277 - dice_TC: 0.8967 - dice_WT: 0.9149 - loss: 0.0384 - mean_dice: 0.8798 - val_dice_ET: 0.7919 - val_dice_TC: 0.8485 - val_dice_WT: 0.8766 - val_loss: 0.0522 - val_mean_dice: 0.8390
# Epoch 70/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8250 - dice_TC: 0.8992 - dice_WT: 0.9130 - loss: 0.0386 - mean_dice: 0.8791
# Epoch 70: val_mean_dice did not improve from 0.83907
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8267 - dice_TC: 0.8966 - dice_WT: 0.9149 - loss: 0.0385 - mean_dice: 0.8794 - val_dice_ET: 0.7887 - val_dice_TC: 0.8494 - val_dice_WT: 0.8777 - val_loss: 0.0525 - val_mean_dice: 0.8386
# Epoch 71/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8290 - dice_TC: 0.8989 - dice_WT: 0.9201 - loss: 0.0379 - mean_dice: 0.8827
# Epoch 71: val_mean_dice improved from 0.83907 to 0.84000, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 71: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.8295 - dice_TC: 0.8979 - dice_WT: 0.9170 - loss: 0.0381 - mean_dice: 0.8814 - val_dice_ET: 0.7919 - val_dice_TC: 0.8499 - val_dice_WT: 0.8782 - val_loss: 0.0524 - val_mean_dice: 0.8400
# Epoch 72/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8320 - dice_TC: 0.8984 - dice_WT: 0.9215 - loss: 0.0380 - mean_dice: 0.8840
# Epoch 72: val_mean_dice improved from 0.84000 to 0.84081, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 72: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.8303 - dice_TC: 0.8965 - dice_WT: 0.9181 - loss: 0.0382 - mean_dice: 0.8816 - val_dice_ET: 0.7910 - val_dice_TC: 0.8518 - val_dice_WT: 0.8797 - val_loss: 0.0528 - val_mean_dice: 0.8408
# Epoch 73/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8312 - dice_TC: 0.8971 - dice_WT: 0.9166 - loss: 0.0381 - mean_dice: 0.8816
# Epoch 73: val_mean_dice improved from 0.84081 to 0.84144, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 73: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.8287 - dice_TC: 0.8971 - dice_WT: 0.9168 - loss: 0.0380 - mean_dice: 0.8809 - val_dice_ET: 0.7928 - val_dice_TC: 0.8510 - val_dice_WT: 0.8805 - val_loss: 0.0517 - val_mean_dice: 0.8414
# Epoch 74/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8269 - dice_TC: 0.8969 - dice_WT: 0.9156 - loss: 0.0380 - mean_dice: 0.8798
# Epoch 74: val_mean_dice did not improve from 0.84144
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8276 - dice_TC: 0.8973 - dice_WT: 0.9171 - loss: 0.0381 - mean_dice: 0.8807 - val_dice_ET: 0.7904 - val_dice_TC: 0.8515 - val_dice_WT: 0.8812 - val_loss: 0.0519 - val_mean_dice: 0.8410
# Epoch 75/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8315 - dice_TC: 0.8996 - dice_WT: 0.9189 - loss: 0.0376 - mean_dice: 0.8833
# Epoch 75: val_mean_dice did not improve from 0.84144
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8281 - dice_TC: 0.8971 - dice_WT: 0.9169 - loss: 0.0379 - mean_dice: 0.8807 - val_dice_ET: 0.7885 - val_dice_TC: 0.8491 - val_dice_WT: 0.8796 - val_loss: 0.0521 - val_mean_dice: 0.8390
# Epoch 76/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8283 - dice_TC: 0.8953 - dice_WT: 0.9175 - loss: 0.0377 - mean_dice: 0.8804
# Epoch 76: val_mean_dice did not improve from 0.84144
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8299 - dice_TC: 0.8982 - dice_WT: 0.9181 - loss: 0.0379 - mean_dice: 0.8820 - val_dice_ET: 0.7934 - val_dice_TC: 0.8506 - val_dice_WT: 0.8800 - val_loss: 0.0520 - val_mean_dice: 0.8413
# Epoch 77/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8323 - dice_TC: 0.8976 - dice_WT: 0.9168 - loss: 0.0380 - mean_dice: 0.8822
# Epoch 77: val_mean_dice did not improve from 0.84144
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8290 - dice_TC: 0.8988 - dice_WT: 0.9177 - loss: 0.0379 - mean_dice: 0.8818 - val_dice_ET: 0.7927 - val_dice_TC: 0.8515 - val_dice_WT: 0.8792 - val_loss: 0.0518 - val_mean_dice: 0.8411
# Epoch 78/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8338 - dice_TC: 0.8964 - dice_WT: 0.9184 - loss: 0.0380 - mean_dice: 0.8829
# Epoch 78: val_mean_dice did not improve from 0.84144
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8311 - dice_TC: 0.8975 - dice_WT: 0.9191 - loss: 0.0378 - mean_dice: 0.8826 - val_dice_ET: 0.7867 - val_dice_TC: 0.8514 - val_dice_WT: 0.8802 - val_loss: 0.0514 - val_mean_dice: 0.8394
# Epoch 79/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8347 - dice_TC: 0.9012 - dice_WT: 0.9191 - loss: 0.0382 - mean_dice: 0.8850
# Epoch 79: val_mean_dice improved from 0.84144 to 0.84266, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 79: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.8332 - dice_TC: 0.9006 - dice_WT: 0.9192 - loss: 0.0379 - mean_dice: 0.8843 - val_dice_ET: 0.7937 - val_dice_TC: 0.8524 - val_dice_WT: 0.8818 - val_loss: 0.0519 - val_mean_dice: 0.8427
# Epoch 80/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8273 - dice_TC: 0.8971 - dice_WT: 0.9180 - loss: 0.0376 - mean_dice: 0.8808
# Epoch 80: val_mean_dice did not improve from 0.84266
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.8290 - dice_TC: 0.8974 - dice_WT: 0.9172 - loss: 0.0376 - mean_dice: 0.8812 - val_dice_ET: 0.7912 - val_dice_TC: 0.8513 - val_dice_WT: 0.8801 - val_loss: 0.0516 - val_mean_dice: 0.8409
# Epoch 81/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8322 - dice_TC: 0.8985 - dice_WT: 0.9174 - loss: 0.0374 - mean_dice: 0.8827
# Epoch 81: val_mean_dice improved from 0.84266 to 0.84307, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 81: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 32s 53ms/step - dice_ET: 0.8299 - dice_TC: 0.8983 - dice_WT: 0.9194 - loss: 0.0375 - mean_dice: 0.8826 - val_dice_ET: 0.7954 - val_dice_TC: 0.8527 - val_dice_WT: 0.8811 - val_loss: 0.0516 - val_mean_dice: 0.8431
# Epoch 82/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8322 - dice_TC: 0.9008 - dice_WT: 0.9221 - loss: 0.0374 - mean_dice: 0.8850
# Epoch 82: val_mean_dice did not improve from 0.84307
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8314 - dice_TC: 0.8986 - dice_WT: 0.9198 - loss: 0.0375 - mean_dice: 0.8833 - val_dice_ET: 0.7926 - val_dice_TC: 0.8514 - val_dice_WT: 0.8798 - val_loss: 0.0518 - val_mean_dice: 0.8413
# Epoch 83/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8339 - dice_TC: 0.9029 - dice_WT: 0.9199 - loss: 0.0375 - mean_dice: 0.8856
# Epoch 83: val_mean_dice did not improve from 0.84307
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8328 - dice_TC: 0.9003 - dice_WT: 0.9173 - loss: 0.0376 - mean_dice: 0.8835 - val_dice_ET: 0.7918 - val_dice_TC: 0.8518 - val_dice_WT: 0.8812 - val_loss: 0.0515 - val_mean_dice: 0.8416
# Epoch 84/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8314 - dice_TC: 0.8998 - dice_WT: 0.9174 - loss: 0.0372 - mean_dice: 0.8828
# Epoch 84: val_mean_dice did not improve from 0.84307
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8339 - dice_TC: 0.9003 - dice_WT: 0.9189 - loss: 0.0375 - mean_dice: 0.8844 - val_dice_ET: 0.7902 - val_dice_TC: 0.8513 - val_dice_WT: 0.8786 - val_loss: 0.0514 - val_mean_dice: 0.8400
# Epoch 85/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8330 - dice_TC: 0.8964 - dice_WT: 0.9137 - loss: 0.0376 - mean_dice: 0.8810
# Epoch 85: val_mean_dice did not improve from 0.84307
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.8321 - dice_TC: 0.8998 - dice_WT: 0.9185 - loss: 0.0375 - mean_dice: 0.8835 - val_dice_ET: 0.7913 - val_dice_TC: 0.8516 - val_dice_WT: 0.8808 - val_loss: 0.0515 - val_mean_dice: 0.8412
# Epoch 86/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8338 - dice_TC: 0.9017 - dice_WT: 0.9196 - loss: 0.0375 - mean_dice: 0.8850
# Epoch 86: val_mean_dice improved from 0.84307 to 0.84385, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 86: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.8302 - dice_TC: 0.8985 - dice_WT: 0.9193 - loss: 0.0375 - mean_dice: 0.8827 - val_dice_ET: 0.7953 - val_dice_TC: 0.8549 - val_dice_WT: 0.8814 - val_loss: 0.0515 - val_mean_dice: 0.8438
# Epoch 87/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8361 - dice_TC: 0.9007 - dice_WT: 0.9209 - loss: 0.0371 - mean_dice: 0.8859
# Epoch 87: val_mean_dice did not improve from 0.84385
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8319 - dice_TC: 0.9008 - dice_WT: 0.9192 - loss: 0.0374 - mean_dice: 0.8840 - val_dice_ET: 0.7929 - val_dice_TC: 0.8522 - val_dice_WT: 0.8802 - val_loss: 0.0511 - val_mean_dice: 0.8418
# Epoch 88/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8296 - dice_TC: 0.8993 - dice_WT: 0.9194 - loss: 0.0375 - mean_dice: 0.8828
# Epoch 88: val_mean_dice did not improve from 0.84385
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - dice_ET: 0.8335 - dice_TC: 0.8996 - dice_WT: 0.9181 - loss: 0.0374 - mean_dice: 0.8838 - val_dice_ET: 0.7932 - val_dice_TC: 0.8533 - val_dice_WT: 0.8817 - val_loss: 0.0513 - val_mean_dice: 0.8427
# Epoch 89/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8330 - dice_TC: 0.9010 - dice_WT: 0.9174 - loss: 0.0375 - mean_dice: 0.8838
# Epoch 89: val_mean_dice improved from 0.84385 to 0.84438, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 89: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.8313 - dice_TC: 0.8996 - dice_WT: 0.9194 - loss: 0.0374 - mean_dice: 0.8834 - val_dice_ET: 0.7967 - val_dice_TC: 0.8552 - val_dice_WT: 0.8812 - val_loss: 0.0513 - val_mean_dice: 0.8444
# Epoch 90/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8318 - dice_TC: 0.9014 - dice_WT: 0.9186 - loss: 0.0372 - mean_dice: 0.8839
# Epoch 90: val_mean_dice did not improve from 0.84438
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.8334 - dice_TC: 0.9000 - dice_WT: 0.9196 - loss: 0.0373 - mean_dice: 0.8843 - val_dice_ET: 0.7935 - val_dice_TC: 0.8536 - val_dice_WT: 0.8813 - val_loss: 0.0513 - val_mean_dice: 0.8428
# Epoch 91/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8361 - dice_TC: 0.8994 - dice_WT: 0.9178 - loss: 0.0372 - mean_dice: 0.8844
# Epoch 91: val_mean_dice did not improve from 0.84438
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.8331 - dice_TC: 0.9005 - dice_WT: 0.9191 - loss: 0.0374 - mean_dice: 0.8842 - val_dice_ET: 0.7952 - val_dice_TC: 0.8545 - val_dice_WT: 0.8805 - val_loss: 0.0515 - val_mean_dice: 0.8434
# Epoch 92/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8327 - dice_TC: 0.9035 - dice_WT: 0.9224 - loss: 0.0368 - mean_dice: 0.8862
# Epoch 92: val_mean_dice did not improve from 0.84438
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.8348 - dice_TC: 0.9009 - dice_WT: 0.9203 - loss: 0.0372 - mean_dice: 0.8854 - val_dice_ET: 0.7929 - val_dice_TC: 0.8529 - val_dice_WT: 0.8808 - val_loss: 0.0515 - val_mean_dice: 0.8422
# Epoch 93/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8347 - dice_TC: 0.8985 - dice_WT: 0.9179 - loss: 0.0372 - mean_dice: 0.8837
# Epoch 93: val_mean_dice did not improve from 0.84438
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.8336 - dice_TC: 0.9000 - dice_WT: 0.9194 - loss: 0.0373 - mean_dice: 0.8843 - val_dice_ET: 0.7949 - val_dice_TC: 0.8538 - val_dice_WT: 0.8813 - val_loss: 0.0511 - val_mean_dice: 0.8433
# Epoch 94/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8308 - dice_TC: 0.9031 - dice_WT: 0.9226 - loss: 0.0374 - mean_dice: 0.8855
# Epoch 94: val_mean_dice did not improve from 0.84438
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.8312 - dice_TC: 0.9006 - dice_WT: 0.9201 - loss: 0.0374 - mean_dice: 0.8840 - val_dice_ET: 0.7948 - val_dice_TC: 0.8541 - val_dice_WT: 0.8815 - val_loss: 0.0512 - val_mean_dice: 0.8434
# Epoch 95/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8286 - dice_TC: 0.8998 - dice_WT: 0.9202 - loss: 0.0370 - mean_dice: 0.8829
# Epoch 95: val_mean_dice improved from 0.84438 to 0.84509, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 95: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.8308 - dice_TC: 0.9003 - dice_WT: 0.9192 - loss: 0.0372 - mean_dice: 0.8834 - val_dice_ET: 0.7957 - val_dice_TC: 0.8570 - val_dice_WT: 0.8825 - val_loss: 0.0513 - val_mean_dice: 0.8451
# Epoch 96/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8318 - dice_TC: 0.8990 - dice_WT: 0.9215 - loss: 0.0369 - mean_dice: 0.8841
# Epoch 96: val_mean_dice did not improve from 0.84509
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 42s 70ms/step - dice_ET: 0.8321 - dice_TC: 0.9011 - dice_WT: 0.9208 - loss: 0.0371 - mean_dice: 0.8847 - val_dice_ET: 0.7983 - val_dice_TC: 0.8550 - val_dice_WT: 0.8815 - val_loss: 0.0511 - val_mean_dice: 0.8450
# Epoch 97/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8309 - dice_TC: 0.8972 - dice_WT: 0.9150 - loss: 0.0373 - mean_dice: 0.8811
# Epoch 97: val_mean_dice improved from 0.84509 to 0.84510, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 97: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.8315 - dice_TC: 0.9008 - dice_WT: 0.9186 - loss: 0.0371 - mean_dice: 0.8836 - val_dice_ET: 0.7976 - val_dice_TC: 0.8556 - val_dice_WT: 0.8821 - val_loss: 0.0511 - val_mean_dice: 0.8451
# Epoch 98/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8337 - dice_TC: 0.9018 - dice_WT: 0.9218 - loss: 0.0370 - mean_dice: 0.8858
# Epoch 98: val_mean_dice improved from 0.84510 to 0.84522, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 98: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.8340 - dice_TC: 0.9016 - dice_WT: 0.9208 - loss: 0.0371 - mean_dice: 0.8855 - val_dice_ET: 0.7987 - val_dice_TC: 0.8556 - val_dice_WT: 0.8813 - val_loss: 0.0514 - val_mean_dice: 0.8452
# Epoch 99/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8339 - dice_TC: 0.9013 - dice_WT: 0.9229 - loss: 0.0370 - mean_dice: 0.8861
# Epoch 99: val_mean_dice did not improve from 0.84522
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.8331 - dice_TC: 0.8994 - dice_WT: 0.9196 - loss: 0.0371 - mean_dice: 0.8840 - val_dice_ET: 0.7971 - val_dice_TC: 0.8556 - val_dice_WT: 0.8815 - val_loss: 0.0511 - val_mean_dice: 0.8447
# Epoch 100/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_ET: 0.8331 - dice_TC: 0.8987 - dice_WT: 0.9198 - loss: 0.0375 - mean_dice: 0.8838
# Epoch 100: val_mean_dice improved from 0.84522 to 0.84534, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
#
# Epoch 100: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - dice_ET: 0.8347 - dice_TC: 0.8995 - dice_WT: 0.9197 - loss: 0.0371 - mean_dice: 0.8846 - val_dice_ET: 0.7979 - val_dice_TC: 0.8567 - val_dice_WT: 0.8814 - val_loss: 0.0508 - val_mean_dice: 0.8453
# Restoring model weights from the end of the best epoch: 100.

# %%
# Training Curves

def plot_training_curves(history, save_path):
    hist   = history.history
    epochs = range(1, len(hist["loss"]) + 1)

    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    fig.suptitle("Training & Validation Curves", fontsize=14)

    # Loss
    ax = axes[0, 0]
    ax.plot(epochs, hist["loss"],     label="Train", color="steelblue")
    ax.plot(epochs, hist["val_loss"], label="Val",   color="tomato", linestyle="--")
    ax.set_title("Loss")
    ax.set_xlabel("Epoch"); ax.legend(); ax.grid(True, alpha=0.3)

    # Mean Dice
    ax = axes[0, 1]
    ax.plot(epochs, hist["mean_dice"],     label="Train", color="steelblue")
    ax.plot(epochs, hist["val_mean_dice"], label="Val",   color="tomato", linestyle="--")
    ax.set_title("Mean Dice")
    ax.set_xlabel("Epoch"); ax.legend(); ax.grid(True, alpha=0.3)

    # Learning rate
    ax = axes[0, 2]
    if "lr" in hist:
        ax.semilogy(epochs, hist["lr"], color="purple")
    ax.set_title("Learning Rate (log scale)")
    ax.set_xlabel("Epoch"); ax.grid(True, alpha=0.3)

    # Per-region Dice
    region_cfg = [
        ("dice_WT", "val_dice_WT", "WT Dice", "royalblue"),
        ("dice_ET", "val_dice_ET", "ET Dice", "tomato"),
        ("dice_TC", "val_dice_TC", "TC Dice", "darkorange"),
    ]
    for idx, (tr_key, val_key, title, color) in enumerate(region_cfg):
        ax = axes[1, idx]
        if tr_key  in hist: ax.plot(epochs, hist[tr_key],  label="Train",
                                    color=color)
        if val_key in hist: ax.plot(epochs, hist[val_key], label="Val",
                                    color=color, linestyle="--", alpha=0.7)
        ax.set_title(title)
        ax.set_xlabel("Epoch"); ax.legend(); ax.grid(True, alpha=0.3)

    fig.tight_layout()
    save_and_show(fig, save_path, "training curves")

plot_training_curves(history, CURVES_PATH)
# Out:
# Saved → /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/training_curves.png  (training curves)

# %%
# Evaluation on Test Set

print("\n" + "="*58)
print("  Evaluating on Test  (best model weights)")
print("="*58)

test_results = model.evaluate(test_ds, verbose=1)
metric_names = model.metrics_names

print("\n ")
print("   Test Evaluation:         ")

for name, val in zip(metric_names, test_results):
    print(f"  {name:<24s}: {val:.4f}  ")


with open(EVAL_PATH, "w") as f:
    f.write("=" * 52 + "\n")
    f.write("  Test Evaluation Results\n")
    f.write("=" * 52 + "\n")
    for name, val in zip(metric_names, test_results):
        f.write(f"  {name:<28s}: {val:.6f}\n")
    f.write("=" * 52 + "\n")

print(f"\nEvaluation results saved → {EVAL_PATH}")
# Out:
# ==========================================================
#   Evaluating on Test  (best model weights)
# ==========================================================
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - dice_ET: 0.7953 - dice_TC: 0.8506 - dice_WT: 0.8815 - loss: 0.0506 - mean_dice: 0.8425
#
#
#    Test Evaluation:
#   loss                    : 0.0506
#   compile_metrics         : 0.8815
#
# Evaluation results saved → /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run80/evaluation_results.txt
