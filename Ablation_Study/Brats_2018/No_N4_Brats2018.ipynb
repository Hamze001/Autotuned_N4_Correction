# %%
pip install nilearn
# Out:
# Collecting nilearn
#   Downloading nilearn-0.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from nilearn) (3.1.6)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (1.5.3)
# Requirement already satisfied: nibabel>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (5.4.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.12/dist-packages (from nilearn) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from nilearn) (26.0)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (2.2.2)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (2.32.4)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (1.6.1)
# Requirement already satisfied: scipy>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (1.16.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1.2->nilearn) (3.0.3)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.12/dist-packages (from nibabel>=5.2.0->nilearn) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->nilearn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->nilearn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->nilearn) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (2026.2.25)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.0->nilearn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->nilearn) (1.17.0)
# Downloading nilearn-0.13.1-py3-none-any.whl (10.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 29.8 MB/s eta 0:00:00
# Installing collected packages: nilearn
# Successfully installed nilearn-0.13.1

# %%
import os
import cv2
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
from skimage import data
from skimage.util import montage
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps

import nilearn as nl
import nibabel as nib
import nilearn.plotting as nlplt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom, Rescaling
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam

from scipy.spatial.distance import directed_hausdorff
from scipy.ndimage import binary_erosion, generate_binary_structure
from scipy.spatial.distance import cdist

np.set_printoptions(precision=3, suppress=True)
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import (
    EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
)
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split

import matplotlib
matplotlib.use("module://ipykernel.pylab.backend_inline")
import matplotlib.pyplot as plt
plt.rcParams["figure.dpi"] = 110

print("TensorFlow:", tf.__version__)
print("Keras:     ", tf.keras.__version__)
print("GPU:", tf.config.list_physical_devices("GPU"))
tf.keras.backend.set_floatx("float32")

SAVE_DIR = "/content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78"
os.makedirs(SAVE_DIR, exist_ok=True)
# Out:
# TensorFlow: 2.19.0
# Keras:      3.13.2
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Paths & Configuration

BEST_MODEL_PATH   = os.path.join(SAVE_DIR, "best_model.keras")
LAST_WEIGHTS_PATH = os.path.join(SAVE_DIR, "last.weights.h5")
LOG_PATH          = os.path.join(SAVE_DIR, "history.csv")
CURVES_PATH       = os.path.join(SAVE_DIR, "training_curves.png")
PREDS_PATH        = os.path.join(SAVE_DIR, "predictions.png")
EVAL_PATH         = os.path.join(SAVE_DIR, "evaluation_results.txt")


IMG_HEIGHT    = 160
IMG_WIDTH     = 160
IN_CHANNELS   = 4
OUT_CHANNELS  = 3
BASE_FILTERS  = 64
GROUPS        = 8

BATCH_SIZE    = 16
EPOCHS        = 100
LEARNING_RATE = 1e-4
PATIENCE      = 10
VAL_SPLIT     = 0.15
TEST_SPLIT    = 0.15
SEED          = 42

WT_WEIGHT     = 1.0
ET_WEIGHT     = 2.0
TC_WEIGHT     = 1.5

KEEP_TIER_A   = 1.00
KEEP_TIER_B   = 0.60
KEEP_TIER_C   = 0.15
KEEP_TIER_D   = 0.05
MIN_ET_VOXELS = 5
MIN_TC_VOXELS = 10
MIN_WT_VOXELS = 10

CHANNEL_NAMES   = ["WT", "ET", "TC"]
CHANNEL_WEIGHTS = [WT_WEIGHT, ET_WEIGHT, TC_WEIGHT]

# %%
# save figure to Drive AND display inline

def save_and_show(fig, save_path, caption=""):
    fig.savefig(save_path, dpi=150, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print(f"Saved → {save_path}" + (f"  ({caption})" if caption else ""))

# %%
# Data Loading

from zipfile import ZipFile
with ZipFile('/content/drive/MyDrive/BRAIN2018_NORMALIZED_CROPPED.zip', 'r') as z:
    z.extractall('/content/CROPPED2018')

BRAIN2018_CROPPED = "/content/CROPPED2018"


def create_multimodal_image(dataset_root_dir):
    modalities = ["t1", "t1ce", "t2", "flair"]
    data, grade = {}, {}
    for gf in ["HGG", "LGG"]:
        gp = os.path.join(dataset_root_dir, gf)
        if not os.path.exists(gp):
            continue
        for pid in os.listdir(gp):
            pd_ = os.path.join(gp, pid)
            if not os.path.isdir(pd_):
                continue
            imgs, ok = [], True
            for mod in modalities:
                fp = os.path.join(pd_, f"{pid}_{mod}.nii")
                if not os.path.exists(fp):
                    ok = False; break
                imgs.append(nib.load(fp).get_fdata().astype(np.float32))
            if ok:
                data[pid]  = np.stack(imgs, axis=-1)
                grade[pid] = gf
    return data, grade


def create_combined_label_masks(seg_path):
    seg = nib.load(seg_path).get_fdata().astype(np.uint8)
    return np.stack([
        np.isin(seg, [1, 2, 4]).astype(np.float32),   # WT
        (seg == 4).astype(np.float32),                  # ET
        np.isin(seg, [1, 4]).astype(np.float32),        # TC
    ], axis=-1)


def load_all_patients(root):
    mdata, mgrade = create_multimodal_image(root)
    pids, grades, xvols, yvols = [], [], [], []
    for pid in mdata:
        for gf in ["HGG", "LGG"]:
            sp = os.path.join(root, gf, pid, f"{pid}_seg.nii")
            if os.path.exists(sp):
                xv = mdata[pid]; yv = create_combined_label_masks(sp)
                if xv.shape[:3] == yv.shape[:3]:
                    pids.append(pid); grades.append(mgrade[pid])
                    xvols.append(xv);  yvols.append(yv)
                break
    print(f"Loaded {len(xvols)} patients")
    return pids, grades, xvols, yvols


patient_ids, grades, X_volumes, Y_volumes = load_all_patients(BRAIN2018_CROPPED)
# Out:
# Loaded 285 patients

# %%
# Volume Cleaning

def clean_volumes(xvols):
    return [
        np.clip(np.nan_to_num(x, nan=0., posinf=0., neginf=0.), -5., 5.)
        for x in xvols
    ]

X_volumes = clean_volumes(X_volumes)

# %%
# Balanced Slice Extraction

def volumes_to_2d_slices_balanced(
    x_volumes, y_volumes,
    min_et_voxels=MIN_ET_VOXELS, min_tc_voxels=MIN_TC_VOXELS,
    min_wt_voxels=MIN_WT_VOXELS,
    keep_tier_a=KEEP_TIER_A, keep_tier_b=KEEP_TIER_B,
    keep_tier_c=KEEP_TIER_C, keep_tier_d=KEEP_TIER_D, seed=SEED,
):
    rng = np.random.default_rng(seed)
    xl, yl, tl = [], [], []
    counts = {t: 0 for t in ["A","B","C","D","A_skip","B_skip","C_skip","D_skip"]}
    for xv, yv in zip(x_volumes, y_volumes):
        for d in range(xv.shape[2]):
            xs = xv[:, :, d, :]; ys = yv[:, :, d, :]
            wt_fg = int(ys[..., 0].sum()) >= min_wt_voxels
            tc_fg = int(ys[..., 2].sum()) >= min_tc_voxels
            et_fg = int(ys[..., 1].sum()) >= min_et_voxels
            if   wt_fg and tc_fg and et_fg: tier, rate = "A", keep_tier_a
            elif wt_fg and tc_fg:           tier, rate = "B", keep_tier_b
            elif wt_fg:                     tier, rate = "C", keep_tier_c
            else:                           tier, rate = "D", keep_tier_d
            if rng.random() < rate:
                xl.append(xs); yl.append(ys); tl.append(tier)
                counts[tier] += 1
            else:
                counts[f"{tier}_skip"] += 1
    X = np.array(xl, np.float32); Y = np.array(yl, np.float32)
    descs = {"A":"WT+TC+ET","B":"WT+TC (no ET)","C":"WT only","D":"no fg"}
    print("\n" + "="*58)
    print("  Balanced Slice Extraction")
    print("="*58)
    for t in ["A","B","C","D"]:
        print(f"  Tier {t} ({descs[t]:<16}): "
              f"kept={counts[t]:5d}  skipped={counts[t+'_skip']:5d}")
    print(f"  Total: {len(X)}")
    print("="*58)
    return X, Y, tl


def print_slice_balance(Y, tier_labels, split_name="Dataset"):
    wt_v = Y[...,0].sum(axis=(1,2)); et_v = Y[...,1].sum(axis=(1,2))
    tc_v = Y[...,2].sum(axis=(1,2)); N = len(Y)
    tc = {t: tier_labels.count(t) for t in ["A","B","C","D"]}
    print(f"\n  [{split_name}]  {N} slices  "
          f"A={tc['A']} B={tc['B']} C={tc['C']} D={tc['D']}")
    for name, v in [("WT", wt_v), ("ET", et_v), ("TC", tc_v)]:
        print(f"    {name}: {(v>0).mean()*100:5.1f}% present  "
              f"mean={v.mean():.1f} vox")
    print(f"    Nesting: ET≤TC={(et_v<=tc_v+1).all()}  "
          f"TC≤WT={(tc_v<=wt_v+1).all()}")


X_sl, Y_sl, tier_labels = volumes_to_2d_slices_balanced(X_volumes, Y_volumes)
del X_volumes, Y_volumes
print_slice_balance(Y_sl, tier_labels, "Full balanced dataset")
# Out:
# ==========================================================
#   Balanced Slice Extraction
# ==========================================================
#   Tier A (WT+TC+ET        ): kept=10288  skipped=    0
#   Tier B (WT+TC (no ET)   ): kept= 1412  skipped=  973
#   Tier C (WT only         ): kept=  855  skipped= 4874
#   Tier D (no fg           ): kept=  926  skipped=17152
#   Total: 13481
# ==========================================================
#
#   [Full balanced dataset]  13481 slices  A=10288 B=1412 C=855 D=926
#     WT:  93.3% present  mean=1765.1 vox
#     ET:  77.2% present  mean=384.1 vox
#     TC:  87.2% present  mean=834.7 vox
#     Nesting: ET≤TC=True  TC≤WT=True

# %%
# Train / Val / Test Split  (70% / 15% / 15%)

X_trainval, X_test, Y_trainval, Y_test, tl_trainval, tl_test = train_test_split(
    X_sl, Y_sl, tier_labels,
    test_size=TEST_SPLIT, random_state=SEED, shuffle=True
)

val_fraction_of_trainval = VAL_SPLIT / (1.0 - TEST_SPLIT)

X_train, X_val, Y_train, Y_val, tl_train, tl_val = train_test_split(
    X_trainval, Y_trainval, tl_trainval,
    test_size=val_fraction_of_trainval, random_state=SEED, shuffle=True
)

del X_sl, Y_sl, X_trainval, Y_trainval

print("\nAfter split:")
print_slice_balance(Y_train, tl_train, "Train  (~70%)")
print_slice_balance(Y_val,   tl_val,   "Val    (~15%)")
print_slice_balance(Y_test,  tl_test,  "Test   (~15%)")
print(f"\nTrain : {X_train.shape}"
      f"\nVal   : {X_val.shape}"
      f"\nTest  : {X_test.shape}")
# Out:
# After split:
#
#   [Train  (~70%)]  9435 slices  A=7197 B=989 C=590 D=659
#     WT:  93.2% present  mean=1764.9 vox
#     ET:  77.1% present  mean=386.1 vox
#     TC:  87.1% present  mean=835.2 vox
#     Nesting: ET≤TC=True  TC≤WT=True
#
#   [Val    (~15%)]  2023 slices  A=1558 B=213 C=128 D=124
#     WT:  93.9% present  mean=1776.1 vox
#     ET:  78.1% present  mean=381.4 vox
#     TC:  87.8% present  mean=836.0 vox
#     Nesting: ET≤TC=True  TC≤WT=True
#
#   [Test   (~15%)]  2023 slices  A=1533 B=210 C=137 D=143
#     WT:  93.1% present  mean=1754.5 vox
#     ET:  76.8% present  mean=377.4 vox
#     TC:  86.8% present  mean=830.8 vox
#     Nesting: ET≤TC=True  TC≤WT=True
#
# Train : (9435, 160, 160, 4)
# Val   : (2023, 160, 160, 4)
# Test  : (2023, 160, 160, 4)

# %%
# tf.data Pipeline

AUTOTUNE = tf.data.AUTOTUNE


def augment(img, msk):

    # Zoom (±20%)
    zoom = tf.random.uniform([], 0.8, 1.2)

    h = tf.shape(img)[0]
    w = tf.shape(img)[1]

    new_h = tf.cast(tf.cast(h, tf.float32) * zoom, tf.int32)
    new_w = tf.cast(tf.cast(w, tf.float32) * zoom, tf.int32)

    img = tf.image.resize(img, (new_h, new_w), method='bilinear')
    msk = tf.image.resize(msk, (new_h, new_w), method='nearest')

    img = tf.image.resize_with_crop_or_pad(img, h, w)
    msk = tf.image.resize_with_crop_or_pad(msk, h, w)


    # Width & Height Shift (±20%)
    max_dx = tf.cast(0.2 * tf.cast(w, tf.float32), tf.int32)
    max_dy = tf.cast(0.2 * tf.cast(h, tf.float32), tf.int32)

    dx = tf.random.uniform([], -max_dx, max_dx, dtype=tf.int32)
    dy = tf.random.uniform([], -max_dy, max_dy, dtype=tf.int32)

    img = tf.roll(img, shift=[dy, dx], axis=[0, 1])
    msk = tf.roll(msk, shift=[dy, dx], axis=[0, 1])

    #Flip
    if tf.random.uniform(()) > 0.2:
      img = tf.image.flip_left_right(img)
      msk = tf.image.flip_left_right(msk)
    if tf.random.uniform(()) > 0.2:
      img = tf.image.flip_up_down(img)
      msk = tf.image.flip_up_down(msk)

    return img, msk


def make_dataset(X, Y, training=False):
    ds = tf.data.Dataset.from_tensor_slices((X, Y))
    if training:
        ds = ds.shuffle(len(X), seed=SEED).map(augment, num_parallel_calls=AUTOTUNE)
    return ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)


train_ds = make_dataset(X_train, Y_train, training=True)
val_ds   = make_dataset(X_val,   Y_val,   training=False)
test_ds  = make_dataset(X_test,  Y_test,  training=False)

print(f"\nTrain batches : {len(train_ds)}"
      f"\nVal   batches : {len(val_ds)}"
      f"\nTest  batches : {len(test_ds)}")
# Out:
# Train batches : 590
# Val   batches : 127
# Test  batches : 127

# %%
# U-Net Architecture

def conv_block(x, filters, groups=GROUPS):

    for _ in range(2):
        x = layers.Conv2D(
            filters, 3, padding="same", use_bias=False,
            kernel_initializer="he_normal"
        )(x)
        x = layers.GroupNormalization(groups=groups)(x)
        x = layers.Activation("relu")(x)
    return x


def encoder_block(x, filters):

    skip = conv_block(x, filters)
    pool = layers.MaxPooling2D(2)(skip)
    return skip, pool


def decoder_block(x, skip, filters):

    x = layers.Conv2DTranspose(
        filters, 2, strides=2, padding="same",
        kernel_initializer="he_normal"
    )(x)
    x = layers.Concatenate()([x, skip])
    x = conv_block(x, filters)
    return x


def build_unet(
    img_height=IMG_HEIGHT, img_width=IMG_WIDTH,
    in_channels=IN_CHANNELS, out_channels=OUT_CHANNELS,
    base_filters=BASE_FILTERS, dropout_rate=0.3
):

    inputs = layers.Input(
        shape=(img_height, img_width, in_channels), name="input"
    )

    # ── Encoder ────────────────────────────────────────────────────────────
    s1, p1 = encoder_block(inputs, base_filters)         # filters=64
    s2, p2 = encoder_block(p1,     base_filters * 2)     # filters=128
    s3, p3 = encoder_block(p2,     base_filters * 4)     # filters=256
    s4, p4 = encoder_block(p3,     base_filters * 8)     # filters=512

    # ── Bottleneck ─────────────────────────────────────────────────────────
    b = conv_block(p4, base_filters * 16)                # filters=1024
    b = layers.Dropout(dropout_rate)(b)

    # ── Decoder ────────────────────────────────────────────────────────────
    d4 = decoder_block(b,  s4, base_filters * 8)         # filters=512
    d3 = decoder_block(d4, s3, base_filters * 4)         # filters=256
    d2 = decoder_block(d3, s2, base_filters * 2)         # filters=128
    d1 = decoder_block(d2, s1, base_filters)             # filters=64

    # ── Output ────────────────────────────────────────────────────────
    outputs = layers.Conv2D(
        out_channels, 1, activation="sigmoid", name="output"
    )(d1)

    return Model(inputs, outputs, name="UNet_2D")


model = build_unet()
model.summary()
# Out:
# Model: "UNet_2D"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 160, 160,  │          0 │ -                 │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 160, 160,  │      2,304 │ input[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalization │ (None, 160, 160,  │        128 │ conv2d[0][0]      │
# │ (GroupNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 160, 160,  │          0 │ group_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 160, 160,  │     36,864 │ activation[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 160, 160,  │        128 │ conv2d_1[0][0]    │
# │ (GroupNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 160, 160,  │          0 │ group_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 80, 80,    │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 80, 80,    │     73,728 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 80, 80,    │        256 │ conv2d_2[0][0]    │
# │ (GroupNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 80, 80,    │          0 │ group_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 80, 80,    │    147,456 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 80, 80,    │        256 │ conv2d_3[0][0]    │
# │ (GroupNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 80, 80,    │          0 │ group_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 40, 40,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 40, 40,    │    294,912 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 40, 40,    │        512 │ conv2d_4[0][0]    │
# │ (GroupNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 40, 40,    │          0 │ group_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 40, 40,    │    589,824 │ activation_4[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 40, 40,    │        512 │ conv2d_5[0][0]    │
# │ (GroupNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 40, 40,    │          0 │ group_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 20, 20,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 20, 20,    │  1,179,648 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 20, 20,    │      1,024 │ conv2d_6[0][0]    │
# │ (GroupNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 20, 20,    │          0 │ group_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 20, 20,    │  2,359,296 │ activation_6[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 20, 20,    │      1,024 │ conv2d_7[0][0]    │
# │ (GroupNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 20, 20,    │          0 │ group_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 10, 10,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 10, 10,    │  4,718,592 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 10, 10,    │      2,048 │ conv2d_8[0][0]    │
# │ (GroupNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 10, 10,    │          0 │ group_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 10, 10,    │  9,437,184 │ activation_8[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 10, 10,    │      2,048 │ conv2d_9[0][0]    │
# │ (GroupNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 10, 10,    │          0 │ group_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 10, 10,    │          0 │ activation_9[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 20, 20,    │  2,097,664 │ dropout[0][0]     │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 20, 20,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 20, 20,    │  4,718,592 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 20, 20,    │      1,024 │ conv2d_10[0][0]   │
# │ (GroupNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 20, 20,    │          0 │ group_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 20, 20,    │  2,359,296 │ activation_10[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 20, 20,    │      1,024 │ conv2d_11[0][0]   │
# │ (GroupNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 20, 20,    │          0 │ group_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 40, 40,    │    524,544 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 40, 40,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 40, 40,    │  1,179,648 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 40, 40,    │        512 │ conv2d_12[0][0]   │
# │ (GroupNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 40, 40,    │          0 │ group_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 40, 40,    │    589,824 │ activation_12[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 40, 40,    │        512 │ conv2d_13[0][0]   │
# │ (GroupNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 40, 40,    │          0 │ group_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 80, 80,    │    131,200 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 80, 80,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 80, 80,    │    294,912 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 80, 80,    │        256 │ conv2d_14[0][0]   │
# │ (GroupNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 80, 80,    │          0 │ group_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 80, 80,    │    147,456 │ activation_14[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 80, 80,    │        256 │ conv2d_15[0][0]   │
# │ (GroupNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 80, 80,    │          0 │ group_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 160, 160,  │     32,832 │ activation_15[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 160, 160,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 160, 160,  │     73,728 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 160, 160,  │        128 │ conv2d_16[0][0]   │
# │ (GroupNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 160, 160,  │          0 │ group_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 160, 160,  │     36,864 │ activation_16[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ group_normalizatio… │ (None, 160, 160,  │        128 │ conv2d_17[0][0]   │
# │ (GroupNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 160, 160,  │          0 │ group_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Conv2D)     │ (None, 160, 160,  │        195 │ activation_17[0]… │
# │                     │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,038,339 (118.40 MB)
#  Trainable params: 31,038,339 (118.40 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Loss Function

def _boundary_weight_map(y_true_ch, pool_size=11, border_weight=3.0):

    averaged = tf.nn.avg_pool2d(
        y_true_ch,
        ksize=pool_size,
        strides=1,
        padding="SAME"
    )                                      # (B, H, W, 1)

    border = tf.cast(averaged > 0.005, tf.float32) * \
             tf.cast(averaged < 0.995, tf.float32)   # (B, H, W, 1)

    weight  = tf.ones_like(averaged)
    w0      = tf.reduce_sum(weight)
    weight  = weight + border * (border_weight - 1.0)
    w1      = tf.reduce_sum(weight)

    weight  = weight * (w0 / (w1 + 1e-8))
    return weight


def _weighted_bce_channel(y_true_ch, y_pred_ch, weight):

    epsilon   = 1e-7
    y_pred_ch = tf.clip_by_value(y_pred_ch, epsilon, 1.0 - epsilon)
    logit     = tf.math.log(y_pred_ch / (1.0 - y_pred_ch))

    bce = ((1.0 - y_true_ch) * logit
           + (1.0 + (weight - 1.0) * y_true_ch)
           * (tf.math.log(1.0 + tf.exp(-tf.abs(logit)))
              + tf.maximum(-logit, 0.0)))

    return tf.reduce_sum(bce) / (tf.reduce_sum(weight) + 1e-8)


def _weighted_dice_channel(y_true_ch, y_pred_ch, weight, smooth=1.0):

    w   = weight * weight
    m1  = y_true_ch
    m2  = y_pred_ch
    intersection = tf.reduce_sum(w * m1 * m2)
    denom        = tf.reduce_sum(w * (m1 ** 2)) + tf.reduce_sum(w * (m2 ** 2))
    score        = (2.0 * intersection + smooth) / (denom + smooth)
    return 1.0 - score


def weighted_boundary_loss_fn(
    wt_weight   = WT_WEIGHT,    # 1.0
    et_weight   = ET_WEIGHT,    # 2.0
    tc_weight   = TC_WEIGHT,    # 1.5
    pool_size   = 11,
    border_mult = 3.0,
    bce_frac    = 0.5,
):

    channel_weights = tf.constant(
        [wt_weight, et_weight, tc_weight], dtype=tf.float32)
    total_w = wt_weight + et_weight + tc_weight

    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.clip_by_value(tf.cast(y_pred, tf.float32), 1e-7, 1 - 1e-7)

        channel_losses = []
        for ch in range(3):
            y_t_ch = tf.expand_dims(y_true[..., ch], axis=-1)  # (B,H,W,1)
            y_p_ch = tf.expand_dims(y_pred[..., ch], axis=-1)

            w_map = _boundary_weight_map(y_t_ch, pool_size, border_mult)

            bce  = _weighted_bce_channel( y_t_ch, y_p_ch, w_map)
            dice = _weighted_dice_channel(y_t_ch, y_p_ch, w_map)

            ch_loss = bce_frac * bce + (1.0 - bce_frac) * dice
            channel_losses.append(ch_loss * channel_weights[ch])

        return tf.reduce_sum(tf.stack(channel_losses)) / total_w

    loss.__name__ = "weighted_boundary_loss"
    return loss


loss_fn = weighted_boundary_loss_fn()

# ── Pre-training loss check ────────────────────────────────────────────────────
print("\nLoss function: Weighted Boundary-Aware BCE + Dice (Rehman et al.)")
print(f"  pool_size={11}  border_mult=3.0  bce_frac=0.5")
print(f"  Channel weights: WT={WT_WEIGHT}  ET={ET_WEIGHT}  TC={TC_WEIGHT}")

for xb, yb in train_ds.take(1):
    out = model(xb, training=False)
    lv  = loss_fn(yb, out).numpy()
    print(f"\nPre-training check:  loss={lv:.4f}  "
          f"NaN={np.isnan(out.numpy()).any()}")
# Out:
# Loss function: Weighted Boundary-Aware BCE + Dice (Rehman et al.)
#   pool_size=11  border_mult=3.0  bce_frac=0.5
#   Channel weights: WT=1.0  ET=2.0  TC=1.5
#
# Pre-training check:  loss=0.7458  NaN=False

# %%
# Metrics

def soft_dice_per_channel(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    axes         = [1, 2]
    intersection = tf.reduce_sum(y_true * y_pred, axis=axes)   # (B, C)
    denom        = tf.reduce_sum(y_true + y_pred, axis=axes)   # (B, C)
    return (2.0 * intersection + smooth) / (denom + smooth)    # (B, C)


def dice_WT(y_true, y_pred, smooth=1e-6):
    return tf.reduce_mean(
        soft_dice_per_channel(y_true[..., 0:1], y_pred[..., 0:1], smooth)
    )

def dice_ET(y_true, y_pred, smooth=1e-6):
    return tf.reduce_mean(
        soft_dice_per_channel(y_true[..., 1:2], y_pred[..., 1:2], smooth)
    )

def dice_TC(y_true, y_pred, smooth=1e-6):
    return tf.reduce_mean(
        soft_dice_per_channel(y_true[..., 2:3], y_pred[..., 2:3], smooth)
    )

def dice_mean(y_true, y_pred, smooth=1e-6):
    return (dice_WT(y_true, y_pred, smooth) +
            dice_ET(y_true, y_pred, smooth) +
            dice_TC(y_true, y_pred, smooth)) / 3.0

def make_metrics():
    return [
        tf.keras.metrics.MeanMetricWrapper(dice_WT,   name="dice_WT"),
        tf.keras.metrics.MeanMetricWrapper(dice_ET,   name="dice_ET"),
        tf.keras.metrics.MeanMetricWrapper(dice_TC,   name="dice_TC"),
        tf.keras.metrics.MeanMetricWrapper(dice_mean, name="mean_dice"),
    ]


# ── Metric sanity check ────────────────────────────────────────────────────
print("\nMetric check ...")
_m = make_metrics()
for xb, yb in train_ds.take(1):
    _out = model(xb, training=False)
    for m in _m:
        m.update_state(yb, _out)
        print(f"  {m.name:<15} = {m.result().numpy():.4f}")
        m.reset_state()
del _m, _out
# Out:
# Metric check ...
#   dice_WT         = 0.0919
#   dice_ET         = 0.0164
#   dice_TC         = 0.0325
#   mean_dice       = 0.0470

# %%
# Compile

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=loss_fn,
    metrics=make_metrics()
)

for xb, yb in train_ds.take(1):
    out = model(xb, training=False)
    lv  = loss_fn(yb, out).numpy()
    print(f"\nPre-training check:  loss={lv:.4f}  NaN={np.isnan(out.numpy()).any()}")
# Out:
# Pre-training check:  loss=0.7287  NaN=False

# %%
callbacks = [
    ModelCheckpoint(
        filepath=BEST_MODEL_PATH,
        monitor="val_mean_dice",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    ModelCheckpoint(
        filepath=LAST_WEIGHTS_PATH,
        save_weights_only=True,
        verbose=0
    ),
    EarlyStopping(
        monitor="val_mean_dice",
        mode="max",
        patience=PATIENCE,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor="val_mean_dice",
        mode="max",
        factor=0.5,
        patience=5,
        min_lr=1e-7,
        verbose=0
    ),
    CSVLogger(LOG_PATH, append=True),
]

# %%
# Training

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - dice_ET: 0.0675 - dice_TC: 0.1125 - dice_WT: 0.1590 - loss: 0.5053 - mean_dice: 0.1130
# Epoch 1: val_mean_dice improved from None to 0.33325, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 128s 136ms/step - dice_ET: 0.1265 - dice_TC: 0.1991 - dice_WT: 0.2485 - loss: 0.3225 - mean_dice: 0.1913 - val_dice_ET: 0.2264 - val_dice_TC: 0.3512 - val_dice_WT: 0.4222 - val_loss: 0.1339 - val_mean_dice: 0.3333
# Epoch 2/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.2473 - dice_TC: 0.3720 - dice_WT: 0.4550 - loss: 0.1256 - mean_dice: 0.3581
# Epoch 2: val_mean_dice improved from 0.33325 to 0.44858, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 35s 59ms/step - dice_ET: 0.2693 - dice_TC: 0.4024 - dice_WT: 0.4939 - loss: 0.1175 - mean_dice: 0.3885 - val_dice_ET: 0.3158 - val_dice_TC: 0.4696 - val_dice_WT: 0.5604 - val_loss: 0.1012 - val_mean_dice: 0.4486
# Epoch 3/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.3210 - dice_TC: 0.4663 - dice_WT: 0.5672 - loss: 0.1008 - mean_dice: 0.4515
# Epoch 3: val_mean_dice improved from 0.44858 to 0.50371, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 38s 63ms/step - dice_ET: 0.3366 - dice_TC: 0.4808 - dice_WT: 0.5824 - loss: 0.0968 - mean_dice: 0.4666 - val_dice_ET: 0.3711 - val_dice_TC: 0.5197 - val_dice_WT: 0.6203 - val_loss: 0.0891 - val_mean_dice: 0.5037
# Epoch 4/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.3734 - dice_TC: 0.5184 - dice_WT: 0.6288 - loss: 0.0891 - mean_dice: 0.5069
# Epoch 4: val_mean_dice improved from 0.50371 to 0.54890, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 37s 63ms/step - dice_ET: 0.3857 - dice_TC: 0.5266 - dice_WT: 0.6409 - loss: 0.0868 - mean_dice: 0.5178 - val_dice_ET: 0.4133 - val_dice_TC: 0.5558 - val_dice_WT: 0.6776 - val_loss: 0.0828 - val_mean_dice: 0.5489
# Epoch 5/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.4225 - dice_TC: 0.5623 - dice_WT: 0.6801 - loss: 0.0807 - mean_dice: 0.5550
# Epoch 5: val_mean_dice improved from 0.54890 to 0.57411, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 32s 54ms/step - dice_ET: 0.4253 - dice_TC: 0.5607 - dice_WT: 0.6841 - loss: 0.0802 - mean_dice: 0.5567 - val_dice_ET: 0.4457 - val_dice_TC: 0.5691 - val_dice_WT: 0.7075 - val_loss: 0.0842 - val_mean_dice: 0.5741
# Epoch 6/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.4504 - dice_TC: 0.5807 - dice_WT: 0.7031 - loss: 0.0762 - mean_dice: 0.5781
# Epoch 6: val_mean_dice improved from 0.57411 to 0.59993, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.4575 - dice_TC: 0.5864 - dice_WT: 0.7146 - loss: 0.0755 - mean_dice: 0.5862 - val_dice_ET: 0.4722 - val_dice_TC: 0.5970 - val_dice_WT: 0.7306 - val_loss: 0.0765 - val_mean_dice: 0.5999
# Epoch 7/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.4687 - dice_TC: 0.6009 - dice_WT: 0.7318 - loss: 0.0720 - mean_dice: 0.6004
# Epoch 7: val_mean_dice improved from 0.59993 to 0.62738, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 32s 53ms/step - dice_ET: 0.4800 - dice_TC: 0.6079 - dice_WT: 0.7332 - loss: 0.0714 - mean_dice: 0.6070 - val_dice_ET: 0.5006 - val_dice_TC: 0.6326 - val_dice_WT: 0.7489 - val_loss: 0.0700 - val_mean_dice: 0.6274
# Epoch 8/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5011 - dice_TC: 0.6272 - dice_WT: 0.7455 - loss: 0.0681 - mean_dice: 0.6246
# Epoch 8: val_mean_dice improved from 0.62738 to 0.63442, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 36s 61ms/step - dice_ET: 0.4972 - dice_TC: 0.6254 - dice_WT: 0.7479 - loss: 0.0681 - mean_dice: 0.6235 - val_dice_ET: 0.5112 - val_dice_TC: 0.6347 - val_dice_WT: 0.7574 - val_loss: 0.0695 - val_mean_dice: 0.6344
# Epoch 9/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5040 - dice_TC: 0.6290 - dice_WT: 0.7542 - loss: 0.0667 - mean_dice: 0.6291
# Epoch 9: val_mean_dice improved from 0.63442 to 0.64130, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.5094 - dice_TC: 0.6368 - dice_WT: 0.7577 - loss: 0.0655 - mean_dice: 0.6347 - val_dice_ET: 0.5183 - val_dice_TC: 0.6412 - val_dice_WT: 0.7645 - val_loss: 0.0673 - val_mean_dice: 0.6413
# Epoch 10/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5204 - dice_TC: 0.6393 - dice_WT: 0.7604 - loss: 0.0647 - mean_dice: 0.6400
# Epoch 10: val_mean_dice improved from 0.64130 to 0.65069, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.5196 - dice_TC: 0.6472 - dice_WT: 0.7650 - loss: 0.0635 - mean_dice: 0.6439 - val_dice_ET: 0.5281 - val_dice_TC: 0.6530 - val_dice_WT: 0.7709 - val_loss: 0.0663 - val_mean_dice: 0.6507
# Epoch 11/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5281 - dice_TC: 0.6519 - dice_WT: 0.7698 - loss: 0.0618 - mean_dice: 0.6499
# Epoch 11: val_mean_dice improved from 0.65069 to 0.65612, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 35s 59ms/step - dice_ET: 0.5275 - dice_TC: 0.6546 - dice_WT: 0.7701 - loss: 0.0622 - mean_dice: 0.6507 - val_dice_ET: 0.5350 - val_dice_TC: 0.6599 - val_dice_WT: 0.7734 - val_loss: 0.0673 - val_mean_dice: 0.6561
# Epoch 12/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5362 - dice_TC: 0.6628 - dice_WT: 0.7732 - loss: 0.0603 - mean_dice: 0.6574
# Epoch 12: val_mean_dice improved from 0.65612 to 0.65689, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 38s 64ms/step - dice_ET: 0.5356 - dice_TC: 0.6634 - dice_WT: 0.7755 - loss: 0.0600 - mean_dice: 0.6582 - val_dice_ET: 0.5359 - val_dice_TC: 0.6540 - val_dice_WT: 0.7808 - val_loss: 0.0652 - val_mean_dice: 0.6569
# Epoch 13/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5443 - dice_TC: 0.6692 - dice_WT: 0.7789 - loss: 0.0587 - mean_dice: 0.6641
# Epoch 13: val_mean_dice improved from 0.65689 to 0.67040, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 13: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 39s 66ms/step - dice_ET: 0.5407 - dice_TC: 0.6686 - dice_WT: 0.7801 - loss: 0.0586 - mean_dice: 0.6631 - val_dice_ET: 0.5479 - val_dice_TC: 0.6749 - val_dice_WT: 0.7884 - val_loss: 0.0630 - val_mean_dice: 0.6704
# Epoch 14/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5488 - dice_TC: 0.6751 - dice_WT: 0.7828 - loss: 0.0576 - mean_dice: 0.6689
# Epoch 14: val_mean_dice improved from 0.67040 to 0.67266, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 14: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 37s 62ms/step - dice_ET: 0.5466 - dice_TC: 0.6751 - dice_WT: 0.7841 - loss: 0.0574 - mean_dice: 0.6686 - val_dice_ET: 0.5527 - val_dice_TC: 0.6766 - val_dice_WT: 0.7887 - val_loss: 0.0629 - val_mean_dice: 0.6727
# Epoch 15/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5545 - dice_TC: 0.6823 - dice_WT: 0.7881 - loss: 0.0556 - mean_dice: 0.6749
# Epoch 15: val_mean_dice did not improve from 0.67266
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.5503 - dice_TC: 0.6805 - dice_WT: 0.7867 - loss: 0.0561 - mean_dice: 0.6725 - val_dice_ET: 0.5543 - val_dice_TC: 0.6655 - val_dice_WT: 0.7903 - val_loss: 0.0619 - val_mean_dice: 0.6700
# Epoch 16/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5548 - dice_TC: 0.6807 - dice_WT: 0.7885 - loss: 0.0549 - mean_dice: 0.6747
# Epoch 16: val_mean_dice did not improve from 0.67266
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 33s 55ms/step - dice_ET: 0.5545 - dice_TC: 0.6842 - dice_WT: 0.7894 - loss: 0.0551 - mean_dice: 0.6760 - val_dice_ET: 0.5450 - val_dice_TC: 0.6627 - val_dice_WT: 0.7804 - val_loss: 0.0655 - val_mean_dice: 0.6627
# Epoch 17/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5598 - dice_TC: 0.6919 - dice_WT: 0.7945 - loss: 0.0542 - mean_dice: 0.6821
# Epoch 17: val_mean_dice improved from 0.67266 to 0.67484, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 17: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 35s 59ms/step - dice_ET: 0.5583 - dice_TC: 0.6886 - dice_WT: 0.7922 - loss: 0.0540 - mean_dice: 0.6797 - val_dice_ET: 0.5571 - val_dice_TC: 0.6782 - val_dice_WT: 0.7892 - val_loss: 0.0612 - val_mean_dice: 0.6748
# Epoch 18/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5645 - dice_TC: 0.6933 - dice_WT: 0.7929 - loss: 0.0532 - mean_dice: 0.6836
# Epoch 18: val_mean_dice improved from 0.67484 to 0.67551, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 18: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.5616 - dice_TC: 0.6918 - dice_WT: 0.7938 - loss: 0.0532 - mean_dice: 0.6824 - val_dice_ET: 0.5617 - val_dice_TC: 0.6797 - val_dice_WT: 0.7851 - val_loss: 0.0594 - val_mean_dice: 0.6755
# Epoch 19/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5669 - dice_TC: 0.6902 - dice_WT: 0.7925 - loss: 0.0520 - mean_dice: 0.6832
# Epoch 19: val_mean_dice improved from 0.67551 to 0.68615, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 19: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.5642 - dice_TC: 0.6946 - dice_WT: 0.7954 - loss: 0.0523 - mean_dice: 0.6847 - val_dice_ET: 0.5659 - val_dice_TC: 0.6912 - val_dice_WT: 0.8014 - val_loss: 0.0594 - val_mean_dice: 0.6862
# Epoch 20/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5659 - dice_TC: 0.7017 - dice_WT: 0.8012 - loss: 0.0513 - mean_dice: 0.6896
# Epoch 20: val_mean_dice did not improve from 0.68615
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.5679 - dice_TC: 0.6999 - dice_WT: 0.7984 - loss: 0.0511 - mean_dice: 0.6887 - val_dice_ET: 0.5661 - val_dice_TC: 0.6856 - val_dice_WT: 0.7980 - val_loss: 0.0590 - val_mean_dice: 0.6832
# Epoch 21/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5695 - dice_TC: 0.7021 - dice_WT: 0.7968 - loss: 0.0496 - mean_dice: 0.6895
# Epoch 21: val_mean_dice did not improve from 0.68615
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.5717 - dice_TC: 0.7039 - dice_WT: 0.8019 - loss: 0.0499 - mean_dice: 0.6925 - val_dice_ET: 0.5660 - val_dice_TC: 0.6868 - val_dice_WT: 0.8019 - val_loss: 0.0571 - val_mean_dice: 0.6849
# Epoch 22/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5709 - dice_TC: 0.7023 - dice_WT: 0.8001 - loss: 0.0503 - mean_dice: 0.6911
# Epoch 22: val_mean_dice improved from 0.68615 to 0.69012, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 22: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.5719 - dice_TC: 0.7044 - dice_WT: 0.8017 - loss: 0.0500 - mean_dice: 0.6927 - val_dice_ET: 0.5732 - val_dice_TC: 0.6942 - val_dice_WT: 0.8029 - val_loss: 0.0565 - val_mean_dice: 0.6901
# Epoch 23/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5828 - dice_TC: 0.7112 - dice_WT: 0.8034 - loss: 0.0491 - mean_dice: 0.6992
# Epoch 23: val_mean_dice improved from 0.69012 to 0.69020, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 23: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 32s 55ms/step - dice_ET: 0.5750 - dice_TC: 0.7069 - dice_WT: 0.8040 - loss: 0.0492 - mean_dice: 0.6953 - val_dice_ET: 0.5743 - val_dice_TC: 0.6960 - val_dice_WT: 0.8003 - val_loss: 0.0570 - val_mean_dice: 0.6902
# Epoch 24/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5767 - dice_TC: 0.7100 - dice_WT: 0.8079 - loss: 0.0483 - mean_dice: 0.6982
# Epoch 24: val_mean_dice did not improve from 0.69020
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.5777 - dice_TC: 0.7108 - dice_WT: 0.8065 - loss: 0.0483 - mean_dice: 0.6983 - val_dice_ET: 0.5693 - val_dice_TC: 0.6928 - val_dice_WT: 0.8018 - val_loss: 0.0580 - val_mean_dice: 0.6880
# Epoch 25/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5841 - dice_TC: 0.7133 - dice_WT: 0.8127 - loss: 0.0478 - mean_dice: 0.7033
# Epoch 25: val_mean_dice improved from 0.69020 to 0.69346, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 25: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.5792 - dice_TC: 0.7125 - dice_WT: 0.8077 - loss: 0.0480 - mean_dice: 0.6998 - val_dice_ET: 0.5766 - val_dice_TC: 0.7023 - val_dice_WT: 0.8015 - val_loss: 0.0543 - val_mean_dice: 0.6935
# Epoch 26/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5854 - dice_TC: 0.7156 - dice_WT: 0.8115 - loss: 0.0465 - mean_dice: 0.7042
# Epoch 26: val_mean_dice did not improve from 0.69346
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 32s 53ms/step - dice_ET: 0.5820 - dice_TC: 0.7165 - dice_WT: 0.8101 - loss: 0.0467 - mean_dice: 0.7028 - val_dice_ET: 0.5681 - val_dice_TC: 0.6975 - val_dice_WT: 0.8049 - val_loss: 0.0556 - val_mean_dice: 0.6902
# Epoch 27/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5874 - dice_TC: 0.7221 - dice_WT: 0.8145 - loss: 0.0460 - mean_dice: 0.7080
# Epoch 27: val_mean_dice improved from 0.69346 to 0.69505, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 27: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 37s 63ms/step - dice_ET: 0.5839 - dice_TC: 0.7174 - dice_WT: 0.8118 - loss: 0.0463 - mean_dice: 0.7044 - val_dice_ET: 0.5790 - val_dice_TC: 0.7016 - val_dice_WT: 0.8046 - val_loss: 0.0556 - val_mean_dice: 0.6951
# Epoch 28/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5842 - dice_TC: 0.7223 - dice_WT: 0.8084 - loss: 0.0459 - mean_dice: 0.7050
# Epoch 28: val_mean_dice improved from 0.69505 to 0.69554, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 28: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 40s 67ms/step - dice_ET: 0.5849 - dice_TC: 0.7200 - dice_WT: 0.8121 - loss: 0.0460 - mean_dice: 0.7057 - val_dice_ET: 0.5775 - val_dice_TC: 0.7026 - val_dice_WT: 0.8065 - val_loss: 0.0559 - val_mean_dice: 0.6955
# Epoch 29/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5916 - dice_TC: 0.7243 - dice_WT: 0.8159 - loss: 0.0459 - mean_dice: 0.7106
# Epoch 29: val_mean_dice improved from 0.69554 to 0.70028, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 29: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 36s 60ms/step - dice_ET: 0.5866 - dice_TC: 0.7213 - dice_WT: 0.8133 - loss: 0.0455 - mean_dice: 0.7071 - val_dice_ET: 0.5814 - val_dice_TC: 0.7111 - val_dice_WT: 0.8083 - val_loss: 0.0548 - val_mean_dice: 0.7003
# Epoch 30/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5855 - dice_TC: 0.7264 - dice_WT: 0.8192 - loss: 0.0444 - mean_dice: 0.7104
# Epoch 30: val_mean_dice did not improve from 0.70028
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.5872 - dice_TC: 0.7234 - dice_WT: 0.8155 - loss: 0.0448 - mean_dice: 0.7087 - val_dice_ET: 0.5714 - val_dice_TC: 0.6971 - val_dice_WT: 0.8006 - val_loss: 0.0554 - val_mean_dice: 0.6897
# Epoch 31/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5920 - dice_TC: 0.7277 - dice_WT: 0.8167 - loss: 0.0448 - mean_dice: 0.7121
# Epoch 31: val_mean_dice improved from 0.70028 to 0.70271, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 31: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 32s 53ms/step - dice_ET: 0.5893 - dice_TC: 0.7255 - dice_WT: 0.8167 - loss: 0.0445 - mean_dice: 0.7105 - val_dice_ET: 0.5847 - val_dice_TC: 0.7115 - val_dice_WT: 0.8119 - val_loss: 0.0540 - val_mean_dice: 0.7027
# Epoch 32/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5898 - dice_TC: 0.7233 - dice_WT: 0.8145 - loss: 0.0444 - mean_dice: 0.7092
# Epoch 32: val_mean_dice did not improve from 0.70271
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.5910 - dice_TC: 0.7276 - dice_WT: 0.8183 - loss: 0.0439 - mean_dice: 0.7123 - val_dice_ET: 0.5825 - val_dice_TC: 0.7114 - val_dice_WT: 0.8135 - val_loss: 0.0526 - val_mean_dice: 0.7025
# Epoch 33/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5967 - dice_TC: 0.7293 - dice_WT: 0.8190 - loss: 0.0438 - mean_dice: 0.7150
# Epoch 33: val_mean_dice improved from 0.70271 to 0.70696, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 33: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.5919 - dice_TC: 0.7284 - dice_WT: 0.8189 - loss: 0.0437 - mean_dice: 0.7131 - val_dice_ET: 0.5910 - val_dice_TC: 0.7175 - val_dice_WT: 0.8124 - val_loss: 0.0518 - val_mean_dice: 0.7070
# Epoch 34/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5911 - dice_TC: 0.7359 - dice_WT: 0.8232 - loss: 0.0429 - mean_dice: 0.7167
# Epoch 34: val_mean_dice did not improve from 0.70696
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 50ms/step - dice_ET: 0.5937 - dice_TC: 0.7311 - dice_WT: 0.8204 - loss: 0.0429 - mean_dice: 0.7151 - val_dice_ET: 0.5835 - val_dice_TC: 0.7123 - val_dice_WT: 0.8123 - val_loss: 0.0521 - val_mean_dice: 0.7027
# Epoch 35/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5968 - dice_TC: 0.7305 - dice_WT: 0.8214 - loss: 0.0423 - mean_dice: 0.7163
# Epoch 35: val_mean_dice did not improve from 0.70696
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 50ms/step - dice_ET: 0.5951 - dice_TC: 0.7324 - dice_WT: 0.8213 - loss: 0.0426 - mean_dice: 0.7163 - val_dice_ET: 0.5859 - val_dice_TC: 0.7154 - val_dice_WT: 0.8128 - val_loss: 0.0515 - val_mean_dice: 0.7047
# Epoch 36/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5958 - dice_TC: 0.7350 - dice_WT: 0.8250 - loss: 0.0425 - mean_dice: 0.7186
# Epoch 36: val_mean_dice did not improve from 0.70696
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.5959 - dice_TC: 0.7322 - dice_WT: 0.8226 - loss: 0.0426 - mean_dice: 0.7169 - val_dice_ET: 0.5862 - val_dice_TC: 0.7163 - val_dice_WT: 0.8139 - val_loss: 0.0512 - val_mean_dice: 0.7055
# Epoch 37/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5962 - dice_TC: 0.7361 - dice_WT: 0.8248 - loss: 0.0424 - mean_dice: 0.7190
# Epoch 37: val_mean_dice improved from 0.70696 to 0.70953, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 37: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.5988 - dice_TC: 0.7365 - dice_WT: 0.8239 - loss: 0.0420 - mean_dice: 0.7197 - val_dice_ET: 0.5910 - val_dice_TC: 0.7217 - val_dice_WT: 0.8159 - val_loss: 0.0513 - val_mean_dice: 0.7095
# Epoch 38/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5965 - dice_TC: 0.7372 - dice_WT: 0.8226 - loss: 0.0416 - mean_dice: 0.7187
# Epoch 38: val_mean_dice did not improve from 0.70953
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.5990 - dice_TC: 0.7371 - dice_WT: 0.8248 - loss: 0.0416 - mean_dice: 0.7203 - val_dice_ET: 0.5885 - val_dice_TC: 0.7161 - val_dice_WT: 0.8165 - val_loss: 0.0507 - val_mean_dice: 0.7070
# Epoch 39/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5984 - dice_TC: 0.7313 - dice_WT: 0.8187 - loss: 0.0413 - mean_dice: 0.7161
# Epoch 39: val_mean_dice improved from 0.70953 to 0.70994, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 39: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.5999 - dice_TC: 0.7371 - dice_WT: 0.8248 - loss: 0.0415 - mean_dice: 0.7206 - val_dice_ET: 0.5925 - val_dice_TC: 0.7213 - val_dice_WT: 0.8161 - val_loss: 0.0507 - val_mean_dice: 0.7099
# Epoch 40/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5953 - dice_TC: 0.7330 - dice_WT: 0.8220 - loss: 0.0412 - mean_dice: 0.7168
# Epoch 40: val_mean_dice improved from 0.70994 to 0.71051, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 40: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6013 - dice_TC: 0.7388 - dice_WT: 0.8256 - loss: 0.0410 - mean_dice: 0.7219 - val_dice_ET: 0.5931 - val_dice_TC: 0.7215 - val_dice_WT: 0.8170 - val_loss: 0.0495 - val_mean_dice: 0.7105
# Epoch 41/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6019 - dice_TC: 0.7440 - dice_WT: 0.8296 - loss: 0.0407 - mean_dice: 0.7252
# Epoch 41: val_mean_dice did not improve from 0.71051
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.6024 - dice_TC: 0.7411 - dice_WT: 0.8272 - loss: 0.0407 - mean_dice: 0.7236 - val_dice_ET: 0.5902 - val_dice_TC: 0.7197 - val_dice_WT: 0.8193 - val_loss: 0.0513 - val_mean_dice: 0.7097
# Epoch 42/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6051 - dice_TC: 0.7453 - dice_WT: 0.8308 - loss: 0.0405 - mean_dice: 0.7271
# Epoch 42: val_mean_dice improved from 0.71051 to 0.71208, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 42: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6039 - dice_TC: 0.7422 - dice_WT: 0.8279 - loss: 0.0403 - mean_dice: 0.7247 - val_dice_ET: 0.5946 - val_dice_TC: 0.7246 - val_dice_WT: 0.8170 - val_loss: 0.0489 - val_mean_dice: 0.7121
# Epoch 43/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6050 - dice_TC: 0.7461 - dice_WT: 0.8287 - loss: 0.0401 - mean_dice: 0.7266
# Epoch 43: val_mean_dice improved from 0.71208 to 0.71299, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 43: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 32s 54ms/step - dice_ET: 0.6039 - dice_TC: 0.7434 - dice_WT: 0.8285 - loss: 0.0401 - mean_dice: 0.7253 - val_dice_ET: 0.5957 - val_dice_TC: 0.7244 - val_dice_WT: 0.8189 - val_loss: 0.0493 - val_mean_dice: 0.7130
# Epoch 44/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6056 - dice_TC: 0.7464 - dice_WT: 0.8319 - loss: 0.0400 - mean_dice: 0.7280
# Epoch 44: val_mean_dice did not improve from 0.71299
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6050 - dice_TC: 0.7445 - dice_WT: 0.8302 - loss: 0.0399 - mean_dice: 0.7266 - val_dice_ET: 0.5927 - val_dice_TC: 0.7205 - val_dice_WT: 0.8163 - val_loss: 0.0489 - val_mean_dice: 0.7098
# Epoch 45/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.5965 - dice_TC: 0.7438 - dice_WT: 0.8279 - loss: 0.0396 - mean_dice: 0.7227
# Epoch 45: val_mean_dice improved from 0.71299 to 0.71642, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 45: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6062 - dice_TC: 0.7460 - dice_WT: 0.8302 - loss: 0.0395 - mean_dice: 0.7275 - val_dice_ET: 0.5997 - val_dice_TC: 0.7281 - val_dice_WT: 0.8215 - val_loss: 0.0483 - val_mean_dice: 0.7164
# Epoch 46/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6080 - dice_TC: 0.7460 - dice_WT: 0.8300 - loss: 0.0392 - mean_dice: 0.7280
# Epoch 46: val_mean_dice improved from 0.71642 to 0.71815, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 46: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6072 - dice_TC: 0.7464 - dice_WT: 0.8318 - loss: 0.0393 - mean_dice: 0.7285 - val_dice_ET: 0.6024 - val_dice_TC: 0.7313 - val_dice_WT: 0.8208 - val_loss: 0.0477 - val_mean_dice: 0.7182
# Epoch 47/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6085 - dice_TC: 0.7463 - dice_WT: 0.8296 - loss: 0.0390 - mean_dice: 0.7282
# Epoch 47: val_mean_dice did not improve from 0.71815
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.6074 - dice_TC: 0.7479 - dice_WT: 0.8320 - loss: 0.0390 - mean_dice: 0.7291 - val_dice_ET: 0.5993 - val_dice_TC: 0.7292 - val_dice_WT: 0.8215 - val_loss: 0.0473 - val_mean_dice: 0.7167
# Epoch 48/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6095 - dice_TC: 0.7485 - dice_WT: 0.8344 - loss: 0.0385 - mean_dice: 0.7308
# Epoch 48: val_mean_dice did not improve from 0.71815
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 50ms/step - dice_ET: 0.6093 - dice_TC: 0.7491 - dice_WT: 0.8332 - loss: 0.0388 - mean_dice: 0.7305 - val_dice_ET: 0.6005 - val_dice_TC: 0.7322 - val_dice_WT: 0.8198 - val_loss: 0.0478 - val_mean_dice: 0.7175
# Epoch 49/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6056 - dice_TC: 0.7474 - dice_WT: 0.8347 - loss: 0.0387 - mean_dice: 0.7292
# Epoch 49: val_mean_dice did not improve from 0.71815
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.6088 - dice_TC: 0.7494 - dice_WT: 0.8343 - loss: 0.0386 - mean_dice: 0.7308 - val_dice_ET: 0.6008 - val_dice_TC: 0.7298 - val_dice_WT: 0.8222 - val_loss: 0.0469 - val_mean_dice: 0.7176
# Epoch 50/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6089 - dice_TC: 0.7474 - dice_WT: 0.8339 - loss: 0.0386 - mean_dice: 0.7301
# Epoch 50: val_mean_dice did not improve from 0.71815
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 50ms/step - dice_ET: 0.6104 - dice_TC: 0.7508 - dice_WT: 0.8346 - loss: 0.0382 - mean_dice: 0.7320 - val_dice_ET: 0.5971 - val_dice_TC: 0.7298 - val_dice_WT: 0.8209 - val_loss: 0.0473 - val_mean_dice: 0.7159
# Epoch 51/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6143 - dice_TC: 0.7519 - dice_WT: 0.8378 - loss: 0.0380 - mean_dice: 0.7347
# Epoch 51: val_mean_dice improved from 0.71815 to 0.71818, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 51: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6115 - dice_TC: 0.7513 - dice_WT: 0.8349 - loss: 0.0380 - mean_dice: 0.7325 - val_dice_ET: 0.6004 - val_dice_TC: 0.7312 - val_dice_WT: 0.8230 - val_loss: 0.0465 - val_mean_dice: 0.7182
# Epoch 52/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6146 - dice_TC: 0.7512 - dice_WT: 0.8350 - loss: 0.0376 - mean_dice: 0.7336
# Epoch 52: val_mean_dice did not improve from 0.71818
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.6113 - dice_TC: 0.7525 - dice_WT: 0.8356 - loss: 0.0378 - mean_dice: 0.7331 - val_dice_ET: 0.5983 - val_dice_TC: 0.7310 - val_dice_WT: 0.8221 - val_loss: 0.0467 - val_mean_dice: 0.7171
# Epoch 53/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6120 - dice_TC: 0.7501 - dice_WT: 0.8341 - loss: 0.0371 - mean_dice: 0.7321
# Epoch 53: val_mean_dice improved from 0.71818 to 0.71843, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 53: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6138 - dice_TC: 0.7551 - dice_WT: 0.8377 - loss: 0.0373 - mean_dice: 0.7355 - val_dice_ET: 0.6006 - val_dice_TC: 0.7305 - val_dice_WT: 0.8241 - val_loss: 0.0469 - val_mean_dice: 0.7184
# Epoch 54/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6164 - dice_TC: 0.7564 - dice_WT: 0.8393 - loss: 0.0374 - mean_dice: 0.7373
# Epoch 54: val_mean_dice improved from 0.71843 to 0.72184, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 54: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 37s 62ms/step - dice_ET: 0.6147 - dice_TC: 0.7551 - dice_WT: 0.8376 - loss: 0.0374 - mean_dice: 0.7358 - val_dice_ET: 0.6040 - val_dice_TC: 0.7361 - val_dice_WT: 0.8254 - val_loss: 0.0464 - val_mean_dice: 0.7218
# Epoch 55/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6167 - dice_TC: 0.7600 - dice_WT: 0.8423 - loss: 0.0368 - mean_dice: 0.7397
# Epoch 55: val_mean_dice improved from 0.72184 to 0.72259, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 55: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6144 - dice_TC: 0.7558 - dice_WT: 0.8381 - loss: 0.0369 - mean_dice: 0.7361 - val_dice_ET: 0.6067 - val_dice_TC: 0.7358 - val_dice_WT: 0.8252 - val_loss: 0.0460 - val_mean_dice: 0.7226
# Epoch 56/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6153 - dice_TC: 0.7534 - dice_WT: 0.8353 - loss: 0.0366 - mean_dice: 0.7347
# Epoch 56: val_mean_dice did not improve from 0.72259
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.6156 - dice_TC: 0.7565 - dice_WT: 0.8379 - loss: 0.0369 - mean_dice: 0.7367 - val_dice_ET: 0.6052 - val_dice_TC: 0.7369 - val_dice_WT: 0.8253 - val_loss: 0.0457 - val_mean_dice: 0.7225
# Epoch 57/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6195 - dice_TC: 0.7597 - dice_WT: 0.8409 - loss: 0.0365 - mean_dice: 0.7400
# Epoch 57: val_mean_dice improved from 0.72259 to 0.72415, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 57: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6164 - dice_TC: 0.7576 - dice_WT: 0.8390 - loss: 0.0366 - mean_dice: 0.7377 - val_dice_ET: 0.6069 - val_dice_TC: 0.7385 - val_dice_WT: 0.8270 - val_loss: 0.0455 - val_mean_dice: 0.7242
# Epoch 58/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6087 - dice_TC: 0.7516 - dice_WT: 0.8342 - loss: 0.0361 - mean_dice: 0.7315
# Epoch 58: val_mean_dice did not improve from 0.72415
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.6162 - dice_TC: 0.7584 - dice_WT: 0.8396 - loss: 0.0365 - mean_dice: 0.7381 - val_dice_ET: 0.6047 - val_dice_TC: 0.7359 - val_dice_WT: 0.8262 - val_loss: 0.0449 - val_mean_dice: 0.7223
# Epoch 59/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6144 - dice_TC: 0.7564 - dice_WT: 0.8404 - loss: 0.0365 - mean_dice: 0.7371
# Epoch 59: val_mean_dice did not improve from 0.72415
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 50ms/step - dice_ET: 0.6163 - dice_TC: 0.7585 - dice_WT: 0.8401 - loss: 0.0364 - mean_dice: 0.7383 - val_dice_ET: 0.6046 - val_dice_TC: 0.7363 - val_dice_WT: 0.8255 - val_loss: 0.0448 - val_mean_dice: 0.7221
# Epoch 60/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6179 - dice_TC: 0.7593 - dice_WT: 0.8404 - loss: 0.0362 - mean_dice: 0.7392
# Epoch 60: val_mean_dice improved from 0.72415 to 0.72510, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 60: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6183 - dice_TC: 0.7605 - dice_WT: 0.8412 - loss: 0.0360 - mean_dice: 0.7400 - val_dice_ET: 0.6075 - val_dice_TC: 0.7410 - val_dice_WT: 0.8268 - val_loss: 0.0451 - val_mean_dice: 0.7251
# Epoch 61/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6222 - dice_TC: 0.7651 - dice_WT: 0.8431 - loss: 0.0354 - mean_dice: 0.7435
# Epoch 61: val_mean_dice did not improve from 0.72510
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 50ms/step - dice_ET: 0.6187 - dice_TC: 0.7610 - dice_WT: 0.8416 - loss: 0.0359 - mean_dice: 0.7405 - val_dice_ET: 0.6086 - val_dice_TC: 0.7396 - val_dice_WT: 0.8270 - val_loss: 0.0445 - val_mean_dice: 0.7251
# Epoch 62/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6146 - dice_TC: 0.7574 - dice_WT: 0.8412 - loss: 0.0356 - mean_dice: 0.7377
# Epoch 62: val_mean_dice did not improve from 0.72510
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6191 - dice_TC: 0.7607 - dice_WT: 0.8420 - loss: 0.0357 - mean_dice: 0.7406 - val_dice_ET: 0.6074 - val_dice_TC: 0.7405 - val_dice_WT: 0.8262 - val_loss: 0.0449 - val_mean_dice: 0.7247
# Epoch 63/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6189 - dice_TC: 0.7608 - dice_WT: 0.8406 - loss: 0.0357 - mean_dice: 0.7401
# Epoch 63: val_mean_dice improved from 0.72510 to 0.72642, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 63: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6192 - dice_TC: 0.7615 - dice_WT: 0.8424 - loss: 0.0356 - mean_dice: 0.7410 - val_dice_ET: 0.6087 - val_dice_TC: 0.7424 - val_dice_WT: 0.8282 - val_loss: 0.0443 - val_mean_dice: 0.7264
# Epoch 64/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6194 - dice_TC: 0.7624 - dice_WT: 0.8427 - loss: 0.0350 - mean_dice: 0.7415
# Epoch 64: val_mean_dice improved from 0.72642 to 0.72712, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 64: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6205 - dice_TC: 0.7626 - dice_WT: 0.8429 - loss: 0.0353 - mean_dice: 0.7420 - val_dice_ET: 0.6099 - val_dice_TC: 0.7430 - val_dice_WT: 0.8285 - val_loss: 0.0435 - val_mean_dice: 0.7271
# Epoch 65/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6258 - dice_TC: 0.7666 - dice_WT: 0.8460 - loss: 0.0352 - mean_dice: 0.7461
# Epoch 65: val_mean_dice improved from 0.72712 to 0.72713, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 65: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6212 - dice_TC: 0.7637 - dice_WT: 0.8430 - loss: 0.0352 - mean_dice: 0.7427 - val_dice_ET: 0.6104 - val_dice_TC: 0.7426 - val_dice_WT: 0.8284 - val_loss: 0.0441 - val_mean_dice: 0.7271
# Epoch 66/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6240 - dice_TC: 0.7700 - dice_WT: 0.8457 - loss: 0.0349 - mean_dice: 0.7466
# Epoch 66: val_mean_dice did not improve from 0.72713
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6219 - dice_TC: 0.7649 - dice_WT: 0.8443 - loss: 0.0349 - mean_dice: 0.7437 - val_dice_ET: 0.6097 - val_dice_TC: 0.7410 - val_dice_WT: 0.8275 - val_loss: 0.0440 - val_mean_dice: 0.7261
# Epoch 67/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6210 - dice_TC: 0.7677 - dice_WT: 0.8457 - loss: 0.0351 - mean_dice: 0.7448
# Epoch 67: val_mean_dice improved from 0.72713 to 0.72851, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 67: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6219 - dice_TC: 0.7638 - dice_WT: 0.8439 - loss: 0.0350 - mean_dice: 0.7432 - val_dice_ET: 0.6122 - val_dice_TC: 0.7439 - val_dice_WT: 0.8295 - val_loss: 0.0435 - val_mean_dice: 0.7285
# Epoch 68/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6241 - dice_TC: 0.7649 - dice_WT: 0.8436 - loss: 0.0345 - mean_dice: 0.7442
# Epoch 68: val_mean_dice did not improve from 0.72851
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 36s 61ms/step - dice_ET: 0.6226 - dice_TC: 0.7655 - dice_WT: 0.8452 - loss: 0.0348 - mean_dice: 0.7444 - val_dice_ET: 0.6097 - val_dice_TC: 0.7432 - val_dice_WT: 0.8280 - val_loss: 0.0435 - val_mean_dice: 0.7269
# Epoch 69/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6207 - dice_TC: 0.7697 - dice_WT: 0.8454 - loss: 0.0347 - mean_dice: 0.7453
# Epoch 69: val_mean_dice did not improve from 0.72851
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.6224 - dice_TC: 0.7662 - dice_WT: 0.8454 - loss: 0.0347 - mean_dice: 0.7447 - val_dice_ET: 0.6116 - val_dice_TC: 0.7445 - val_dice_WT: 0.8292 - val_loss: 0.0430 - val_mean_dice: 0.7284
# Epoch 70/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6209 - dice_TC: 0.7660 - dice_WT: 0.8450 - loss: 0.0346 - mean_dice: 0.7439
# Epoch 70: val_mean_dice did not improve from 0.72851
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.6234 - dice_TC: 0.7661 - dice_WT: 0.8455 - loss: 0.0346 - mean_dice: 0.7450 - val_dice_ET: 0.6097 - val_dice_TC: 0.7431 - val_dice_WT: 0.8295 - val_loss: 0.0428 - val_mean_dice: 0.7274
# Epoch 71/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6293 - dice_TC: 0.7754 - dice_WT: 0.8505 - loss: 0.0343 - mean_dice: 0.7518
# Epoch 71: val_mean_dice improved from 0.72851 to 0.72888, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 71: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6236 - dice_TC: 0.7667 - dice_WT: 0.8459 - loss: 0.0344 - mean_dice: 0.7454 - val_dice_ET: 0.6117 - val_dice_TC: 0.7445 - val_dice_WT: 0.8305 - val_loss: 0.0435 - val_mean_dice: 0.7289
# Epoch 72/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6290 - dice_TC: 0.7702 - dice_WT: 0.8484 - loss: 0.0340 - mean_dice: 0.7492
# Epoch 72: val_mean_dice improved from 0.72888 to 0.73033, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 72: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6240 - dice_TC: 0.7672 - dice_WT: 0.8462 - loss: 0.0343 - mean_dice: 0.7458 - val_dice_ET: 0.6133 - val_dice_TC: 0.7460 - val_dice_WT: 0.8316 - val_loss: 0.0431 - val_mean_dice: 0.7303
# Epoch 73/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6298 - dice_TC: 0.7706 - dice_WT: 0.8511 - loss: 0.0343 - mean_dice: 0.7505
# Epoch 73: val_mean_dice improved from 0.73033 to 0.73045, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 73: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6246 - dice_TC: 0.7679 - dice_WT: 0.8467 - loss: 0.0343 - mean_dice: 0.7464 - val_dice_ET: 0.6131 - val_dice_TC: 0.7469 - val_dice_WT: 0.8313 - val_loss: 0.0424 - val_mean_dice: 0.7305
# Epoch 74/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6282 - dice_TC: 0.7711 - dice_WT: 0.8493 - loss: 0.0340 - mean_dice: 0.7496
# Epoch 74: val_mean_dice improved from 0.73045 to 0.73111, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 74: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6254 - dice_TC: 0.7691 - dice_WT: 0.8473 - loss: 0.0339 - mean_dice: 0.7472 - val_dice_ET: 0.6137 - val_dice_TC: 0.7473 - val_dice_WT: 0.8324 - val_loss: 0.0425 - val_mean_dice: 0.7311
# Epoch 75/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6296 - dice_TC: 0.7714 - dice_WT: 0.8492 - loss: 0.0335 - mean_dice: 0.7501
# Epoch 75: val_mean_dice improved from 0.73111 to 0.73133, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 75: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 37s 63ms/step - dice_ET: 0.6257 - dice_TC: 0.7687 - dice_WT: 0.8476 - loss: 0.0339 - mean_dice: 0.7473 - val_dice_ET: 0.6146 - val_dice_TC: 0.7479 - val_dice_WT: 0.8314 - val_loss: 0.0423 - val_mean_dice: 0.7313
# Epoch 76/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6269 - dice_TC: 0.7673 - dice_WT: 0.8456 - loss: 0.0339 - mean_dice: 0.7466
# Epoch 76: val_mean_dice improved from 0.73133 to 0.73312, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 76: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 34s 58ms/step - dice_ET: 0.6264 - dice_TC: 0.7700 - dice_WT: 0.8476 - loss: 0.0338 - mean_dice: 0.7480 - val_dice_ET: 0.6164 - val_dice_TC: 0.7496 - val_dice_WT: 0.8333 - val_loss: 0.0423 - val_mean_dice: 0.7331
# Epoch 77/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6298 - dice_TC: 0.7691 - dice_WT: 0.8469 - loss: 0.0337 - mean_dice: 0.7486
# Epoch 77: val_mean_dice did not improve from 0.73312
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 50ms/step - dice_ET: 0.6261 - dice_TC: 0.7697 - dice_WT: 0.8481 - loss: 0.0336 - mean_dice: 0.7480 - val_dice_ET: 0.6152 - val_dice_TC: 0.7473 - val_dice_WT: 0.8324 - val_loss: 0.0424 - val_mean_dice: 0.7316
# Epoch 78/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6233 - dice_TC: 0.7666 - dice_WT: 0.8472 - loss: 0.0337 - mean_dice: 0.7457
# Epoch 78: val_mean_dice did not improve from 0.73312
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 51ms/step - dice_ET: 0.6263 - dice_TC: 0.7705 - dice_WT: 0.8482 - loss: 0.0335 - mean_dice: 0.7483 - val_dice_ET: 0.6140 - val_dice_TC: 0.7476 - val_dice_WT: 0.8325 - val_loss: 0.0421 - val_mean_dice: 0.7314
# Epoch 79/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6297 - dice_TC: 0.7739 - dice_WT: 0.8537 - loss: 0.0337 - mean_dice: 0.7524
# Epoch 79: val_mean_dice did not improve from 0.73312
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 50ms/step - dice_ET: 0.6269 - dice_TC: 0.7708 - dice_WT: 0.8488 - loss: 0.0336 - mean_dice: 0.7488 - val_dice_ET: 0.6150 - val_dice_TC: 0.7490 - val_dice_WT: 0.8331 - val_loss: 0.0420 - val_mean_dice: 0.7324
# Epoch 80/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6285 - dice_TC: 0.7709 - dice_WT: 0.8453 - loss: 0.0334 - mean_dice: 0.7482
# Epoch 80: val_mean_dice improved from 0.73312 to 0.73385, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 80: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6269 - dice_TC: 0.7711 - dice_WT: 0.8486 - loss: 0.0335 - mean_dice: 0.7489 - val_dice_ET: 0.6178 - val_dice_TC: 0.7505 - val_dice_WT: 0.8333 - val_loss: 0.0419 - val_mean_dice: 0.7339
# Epoch 81/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6315 - dice_TC: 0.7730 - dice_WT: 0.8494 - loss: 0.0333 - mean_dice: 0.7513
# Epoch 81: val_mean_dice did not improve from 0.73385
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.6275 - dice_TC: 0.7716 - dice_WT: 0.8489 - loss: 0.0334 - mean_dice: 0.7493 - val_dice_ET: 0.6170 - val_dice_TC: 0.7501 - val_dice_WT: 0.8337 - val_loss: 0.0417 - val_mean_dice: 0.7336
# Epoch 82/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6336 - dice_TC: 0.7772 - dice_WT: 0.8527 - loss: 0.0333 - mean_dice: 0.7545
# Epoch 82: val_mean_dice did not improve from 0.73385
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 50ms/step - dice_ET: 0.6274 - dice_TC: 0.7714 - dice_WT: 0.8495 - loss: 0.0333 - mean_dice: 0.7494 - val_dice_ET: 0.6166 - val_dice_TC: 0.7494 - val_dice_WT: 0.8332 - val_loss: 0.0423 - val_mean_dice: 0.7331
# Epoch 83/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6335 - dice_TC: 0.7795 - dice_WT: 0.8540 - loss: 0.0330 - mean_dice: 0.7557
# Epoch 83: val_mean_dice did not improve from 0.73385
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 49ms/step - dice_ET: 0.6277 - dice_TC: 0.7716 - dice_WT: 0.8491 - loss: 0.0331 - mean_dice: 0.7494 - val_dice_ET: 0.6154 - val_dice_TC: 0.7498 - val_dice_WT: 0.8332 - val_loss: 0.0418 - val_mean_dice: 0.7328
# Epoch 84/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6203 - dice_TC: 0.7661 - dice_WT: 0.8449 - loss: 0.0329 - mean_dice: 0.7438
# Epoch 84: val_mean_dice did not improve from 0.73385
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 50ms/step - dice_ET: 0.6281 - dice_TC: 0.7729 - dice_WT: 0.8494 - loss: 0.0331 - mean_dice: 0.7502 - val_dice_ET: 0.6170 - val_dice_TC: 0.7497 - val_dice_WT: 0.8338 - val_loss: 0.0419 - val_mean_dice: 0.7335
# Epoch 85/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6266 - dice_TC: 0.7673 - dice_WT: 0.8444 - loss: 0.0331 - mean_dice: 0.7461
# Epoch 85: val_mean_dice improved from 0.73385 to 0.73408, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 85: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6289 - dice_TC: 0.7730 - dice_WT: 0.8500 - loss: 0.0330 - mean_dice: 0.7507 - val_dice_ET: 0.6179 - val_dice_TC: 0.7505 - val_dice_WT: 0.8339 - val_loss: 0.0419 - val_mean_dice: 0.7341
# Epoch 86/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6377 - dice_TC: 0.7801 - dice_WT: 0.8526 - loss: 0.0328 - mean_dice: 0.7568
# Epoch 86: val_mean_dice did not improve from 0.73408
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.6289 - dice_TC: 0.7733 - dice_WT: 0.8502 - loss: 0.0330 - mean_dice: 0.7508 - val_dice_ET: 0.6165 - val_dice_TC: 0.7496 - val_dice_WT: 0.8335 - val_loss: 0.0418 - val_mean_dice: 0.7332
# Epoch 87/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6275 - dice_TC: 0.7695 - dice_WT: 0.8510 - loss: 0.0327 - mean_dice: 0.7494
# Epoch 87: val_mean_dice did not improve from 0.73408
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.6289 - dice_TC: 0.7732 - dice_WT: 0.8501 - loss: 0.0329 - mean_dice: 0.7507 - val_dice_ET: 0.6163 - val_dice_TC: 0.7508 - val_dice_WT: 0.8335 - val_loss: 0.0416 - val_mean_dice: 0.7335
# Epoch 88/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6295 - dice_TC: 0.7779 - dice_WT: 0.8530 - loss: 0.0331 - mean_dice: 0.7535
# Epoch 88: val_mean_dice did not improve from 0.73408
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 33s 55ms/step - dice_ET: 0.6288 - dice_TC: 0.7736 - dice_WT: 0.8505 - loss: 0.0330 - mean_dice: 0.7510 - val_dice_ET: 0.6167 - val_dice_TC: 0.7503 - val_dice_WT: 0.8338 - val_loss: 0.0416 - val_mean_dice: 0.7336
# Epoch 89/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6203 - dice_TC: 0.7703 - dice_WT: 0.8450 - loss: 0.0329 - mean_dice: 0.7452
# Epoch 89: val_mean_dice did not improve from 0.73408
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 50ms/step - dice_ET: 0.6288 - dice_TC: 0.7732 - dice_WT: 0.8504 - loss: 0.0327 - mean_dice: 0.7508 - val_dice_ET: 0.6169 - val_dice_TC: 0.7506 - val_dice_WT: 0.8337 - val_loss: 0.0416 - val_mean_dice: 0.7337
# Epoch 90/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6338 - dice_TC: 0.7800 - dice_WT: 0.8550 - loss: 0.0328 - mean_dice: 0.7563
# Epoch 90: val_mean_dice did not improve from 0.73408
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - dice_ET: 0.6290 - dice_TC: 0.7735 - dice_WT: 0.8503 - loss: 0.0328 - mean_dice: 0.7509 - val_dice_ET: 0.6165 - val_dice_TC: 0.7507 - val_dice_WT: 0.8341 - val_loss: 0.0415 - val_mean_dice: 0.7338
# Epoch 91/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6359 - dice_TC: 0.7782 - dice_WT: 0.8535 - loss: 0.0326 - mean_dice: 0.7559
# Epoch 91: val_mean_dice improved from 0.73408 to 0.73423, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 91: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6297 - dice_TC: 0.7744 - dice_WT: 0.8510 - loss: 0.0328 - mean_dice: 0.7517 - val_dice_ET: 0.6172 - val_dice_TC: 0.7513 - val_dice_WT: 0.8342 - val_loss: 0.0414 - val_mean_dice: 0.7342
# Epoch 92/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6350 - dice_TC: 0.7792 - dice_WT: 0.8540 - loss: 0.0328 - mean_dice: 0.7561
# Epoch 92: val_mean_dice improved from 0.73423 to 0.73436, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 92: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6295 - dice_TC: 0.7741 - dice_WT: 0.8507 - loss: 0.0328 - mean_dice: 0.7515 - val_dice_ET: 0.6174 - val_dice_TC: 0.7513 - val_dice_WT: 0.8344 - val_loss: 0.0416 - val_mean_dice: 0.7344
# Epoch 93/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6329 - dice_TC: 0.7778 - dice_WT: 0.8534 - loss: 0.0327 - mean_dice: 0.7547
# Epoch 93: val_mean_dice did not improve from 0.73436
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 50ms/step - dice_ET: 0.6295 - dice_TC: 0.7743 - dice_WT: 0.8508 - loss: 0.0328 - mean_dice: 0.7515 - val_dice_ET: 0.6167 - val_dice_TC: 0.7512 - val_dice_WT: 0.8343 - val_loss: 0.0413 - val_mean_dice: 0.7340
# Epoch 94/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6375 - dice_TC: 0.7776 - dice_WT: 0.8521 - loss: 0.0327 - mean_dice: 0.7558
# Epoch 94: val_mean_dice improved from 0.73436 to 0.73478, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 94: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 52ms/step - dice_ET: 0.6293 - dice_TC: 0.7739 - dice_WT: 0.8509 - loss: 0.0326 - mean_dice: 0.7514 - val_dice_ET: 0.6180 - val_dice_TC: 0.7517 - val_dice_WT: 0.8346 - val_loss: 0.0413 - val_mean_dice: 0.7348
# Epoch 95/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6265 - dice_TC: 0.7728 - dice_WT: 0.8525 - loss: 0.0324 - mean_dice: 0.7506
# Epoch 95: val_mean_dice did not improve from 0.73478
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 29s 50ms/step - dice_ET: 0.6296 - dice_TC: 0.7740 - dice_WT: 0.8510 - loss: 0.0326 - mean_dice: 0.7516 - val_dice_ET: 0.6176 - val_dice_TC: 0.7516 - val_dice_WT: 0.8345 - val_loss: 0.0413 - val_mean_dice: 0.7346
# Epoch 96/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6313 - dice_TC: 0.7758 - dice_WT: 0.8501 - loss: 0.0325 - mean_dice: 0.7524
# Epoch 96: val_mean_dice improved from 0.73478 to 0.73494, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 96: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 53ms/step - dice_ET: 0.6301 - dice_TC: 0.7747 - dice_WT: 0.8506 - loss: 0.0326 - mean_dice: 0.7518 - val_dice_ET: 0.6181 - val_dice_TC: 0.7520 - val_dice_WT: 0.8346 - val_loss: 0.0413 - val_mean_dice: 0.7349
# Epoch 97/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6240 - dice_TC: 0.7679 - dice_WT: 0.8494 - loss: 0.0327 - mean_dice: 0.7471
# Epoch 97: val_mean_dice did not improve from 0.73494
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 40s 68ms/step - dice_ET: 0.6298 - dice_TC: 0.7742 - dice_WT: 0.8512 - loss: 0.0325 - mean_dice: 0.7517 - val_dice_ET: 0.6175 - val_dice_TC: 0.7515 - val_dice_WT: 0.8345 - val_loss: 0.0414 - val_mean_dice: 0.7345
# Epoch 98/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6261 - dice_TC: 0.7718 - dice_WT: 0.8500 - loss: 0.0326 - mean_dice: 0.7493
# Epoch 98: val_mean_dice did not improve from 0.73494
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 31s 51ms/step - dice_ET: 0.6299 - dice_TC: 0.7749 - dice_WT: 0.8513 - loss: 0.0326 - mean_dice: 0.7520 - val_dice_ET: 0.6180 - val_dice_TC: 0.7517 - val_dice_WT: 0.8345 - val_loss: 0.0415 - val_mean_dice: 0.7348
# Epoch 99/100
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6304 - dice_TC: 0.7742 - dice_WT: 0.8535 - loss: 0.0324 - mean_dice: 0.7527
# Epoch 99: val_mean_dice did not improve from 0.73494
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 33s 56ms/step - dice_ET: 0.6304 - dice_TC: 0.7748 - dice_WT: 0.8509 - loss: 0.0326 - mean_dice: 0.7521 - val_dice_ET: 0.6181 - val_dice_TC: 0.7518 - val_dice_WT: 0.8346 - val_loss: 0.0412 - val_mean_dice: 0.7348
# Epoch 100/100
# 589/590 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_ET: 0.6268 - dice_TC: 0.7706 - dice_WT: 0.8509 - loss: 0.0328 - mean_dice: 0.7494
# Epoch 100: val_mean_dice improved from 0.73494 to 0.73498, saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
#
# Epoch 100: finished saving model to /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/best_model.keras
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 35s 58ms/step - dice_ET: 0.6304 - dice_TC: 0.7753 - dice_WT: 0.8514 - loss: 0.0325 - mean_dice: 0.7524 - val_dice_ET: 0.6182 - val_dice_TC: 0.7521 - val_dice_WT: 0.8347 - val_loss: 0.0413 - val_mean_dice: 0.7350
# Restoring model weights from the end of the best epoch: 100.

# %%
# Training Curves

def plot_training_curves(history, save_path):
    hist   = history.history
    epochs = range(1, len(hist["loss"]) + 1)

    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    fig.suptitle("Training & Validation Curves", fontsize=14)

    # Loss
    ax = axes[0, 0]
    ax.plot(epochs, hist["loss"],     label="Train", color="steelblue")
    ax.plot(epochs, hist["val_loss"], label="Val",   color="tomato", linestyle="--")
    ax.set_title("Loss")
    ax.set_xlabel("Epoch"); ax.legend(); ax.grid(True, alpha=0.3)

    # Mean Dice
    ax = axes[0, 1]
    ax.plot(epochs, hist["mean_dice"],     label="Train", color="steelblue")
    ax.plot(epochs, hist["val_mean_dice"], label="Val",   color="tomato", linestyle="--")
    ax.set_title("Mean Dice")
    ax.set_xlabel("Epoch"); ax.legend(); ax.grid(True, alpha=0.3)

    # Learning rate
    ax = axes[0, 2]
    if "lr" in hist:
        ax.semilogy(epochs, hist["lr"], color="purple")
    ax.set_title("Learning Rate (log scale)")
    ax.set_xlabel("Epoch"); ax.grid(True, alpha=0.3)

    # Per-region Dice
    region_cfg = [
        ("dice_WT", "val_dice_WT", "WT Dice", "royalblue"),
        ("dice_ET", "val_dice_ET", "ET Dice", "tomato"),
        ("dice_TC", "val_dice_TC", "TC Dice", "darkorange"),
    ]
    for idx, (tr_key, val_key, title, color) in enumerate(region_cfg):
        ax = axes[1, idx]
        if tr_key  in hist: ax.plot(epochs, hist[tr_key],  label="Train",
                                    color=color)
        if val_key in hist: ax.plot(epochs, hist[val_key], label="Val",
                                    color=color, linestyle="--", alpha=0.7)
        ax.set_title(title)
        ax.set_xlabel("Epoch"); ax.legend(); ax.grid(True, alpha=0.3)

    fig.tight_layout()
    save_and_show(fig, save_path, "training curves")

plot_training_curves(history, CURVES_PATH)
# Out:
# Saved → /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/training_curves.png  (training curves)

# %%
# Evaluation on Test Set

print("\n" + "="*58)
print("  Evaluating on Test  (best model weights)")
print("="*58)

test_results = model.evaluate(test_ds, verbose=1)
metric_names = model.metrics_names

print("\n ")
print("   Test Evaluation:         ")

for name, val in zip(metric_names, test_results):
    print(f"  {name:<24s}: {val:.4f}  ")


with open(EVAL_PATH, "w") as f:
    f.write("=" * 52 + "\n")
    f.write("  Test Evaluation Results\n")
    f.write("=" * 52 + "\n")
    for name, val in zip(metric_names, test_results):
        f.write(f"  {name:<28s}: {val:.6f}\n")
    f.write("=" * 52 + "\n")

print(f"\nEvaluation results saved → {EVAL_PATH}")
# Out:
# ==========================================================
#   Evaluating on Test  (best model weights)
# ==========================================================
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - dice_ET: 0.6082 - dice_TC: 0.7378 - dice_WT: 0.8245 - loss: 0.0411 - mean_dice: 0.7235
#
#
#    Test Evaluation:
#   loss                    : 0.0411
#   compile_metrics         : 0.8245
#
# Evaluation results saved → /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/evaluation_results.txt

# %%
# Prediction Visualisation on Test Samples

def plot_predictions(model, X, Y, save_path, n_samples=5, threshold=0.5):

    fg_idx = np.where(Y[..., 0].sum(axis=(1, 2)) > 0)[0]
    rng    = np.random.default_rng(SEED)
    chosen = rng.choice(fg_idx, size=min(n_samples, len(fg_idx)), replace=False)

    x_s = X[chosen]; y_s = Y[chosen]
    p_s = model.predict(x_s, verbose=0)
    p_b = (p_s > threshold).astype(np.float32)

    ch_layers = [
        (0, np.array([0.0, 0.8, 0.0])),   # WT – green
        (2, np.array([1.0, 1.0, 0.0])),   # TC – yellow
        (1, np.array([1.0, 0.0, 0.0])),   # ET – red  (painted last = on top)
    ]

    def overlay(mask_3ch):
        rgb = np.zeros((*mask_3ch.shape[:2], 3))
        for ch, col in ch_layers:
            fg = mask_3ch[..., ch] > 0.5
            for j in range(3):
                rgb[..., j] = np.where(fg, col[j], rgb[..., j])
        return rgb

    fig, axes = plt.subplots(n_samples, 4, figsize=(16, 4 * n_samples))
    fig.suptitle("Prediction Samples  (Test Set)", fontsize=13)

    for row in range(n_samples):
        flair = x_s[row, :, :, 3]   # FLAIR = channel index 3

        axes[row, 0].imshow(flair, cmap="gray"); axes[row, 0].axis("off")
        if row == 0: axes[row, 0].set_title("FLAIR Input", fontsize=11)

        axes[row, 1].imshow(flair, cmap="gray")
        axes[row, 1].imshow(overlay(y_s[row]), alpha=0.55)
        axes[row, 1].axis("off")
        if row == 0: axes[row, 1].set_title("Ground Truth", fontsize=11)

        axes[row, 2].imshow(flair, cmap="gray")
        axes[row, 2].imshow(overlay(p_b[row]), alpha=0.55)
        axes[row, 2].axis("off")
        if row == 0: axes[row, 2].set_title("Prediction", fontsize=11)

        ax = axes[row, 3]; ax.axis("off")
        if row == 0: ax.set_title("Dice Scores", fontsize=11)
        lines = []
        for c, name in enumerate(CHANNEL_NAMES):
            yt    = y_s[row, ..., c].flatten()
            yp    = p_b[row, ..., c].flatten()
            inter = (yt * yp).sum()
            denom = yt.sum() + yp.sum()
            d     = (2.0 * inter + 1e-6) / (denom + 1e-6)
            lines.append(f"{name} Dice : {d:.3f}")
        ax.text(
            0.1, 0.5, "\n".join(lines),
            transform=ax.transAxes, fontsize=12,
            verticalalignment="center", fontfamily="monospace",
            bbox=dict(boxstyle="round", facecolor="lightyellow", alpha=0.8)
        )

    fig.tight_layout()
    save_and_show(fig, save_path, "prediction samples")


plot_predictions(model, X_test, Y_test, PREDS_PATH, n_samples=5)
# Out:
# Saved → /content/drive/MyDrive/Training_models/Preprocessing/RAAGR2Net_Run78/predictions.png  (prediction samples)
